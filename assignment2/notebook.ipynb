# %% [markdown]
# # **Disclaimer:**
# This assignment must be completed solely by the members of your group. Sharing of code between groups is strictly prohibited. However, you are allowed to discuss general solution approaches or share publicly available resources with members of other groups. Therefore, clearly indicate which public resources you consulted and/or copied code from. Any plagiarism between groups will result in the initiation of a fraud procedure with the director of education.

# %% [markdown]
# # **Introduction**
#
# In this assignment, you will train a Reinforcement Learning (RL) agent to address a Residential Energy Management problem.
#
# The goal is for your agent to control a battery and optimize the electricity costs for a residential household. You will submit your trained agent, which will first be evaluated using an evaluation dataset (different from what you have). Following that, your agent will be deployed in a real-world setting: the [HomeLab](https://idlab.ugent.be/resources/homelab). After deployment, you will receive data detailing the performance of your agent in both environments. Finally, you will write a brief essay analyzing and discussing the results. \
# Moreover, we wrote a set of questions / tasks you can fill in the notebook. Each question will contribute to the final grade you will obtain from this assignment.
#
# The task involves managing energy for a residential household equipped with a Photovoltaic (PV) system and an Energy Storage System (ESS), specifically a battery. In the context of the global shift toward decarbonizing energy sources, these types of challenges are becoming increasingly significant. Reinforcement Learning (RL) has proven to be a promising technique for addressing them.
#
# The setup includes a household where residents consume electricity daily, resulting in a unique consumption profile. Electricity costs are based on a dynamic price profile, with prices varying by the hour. When the household generates more energy (from the PV system or battery) than it consumes, the excess will be sold back to the grid, although the selling price is typically much lower than the buying price.
#
# Your objective is to train an RL agent to control the battery and minimize electricity costs. While this might initially seem straightforward (e.g., charge the battery when prices are low and discharge it when prices are high), there are several challenges that complicate the problem:
#
# *   **Uncertainty in household consumption**: Future consumption is difficult to predict. While models based on inhabitants' habits can provide reasonable estimates[1], there is always a stochastic element involved.
# *   **Variability in PV production**: PV energy generation depends on weather conditions, adding another layer of unpredictability.
# *   **Dynamic price profiles**: Although, for simplicity, we assume a single price profile repeats daily in this assignment, real-world scenarios often involve prices that vary from day to day.
# *   **Physical constraints**: The control of the battery and the accuracy of data from the household (such as PV production and overall consumption) are not perfect. While these issues are ignored in the simulation, they will become evident in the real-world results from HomeLab after your agent has been deployed.
#
# Additionally, although not considered in this assignment, more complex setups may include assets like heat pumps or electric vehicle chargers. These cases may require an extended RL framework, potentially involving multi-agent systems.
#
# In the assignment, you will use an agent based on the [PPO](https://arxiv.org/pdf/1707.06347) algorithm. There are some libraries that have already implemented the algorithm, the most famous being [stable-baselines3](https://stable-baselines3.readthedocs.io/en/master/#). However, in this assignment, you will write the algorithm code yourself. To help you with the task, we provide you with most of the code you will need to develop a PPO agent.
#
# \
#
# ---
#
# \
#
# [1] e.g., by observing that they usually leave for work from 9:00 AM to 18:00 PM and cook at 19:00 PM, we can obtain a sensible model of the expected consumption
#
# \
#
# ---
#
# \
#
#
# Let's now delve into the assignment details!

# %% [markdown]
# # **Support Classes**
#
# In this assignment, we provide the essential code to help you train a PPO agent for a Home Energy Management (HEM) problem. To begin, download the material.zip file available in the course resources. This file contains the necessary code and information to complete the assignment.
#
# After downloading, extract the .py files and upload them into the 'Files' section of this Colab notebook. Next, run the code snippet below, which will import all required external libraries, along with the support classes from the files you just uploaded.
#
# We advise you **not** to change the code we provided you in such files. Any changes in those files that hinder our evaluation of your agents might result in your submission receiving a lower grade.
#
# **N.B:** For training the neural networks used in the PPO algorithm, we require that you use the PyTorch library included in the provided files. Using other deep learning libraries (e.g., TensorFlow) could cause compatibility issues when evaluating your agent.
#
# If you require additional standard Python packages for your work, feel free to import them in the following cell. (by standard Python packages we consider the ones included in the Google colab environment. Avoid using any 'pip install' call in this notebook) \
# In case you want to download the notebook and run it locally, you can recreate the colab environment by installing the same versions in your local machine. The list of packages' versions can be seen through the command `!pip freeze` executed below.

# %%
# !uv pip install numpy
# !uv pip install torch
# !uv pip install pandas
# !uv pip install matplotlib


import sys
import numpy as np
import torch
from torch import nn
from torch.distributions import MultivariateNormal
import matplotlib.pyplot as plt
import pickle

sys.path.insert(0, 'Environment.py')
sys.path.insert(0, 'nn_utils.py')

from Environment import BaseEnvironment
from nn_utils import GenericNeuralNetwork



# Extra imports:
# import ...
# Out:
# Resolved 1 package in 120ms
# Installed 1 package in 53ms
#  + numpy==2.3.4
# Resolved 25 packages in 204ms
# Installed 25 packages in 471ms
#  + filelock==3.20.0
#  + fsspec==2025.10.0
#  + jinja2==3.1.6
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + networkx==3.5
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.5
#  + nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvshmem-cu12==3.3.20
#  + nvidia-nvtx-cu12==12.8.90
#  + sympy==1.14.0
#  + torch==2.9.0
#  + triton==3.5.0
#  + typing-extensions==4.15.0
# Resolved 6 packages in 151ms
# Installed 5 packages in 74ms
#  + pandas==2.3.3
#  + python-dateutil==2.9.0.post0
#  + pytz==2025.2
#  + six==1.17.0
#  + tzdata==2025.2
# Resolved 11 packages in 165ms
# Installed 8 packages in 32ms
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + fonttools==4.60.1
#  + kiwisolver==1.4.9
#  + matplotlib==3.10.7
#  + packaging==25.0
#  + pillow==12.0.0
#  + pyparsing==3.2.5

# %%
# !pip freeze
# Out:
# zsh:1: command not found: pip

# %% [markdown]
# # **Environment**
#
# Now that you imported the classes from the files we provided you, you can start building an RL framework. RL agents learn how to obtain optimal actions by interacting with an environment, modeled by a Markovian Decision Process. The class 'BaseEnvironment' contained in the file 'Environment.py' is exactly that.

# %% [markdown]
# Let's initialize a BaseEnvironment class:
#
# First, you need to fix some hyperparameters defining the details of the environment.
# - `power_capacity` is the max. power the battery is physically capable of injecting (or withdrawing). It is expressed in kW
# - `energy_capacity` is the max. energy the battery is physically allowed to store. It is expressed in kWh
#
# The battery used in the evaluations has a power capacity of 4kW and an energy capacity of 8kWh. Therefore, the agent you upload should be trained with these capacity values.
#
# You will also need to load the 'public_data_dict.pkl' we provided you. The loaded file is a dictionary containing historical data on PV production and household consumption for the weekdays of almost a whole year. Every instance of the `BaseEnvironment` requires as input a data dictionary with the same format we provided you with. \
# Further details of the environment are contained in the documentation we provided in the .zip file. **Please read it carefully**

# %%
# HYPERPARAMETERS:
power_capacity = 4
energy_capacity = 8

### Environment initialization
with open('public_data_dict.pkl', 'rb') as f:
    data_dict = pickle.load(f)

env = BaseEnvironment(power_capacity = power_capacity,
                      energy_capacity = energy_capacity,
                      data = data_dict)

# %% [markdown]
# In machine learning, it is common practice to divide a dataset into at least two parts:
#
# - A training set, used to train the model;
# - A validation set, which remains completely unseen by the model during training and is used to assess its performance during and after training.
#
# This division is not always allowed in RL. For example, in board game environments such as chess you do not necessarily have historical data to divide. Hence, in cases like that it is not possible to separate into different sets. \
# However, in problems like this where historical data is available, you can (and should) divide sets to ensure the agent is not simply overfitting on the training set. Below we suggest a possible division that is based on the data available and the conditions in which the agent will be evaluated.
#
# Additionally, the policy of an agent during training often differs from its policy during evaluation. For instance, when evaluating an agent, it may be beneficial to minimize the effect of stochastic events by standardizing evaluation conditions. One way to achieve this is to consistently use the agent's greedy actions during evaluation and ensure that the environment always starts with the same initial states.

# %%
train_length = int(len(data_dict) * 0.8)

train_set_indexes = list(range(0, train_length))
test_set_indexes = list(range(train_length, len(data_dict)))

# %% [markdown]
# # **PPO Agent**
#
# Now, it is time to start writing the PPO code. In the .zip file, we provided you with some utility classes that will help you train and use a PyTorch neural network. \
# Moreover, to help you with the task of implementing a PPO algorithm, we provided you with most of the code structure. \
# Below, you can find the class of the PPO agent you will use in the assignment. First, we ask you to **carefully read the code** and understand it as much as possible. The code misses some parts that you will need to fill in. In particular, you need to complete the following methods:
# - `train`: Perform `num_iterations` training steps. In each training step, perform `num_batches` rollouts and train both the actor and the critic on the obtained data. In this method, 2 portions needs to be completed. First, you will need to calculate the estimated advantage values `A_k`. For stability reasons, it is good practice to normalize these values by scaling them into a more manageable interval (e.g., ~[-1, 1]); how can you do so? If you do not scale the estimations, what do you notice in your training curve? Then, you need to implement the PPO loss for the actor. For that, it can be handy to use the torch function `torch.clamp`.
# - `calculate_value_logprobs`: Given the batched states and actions, it returns the estimated values of the batched states (from the critic network) and the logarithmic probabilities of the batched actions in relation to the current actor distribution. Check the documentation of the `MultivariateNormal` class, as it will be quite useful for implementing this function.
# - `sample_action`: Given the input `state`, it returns the corresponding action from the actor, and the logarithmic probability of the action in relation to the current actor distribution. There is also a boolean input `explore`. If the boolean is set to `True`, the output is an action sampled from the actor probability distribution. Else, if the boolean is set to `False`, the action will be the most likely one from the actor probability distribution. Check the documentation of the `MultivariateNormal` class, as it will be quite useful for implementing this function.
# - `rollout`: This function perform `num_batches` rollout. Each rollout correspond to the execution of one episode sampling from the actor policy distribution. You can use the `sample_action` method for that. Part of the rollout loop is already provided. You will need to complete it by properly filling the batch lists (`batch_action`, `batch_states`, `batch_rewards`, and `batch_log_probs`) with their corresponding values.
#
# **Important: The agent and critic should be working and training with normalized (i.e., scaled) states, actions, and rewards. Make sure to implement the following code sections accordingly. When evaluating your agent, we will assume your actor neural network takes the normalized state as input and returns the normalized actions. We will normalize the states and de-normalize the actions accordingly to the environment documentation.**

# %%
class PPOHyperparameters():

    def __init__(self, num_batches: int, sampling_variance: float, gamma: float, updates_per_iteration: int, clip_value: float, actor_lr: float, critic_lr: float, entropy_coef: float = 0.0):
        self.num_batches = num_batches

        # Variance of the multivariate Normal distribution used to sample exploratory actions
        self.sampling_variance = sampling_variance

        # Discount factor
        self.gamma = gamma

        # Number of updates in each training iteration
        self.updates_per_iteration = updates_per_iteration

        # Epsilon used in the clip for training
        self.clip_value = clip_value

        # Networks Learning Rate
        self.actor_lr = actor_lr
        self.critic_lr = critic_lr

        # Entropy regularization coefficient (Q5 feature)
        self.entropy_coef = entropy_coef

class PPOAgent:

    def __init__(self, env, state_dim, action_dim, actor: nn.Module, critic: nn.Module, hyperparameters: PPOHyperparameters):

        self.env = env

        self.state_dim = state_dim
        self.action_dim = action_dim

        self.hyperparameters = hyperparameters

        self.actor = actor
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=self.hyperparameters.actor_lr)

        self.critic = critic
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=self.hyperparameters.critic_lr)

        self.cov_var = torch.full(size=(self.action_dim,), fill_value = self.hyperparameters.sampling_variance)
        self.cov_mat = torch.diag(self.cov_var) # This will be used to sample actions from the agent distribution. The higher the variance, the wider the gaussian distribution.

        # Tracking (Q2)
        self.actor_losses = []
        self.critic_losses = []
        self.episode_norm_rewards = []
        self.episode_raw_rewards = []
        self.kl_divergences = []
        self.prob_ratio_means = []
        self.prob_ratio_stds = []
        self.entropies = []

    def train(self, num_iterations:int = 200):
        for iteration in range(num_iterations):
            print(f"Iteration: {iteration}\n")
            batch_states, batch_actions, batch_log_probs, batch_cumulative_rewards, batch_rewards = self.rollout()

            V, _ = self.calculate_value_logprobs(batch_states=batch_states, batch_actions=batch_actions)

            # Exercise: Calculate the Advantage and normalize it
            A_k = batch_cumulative_rewards - V.detach()
            A_k = (A_k - A_k.mean()) / (A_k.std() + 1e-8)

            for _ in range(self.hyperparameters.updates_per_iteration):
                current_V, current_log_probs = self.calculate_value_logprobs(batch_states=batch_states, batch_actions=batch_actions)

                probability_ratios = torch.exp(current_log_probs - batch_log_probs)

                # PPO clipped objective
                surr1 = probability_ratios * A_k
                surr2 = torch.clamp(probability_ratios, 1 - self.hyperparameters.clip_value, 1 + self.hyperparameters.clip_value) * A_k
                ppo_objective = -torch.min(surr1, surr2).mean()

                # Entropy regularization (Q5)
                mean = self.actor(batch_states)
                dist = MultivariateNormal(mean, self.cov_mat.to(mean.device))
                entropy = dist.entropy().mean()
                actor_loss = ppo_objective - self.hyperparameters.entropy_coef * entropy

                self.actor_optimizer.zero_grad()
                actor_loss.backward(retain_graph=True)
                self.actor_optimizer.step()

                critic_loss = torch.nn.MSELoss()(current_V, batch_cumulative_rewards)
                self.critic_optimizer.zero_grad()
                critic_loss.backward()
                self.critic_optimizer.step()

                # Metrics (Q2)
                kl_approx = (batch_log_probs - current_log_probs).mean().item()
                self.kl_divergences.append(kl_approx)
                self.prob_ratio_means.append(probability_ratios.mean().item())
                self.prob_ratio_stds.append(probability_ratios.std(unbiased=False).item())
                self.entropies.append(entropy.item())

            # Store losses for plotting per iteration (last update values)
            self.actor_losses.append(actor_loss.item())
            self.critic_losses.append(critic_loss.item())

            # Average rewards over this rollout
            avg_norm_reward = batch_rewards.mean().item()
            avg_raw_reward = torch.tensor([self.env.descale_reward(r.item()) for r in batch_rewards.flatten()]).mean().item()
            self.episode_norm_rewards.append(avg_norm_reward)
            self.episode_raw_rewards.append(avg_raw_reward)

            print(f"[Train] Iter {iteration+1}/{num_iterations} | "
                  f"Actor: {actor_loss.item():.4f} | Critic: {critic_loss.item():.4f} | "
                  f"KL: {self.kl_divergences[-1]:.5f} | Ratio μ: {self.prob_ratio_means[-1]:.4f} | Ent: {self.entropies[-1]:.4f} | "
                  f"Avg norm R: {avg_norm_reward:.4f} | Avg raw R: {avg_raw_reward:.4f}")
        
    def calculate_value_logprobs(self, batch_states, batch_actions):
        # Exercise: Implement this function
        V = self.critic(batch_states).squeeze(-1)
        mean = self.actor(batch_states)
        dist = torch.distributions.MultivariateNormal(mean, self.cov_mat.to(mean.device))
        log_probs = dist.log_prob(batch_actions)
        return V, log_probs

    def sample_action(self, state, explore=False):
        # Exercise: Implement this function
        norm_state = self.env.scale_state(state)
        norm_state = torch.tensor(norm_state, dtype=torch.float).unsqueeze(0)
        mean = self.actor(norm_state)
        dist = torch.distributions.MultivariateNormal(mean.squeeze(0), self.cov_mat.to(mean.device))
        if explore:
            action = dist.sample()
            log_prob = dist.log_prob(action)
        else:
            action = mean.squeeze(0)
            log_prob = dist.log_prob(action)
        return action.detach(), log_prob.detach()

    def compute_cumulative_rewards(self, batch_rewards):
        batch_cumulative_rewards = []

        for reward_episodes in reversed(batch_rewards):
            discounted_reward = 0

            for reward in reversed(reward_episodes):
                discounted_reward = self.hyperparameters.gamma*discounted_reward + reward
                batch_cumulative_rewards.insert(0, discounted_reward) # Insert discounted reward in the head of the list

        batch_cumulative_rewards = torch.tensor(batch_cumulative_rewards, dtype=torch.float)
        return batch_cumulative_rewards

    def rollout(self):
        # NOTE: Put the correct sizes as comment here
        batch_states = []       # (num_batches * timesteps_per_episode, state_dim)
        batch_actions = []      # (num_batches * timesteps_per_episode, action_dim)
        batch_log_probs = []    # (num_batches * timesteps_per_episode)
        batch_rewards = []      # (num_batches, timesteps_per_episode)

        for t in range(self.hyperparameters.num_batches):
            self.env.reset(np.random.choice(train_set_indexes))   # Train on a random day from the training set
            rewards_episode = []

            state = self.env.state
            done = self.env.done
            # Exercise: Perform an episode (execution until the done flag variable in the environment becomes True)
            # and fill the lists 'batch_state', 'batch_actions', 'batch_log_probs', and 'batch_rewards' with their
            # respective values obtained from the interaction with the environment.
            while not done:
                norm_state = self.env.scale_state(state)
                action, log_prob = self.sample_action(state, explore=True)
                real_action = self.env.descale_action(action.detach().cpu().numpy().item())
                next_state, reward, done, _ = self.env.step(real_action)
                norm_reward = self.env.scale_reward(reward)

                batch_states.append(norm_state)
                batch_actions.append(action.detach().cpu().numpy())
                batch_log_probs.append(log_prob.detach().cpu().item())
                rewards_episode.append(norm_reward)

                state = next_state

            total_norm_reward = sum(rewards_episode)
            total_raw_reward = sum(self.env.descale_reward(r) for r in rewards_episode)
            
            batch_rewards.append(rewards_episode)

        batch_states = torch.tensor(np.array(batch_states), dtype=torch.float)
        batch_actions = torch.tensor(batch_actions, dtype=torch.float)
        batch_log_probs = torch.tensor(batch_log_probs, dtype=torch.float)
        batch_rewards = torch.tensor(batch_rewards, dtype=torch.float)

        batch_cumulative_rewards = self.compute_cumulative_rewards(batch_rewards=batch_rewards)     # (timesteps_per_episode)

        return batch_states, batch_actions, batch_log_probs, batch_cumulative_rewards, batch_rewards

    def save_agent(self):
        with open('actor.pickle', 'wb') as handle:
            pickle.dump(self.actor, handle, protocol=pickle.HIGHEST_PROTOCOL)

    def load_agent(self):
        with open('actor.pickle', 'rb') as handle:
            self.actor = pickle.load(handle)

# %% [markdown]
# # **Interaction agent-environment**
#
# Now that you’ve written the code for the PPO agent, it’s good practice to perform some sanity checks to ensure the agent behaves as expected. But first, we need to implement the code that will serve as the interface between the environment and the agent.
#
# Let’s begin by initializing the agent class. Below is an example of hyperparameters you can use. These values are **intentionally** chosen to be suboptimal. Meaning that the code will run with those values, but the agent **will not have good training performance**. \
# **Remember to adjust them when you start evaluating the agent's performance.**

# %%
state_dim = 5       # Dimension of each state, do not change
action_dim = 1      # Dimension of the actions, do not change

# Improved network architecture: moderate size with low dropout for better learning
actor_nn_params = dict(input_size=state_dim,
                       layers=[(256, 'relu', 0.1),  # Moderate size, low dropout for better gradient flow
                               (128, 'relu', 0.1), ],
                       output_size=action_dim,
                       activation_final='tanh')
actor = GenericNeuralNetwork(params=actor_nn_params)

critic_nn_params = dict(input_size=state_dim,
                        layers=[(256, 'relu', 0.1),
                                (128, 'relu', 0.1), ],
                        output_size=1,
                        activation_final='linear')
critic = GenericNeuralNetwork(params=critic_nn_params)

# Improved hyperparameters based on PPO best practices and energy management domain
hyperparameters = PPOHyperparameters(
    num_batches=128,                # More episodes per rollout for better sample efficiency
    sampling_variance=0.2,          # Moderate exploration variance
    gamma=0.99,                     # High discount for long-term planning (daily cycles matter)
    updates_per_iteration=10,       # More updates per iteration for better data utilization
    clip_value=0.2,                 # Standard PPO clip value
    actor_lr=3e-4,                 # Standard learning rate for actor
    critic_lr=1e-3,                # Slightly higher for critic (value estimation is easier)
    entropy_coef=0.01)             # Entropy regularization for exploration (Q5)

ppo_agent = PPOAgent(env=env, state_dim=state_dim, action_dim=action_dim, actor=actor, critic=critic, hyperparameters=hyperparameters)

# %% [markdown]
# # **Training loop**
#
# Finally, we are ready to train and evaluate the agents. To do so, you can use the train method of the PPO agent. It is good practice to regularly evaluate the agent after a certain amount of iteration during the training phase. In the evaluation process, the actions applied to the environment should be the greedy  ones (i.e., the action the agent currently believes to be the optimal). We provided you with the structure of an evaluation method, you can fill the missing code and properly use it in your training phase \
# As you experiment with this assignment, think of how you can improve the training based on the knowledge you learned in the classes.

# %%
def environment_episode(day_index: int = 0):
    '''
    Reset and interact with the environment until the end of the selected day.

    day_index: Code of the day used in the environment
    '''
    ppo_agent.env.reset(day_index)
    total_reward = 0

    while not env.done:
        state = ppo_agent.env.state
        action, _ = ppo_agent.sample_action(state, explore=False)
        action = action.detach().item()
        next_state, reward, done, _ = env.step(ppo_agent.env.descale_action(action))

        total_reward += reward

    return total_reward

def evaluate_agent():
    # Exercise: Fill this
    # Tip: You can use the function environment_episode(day_index) defined above
    rewards = []
    for day_index in test_set_indexes:
        r = environment_episode(day_index)
        rewards.append(r)
    evaluation_reward = np.mean(rewards)
    return evaluation_reward

num_iteration = 100
iteration_per_evaluation = 1

for training_iteration in range(1, num_iteration):
    ppo_agent.train(num_iterations=20)

    if (training_iteration % iteration_per_evaluation) == 0:
        reward = evaluate_agent()
        print(f"[Eval] Iteration {training_iteration}: Average reward = {reward:.3f}")
# Out:
# Iteration: 0
# /tmp/ipykernel_9941/2625926161.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   batch_actions = torch.tensor(batch_actions, dtype=torch.float)
# [Train] Iter 1/20 | Actor: -0.0051 | Critic: 85.8823 | KL: 0.01160 | Ratio μ: 0.9948 | Ent: 0.6142 | Avg norm R: 0.8155 | Avg raw R: -0.0664
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0054 | Critic: 49.3364 | KL: 0.00644 | Ratio μ: 0.9982 | Ent: 0.6142 | Avg norm R: 0.8125 | Avg raw R: -0.0705
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0094 | Critic: 21.2398 | KL: 0.01260 | Ratio μ: 0.9940 | Ent: 0.6142 | Avg norm R: 0.8155 | Avg raw R: -0.0665
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0081 | Critic: 13.8204 | KL: 0.00312 | Ratio μ: 1.0005 | Ent: 0.6142 | Avg norm R: 0.8148 | Avg raw R: -0.0674
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0044 | Critic: 8.8731 | KL: 0.00260 | Ratio μ: 1.0018 | Ent: 0.6142 | Avg norm R: 0.8148 | Avg raw R: -0.0674
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0092 | Critic: 5.5945 | KL: 0.00515 | Ratio μ: 0.9988 | Ent: 0.6142 | Avg norm R: 0.8170 | Avg raw R: -0.0644
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0076 | Critic: 3.6009 | KL: 0.00400 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8156 | Avg raw R: -0.0663
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0072 | Critic: 2.1801 | KL: 0.00046 | Ratio μ: 1.0035 | Ent: 0.6142 | Avg norm R: 0.8175 | Avg raw R: -0.0637
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0084 | Critic: 1.4653 | KL: 0.00087 | Ratio μ: 1.0038 | Ent: 0.6142 | Avg norm R: 0.8198 | Avg raw R: -0.0606
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0069 | Critic: 1.1615 | KL: 0.00664 | Ratio μ: 1.0010 | Ent: 0.6142 | Avg norm R: 0.8169 | Avg raw R: -0.0645
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0079 | Critic: 0.9645 | KL: 0.00467 | Ratio μ: 0.9997 | Ent: 0.6142 | Avg norm R: 0.8190 | Avg raw R: -0.0617
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0062 | Critic: 1.0132 | KL: 0.00385 | Ratio μ: 0.9995 | Ent: 0.6142 | Avg norm R: 0.8184 | Avg raw R: -0.0625
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0117 | Critic: 0.9242 | KL: 0.00890 | Ratio μ: 0.9970 | Ent: 0.6142 | Avg norm R: 0.8170 | Avg raw R: -0.0644
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0067 | Critic: 0.8596 | KL: 0.00317 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8212 | Avg raw R: -0.0588
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0087 | Critic: 0.8623 | KL: 0.00403 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8177 | Avg raw R: -0.0635
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0089 | Critic: 0.7574 | KL: 0.00892 | Ratio μ: 0.9956 | Ent: 0.6142 | Avg norm R: 0.8190 | Avg raw R: -0.0617
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0093 | Critic: 0.7482 | KL: 0.00784 | Ratio μ: 1.0007 | Ent: 0.6142 | Avg norm R: 0.8195 | Avg raw R: -0.0611
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0093 | Critic: 0.7353 | KL: 0.00857 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8210 | Avg raw R: -0.0591
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0082 | Critic: 0.6832 | KL: 0.00424 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8229 | Avg raw R: -0.0564
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0087 | Critic: 0.6931 | KL: 0.00527 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8228 | Avg raw R: -0.0566
# [Eval] Iteration 1: Average reward = -1.519
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0059 | Critic: 0.6069 | KL: 0.00522 | Ratio μ: 1.0016 | Ent: 0.6142 | Avg norm R: 0.8249 | Avg raw R: -0.0537
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0070 | Critic: 0.6028 | KL: 0.00626 | Ratio μ: 0.9994 | Ent: 0.6142 | Avg norm R: 0.8259 | Avg raw R: -0.0524
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0041 | Critic: 0.6038 | KL: 0.00475 | Ratio μ: 1.0007 | Ent: 0.6142 | Avg norm R: 0.8232 | Avg raw R: -0.0560
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0061 | Critic: 0.5794 | KL: 0.00662 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8258 | Avg raw R: -0.0525
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0042 | Critic: 0.5759 | KL: 0.00700 | Ratio μ: 0.9984 | Ent: 0.6142 | Avg norm R: 0.8238 | Avg raw R: -0.0552
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0061 | Critic: 0.5399 | KL: 0.00981 | Ratio μ: 0.9975 | Ent: 0.6142 | Avg norm R: 0.8271 | Avg raw R: -0.0508
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0058 | Critic: 0.5592 | KL: 0.00988 | Ratio μ: 0.9967 | Ent: 0.6142 | Avg norm R: 0.8244 | Avg raw R: -0.0544
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0053 | Critic: 0.5857 | KL: 0.00655 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8252 | Avg raw R: -0.0534
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0052 | Critic: 0.5554 | KL: 0.00404 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8286 | Avg raw R: -0.0487
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0074 | Critic: 0.5216 | KL: 0.00849 | Ratio μ: 0.9973 | Ent: 0.6142 | Avg norm R: 0.8264 | Avg raw R: -0.0517
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0069 | Critic: 0.5333 | KL: 0.01086 | Ratio μ: 0.9959 | Ent: 0.6142 | Avg norm R: 0.8198 | Avg raw R: -0.0606
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0088 | Critic: 0.5707 | KL: 0.00669 | Ratio μ: 0.9984 | Ent: 0.6142 | Avg norm R: 0.8287 | Avg raw R: -0.0485
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0079 | Critic: 0.5436 | KL: 0.00478 | Ratio μ: 1.0017 | Ent: 0.6142 | Avg norm R: 0.8270 | Avg raw R: -0.0509
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0064 | Critic: 0.5306 | KL: 0.00660 | Ratio μ: 0.9988 | Ent: 0.6142 | Avg norm R: 0.8302 | Avg raw R: -0.0466
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0060 | Critic: 0.5024 | KL: 0.00116 | Ratio μ: 1.0036 | Ent: 0.6142 | Avg norm R: 0.8271 | Avg raw R: -0.0507
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0025 | Critic: 0.5041 | KL: 0.00406 | Ratio μ: 1.0015 | Ent: 0.6142 | Avg norm R: 0.8280 | Avg raw R: -0.0496
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0043 | Critic: 0.4920 | KL: 0.00274 | Ratio μ: 1.0020 | Ent: 0.6142 | Avg norm R: 0.8253 | Avg raw R: -0.0531
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0071 | Critic: 0.5051 | KL: 0.00735 | Ratio μ: 1.0001 | Ent: 0.6142 | Avg norm R: 0.8258 | Avg raw R: -0.0525
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0035 | Critic: 0.5239 | KL: 0.00383 | Ratio μ: 1.0024 | Ent: 0.6142 | Avg norm R: 0.8249 | Avg raw R: -0.0537
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0048 | Critic: 0.4747 | KL: 0.00938 | Ratio μ: 0.9973 | Ent: 0.6142 | Avg norm R: 0.8269 | Avg raw R: -0.0510
# [Eval] Iteration 2: Average reward = -1.427
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0012 | Critic: 0.5334 | KL: 0.00301 | Ratio μ: 1.0025 | Ent: 0.6142 | Avg norm R: 0.8275 | Avg raw R: -0.0502
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0049 | Critic: 0.5002 | KL: 0.00752 | Ratio μ: 0.9984 | Ent: 0.6142 | Avg norm R: 0.8292 | Avg raw R: -0.0480
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0047 | Critic: 0.4876 | KL: 0.00322 | Ratio μ: 1.0014 | Ent: 0.6142 | Avg norm R: 0.8285 | Avg raw R: -0.0489
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0097 | Critic: 0.4623 | KL: 0.00527 | Ratio μ: 1.0009 | Ent: 0.6142 | Avg norm R: 0.8286 | Avg raw R: -0.0487
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0066 | Critic: 0.4934 | KL: 0.00457 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8273 | Avg raw R: -0.0505
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0047 | Critic: 0.5029 | KL: 0.00686 | Ratio μ: 0.9997 | Ent: 0.6142 | Avg norm R: 0.8251 | Avg raw R: -0.0535
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0058 | Critic: 0.5113 | KL: 0.00383 | Ratio μ: 1.0013 | Ent: 0.6142 | Avg norm R: 0.8252 | Avg raw R: -0.0533
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0059 | Critic: 0.4737 | KL: 0.00424 | Ratio μ: 1.0024 | Ent: 0.6142 | Avg norm R: 0.8254 | Avg raw R: -0.0531
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0080 | Critic: 0.4642 | KL: 0.00900 | Ratio μ: 0.9970 | Ent: 0.6142 | Avg norm R: 0.8286 | Avg raw R: -0.0487
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0065 | Critic: 0.4837 | KL: 0.00417 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8291 | Avg raw R: -0.0480
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0061 | Critic: 0.4832 | KL: 0.00457 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8273 | Avg raw R: -0.0505
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0058 | Critic: 0.5069 | KL: 0.00549 | Ratio μ: 1.0009 | Ent: 0.6142 | Avg norm R: 0.8283 | Avg raw R: -0.0492
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0064 | Critic: 0.4839 | KL: 0.00221 | Ratio μ: 1.0052 | Ent: 0.6142 | Avg norm R: 0.8279 | Avg raw R: -0.0497
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0070 | Critic: 0.5096 | KL: 0.00523 | Ratio μ: 1.0004 | Ent: 0.6142 | Avg norm R: 0.8264 | Avg raw R: -0.0516
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0067 | Critic: 0.5047 | KL: 0.00748 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8268 | Avg raw R: -0.0512
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0061 | Critic: 0.4642 | KL: 0.00577 | Ratio μ: 1.0003 | Ent: 0.6142 | Avg norm R: 0.8266 | Avg raw R: -0.0515
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0074 | Critic: 0.4687 | KL: 0.00527 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8274 | Avg raw R: -0.0503
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0040 | Critic: 0.4731 | KL: 0.00494 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8260 | Avg raw R: -0.0522
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0084 | Critic: 0.4848 | KL: 0.00998 | Ratio μ: 1.0000 | Ent: 0.6142 | Avg norm R: 0.8281 | Avg raw R: -0.0494
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0059 | Critic: 0.4918 | KL: 0.00601 | Ratio μ: 1.0037 | Ent: 0.6142 | Avg norm R: 0.8291 | Avg raw R: -0.0481
# [Eval] Iteration 3: Average reward = -1.447
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0032 | Critic: 0.5065 | KL: 0.00745 | Ratio μ: 0.9994 | Ent: 0.6142 | Avg norm R: 0.8305 | Avg raw R: -0.0461
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0057 | Critic: 0.4550 | KL: 0.00747 | Ratio μ: 0.9990 | Ent: 0.6142 | Avg norm R: 0.8328 | Avg raw R: -0.0431
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0044 | Critic: 0.4939 | KL: 0.00497 | Ratio μ: 1.0018 | Ent: 0.6142 | Avg norm R: 0.8279 | Avg raw R: -0.0497
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0080 | Critic: 0.4696 | KL: 0.00777 | Ratio μ: 1.0009 | Ent: 0.6142 | Avg norm R: 0.8319 | Avg raw R: -0.0443
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0058 | Critic: 0.4539 | KL: 0.00518 | Ratio μ: 1.0014 | Ent: 0.6142 | Avg norm R: 0.8293 | Avg raw R: -0.0478
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0053 | Critic: 0.4719 | KL: 0.00556 | Ratio μ: 1.0001 | Ent: 0.6142 | Avg norm R: 0.8270 | Avg raw R: -0.0509
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0074 | Critic: 0.4606 | KL: 0.00689 | Ratio μ: 1.0007 | Ent: 0.6142 | Avg norm R: 0.8297 | Avg raw R: -0.0473
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0042 | Critic: 0.4943 | KL: 0.00832 | Ratio μ: 0.9989 | Ent: 0.6142 | Avg norm R: 0.8314 | Avg raw R: -0.0449
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0012 | Critic: 0.4671 | KL: 0.00547 | Ratio μ: 1.0017 | Ent: 0.6142 | Avg norm R: 0.8288 | Avg raw R: -0.0485
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0075 | Critic: 0.4757 | KL: 0.00571 | Ratio μ: 1.0014 | Ent: 0.6142 | Avg norm R: 0.8265 | Avg raw R: -0.0516
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0053 | Critic: 0.4501 | KL: 0.00985 | Ratio μ: 0.9959 | Ent: 0.6142 | Avg norm R: 0.8308 | Avg raw R: -0.0457
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0017 | Critic: 0.4535 | KL: 0.00568 | Ratio μ: 1.0005 | Ent: 0.6142 | Avg norm R: 0.8348 | Avg raw R: -0.0403
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0067 | Critic: 0.4240 | KL: 0.00643 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8299 | Avg raw R: -0.0470
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0098 | Critic: 0.4888 | KL: 0.01352 | Ratio μ: 0.9944 | Ent: 0.6142 | Avg norm R: 0.8308 | Avg raw R: -0.0458
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0040 | Critic: 0.4765 | KL: 0.00971 | Ratio μ: 0.9963 | Ent: 0.6142 | Avg norm R: 0.8269 | Avg raw R: -0.0511
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0041 | Critic: 0.4706 | KL: 0.00778 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8307 | Avg raw R: -0.0460
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0071 | Critic: 0.4359 | KL: 0.00752 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8308 | Avg raw R: -0.0458
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0019 | Critic: 0.4606 | KL: 0.00556 | Ratio μ: 1.0005 | Ent: 0.6142 | Avg norm R: 0.8302 | Avg raw R: -0.0466
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0048 | Critic: 0.4800 | KL: 0.00530 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8306 | Avg raw R: -0.0460
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0091 | Critic: 0.4791 | KL: 0.00669 | Ratio μ: 1.0003 | Ent: 0.6142 | Avg norm R: 0.8284 | Avg raw R: -0.0490
# [Eval] Iteration 4: Average reward = -1.425
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0030 | Critic: 0.4480 | KL: 0.00322 | Ratio μ: 1.0045 | Ent: 0.6142 | Avg norm R: 0.8282 | Avg raw R: -0.0493
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0020 | Critic: 0.4793 | KL: 0.00476 | Ratio μ: 1.0022 | Ent: 0.6142 | Avg norm R: 0.8302 | Avg raw R: -0.0466
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0047 | Critic: 0.4622 | KL: 0.00895 | Ratio μ: 1.0016 | Ent: 0.6142 | Avg norm R: 0.8336 | Avg raw R: -0.0420
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0056 | Critic: 0.4391 | KL: 0.00717 | Ratio μ: 1.0005 | Ent: 0.6142 | Avg norm R: 0.8313 | Avg raw R: -0.0451
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0017 | Critic: 0.4643 | KL: 0.00819 | Ratio μ: 1.0004 | Ent: 0.6142 | Avg norm R: 0.8310 | Avg raw R: -0.0456
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0051 | Critic: 0.4239 | KL: 0.00459 | Ratio μ: 1.0029 | Ent: 0.6142 | Avg norm R: 0.8309 | Avg raw R: -0.0456
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0046 | Critic: 0.4434 | KL: 0.00904 | Ratio μ: 0.9974 | Ent: 0.6142 | Avg norm R: 0.8328 | Avg raw R: -0.0431
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0055 | Critic: 0.4719 | KL: 0.00751 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8306 | Avg raw R: -0.0460
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0056 | Critic: 0.4678 | KL: 0.00840 | Ratio μ: 0.9980 | Ent: 0.6142 | Avg norm R: 0.8299 | Avg raw R: -0.0470
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0054 | Critic: 0.4535 | KL: 0.00538 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8287 | Avg raw R: -0.0486
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0048 | Critic: 0.4386 | KL: 0.00516 | Ratio μ: 1.0005 | Ent: 0.6142 | Avg norm R: 0.8308 | Avg raw R: -0.0457
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0091 | Critic: 0.4677 | KL: 0.00346 | Ratio μ: 1.0023 | Ent: 0.6142 | Avg norm R: 0.8328 | Avg raw R: -0.0430
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0063 | Critic: 0.4595 | KL: 0.00607 | Ratio μ: 1.0009 | Ent: 0.6142 | Avg norm R: 0.8294 | Avg raw R: -0.0476
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0052 | Critic: 0.4456 | KL: 0.00298 | Ratio μ: 1.0032 | Ent: 0.6142 | Avg norm R: 0.8319 | Avg raw R: -0.0443
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0041 | Critic: 0.4463 | KL: 0.00876 | Ratio μ: 0.9990 | Ent: 0.6142 | Avg norm R: 0.8307 | Avg raw R: -0.0459
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0065 | Critic: 0.4321 | KL: 0.00071 | Ratio μ: 1.0069 | Ent: 0.6142 | Avg norm R: 0.8300 | Avg raw R: -0.0469
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0020 | Critic: 0.4583 | KL: 0.00705 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8290 | Avg raw R: -0.0482
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0019 | Critic: 0.4206 | KL: 0.01015 | Ratio μ: 0.9978 | Ent: 0.6142 | Avg norm R: 0.8315 | Avg raw R: -0.0449
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0043 | Critic: 0.4564 | KL: 0.01129 | Ratio μ: 0.9964 | Ent: 0.6142 | Avg norm R: 0.8320 | Avg raw R: -0.0441
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0056 | Critic: 0.4269 | KL: 0.00765 | Ratio μ: 0.9995 | Ent: 0.6142 | Avg norm R: 0.8324 | Avg raw R: -0.0436
# [Eval] Iteration 5: Average reward = -1.435
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0025 | Critic: 0.4584 | KL: 0.00908 | Ratio μ: 0.9975 | Ent: 0.6142 | Avg norm R: 0.8279 | Avg raw R: -0.0497
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0063 | Critic: 0.4731 | KL: 0.01172 | Ratio μ: 1.0000 | Ent: 0.6142 | Avg norm R: 0.8304 | Avg raw R: -0.0463
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0050 | Critic: 0.4292 | KL: 0.00509 | Ratio μ: 1.0016 | Ent: 0.6142 | Avg norm R: 0.8331 | Avg raw R: -0.0427
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0029 | Critic: 0.4337 | KL: 0.00606 | Ratio μ: 1.0012 | Ent: 0.6142 | Avg norm R: 0.8307 | Avg raw R: -0.0458
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0039 | Critic: 0.4412 | KL: 0.00379 | Ratio μ: 1.0024 | Ent: 0.6142 | Avg norm R: 0.8313 | Avg raw R: -0.0451
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0048 | Critic: 0.4476 | KL: 0.00591 | Ratio μ: 1.0005 | Ent: 0.6142 | Avg norm R: 0.8301 | Avg raw R: -0.0467
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0068 | Critic: 0.4609 | KL: 0.00541 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8278 | Avg raw R: -0.0498
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0067 | Critic: 0.4433 | KL: 0.00467 | Ratio μ: 1.0013 | Ent: 0.6142 | Avg norm R: 0.8331 | Avg raw R: -0.0426
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0071 | Critic: 0.4371 | KL: 0.00164 | Ratio μ: 1.0046 | Ent: 0.6142 | Avg norm R: 0.8309 | Avg raw R: -0.0457
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0063 | Critic: 0.4581 | KL: 0.00970 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8284 | Avg raw R: -0.0490
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0037 | Critic: 0.4379 | KL: 0.00725 | Ratio μ: 0.9996 | Ent: 0.6142 | Avg norm R: 0.8301 | Avg raw R: -0.0467
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0037 | Critic: 0.4794 | KL: 0.01078 | Ratio μ: 0.9971 | Ent: 0.6142 | Avg norm R: 0.8291 | Avg raw R: -0.0481
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0048 | Critic: 0.4486 | KL: 0.00777 | Ratio μ: 0.9997 | Ent: 0.6142 | Avg norm R: 0.8336 | Avg raw R: -0.0420
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0058 | Critic: 0.4372 | KL: 0.00159 | Ratio μ: 1.0054 | Ent: 0.6142 | Avg norm R: 0.8308 | Avg raw R: -0.0457
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0068 | Critic: 0.4334 | KL: 0.00952 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8317 | Avg raw R: -0.0446
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0051 | Critic: 0.4447 | KL: 0.00406 | Ratio μ: 1.0028 | Ent: 0.6142 | Avg norm R: 0.8331 | Avg raw R: -0.0427
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0009 | Critic: 0.4204 | KL: 0.00562 | Ratio μ: 1.0028 | Ent: 0.6142 | Avg norm R: 0.8344 | Avg raw R: -0.0409
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0053 | Critic: 0.4573 | KL: 0.00670 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8316 | Avg raw R: -0.0448
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0061 | Critic: 0.4576 | KL: 0.01148 | Ratio μ: 0.9979 | Ent: 0.6142 | Avg norm R: 0.8331 | Avg raw R: -0.0427
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0034 | Critic: 0.4452 | KL: 0.00793 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8309 | Avg raw R: -0.0456
# [Eval] Iteration 6: Average reward = -1.458
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0058 | Critic: 0.4374 | KL: 0.00670 | Ratio μ: 1.0035 | Ent: 0.6142 | Avg norm R: 0.8335 | Avg raw R: -0.0422
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0027 | Critic: 0.4209 | KL: 0.00585 | Ratio μ: 1.0020 | Ent: 0.6142 | Avg norm R: 0.8313 | Avg raw R: -0.0451
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0028 | Critic: 0.4404 | KL: 0.00826 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8321 | Avg raw R: -0.0440
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0009 | Critic: 0.4663 | KL: 0.01024 | Ratio μ: 0.9989 | Ent: 0.6142 | Avg norm R: 0.8332 | Avg raw R: -0.0425
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0049 | Critic: 0.4477 | KL: 0.00633 | Ratio μ: 1.0021 | Ent: 0.6142 | Avg norm R: 0.8326 | Avg raw R: -0.0434
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0037 | Critic: 0.4730 | KL: 0.01131 | Ratio μ: 0.9995 | Ent: 0.6142 | Avg norm R: 0.8299 | Avg raw R: -0.0470
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0047 | Critic: 0.4520 | KL: 0.00980 | Ratio μ: 0.9987 | Ent: 0.6142 | Avg norm R: 0.8289 | Avg raw R: -0.0483
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0049 | Critic: 0.4258 | KL: 0.00870 | Ratio μ: 0.9999 | Ent: 0.6142 | Avg norm R: 0.8311 | Avg raw R: -0.0454
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0030 | Critic: 0.4249 | KL: 0.00469 | Ratio μ: 1.0032 | Ent: 0.6142 | Avg norm R: 0.8304 | Avg raw R: -0.0463
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0036 | Critic: 0.4491 | KL: 0.01029 | Ratio μ: 0.9974 | Ent: 0.6142 | Avg norm R: 0.8319 | Avg raw R: -0.0442
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0019 | Critic: 0.4356 | KL: 0.00846 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8337 | Avg raw R: -0.0418
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0072 | Critic: 0.4095 | KL: 0.01235 | Ratio μ: 0.9956 | Ent: 0.6142 | Avg norm R: 0.8315 | Avg raw R: -0.0448
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0029 | Critic: 0.4360 | KL: 0.01013 | Ratio μ: 0.9979 | Ent: 0.6142 | Avg norm R: 0.8329 | Avg raw R: -0.0430
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0059 | Critic: 0.4430 | KL: 0.00758 | Ratio μ: 1.0010 | Ent: 0.6142 | Avg norm R: 0.8309 | Avg raw R: -0.0456
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: 0.0013 | Critic: 0.4224 | KL: 0.00976 | Ratio μ: 0.9990 | Ent: 0.6142 | Avg norm R: 0.8325 | Avg raw R: -0.0434
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0047 | Critic: 0.4261 | KL: 0.00866 | Ratio μ: 1.0007 | Ent: 0.6142 | Avg norm R: 0.8338 | Avg raw R: -0.0417
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0038 | Critic: 0.4126 | KL: 0.01003 | Ratio μ: 0.9978 | Ent: 0.6142 | Avg norm R: 0.8316 | Avg raw R: -0.0447
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0026 | Critic: 0.4090 | KL: 0.01111 | Ratio μ: 0.9976 | Ent: 0.6142 | Avg norm R: 0.8330 | Avg raw R: -0.0428
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0013 | Critic: 0.4400 | KL: 0.01058 | Ratio μ: 0.9983 | Ent: 0.6142 | Avg norm R: 0.8313 | Avg raw R: -0.0451
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0034 | Critic: 0.4327 | KL: 0.00971 | Ratio μ: 0.9989 | Ent: 0.6142 | Avg norm R: 0.8306 | Avg raw R: -0.0460
# [Eval] Iteration 7: Average reward = -1.478
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0060 | Critic: 0.4140 | KL: 0.00757 | Ratio μ: 1.0011 | Ent: 0.6142 | Avg norm R: 0.8298 | Avg raw R: -0.0471
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0038 | Critic: 0.4229 | KL: 0.00419 | Ratio μ: 1.0043 | Ent: 0.6142 | Avg norm R: 0.8362 | Avg raw R: -0.0385
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0049 | Critic: 0.4423 | KL: 0.00804 | Ratio μ: 0.9996 | Ent: 0.6142 | Avg norm R: 0.8326 | Avg raw R: -0.0433
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0042 | Critic: 0.4255 | KL: 0.01152 | Ratio μ: 0.9963 | Ent: 0.6142 | Avg norm R: 0.8295 | Avg raw R: -0.0475
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: 0.0004 | Critic: 0.4110 | KL: 0.00959 | Ratio μ: 1.0001 | Ent: 0.6142 | Avg norm R: 0.8315 | Avg raw R: -0.0448
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0032 | Critic: 0.4026 | KL: 0.00894 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8342 | Avg raw R: -0.0411
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0027 | Critic: 0.4407 | KL: 0.00718 | Ratio μ: 1.0030 | Ent: 0.6142 | Avg norm R: 0.8320 | Avg raw R: -0.0442
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: 0.0010 | Critic: 0.4106 | KL: 0.00968 | Ratio μ: 0.9987 | Ent: 0.6142 | Avg norm R: 0.8339 | Avg raw R: -0.0415
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0037 | Critic: 0.4344 | KL: 0.00777 | Ratio μ: 1.0025 | Ent: 0.6142 | Avg norm R: 0.8349 | Avg raw R: -0.0402
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0033 | Critic: 0.4039 | KL: 0.01160 | Ratio μ: 0.9971 | Ent: 0.6142 | Avg norm R: 0.8353 | Avg raw R: -0.0397
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0024 | Critic: 0.4419 | KL: 0.00931 | Ratio μ: 0.9985 | Ent: 0.6142 | Avg norm R: 0.8306 | Avg raw R: -0.0460
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0028 | Critic: 0.4157 | KL: 0.01219 | Ratio μ: 0.9977 | Ent: 0.6142 | Avg norm R: 0.8354 | Avg raw R: -0.0396
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: 0.0015 | Critic: 0.4525 | KL: 0.00551 | Ratio μ: 1.0041 | Ent: 0.6142 | Avg norm R: 0.8309 | Avg raw R: -0.0456
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0044 | Critic: 0.4254 | KL: 0.01071 | Ratio μ: 0.9979 | Ent: 0.6142 | Avg norm R: 0.8348 | Avg raw R: -0.0403
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0024 | Critic: 0.4421 | KL: 0.01496 | Ratio μ: 0.9937 | Ent: 0.6142 | Avg norm R: 0.8341 | Avg raw R: -0.0414
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0029 | Critic: 0.4061 | KL: 0.00703 | Ratio μ: 1.0012 | Ent: 0.6142 | Avg norm R: 0.8357 | Avg raw R: -0.0392
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0031 | Critic: 0.4222 | KL: 0.01262 | Ratio μ: 0.9964 | Ent: 0.6142 | Avg norm R: 0.8329 | Avg raw R: -0.0430
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0023 | Critic: 0.4408 | KL: 0.01109 | Ratio μ: 1.0003 | Ent: 0.6142 | Avg norm R: 0.8333 | Avg raw R: -0.0424
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0052 | Critic: 0.4140 | KL: 0.01286 | Ratio μ: 0.9957 | Ent: 0.6142 | Avg norm R: 0.8322 | Avg raw R: -0.0439
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0027 | Critic: 0.4093 | KL: 0.00899 | Ratio μ: 0.9981 | Ent: 0.6142 | Avg norm R: 0.8317 | Avg raw R: -0.0446
# [Eval] Iteration 8: Average reward = -1.463
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0062 | Critic: 0.4054 | KL: 0.00581 | Ratio μ: 1.0020 | Ent: 0.6142 | Avg norm R: 0.8346 | Avg raw R: -0.0407
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0075 | Critic: 0.4323 | KL: 0.01015 | Ratio μ: 1.0020 | Ent: 0.6142 | Avg norm R: 0.8343 | Avg raw R: -0.0411
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0048 | Critic: 0.3915 | KL: 0.00884 | Ratio μ: 0.9994 | Ent: 0.6142 | Avg norm R: 0.8329 | Avg raw R: -0.0429
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0041 | Critic: 0.4205 | KL: 0.00904 | Ratio μ: 0.9995 | Ent: 0.6142 | Avg norm R: 0.8306 | Avg raw R: -0.0460
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0048 | Critic: 0.4190 | KL: 0.01518 | Ratio μ: 0.9926 | Ent: 0.6142 | Avg norm R: 0.8352 | Avg raw R: -0.0399
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0016 | Critic: 0.4079 | KL: 0.00543 | Ratio μ: 1.0030 | Ent: 0.6142 | Avg norm R: 0.8323 | Avg raw R: -0.0438
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: 0.0019 | Critic: 0.3877 | KL: 0.00662 | Ratio μ: 1.0013 | Ent: 0.6142 | Avg norm R: 0.8331 | Avg raw R: -0.0427
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0051 | Critic: 0.4178 | KL: 0.00555 | Ratio μ: 1.0043 | Ent: 0.6142 | Avg norm R: 0.8343 | Avg raw R: -0.0410
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0028 | Critic: 0.4014 | KL: 0.00998 | Ratio μ: 0.9989 | Ent: 0.6142 | Avg norm R: 0.8348 | Avg raw R: -0.0404
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0002 | Critic: 0.4152 | KL: 0.00379 | Ratio μ: 1.0052 | Ent: 0.6142 | Avg norm R: 0.8325 | Avg raw R: -0.0435
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0031 | Critic: 0.4002 | KL: 0.01228 | Ratio μ: 0.9972 | Ent: 0.6142 | Avg norm R: 0.8357 | Avg raw R: -0.0391
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0024 | Critic: 0.4080 | KL: 0.00995 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8339 | Avg raw R: -0.0415
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0037 | Critic: 0.4054 | KL: 0.00607 | Ratio μ: 1.0024 | Ent: 0.6142 | Avg norm R: 0.8306 | Avg raw R: -0.0461
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0013 | Critic: 0.4168 | KL: 0.01022 | Ratio μ: 0.9990 | Ent: 0.6142 | Avg norm R: 0.8364 | Avg raw R: -0.0382
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0046 | Critic: 0.4175 | KL: 0.01037 | Ratio μ: 0.9983 | Ent: 0.6142 | Avg norm R: 0.8337 | Avg raw R: -0.0419
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0045 | Critic: 0.4054 | KL: 0.00719 | Ratio μ: 1.0028 | Ent: 0.6142 | Avg norm R: 0.8332 | Avg raw R: -0.0425
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0046 | Critic: 0.4014 | KL: 0.01071 | Ratio μ: 0.9981 | Ent: 0.6142 | Avg norm R: 0.8337 | Avg raw R: -0.0418
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0051 | Critic: 0.3818 | KL: 0.01534 | Ratio μ: 0.9976 | Ent: 0.6142 | Avg norm R: 0.8383 | Avg raw R: -0.0357
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0017 | Critic: 0.3887 | KL: 0.00573 | Ratio μ: 1.0049 | Ent: 0.6142 | Avg norm R: 0.8363 | Avg raw R: -0.0383
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0017 | Critic: 0.4042 | KL: 0.00996 | Ratio μ: 1.0001 | Ent: 0.6142 | Avg norm R: 0.8312 | Avg raw R: -0.0453
# [Eval] Iteration 9: Average reward = -1.417
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0002 | Critic: 0.4066 | KL: 0.00928 | Ratio μ: 1.0022 | Ent: 0.6142 | Avg norm R: 0.8344 | Avg raw R: -0.0409
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0039 | Critic: 0.4023 | KL: 0.00975 | Ratio μ: 0.9988 | Ent: 0.6142 | Avg norm R: 0.8350 | Avg raw R: -0.0401
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0022 | Critic: 0.4280 | KL: 0.00987 | Ratio μ: 0.9989 | Ent: 0.6142 | Avg norm R: 0.8330 | Avg raw R: -0.0428
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0057 | Critic: 0.4191 | KL: 0.00871 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8347 | Avg raw R: -0.0405
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0064 | Critic: 0.4212 | KL: 0.00943 | Ratio μ: 0.9994 | Ent: 0.6142 | Avg norm R: 0.8354 | Avg raw R: -0.0395
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0020 | Critic: 0.4148 | KL: 0.00694 | Ratio μ: 1.0030 | Ent: 0.6142 | Avg norm R: 0.8335 | Avg raw R: -0.0421
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0051 | Critic: 0.4162 | KL: 0.00812 | Ratio μ: 1.0018 | Ent: 0.6142 | Avg norm R: 0.8329 | Avg raw R: -0.0429
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0055 | Critic: 0.4153 | KL: 0.00748 | Ratio μ: 1.0003 | Ent: 0.6142 | Avg norm R: 0.8333 | Avg raw R: -0.0424
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0014 | Critic: 0.4223 | KL: 0.01090 | Ratio μ: 0.9974 | Ent: 0.6142 | Avg norm R: 0.8324 | Avg raw R: -0.0437
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0053 | Critic: 0.4146 | KL: 0.01269 | Ratio μ: 0.9974 | Ent: 0.6142 | Avg norm R: 0.8332 | Avg raw R: -0.0425
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0050 | Critic: 0.4235 | KL: 0.00805 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8318 | Avg raw R: -0.0445
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0057 | Critic: 0.4118 | KL: 0.00729 | Ratio μ: 1.0012 | Ent: 0.6142 | Avg norm R: 0.8362 | Avg raw R: -0.0385
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0036 | Critic: 0.4099 | KL: 0.01186 | Ratio μ: 0.9979 | Ent: 0.6142 | Avg norm R: 0.8366 | Avg raw R: -0.0379
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0075 | Critic: 0.3823 | KL: 0.01295 | Ratio μ: 0.9959 | Ent: 0.6142 | Avg norm R: 0.8305 | Avg raw R: -0.0461
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0060 | Critic: 0.4157 | KL: 0.00983 | Ratio μ: 0.9967 | Ent: 0.6142 | Avg norm R: 0.8312 | Avg raw R: -0.0453
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0042 | Critic: 0.4220 | KL: 0.01107 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8327 | Avg raw R: -0.0432
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0050 | Critic: 0.3957 | KL: 0.00883 | Ratio μ: 1.0007 | Ent: 0.6142 | Avg norm R: 0.8336 | Avg raw R: -0.0420
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0033 | Critic: 0.3808 | KL: 0.01297 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8338 | Avg raw R: -0.0417
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0059 | Critic: 0.3674 | KL: 0.01602 | Ratio μ: 0.9942 | Ent: 0.6142 | Avg norm R: 0.8345 | Avg raw R: -0.0407
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0021 | Critic: 0.3955 | KL: 0.00736 | Ratio μ: 0.9992 | Ent: 0.6142 | Avg norm R: 0.8348 | Avg raw R: -0.0403
# [Eval] Iteration 10: Average reward = -1.433
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0059 | Critic: 0.4001 | KL: 0.00779 | Ratio μ: 0.9997 | Ent: 0.6142 | Avg norm R: 0.8328 | Avg raw R: -0.0431
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0036 | Critic: 0.4058 | KL: 0.00761 | Ratio μ: 0.9997 | Ent: 0.6142 | Avg norm R: 0.8299 | Avg raw R: -0.0469
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0064 | Critic: 0.3983 | KL: 0.00917 | Ratio μ: 0.9978 | Ent: 0.6142 | Avg norm R: 0.8320 | Avg raw R: -0.0442
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0037 | Critic: 0.3982 | KL: 0.00385 | Ratio μ: 1.0023 | Ent: 0.6142 | Avg norm R: 0.8339 | Avg raw R: -0.0416
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0075 | Critic: 0.4027 | KL: 0.00215 | Ratio μ: 1.0037 | Ent: 0.6142 | Avg norm R: 0.8329 | Avg raw R: -0.0430
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0063 | Critic: 0.4191 | KL: 0.00718 | Ratio μ: 1.0013 | Ent: 0.6142 | Avg norm R: 0.8357 | Avg raw R: -0.0391
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0028 | Critic: 0.3772 | KL: 0.00598 | Ratio μ: 1.0007 | Ent: 0.6142 | Avg norm R: 0.8340 | Avg raw R: -0.0414
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0050 | Critic: 0.3898 | KL: 0.00750 | Ratio μ: 0.9999 | Ent: 0.6142 | Avg norm R: 0.8355 | Avg raw R: -0.0394
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0078 | Critic: 0.3946 | KL: 0.00875 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8343 | Avg raw R: -0.0411
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0022 | Critic: 0.4026 | KL: 0.01016 | Ratio μ: 0.9975 | Ent: 0.6142 | Avg norm R: 0.8326 | Avg raw R: -0.0433
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0058 | Critic: 0.4027 | KL: 0.01026 | Ratio μ: 0.9978 | Ent: 0.6142 | Avg norm R: 0.8367 | Avg raw R: -0.0378
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0033 | Critic: 0.4144 | KL: 0.01138 | Ratio μ: 0.9982 | Ent: 0.6142 | Avg norm R: 0.8306 | Avg raw R: -0.0460
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0055 | Critic: 0.3667 | KL: 0.00693 | Ratio μ: 1.0018 | Ent: 0.6142 | Avg norm R: 0.8314 | Avg raw R: -0.0450
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0018 | Critic: 0.4072 | KL: 0.00862 | Ratio μ: 1.0005 | Ent: 0.6142 | Avg norm R: 0.8331 | Avg raw R: -0.0427
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0045 | Critic: 0.4078 | KL: 0.01010 | Ratio μ: 0.9976 | Ent: 0.6142 | Avg norm R: 0.8337 | Avg raw R: -0.0419
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0042 | Critic: 0.3971 | KL: 0.00688 | Ratio μ: 1.0005 | Ent: 0.6142 | Avg norm R: 0.8322 | Avg raw R: -0.0439
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0030 | Critic: 0.4118 | KL: 0.00941 | Ratio μ: 1.0003 | Ent: 0.6142 | Avg norm R: 0.8328 | Avg raw R: -0.0430
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0063 | Critic: 0.4173 | KL: 0.00763 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8333 | Avg raw R: -0.0424
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0056 | Critic: 0.3966 | KL: 0.00990 | Ratio μ: 0.9982 | Ent: 0.6142 | Avg norm R: 0.8330 | Avg raw R: -0.0428
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0038 | Critic: 0.4154 | KL: 0.00583 | Ratio μ: 1.0010 | Ent: 0.6142 | Avg norm R: 0.8329 | Avg raw R: -0.0430
# [Eval] Iteration 11: Average reward = -1.434
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0041 | Critic: 0.3956 | KL: 0.00692 | Ratio μ: 1.0014 | Ent: 0.6142 | Avg norm R: 0.8360 | Avg raw R: -0.0387
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0055 | Critic: 0.4012 | KL: 0.00327 | Ratio μ: 1.0047 | Ent: 0.6142 | Avg norm R: 0.8357 | Avg raw R: -0.0391
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0027 | Critic: 0.4031 | KL: 0.00729 | Ratio μ: 1.0004 | Ent: 0.6142 | Avg norm R: 0.8335 | Avg raw R: -0.0422
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0059 | Critic: 0.4042 | KL: 0.00878 | Ratio μ: 0.9989 | Ent: 0.6142 | Avg norm R: 0.8361 | Avg raw R: -0.0386
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0054 | Critic: 0.3901 | KL: 0.00608 | Ratio μ: 1.0033 | Ent: 0.6142 | Avg norm R: 0.8331 | Avg raw R: -0.0427
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0024 | Critic: 0.3861 | KL: 0.01323 | Ratio μ: 1.0001 | Ent: 0.6142 | Avg norm R: 0.8351 | Avg raw R: -0.0400
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0050 | Critic: 0.3954 | KL: 0.00946 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8348 | Avg raw R: -0.0404
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0023 | Critic: 0.4092 | KL: 0.01028 | Ratio μ: 1.0001 | Ent: 0.6142 | Avg norm R: 0.8292 | Avg raw R: -0.0480
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0054 | Critic: 0.3731 | KL: 0.01545 | Ratio μ: 0.9937 | Ent: 0.6142 | Avg norm R: 0.8368 | Avg raw R: -0.0376
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0056 | Critic: 0.3711 | KL: 0.00886 | Ratio μ: 0.9995 | Ent: 0.6142 | Avg norm R: 0.8367 | Avg raw R: -0.0378
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0032 | Critic: 0.3765 | KL: 0.01375 | Ratio μ: 0.9955 | Ent: 0.6142 | Avg norm R: 0.8320 | Avg raw R: -0.0442
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0022 | Critic: 0.3793 | KL: 0.00946 | Ratio μ: 0.9999 | Ent: 0.6142 | Avg norm R: 0.8332 | Avg raw R: -0.0425
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0011 | Critic: 0.3828 | KL: 0.01037 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8342 | Avg raw R: -0.0411
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0029 | Critic: 0.3975 | KL: 0.01128 | Ratio μ: 0.9976 | Ent: 0.6142 | Avg norm R: 0.8320 | Avg raw R: -0.0441
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0077 | Critic: 0.3727 | KL: 0.00869 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8313 | Avg raw R: -0.0451
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: 0.0001 | Critic: 0.3911 | KL: 0.00718 | Ratio μ: 1.0025 | Ent: 0.6142 | Avg norm R: 0.8303 | Avg raw R: -0.0465
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0069 | Critic: 0.3917 | KL: 0.00918 | Ratio μ: 1.0003 | Ent: 0.6142 | Avg norm R: 0.8330 | Avg raw R: -0.0428
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0006 | Critic: 0.3784 | KL: 0.00552 | Ratio μ: 1.0055 | Ent: 0.6142 | Avg norm R: 0.8359 | Avg raw R: -0.0389
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0060 | Critic: 0.3814 | KL: 0.00798 | Ratio μ: 1.0000 | Ent: 0.6142 | Avg norm R: 0.8328 | Avg raw R: -0.0430
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0027 | Critic: 0.4047 | KL: 0.00820 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8323 | Avg raw R: -0.0438
# [Eval] Iteration 12: Average reward = -1.417
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0050 | Critic: 0.3499 | KL: 0.00965 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8326 | Avg raw R: -0.0434
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0038 | Critic: 0.3808 | KL: 0.01099 | Ratio μ: 0.9978 | Ent: 0.6142 | Avg norm R: 0.8348 | Avg raw R: -0.0404
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0045 | Critic: 0.3938 | KL: 0.01108 | Ratio μ: 0.9967 | Ent: 0.6142 | Avg norm R: 0.8355 | Avg raw R: -0.0395
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0019 | Critic: 0.4006 | KL: 0.01105 | Ratio μ: 0.9988 | Ent: 0.6142 | Avg norm R: 0.8307 | Avg raw R: -0.0459
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0039 | Critic: 0.3855 | KL: 0.00696 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8354 | Avg raw R: -0.0396
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0040 | Critic: 0.4168 | KL: 0.00905 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8291 | Avg raw R: -0.0480
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0035 | Critic: 0.4148 | KL: 0.00758 | Ratio μ: 0.9997 | Ent: 0.6142 | Avg norm R: 0.8321 | Avg raw R: -0.0441
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0029 | Critic: 0.4012 | KL: 0.00783 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8334 | Avg raw R: -0.0422
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0051 | Critic: 0.3876 | KL: 0.01167 | Ratio μ: 0.9963 | Ent: 0.6142 | Avg norm R: 0.8312 | Avg raw R: -0.0453
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0028 | Critic: 0.4169 | KL: 0.00805 | Ratio μ: 0.9987 | Ent: 0.6142 | Avg norm R: 0.8321 | Avg raw R: -0.0441
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0058 | Critic: 0.3689 | KL: 0.00745 | Ratio μ: 1.0020 | Ent: 0.6142 | Avg norm R: 0.8346 | Avg raw R: -0.0406
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0020 | Critic: 0.3784 | KL: 0.01091 | Ratio μ: 0.9984 | Ent: 0.6142 | Avg norm R: 0.8351 | Avg raw R: -0.0400
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0013 | Critic: 0.4076 | KL: 0.00720 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8331 | Avg raw R: -0.0426
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0036 | Critic: 0.3998 | KL: 0.01179 | Ratio μ: 0.9957 | Ent: 0.6142 | Avg norm R: 0.8347 | Avg raw R: -0.0405
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0018 | Critic: 0.3811 | KL: 0.00486 | Ratio μ: 1.0021 | Ent: 0.6142 | Avg norm R: 0.8356 | Avg raw R: -0.0393
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0004 | Critic: 0.4050 | KL: 0.00831 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8336 | Avg raw R: -0.0420
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0046 | Critic: 0.3950 | KL: 0.00658 | Ratio μ: 1.0007 | Ent: 0.6142 | Avg norm R: 0.8347 | Avg raw R: -0.0405
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0028 | Critic: 0.3941 | KL: 0.01137 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8345 | Avg raw R: -0.0408
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0044 | Critic: 0.3947 | KL: 0.01080 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8333 | Avg raw R: -0.0424
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0043 | Critic: 0.3765 | KL: 0.01060 | Ratio μ: 0.9981 | Ent: 0.6142 | Avg norm R: 0.8358 | Avg raw R: -0.0390
# [Eval] Iteration 13: Average reward = -1.408
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0068 | Critic: 0.3667 | KL: 0.00535 | Ratio μ: 1.0027 | Ent: 0.6142 | Avg norm R: 0.8338 | Avg raw R: -0.0417
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: 0.0005 | Critic: 0.3887 | KL: 0.00789 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8349 | Avg raw R: -0.0403
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0054 | Critic: 0.4028 | KL: 0.00424 | Ratio μ: 1.0031 | Ent: 0.6142 | Avg norm R: 0.8347 | Avg raw R: -0.0405
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0042 | Critic: 0.3749 | KL: 0.01131 | Ratio μ: 0.9976 | Ent: 0.6142 | Avg norm R: 0.8342 | Avg raw R: -0.0412
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0028 | Critic: 0.3766 | KL: 0.00832 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8332 | Avg raw R: -0.0426
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0051 | Critic: 0.3526 | KL: 0.00753 | Ratio μ: 1.0005 | Ent: 0.6142 | Avg norm R: 0.8359 | Avg raw R: -0.0390
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0061 | Critic: 0.4045 | KL: 0.00627 | Ratio μ: 1.0019 | Ent: 0.6142 | Avg norm R: 0.8346 | Avg raw R: -0.0406
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0011 | Critic: 0.3733 | KL: 0.00929 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8369 | Avg raw R: -0.0376
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0016 | Critic: 0.3936 | KL: 0.00816 | Ratio μ: 1.0004 | Ent: 0.6142 | Avg norm R: 0.8362 | Avg raw R: -0.0385
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0010 | Critic: 0.3695 | KL: 0.00551 | Ratio μ: 1.0040 | Ent: 0.6142 | Avg norm R: 0.8335 | Avg raw R: -0.0422
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0084 | Critic: 0.3659 | KL: 0.00560 | Ratio μ: 1.0025 | Ent: 0.6142 | Avg norm R: 0.8344 | Avg raw R: -0.0410
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: 0.0007 | Critic: 0.4040 | KL: 0.00704 | Ratio μ: 1.0009 | Ent: 0.6142 | Avg norm R: 0.8362 | Avg raw R: -0.0385
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0055 | Critic: 0.4001 | KL: 0.01089 | Ratio μ: 0.9987 | Ent: 0.6142 | Avg norm R: 0.8370 | Avg raw R: -0.0374
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0049 | Critic: 0.3774 | KL: 0.01394 | Ratio μ: 0.9964 | Ent: 0.6142 | Avg norm R: 0.8310 | Avg raw R: -0.0455
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0001 | Critic: 0.3896 | KL: 0.00817 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8355 | Avg raw R: -0.0394
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0028 | Critic: 0.3786 | KL: 0.00780 | Ratio μ: 1.0000 | Ent: 0.6142 | Avg norm R: 0.8329 | Avg raw R: -0.0429
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0091 | Critic: 0.4040 | KL: 0.01163 | Ratio μ: 0.9973 | Ent: 0.6142 | Avg norm R: 0.8336 | Avg raw R: -0.0419
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0021 | Critic: 0.3577 | KL: 0.01164 | Ratio μ: 0.9970 | Ent: 0.6142 | Avg norm R: 0.8397 | Avg raw R: -0.0338
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0062 | Critic: 0.4044 | KL: 0.00704 | Ratio μ: 1.0012 | Ent: 0.6142 | Avg norm R: 0.8336 | Avg raw R: -0.0420
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0054 | Critic: 0.3884 | KL: 0.00578 | Ratio μ: 1.0021 | Ent: 0.6142 | Avg norm R: 0.8354 | Avg raw R: -0.0396
# [Eval] Iteration 14: Average reward = -1.413
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0026 | Critic: 0.3572 | KL: 0.01073 | Ratio μ: 0.9983 | Ent: 0.6142 | Avg norm R: 0.8342 | Avg raw R: -0.0411
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0026 | Critic: 0.3600 | KL: 0.00705 | Ratio μ: 0.9999 | Ent: 0.6142 | Avg norm R: 0.8368 | Avg raw R: -0.0376
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0030 | Critic: 0.3637 | KL: 0.01154 | Ratio μ: 0.9966 | Ent: 0.6142 | Avg norm R: 0.8375 | Avg raw R: -0.0367
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0004 | Critic: 0.3718 | KL: 0.00731 | Ratio μ: 1.0011 | Ent: 0.6142 | Avg norm R: 0.8348 | Avg raw R: -0.0403
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0030 | Critic: 0.4101 | KL: 0.00997 | Ratio μ: 0.9988 | Ent: 0.6142 | Avg norm R: 0.8354 | Avg raw R: -0.0396
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0022 | Critic: 0.3666 | KL: 0.00823 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8395 | Avg raw R: -0.0340
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: 0.0003 | Critic: 0.3931 | KL: 0.00960 | Ratio μ: 0.9989 | Ent: 0.6142 | Avg norm R: 0.8341 | Avg raw R: -0.0413
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0059 | Critic: 0.3915 | KL: 0.01168 | Ratio μ: 0.9962 | Ent: 0.6142 | Avg norm R: 0.8346 | Avg raw R: -0.0406
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0057 | Critic: 0.3718 | KL: 0.00630 | Ratio μ: 1.0007 | Ent: 0.6142 | Avg norm R: 0.8364 | Avg raw R: -0.0382
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0059 | Critic: 0.3821 | KL: 0.01036 | Ratio μ: 0.9958 | Ent: 0.6142 | Avg norm R: 0.8331 | Avg raw R: -0.0427
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0037 | Critic: 0.3761 | KL: 0.01089 | Ratio μ: 0.9979 | Ent: 0.6142 | Avg norm R: 0.8325 | Avg raw R: -0.0434
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0042 | Critic: 0.3959 | KL: 0.01048 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8342 | Avg raw R: -0.0412
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0051 | Critic: 0.3777 | KL: 0.01149 | Ratio μ: 0.9981 | Ent: 0.6142 | Avg norm R: 0.8332 | Avg raw R: -0.0426
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0066 | Critic: 0.3938 | KL: 0.00916 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8320 | Avg raw R: -0.0441
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0039 | Critic: 0.3559 | KL: 0.01163 | Ratio μ: 0.9975 | Ent: 0.6142 | Avg norm R: 0.8339 | Avg raw R: -0.0416
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0049 | Critic: 0.3821 | KL: 0.00838 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8336 | Avg raw R: -0.0420
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0067 | Critic: 0.3611 | KL: 0.00922 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8333 | Avg raw R: -0.0424
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0033 | Critic: 0.3743 | KL: 0.00738 | Ratio μ: 1.0004 | Ent: 0.6142 | Avg norm R: 0.8317 | Avg raw R: -0.0445
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0063 | Critic: 0.3772 | KL: 0.01001 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8347 | Avg raw R: -0.0405
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0060 | Critic: 0.4028 | KL: 0.01001 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8359 | Avg raw R: -0.0388
# [Eval] Iteration 15: Average reward = -1.434
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0027 | Critic: 0.3826 | KL: 0.00710 | Ratio μ: 1.0010 | Ent: 0.6142 | Avg norm R: 0.8347 | Avg raw R: -0.0405
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0037 | Critic: 0.4046 | KL: 0.00605 | Ratio μ: 1.0027 | Ent: 0.6142 | Avg norm R: 0.8328 | Avg raw R: -0.0431
# Iteration: 2
#
# ...
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0063 | Critic: 0.1538 | KL: 0.00163 | Ratio μ: 1.0037 | Ent: 0.6142 | Avg norm R: 0.8396 | Avg raw R: -0.0339
# [Eval] Iteration 94: Average reward = -1.247
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0054 | Critic: 0.1580 | KL: 0.00645 | Ratio μ: 0.9994 | Ent: 0.6142 | Avg norm R: 0.8389 | Avg raw R: -0.0348
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0035 | Critic: 0.1515 | KL: 0.00372 | Ratio μ: 1.0014 | Ent: 0.6142 | Avg norm R: 0.8411 | Avg raw R: -0.0318
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0061 | Critic: 0.1523 | KL: 0.00660 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8367 | Avg raw R: -0.0378
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0053 | Critic: 0.1448 | KL: 0.00703 | Ratio μ: 0.9997 | Ent: 0.6142 | Avg norm R: 0.8397 | Avg raw R: -0.0338
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0054 | Critic: 0.1459 | KL: 0.00587 | Ratio μ: 0.9992 | Ent: 0.6142 | Avg norm R: 0.8396 | Avg raw R: -0.0339
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0047 | Critic: 0.1574 | KL: 0.00721 | Ratio μ: 0.9984 | Ent: 0.6142 | Avg norm R: 0.8402 | Avg raw R: -0.0331
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0059 | Critic: 0.1685 | KL: 0.00080 | Ratio μ: 1.0032 | Ent: 0.6142 | Avg norm R: 0.8369 | Avg raw R: -0.0376
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0055 | Critic: 0.1478 | KL: 0.00778 | Ratio μ: 0.9964 | Ent: 0.6142 | Avg norm R: 0.8399 | Avg raw R: -0.0335
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0055 | Critic: 0.1404 | KL: 0.00550 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8425 | Avg raw R: -0.0299
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0053 | Critic: 0.1460 | KL: 0.00548 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8420 | Avg raw R: -0.0307
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0058 | Critic: 0.1525 | KL: 0.00603 | Ratio μ: 0.9987 | Ent: 0.6142 | Avg norm R: 0.8396 | Avg raw R: -0.0339
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0053 | Critic: 0.1597 | KL: 0.00328 | Ratio μ: 1.0021 | Ent: 0.6142 | Avg norm R: 0.8383 | Avg raw R: -0.0356
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0048 | Critic: 0.1563 | KL: 0.00447 | Ratio μ: 1.0025 | Ent: 0.6142 | Avg norm R: 0.8404 | Avg raw R: -0.0329
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0058 | Critic: 0.1492 | KL: 0.00278 | Ratio μ: 1.0023 | Ent: 0.6142 | Avg norm R: 0.8380 | Avg raw R: -0.0360
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0069 | Critic: 0.1437 | KL: 0.00560 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8402 | Avg raw R: -0.0331
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0061 | Critic: 0.1521 | KL: 0.00241 | Ratio μ: 1.0017 | Ent: 0.6142 | Avg norm R: 0.8362 | Avg raw R: -0.0384
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0060 | Critic: 0.1503 | KL: 0.00771 | Ratio μ: 0.9968 | Ent: 0.6142 | Avg norm R: 0.8396 | Avg raw R: -0.0339
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0053 | Critic: 0.1491 | KL: 0.00302 | Ratio μ: 1.0016 | Ent: 0.6142 | Avg norm R: 0.8376 | Avg raw R: -0.0366
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0053 | Critic: 0.1543 | KL: 0.00441 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8409 | Avg raw R: -0.0321
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0060 | Critic: 0.1508 | KL: 0.00517 | Ratio μ: 1.0012 | Ent: 0.6142 | Avg norm R: 0.8378 | Avg raw R: -0.0364
# [Eval] Iteration 95: Average reward = -1.217
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0059 | Critic: 0.1393 | KL: 0.01043 | Ratio μ: 0.9961 | Ent: 0.6142 | Avg norm R: 0.8400 | Avg raw R: -0.0333
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0042 | Critic: 0.1501 | KL: 0.00431 | Ratio μ: 1.0022 | Ent: 0.6142 | Avg norm R: 0.8398 | Avg raw R: -0.0337
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0059 | Critic: 0.1589 | KL: 0.01010 | Ratio μ: 0.9963 | Ent: 0.6142 | Avg norm R: 0.8405 | Avg raw R: -0.0326
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0054 | Critic: 0.1566 | KL: 0.00686 | Ratio μ: 0.9987 | Ent: 0.6142 | Avg norm R: 0.8409 | Avg raw R: -0.0322
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0040 | Critic: 0.1476 | KL: 0.00699 | Ratio μ: 1.0003 | Ent: 0.6142 | Avg norm R: 0.8401 | Avg raw R: -0.0331
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0056 | Critic: 0.1460 | KL: 0.00759 | Ratio μ: 1.0007 | Ent: 0.6142 | Avg norm R: 0.8422 | Avg raw R: -0.0304
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0051 | Critic: 0.1515 | KL: 0.00324 | Ratio μ: 1.0013 | Ent: 0.6142 | Avg norm R: 0.8400 | Avg raw R: -0.0334
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0043 | Critic: 0.1388 | KL: 0.00434 | Ratio μ: 1.0014 | Ent: 0.6142 | Avg norm R: 0.8388 | Avg raw R: -0.0350
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0058 | Critic: 0.1480 | KL: 0.00663 | Ratio μ: 1.0004 | Ent: 0.6142 | Avg norm R: 0.8418 | Avg raw R: -0.0309
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0051 | Critic: 0.1664 | KL: 0.00590 | Ratio μ: 1.0004 | Ent: 0.6142 | Avg norm R: 0.8369 | Avg raw R: -0.0375
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0061 | Critic: 0.1630 | KL: 0.00462 | Ratio μ: 1.0008 | Ent: 0.6142 | Avg norm R: 0.8398 | Avg raw R: -0.0337
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0041 | Critic: 0.1587 | KL: 0.00405 | Ratio μ: 1.0042 | Ent: 0.6142 | Avg norm R: 0.8406 | Avg raw R: -0.0325
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0038 | Critic: 0.1559 | KL: 0.00789 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8380 | Avg raw R: -0.0361
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0060 | Critic: 0.1607 | KL: 0.00407 | Ratio μ: 1.0013 | Ent: 0.6142 | Avg norm R: 0.8377 | Avg raw R: -0.0364
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0041 | Critic: 0.1378 | KL: -0.00027 | Ratio μ: 1.0042 | Ent: 0.6142 | Avg norm R: 0.8414 | Avg raw R: -0.0314
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0039 | Critic: 0.1607 | KL: 0.00626 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8400 | Avg raw R: -0.0333
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0054 | Critic: 0.1518 | KL: 0.00704 | Ratio μ: 0.9970 | Ent: 0.6142 | Avg norm R: 0.8391 | Avg raw R: -0.0346
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0059 | Critic: 0.1498 | KL: 0.00604 | Ratio μ: 0.9985 | Ent: 0.6142 | Avg norm R: 0.8366 | Avg raw R: -0.0379
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0051 | Critic: 0.1408 | KL: 0.00574 | Ratio μ: 1.0010 | Ent: 0.6142 | Avg norm R: 0.8411 | Avg raw R: -0.0319
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0054 | Critic: 0.1566 | KL: 0.00257 | Ratio μ: 1.0035 | Ent: 0.6142 | Avg norm R: 0.8420 | Avg raw R: -0.0306
# [Eval] Iteration 96: Average reward = -1.219
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0059 | Critic: 0.1431 | KL: 0.00574 | Ratio μ: 0.9988 | Ent: 0.6142 | Avg norm R: 0.8389 | Avg raw R: -0.0348
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0021 | Critic: 0.1551 | KL: 0.00546 | Ratio μ: 1.0003 | Ent: 0.6142 | Avg norm R: 0.8387 | Avg raw R: -0.0351
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0059 | Critic: 0.1561 | KL: 0.00667 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8409 | Avg raw R: -0.0322
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0063 | Critic: 0.1393 | KL: 0.00844 | Ratio μ: 0.9994 | Ent: 0.6142 | Avg norm R: 0.8396 | Avg raw R: -0.0339
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0063 | Critic: 0.1681 | KL: 0.00716 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8377 | Avg raw R: -0.0365
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0041 | Critic: 0.1391 | KL: 0.00774 | Ratio μ: 0.9972 | Ent: 0.6142 | Avg norm R: 0.8414 | Avg raw R: -0.0315
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0086 | Critic: 0.1575 | KL: 0.01453 | Ratio μ: 0.9965 | Ent: 0.6142 | Avg norm R: 0.8418 | Avg raw R: -0.0309
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0053 | Critic: 0.1511 | KL: 0.00798 | Ratio μ: 0.9975 | Ent: 0.6142 | Avg norm R: 0.8398 | Avg raw R: -0.0337
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0048 | Critic: 0.1381 | KL: 0.00969 | Ratio μ: 0.9976 | Ent: 0.6142 | Avg norm R: 0.8395 | Avg raw R: -0.0341
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0072 | Critic: 0.1385 | KL: 0.00848 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8396 | Avg raw R: -0.0339
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0061 | Critic: 0.1424 | KL: 0.00490 | Ratio μ: 0.9992 | Ent: 0.6142 | Avg norm R: 0.8414 | Avg raw R: -0.0314
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0053 | Critic: 0.1330 | KL: 0.00543 | Ratio μ: 0.9989 | Ent: 0.6142 | Avg norm R: 0.8411 | Avg raw R: -0.0318
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0049 | Critic: 0.1371 | KL: 0.01388 | Ratio μ: 0.9960 | Ent: 0.6142 | Avg norm R: 0.8432 | Avg raw R: -0.0290
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0051 | Critic: 0.1449 | KL: 0.00732 | Ratio μ: 0.9977 | Ent: 0.6142 | Avg norm R: 0.8379 | Avg raw R: -0.0362
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0042 | Critic: 0.1568 | KL: 0.00227 | Ratio μ: 1.0029 | Ent: 0.6142 | Avg norm R: 0.8370 | Avg raw R: -0.0374
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0050 | Critic: 0.1530 | KL: 0.00658 | Ratio μ: 0.9980 | Ent: 0.6142 | Avg norm R: 0.8408 | Avg raw R: -0.0323
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0053 | Critic: 0.1698 | KL: 0.00495 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8370 | Avg raw R: -0.0374
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0023 | Critic: 0.1543 | KL: 0.00832 | Ratio μ: 0.9972 | Ent: 0.6142 | Avg norm R: 0.8421 | Avg raw R: -0.0305
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0037 | Critic: 0.1600 | KL: 0.00586 | Ratio μ: 0.9994 | Ent: 0.6142 | Avg norm R: 0.8397 | Avg raw R: -0.0337
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0043 | Critic: 0.1457 | KL: 0.00617 | Ratio μ: 0.9992 | Ent: 0.6142 | Avg norm R: 0.8406 | Avg raw R: -0.0326
# [Eval] Iteration 97: Average reward = -1.223
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0052 | Critic: 0.1440 | KL: 0.00552 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8417 | Avg raw R: -0.0310
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0043 | Critic: 0.1660 | KL: 0.00393 | Ratio μ: 1.0006 | Ent: 0.6142 | Avg norm R: 0.8383 | Avg raw R: -0.0356
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0064 | Critic: 0.1564 | KL: 0.00363 | Ratio μ: 1.0004 | Ent: 0.6142 | Avg norm R: 0.8415 | Avg raw R: -0.0313
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0044 | Critic: 0.1375 | KL: 0.00308 | Ratio μ: 1.0027 | Ent: 0.6142 | Avg norm R: 0.8440 | Avg raw R: -0.0279
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0060 | Critic: 0.1489 | KL: 0.00515 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8413 | Avg raw R: -0.0316
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0052 | Critic: 0.1468 | KL: 0.00456 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8401 | Avg raw R: -0.0332
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0047 | Critic: 0.1507 | KL: 0.00532 | Ratio μ: 0.9993 | Ent: 0.6142 | Avg norm R: 0.8393 | Avg raw R: -0.0343
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0074 | Critic: 0.1504 | KL: 0.00780 | Ratio μ: 0.9968 | Ent: 0.6142 | Avg norm R: 0.8410 | Avg raw R: -0.0320
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0054 | Critic: 0.1479 | KL: 0.00232 | Ratio μ: 1.0018 | Ent: 0.6142 | Avg norm R: 0.8382 | Avg raw R: -0.0358
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0046 | Critic: 0.1626 | KL: 0.00638 | Ratio μ: 0.9980 | Ent: 0.6142 | Avg norm R: 0.8389 | Avg raw R: -0.0348
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0047 | Critic: 0.1354 | KL: 0.00494 | Ratio μ: 0.9989 | Ent: 0.6142 | Avg norm R: 0.8400 | Avg raw R: -0.0334
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0057 | Critic: 0.1462 | KL: 0.00414 | Ratio μ: 0.9999 | Ent: 0.6142 | Avg norm R: 0.8388 | Avg raw R: -0.0350
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0069 | Critic: 0.1542 | KL: 0.00686 | Ratio μ: 0.9986 | Ent: 0.6142 | Avg norm R: 0.8425 | Avg raw R: -0.0300
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0059 | Critic: 0.1424 | KL: 0.00532 | Ratio μ: 0.9981 | Ent: 0.6142 | Avg norm R: 0.8427 | Avg raw R: -0.0297
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0054 | Critic: 0.1317 | KL: 0.00676 | Ratio μ: 0.9973 | Ent: 0.6142 | Avg norm R: 0.8429 | Avg raw R: -0.0294
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0036 | Critic: 0.1568 | KL: 0.00375 | Ratio μ: 1.0000 | Ent: 0.6142 | Avg norm R: 0.8396 | Avg raw R: -0.0339
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0061 | Critic: 0.1444 | KL: 0.00497 | Ratio μ: 0.9994 | Ent: 0.6142 | Avg norm R: 0.8397 | Avg raw R: -0.0337
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0046 | Critic: 0.1473 | KL: 0.00525 | Ratio μ: 1.0000 | Ent: 0.6142 | Avg norm R: 0.8385 | Avg raw R: -0.0353
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0068 | Critic: 0.1436 | KL: 0.00629 | Ratio μ: 0.9978 | Ent: 0.6142 | Avg norm R: 0.8403 | Avg raw R: -0.0329
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0053 | Critic: 0.1585 | KL: 0.00565 | Ratio μ: 0.9984 | Ent: 0.6142 | Avg norm R: 0.8366 | Avg raw R: -0.0380
# [Eval] Iteration 98: Average reward = -1.211
# Iteration: 0
#
# [Train] Iter 1/20 | Actor: -0.0049 | Critic: 0.1468 | KL: 0.00484 | Ratio μ: 1.0002 | Ent: 0.6142 | Avg norm R: 0.8347 | Avg raw R: -0.0405
# Iteration: 1
#
# [Train] Iter 2/20 | Actor: -0.0052 | Critic: 0.1342 | KL: 0.00567 | Ratio μ: 0.9982 | Ent: 0.6142 | Avg norm R: 0.8408 | Avg raw R: -0.0323
# Iteration: 2
#
# [Train] Iter 3/20 | Actor: -0.0049 | Critic: 0.1571 | KL: 0.00364 | Ratio μ: 1.0025 | Ent: 0.6142 | Avg norm R: 0.8397 | Avg raw R: -0.0337
# Iteration: 3
#
# [Train] Iter 4/20 | Actor: -0.0058 | Critic: 0.1619 | KL: 0.00462 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8367 | Avg raw R: -0.0378
# Iteration: 4
#
# [Train] Iter 5/20 | Actor: -0.0057 | Critic: 0.1549 | KL: 0.00362 | Ratio μ: 0.9997 | Ent: 0.6142 | Avg norm R: 0.8398 | Avg raw R: -0.0336
# Iteration: 5
#
# [Train] Iter 6/20 | Actor: -0.0063 | Critic: 0.1498 | KL: 0.00705 | Ratio μ: 0.9975 | Ent: 0.6142 | Avg norm R: 0.8412 | Avg raw R: -0.0318
# Iteration: 6
#
# [Train] Iter 7/20 | Actor: -0.0054 | Critic: 0.1532 | KL: 0.00614 | Ratio μ: 0.9981 | Ent: 0.6142 | Avg norm R: 0.8413 | Avg raw R: -0.0316
# Iteration: 7
#
# [Train] Iter 8/20 | Actor: -0.0050 | Critic: 0.1519 | KL: 0.00723 | Ratio μ: 0.9991 | Ent: 0.6142 | Avg norm R: 0.8396 | Avg raw R: -0.0339
# Iteration: 8
#
# [Train] Iter 9/20 | Actor: -0.0043 | Critic: 0.1492 | KL: 0.00393 | Ratio μ: 1.0004 | Ent: 0.6142 | Avg norm R: 0.8404 | Avg raw R: -0.0327
# Iteration: 9
#
# [Train] Iter 10/20 | Actor: -0.0037 | Critic: 0.1580 | KL: 0.00968 | Ratio μ: 0.9980 | Ent: 0.6142 | Avg norm R: 0.8389 | Avg raw R: -0.0348
# Iteration: 10
#
# [Train] Iter 11/20 | Actor: -0.0041 | Critic: 0.1456 | KL: 0.00496 | Ratio μ: 1.0018 | Ent: 0.6142 | Avg norm R: 0.8384 | Avg raw R: -0.0356
# Iteration: 11
#
# [Train] Iter 12/20 | Actor: -0.0069 | Critic: 0.1442 | KL: 0.00581 | Ratio μ: 0.9990 | Ent: 0.6142 | Avg norm R: 0.8417 | Avg raw R: -0.0311
# Iteration: 12
#
# [Train] Iter 13/20 | Actor: -0.0053 | Critic: 0.1417 | KL: 0.00034 | Ratio μ: 1.0042 | Ent: 0.6142 | Avg norm R: 0.8417 | Avg raw R: -0.0310
# Iteration: 13
#
# [Train] Iter 14/20 | Actor: -0.0043 | Critic: 0.1471 | KL: 0.00634 | Ratio μ: 0.9977 | Ent: 0.6142 | Avg norm R: 0.8382 | Avg raw R: -0.0358
# Iteration: 14
#
# [Train] Iter 15/20 | Actor: -0.0050 | Critic: 0.1535 | KL: 0.00476 | Ratio μ: 0.9998 | Ent: 0.6142 | Avg norm R: 0.8384 | Avg raw R: -0.0355
# Iteration: 15
#
# [Train] Iter 16/20 | Actor: -0.0073 | Critic: 0.1436 | KL: 0.00328 | Ratio μ: 1.0029 | Ent: 0.6142 | Avg norm R: 0.8392 | Avg raw R: -0.0344
# Iteration: 16
#
# [Train] Iter 17/20 | Actor: -0.0041 | Critic: 0.1424 | KL: 0.00199 | Ratio μ: 1.0034 | Ent: 0.6142 | Avg norm R: 0.8392 | Avg raw R: -0.0344
# Iteration: 17
#
# [Train] Iter 18/20 | Actor: -0.0049 | Critic: 0.1457 | KL: 0.00946 | Ratio μ: 0.9965 | Ent: 0.6142 | Avg norm R: 0.8382 | Avg raw R: -0.0357
# Iteration: 18
#
# [Train] Iter 19/20 | Actor: -0.0037 | Critic: 0.1500 | KL: 0.00734 | Ratio μ: 0.9979 | Ent: 0.6142 | Avg norm R: 0.8399 | Avg raw R: -0.0335
# Iteration: 19
#
# [Train] Iter 20/20 | Actor: -0.0035 | Critic: 0.1493 | KL: 0.01042 | Ratio μ: 0.9985 | Ent: 0.6142 | Avg norm R: 0.8383 | Avg raw R: -0.0357
# [Eval] Iteration 99: Average reward = -1.202

# %%
# Ensure the agent has training data
if hasattr(ppo_agent, "actor_losses"):
    fig, axs = plt.subplots(3, 1, figsize=(10, 10))

    # Actor Loss
    axs[0].plot(ppo_agent.actor_losses, label='Actor Loss', color='tab:blue')
    axs[0].set_title('Actor Loss over Training')
    axs[0].set_xlabel('Iteration')
    axs[0].set_ylabel('Loss')
    axs[0].legend()
    axs[0].grid(True)

    # Critic Loss
    axs[1].plot(ppo_agent.critic_losses, label='Critic Loss', color='tab:orange')
    axs[1].set_title('Critic Loss over Training')
    axs[1].set_xlabel('Iteration')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    axs[1].grid(True)

    # Rewards
    axs[2].plot(ppo_agent.episode_raw_rewards, label='Raw Reward', color='tab:red')
    axs[2].set_title('Average Raw Reward per Rollout')
    axs[2].set_xlabel('Iteration')
    axs[2].set_ylabel('Reward')
    axs[2].legend()
    axs[2].grid(True)

    plt.tight_layout()
    plt.show()
else:
    print("No training data found. Run ppo_agent.train() first.")

# %% [markdown]
# # **Conclusions**
#
# Now you have everything you need to start training an effective agent.
#
# To proceed further, you can change the hyperparameters, write new functions to keep track of the training process, and produce informative graphs that can help you understand what is going on behind the curtains of the model. \
# To double check the code you just wrote, try to train and evaluate the agent on a single day (i.e., using the same data of 1 single day for both training and evaluation). This is a very simple task, hence your agent is supposed to behave well without too many difficulties. For example, try with day number 100. With that day, your agent should be able to achieve a daily total reward that is at least greater than -0.4 (when using a 4kW, 8kWh battery). \
# Keep in mind that the algorithm will require some time to get trained. Don't give up on a parameter setting after only a bunch of minutes of training. Sometimes the agent might just need some extra episodes of training to start getting some sense of its actions.
#
# **Your final agent needs to be saved using the methods we provided you. The agent you will upload will be evaluated on a private dataset taken out of the data we gave you, and the results will influence the score of your assignment.**
#
# Whatever extra code you think you will need to train the agent, please write it below. \
# **Moreover, we prepared a set of questions and tasks for you. These are part of your assignment evaluation.**

# %%
# Save the trained agent
ppo_agent.save_agent()
print("Agent saved successfully to 'actor.pickle'")
# Out:
# Agent saved successfully to 'actor.pickle'

# %% [markdown]
# ### **Question 0**
#
# As explained before, we ask you to train your agent by working with normalize states, actions, and rewards by scaling their original value in more contained domain ([0, 1] or [-1, 1]). Can you reflect on this, giving your thoughts on why this should be (or should not be) done?
#
# Write you brief considerations below: \
# Normalization is very important for PPO and should definitely be done. Without it, some state values might be very large (like 1000) while others are tiny (like 0.01), which confuses the neural network and makes learning unstable. The network's optimizer struggles when values have different scales because it uses the same learning rate for everything. Normalizing rewards is especially critical because PPO's clipping mechanism and advantage calculations assume rewards are on a reasonable scale - otherwise you get exploding or vanishing gradients. It also makes your hyperparameters work across different environments instead of needing to retune everything each time. The main downside is you lose some interpretability since normalized rewards don't have their original meaning anymore, but the stability and speed improvements are worth it. In practice, normalizing to ranges like [-1, 1] or [0, 1] helps PPO learn much faster and more reliably.

# %% [markdown]
# ### **Question 1**
# Coming out with good hyperparameters is not straightforward. Can you make a list below of the **most important** hyperparameters you had to choose to obtain better results? Give brief intuitions for each. If needed, you can back it up with evaluation results.
#
#
# - num_batches (128): fixed to 128 for better sample efficiency. More episodes per rollout provide more diverse experiences and better gradient estimates. This is particularly important for energy management where different days have varying PV/consumption patterns. However, too many batches increases computation time without proportional benefits.
# - sampling_variance (0.2): fixed to 0.2 for moderate exploration. Higher values (e.g., 0.3-0.4) provide more exploration but can destabilize training, while lower values (e.g., 0.1) reduce exploration and may cause the policy to get stuck in local optima. For energy management, we need enough exploration to discover good charging/discharging strategies while maintaining stability.
# - critic_lr (1e-3): Set higher than actor_lr (1e-3 vs 3e-4) because value estimation is generally easier than policy optimization. The critic needs to learn faster to provide accurate advantage estimates for the actor. Too low critic learning rates (e.g., 1e-5) result in poor value estimates, leading to noisy advantages and slower policy learning.

# %% [markdown]
# ### **Question 2:**
# When training an RL agent (or whatever Machine Learning model), a crucial step is to track the learning. Can you produce some informative graphs that tells you how is the training going? What observation can you draw from those?
#
# Can you think of some other insightful graphs / information about the agent? For example, what kind of extra metric can you keep track of? Here are some examples:
# - Probability ratio of the actions during training
# - KL divergence of the policy before and after each training step
#
# Briefly explain what you did and why here:
#
# When training an RL agent, tracking learning dynamics is essential. We added:
# - Actor/Critic losses per iteration (optimization progress)
# - Avg normalized/raw rewards per rollout (learning signal)
# - Approx KL(old‖new) and probability ratio mean±std (policy update size/stability)
# - Policy entropy (exploration)
#
# Observations (typical/expected):
# - As training stabilizes, KL stays small (near 0) and ratios cluster near 1 due to PPO clipping.
# - Rewards trend upward if learning; large oscillations often correlate with large KL/ratios.
# - Entropy decays as policy becomes confident; adding entropy regularization slows this decay to avoid premature collapse.
#
# Why these metrics: PPO’s trust-region behavior is governed by clipped ratios/implicit KL. Monitoring them catches overly aggressive updates and guides tuning of `clip_value`, learning rates, and entropy strength.

# %%
# Training graphs

if hasattr(ppo_agent, "actor_losses") and len(ppo_agent.actor_losses) > 0:
    fig, axs = plt.subplots(3, 2, figsize=(14, 12))

    # Losses
    axs[0, 0].plot(ppo_agent.actor_losses, label='Actor Loss', color='tab:blue')
    axs[0, 0].set_title('Actor Loss')
    axs[0, 0].set_xlabel('Iteration')
    axs[0, 0].grid(True)

    axs[0, 1].plot(ppo_agent.critic_losses, label='Critic Loss', color='tab:orange')
    axs[0, 1].set_title('Critic Loss')
    axs[0, 1].set_xlabel('Iteration')
    axs[0, 1].grid(True)

    # Rewards (raw and normalized)
    axs[1, 0].plot(ppo_agent.episode_norm_rewards, label='Avg Norm Reward', color='tab:green')
    axs[1, 0].set_title('Avg Normalized Reward per Rollout')
    axs[1, 0].set_xlabel('Iteration')
    axs[1, 0].grid(True)

    axs[1, 1].plot(ppo_agent.episode_raw_rewards, label='Avg Raw Reward', color='tab:red')
    axs[1, 1].set_title('Avg Raw Reward per Rollout')
    axs[1, 1].set_xlabel('Iteration')
    axs[1, 1].grid(True)

    # KL and probability ratio stats
    if hasattr(ppo_agent, 'kl_divergences') and len(ppo_agent.kl_divergences) > 0:
        axs[2, 0].plot(ppo_agent.kl_divergences, color='tab:purple')
        axs[2, 0].set_title('Approx KL(old||new)')
        axs[2, 0].set_xlabel('Update Step (appended during training)')
        axs[2, 0].grid(True)

    if hasattr(ppo_agent, 'prob_ratio_means') and len(ppo_agent.prob_ratio_means) > 0:
        ratios_mu = np.array(ppo_agent.prob_ratio_means)
        ratios_std = np.array(ppo_agent.prob_ratio_stds)
        axs[2, 1].plot(ratios_mu, label='ratio mean', color='tab:blue')
        axs[2, 1].fill_between(np.arange(len(ratios_mu)), ratios_mu - ratios_std, ratios_mu + ratios_std, color='tab:blue', alpha=0.2)
        axs[2, 1].axhline(1.0, color='k', linestyle='--', linewidth=1)
        axs[2, 1].set_title('Probability Ratio (mean ± std)')
        axs[2, 1].set_xlabel('Update Step (appended during training)')
        axs[2, 1].grid(True)

    plt.tight_layout()
    plt.show()

    # Entropy trace (separate figure)
    if hasattr(ppo_agent, 'entropies') and len(ppo_agent.entropies) > 0:
        plt.figure(figsize=(7,4))
        plt.plot(ppo_agent.entropies, color='tab:gray')
        plt.title('Policy Entropy')
        plt.xlabel('Update Step (appended during training)')
        plt.grid(True)
        plt.show()
else:
    print("No training data found. Run ppo_agent.train() first.")

# %% [markdown]
# ### **Question 3:**
#
# When using RL on a given problem, **you** also need to understand what the problem is about. Following that, it is important to keep track of the agent's performance by not only checking its numerical metrics (e.g., the obtained daily rewards), but also by checking if its actions make sense in the first place. To do so, plotting the policies obtained on a limited interval of time (e.g., a single day) is crucial. Can you write a function that does that? What observations / conclusions can you draw when you plot the agent policies?
#
# Can you also think of additional way you can plot the policy without specifically referring to any specific day? In other words, can you generate a plot that describes the general behavior of the learnt policy in relation to some state inputs (not necessarily from the actual dataset; they could be artificially made just for the sake of the plot)?
#
# Briefly explain your observations here:
#
# We added two plots:
# - Per-day greedy policy: action (kW), SoC, price, PV, and load over a single day.
# - Policy heatmap (SoC×Price): greedy action (kW) over a grid with fixed time and PV/load.
#
# Observations (expected when trained well):
# - Charge at low prices (especially with low SoC and PV surplus), discharge at high prices; SoC stays within bounds.
# - Heatmap shows a monotone structure: higher prices push toward discharge; at very low SoC the policy avoids over-discharge, and at high SoC/low prices it prefers charging.
#
# These views validate whether the learned policy aligns with domain intuition (time-of-day price peaks, PV midday production, SoC safety).

# %%
# Policy graphs

from typing import List, Tuple

def plot_policy_for_day(day_index: int):
    """Plot greedy actions and environment signals for a single day."""
    env.reset(day_index)
    T = 24
    hours = []
    actions_kw = []
    socs = []
    prices = []
    pvs = []
    loads = []

    while not env.done:
        state = env.state
        action_norm, _ = ppo_agent.sample_action(state, explore=False)
        action_kw = env.descale_action(action_norm.item())
        next_state, reward, done, _ = env.step(action_kw)

        hours.append(state[0])
        actions_kw.append(action_kw)
        socs.append(state[1])
        prices.append(state[2])
        pvs.append(state[3])
        loads.append(state[4])

    fig, axs = plt.subplots(3, 1, figsize=(12, 10), sharex=True)

    axs[0].plot(hours, actions_kw, label='Action (kW)', color='tab:blue')
    axs[0].axhline(0, color='k', linewidth=1)
    axs[0].set_ylabel('kW')
    axs[0].set_title(f'Greedy Policy on Day {day_index}')
    axs[0].grid(True)

    axs[1].plot(hours, socs, label='SoC', color='tab:green')
    axs[1].set_ylabel('State of Charge')
    axs[1].set_ylim(0, 1)
    axs[1].grid(True)

    ax2 = axs[2]
    ax2.plot(hours, prices, label='Price (€/kWh)', color='tab:red')
    ax2.set_ylabel('Price')
    ax2b = ax2.twinx()
    ax2b.plot(hours, pvs, label='PV (kW)', color='tab:orange', alpha=0.7)
    ax2b.plot(hours, loads, label='Load (kW)', color='tab:purple', alpha=0.7)
    ax2.set_xlabel('Hour')
    ax2.grid(True)

    # Legends
    lines1, labels1 = ax2.get_legend_handles_labels()
    lines2, labels2 = ax2b.get_legend_handles_labels()
    axs[2].legend(lines1 + lines2, labels1 + labels2, loc='upper right')

    plt.tight_layout()
    plt.show()


def plot_policy_heatmap_soc_price(t_hour: int = 12, pv_kw: float = 0.0, load_kw: float = 0.0,
                                  soc_points: int = 41, price_points: int = 41):
    """Heatmap of action (kW) over SoC × Price grid, with fixed time and PV/Load."""
    soc_grid = np.linspace(0.0, 1.0, soc_points)
    price_grid = np.linspace(0.0, env.max_price, price_points)

    action_grid = np.zeros((soc_points, price_points))
    for i, soc in enumerate(soc_grid):
        for j, price in enumerate(price_grid):
            state = [t_hour, float(soc), float(price), float(pv_kw), float(load_kw)]
            action_norm, _ = ppo_agent.sample_action(state, explore=False)
            action_grid[i, j] = env.descale_action(action_norm.item())

    plt.figure(figsize=(10, 6))
    im = plt.imshow(action_grid, origin='lower', aspect='auto',
                    extent=[price_grid[0], price_grid[-1], soc_grid[0], soc_grid[-1]],
                    cmap='coolwarm')
    plt.colorbar(im, label='Action (kW)')
    plt.xlabel('Price (€/kWh)')
    plt.ylabel('SoC')
    plt.title(f'Policy Heatmap (t={t_hour}h, PV={pv_kw} kW, Load={load_kw} kW)')
    plt.show()

# Example usage (uncomment to run after training):
plot_policy_for_day(day_index=train_set_indexes[0])
plot_policy_heatmap_soc_price(t_hour=12, pv_kw=0.0, load_kw=0.0)

# %% [markdown]
# ### **Question 4.1:**
#
# PPO stands in the RL algorithm family of policy gradients methods. These differ from value-based methods such as Deep Q-Network (DQN) in the way the agent obtain the actions.
# Policy gradient methods have an actor model that directly returns an action after processing an input state. In value-based methods, instead, the actor processes the input state to approximate the Q-function (or the value function) of the problem; the action is then selected based on the approximated Q-function values (for example by argmaxing each Q values). \
# Specifically thinking about this problem (home energy management), can you reflect on what major advantages/disadvantages one algorithmic family brings over the other?
#
# Briefly explain your observations here:
# - Policy gradients (PPO): handle continuous actions naturally (kW setpoint), optimize stochastic policies directly, and can incorporate action constraints via squashing functions. Downsides: higher variance in gradient estimates, sensitivity to reward scaling and hyperparameters.
# - Value-based (e.g., DQN): simple and data-efficient for discrete actions, but need discretization for kW which introduces suboptimality and brittle behavior, or more complex variants (DDPG/SAC) for continuous actions.
# - For HEM: continuous control with safety/SoC limits favors policy gradients; PPO’s clipping provides stable updates under nonstationary price/PV signals. If discretized, DQN can miss fine control necessary to track price signals and battery limits.

# %% [markdown]
# ### **Question 4.2:**
#
# In this assignment, you used 2 neural networks as models for both the critic and actor. This is a choice we made when designing this assignment, but it is not mandatory. Other regression architectures/models could have been used. Can you think of any specific reason why we would want to use a different model?  Write some considerations regarding this, with specific focus on the actor model.
#
# Briefly explain your observations here:
#
# Reasons to consider alternatives to plain MLPs for the actor:
# - Inductive bias: Temporal structure (hourly cycles) could benefit from sequence models (GRU/Transformer) or Fourier features.
# - Constraints: Policies with action-feasibility layers (e.g., differentiable clipping/saturation penalties) or energy-aware architectures that encode SoC dynamics.
# - Data efficiency: Smaller/tabular regimes could use linear models with engineered features; conversely, convolution over time-of-day embeddings can improve generalization across hours.
# - Stability: Squashed Gaussian policy with state-dependent variance (learnable log-std) may adapt exploration better than fixed covariance.

# %% [markdown]
# ### **Question 5:**
#
# One of the benefits of implementing an algorithm from scratch (besides the obvious one of understanding more deeply what the algorithm is about) is the total control over the code you just wrote. This enables you to customize your code to, for example, gain informative insights regarding the algorithm dynamics.
# There are a few things you can implement in your PPO code to potentially improve its performance. Here we give you some suggestions, but feel free to also check online sources to take additional inspiration.
# - Entropy regularization
# - Generalized Advantage Estimation (check [paper](https://arxiv.org/pdf/1506.02438))
# - Learnable sampling variance
# - Mini-batch partition fo the rollout data when training
# - Learning Rate Annealing
#
# Can you implement some of these additional features and report their value over the agent training phase? You do not have to implement them all, but even if you do, **please report only 1 or 2 of them**. \
# Make a complete report of what differences you noticed using or not using the additional feature you implemented. Consider it as a mini scientific report.
#
# ... \
# ... \
# ... \

# %% [markdown]
# """
# ### Implemented features report (Question 5)
#
# - Feature: Entropy regularization (`entropy_coef=0.01`).
# - Rationale: Maintain exploration early; prevent premature policy collapse; stabilize updates.
# - Implementation: Added `-entropy_coef * H(π)` to actor loss, logged entropy; exposed `entropy_coef` in hyperparameters.
#
# Expected effects:
# - Early: higher entropy, smoother reward gains, reduced oscillations in KL/ratios.
# - Later: entropy decays but stays > 0; policy remains adaptable; improved reward stability.
# - Tuning: too high slows learning; too low collapses exploration. Try {0.0, 0.005, 0.01, 0.02} and compare reward/entropy/KL curves.
#
# Possible extensions (not implemented here): GAE for lower-variance advantages; mini-batch updates; learnable log-std for state-dependent exploration; LR annealing.
# """
