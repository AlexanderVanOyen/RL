# %% [markdown]
# # Assignment 1: Deep Q-Networks (DQN) with [PufferLib Ocean Environments](https://puffer.ai/ocean.html)

# %% [markdown]
# *This assignment must be completed solely by the members of your group. Sharing of code between groups is strictly prohibited. However, you are allowed to discuss general solution approaches or share publicly available resources with members of other groups. Therefore, clearly indicate which public resources you consulted and/or copied code from. Any plagiarism between groups will result in the initiation of a fraud procedure with the director of education.*

# %% [markdown]
# ## Overview
#
# In this notebook, your group will implement a fully vectorized Deep Q-Network (DQN) agent and several of its key improvements, inspired by the ["Rainbow"](https://arxiv.org/abs/1710.02298) paper. The project is divided into a foundational group task followed by individual implementation of specific DQN extensions. Your goal is to compare the performance of these components and then combine them into the ultimate rainbow-lite agent.
#
# ### Project Structure:
# 1.  **Foundational (Group Task):** The entire group will first collaborate to right the necessary code to  make simple DQN work.
# 2.  **Individual Extensions:** Once the baseline is complete, each group member will be assigned one of the following algorithmic extensions to implement:
#     *   **Extension A:** Double DQN & Dueling DQN (Architectural Improvements)
#     *   **Extension B:** Prioritized Experience Replay (PER) (Advanced Sampling)
#     *   **Extension C:** N-Step Returns & Noisy Networks (Target & Exploration Improvements)
# 3.  **Analysis (Group Task):** The group will integrate all components, run a comparative analysis on the `breakout` environment, and collaboratively answer the conceptual and reflection questions in a final report.
#
# Cells with `TODO` indicate where you must add or adjust code. However feel free to modify any part of the code to improve clarity, efficiency, or performance. You are encouraged to experiment with hyperparameters and other design choices to optimize your agent's learning.
#
# ---
#
# ### Environment Tiers:
# You will use three types of environments from `pufferlib.ocean`:
# 1.  **Debug:** `squared` (fast iterations; verify your code  is correct, your agent should learn within seconds and become optimal around 2 minutes, max episode score is 1).
# 2.  **Comparing:** `cartpole` (fast iterations; verify your extensions and evaluate the agent, learning signs should be clear within 2 minutes but optimal agent could take 30+ minutes, max episode score is 199).
# 3. **Challenge:** `breakout` (focus on performance, and diagnostics, an optimal agent can take multiple hours, you will get bonus points if you find an optimal agent in this environment, max episode score is 864).
#
# You are allowed to experiment with other environments from `pufferlib.ocean` if you wish, but the above three are mandatory.
#
# ---
#
# ### Report
# We expect you to write the report in a separate document and submit both the notebook and the report on Ufora. Remember that a plot often tells more than a thousand words. When you explain somethings or you show your results, try to add figures to accompany the text. Go beyond just souly describing what you did or how the techniques work but additionally, share your observations, reflect on why things turned out the way they did, and help us understand the story behind your findings.
#
# The report has a soft limit of 8 pages. You are welcome to go over this limit if you keep your writing concise and make sure any extra content is relevant. If you are highly motivated and want to test many different things, feel free to share your findings as long as you follow the requirements mentioned earlier.
#
# If your group is smaller than 3 people, you can choose to implement more than one extension per person. In that case, please clearly indicate who did what in the report.
#
# **Deadline:** October 26, 2025, 23:59
#
#
# ### Office hours
# We will hold weekly office hours to help you with questions about the assignment. Your are more then welcome between 13:30 and 16:00. We reserved IDLab9 (IGent) for you. If we are not there, you can find us in our offices on the 10th floor (IGent): 200.026 (Elias and Thibault), 200.031 (Ciem).
#
#
# ---
#
# ### Docker
# To ensure a consistent and hassle-free setup, we have prepared a Docker image with all necessary dependencies pre-installed. This is the recommended way to run the notebook to avoid issues with package versions.
#
# You can also use there container more information at [puffertank](https://github.com/PufferAI/PufferTank).
#
# The Docker image is available on Docker Hub:
# *   **Image:** `ciemcornelissen/puffer-notebook:latest`
# *   **URL:** [https://hub.docker.com/r/ciemcornelissen/puffer-notebook](https://hub.docker.com/r/ciemcornelissen/puffer-notebook)
#
# You can use this image in several ways. Below are instructions for three common setups: VS Code (recommended for local use), Deepnote for a cloud-based environment, and locally with classic Jupyter.
#
#
# ### Option 1: Local Development with VS Code
#
# This is the most seamless way to work locally. VS Code's "Dev Containers" extension allows you to open your project folder directly inside the running container, giving you access to a fully integrated terminal, file editor, and Jupyter renderer.
#
# **Prerequisites:**
# *   [Docker Desktop](https://www.docker.com/products/docker-desktop/) installed and running.
# *   [Visual Studio Code](https://code.visualstudio.com/) installed.
# *   The [Dev Containers extension](https://marketplace.visualstudio.com/items?itemName=ms-vscode-remote.remote-containers) installed in VS Code.
#
# **Instructions:**
#
# 1.  **Pull and Run the Container:** Open a terminal in your project directory (where this notebook is located) and run the appropriate command below. **Keep this terminal window open.**
#
#     *   **For Linux, Windows (WSL), and Intel-based Macs:**
#         ```bash
#         docker run -it --rm -p 8888:8888 -v "$(pwd)":/app --name puffer-dev ciemcornelissen/puffer-notebook:latest
#
#     *   **For Apple Silicon (M1/M2/M3) Macs:** You must add the `--platform` flag to emulate the correct architecture.
#         ```bash
#         docker run -it --rm --platform linux/amd64 -p 8888:8888 -v "$(pwd)":/app --name puffer-dev ciemcornelissen/puffer-notebook:latest
#
#     *   *(Note: We use `--name puffer-dev` to give the container an easy-to-find name).*
#
# 2.  **Attach VS Code to the Container:**
#     *   Open VS Code.
#     *   Attach vsual studio code to the running container:
#         1.  Click on the container extension in VS Code.
#         2.  Select **"Attach to Running Container..."**.
#         3.  Choose the container named `puffer-dev`.
#     *   Or open the Command Palette (`Ctrl+Shift+P` on Windows/Linux, `Cmd+Shift+P` on Mac).
#     *   Type and select **"Dev Containers: Attach to Running Container..."**.
#     *   Choose the right container from the list.
#
#
# 3.  **Start Working:** A new VS Code window will open, connected to the container. Click **"Open Folder"** to open your project files. You can now edit code, run the notebook, and use the terminal as if you were running natively inside the correct environment.
#
# **If you can not select a kernel when trying to run code in the notebook then you need to update the jupyter extension of vsc. This can be done by clicking on the extensions tab on the left and searching for jupyter. Then click on the little gear icon and select install a specific version and choose the newest version.**
#
# ### Option 2: Cloud Development with [Deepnote](https://deepnote.com/)
#
# If you prefer not to install Docker locally, you can use Deepnote to run the environment in the cloud.
#
# **Instructions:**
#
# 1.  In your Deepnote project, navigate to the **Environment** tab in the left sidebar at the bottem under machine.
# 2.  Click on the **"Set up a new Docker image"**.
# 3.  In the "Docker image" field, paste the image name:
#     ```
#     ciemcornelissen/puffer-notebook:latest
#
# 4.  Deepnote will pull the image. Once it's ready, you'll be ready to work.
#
#
#
# ### Option 3: Local Development with Classic Jupyter
#
# This method uses the command line to start a Jupyter server, which you access through your web browser.
#
# **Instructions:**
#
# 1.  **Pull the Image:**
#     ```bash
#     docker pull ciemcornelissen/puffer-notebook:latest
#
# 2.  **Run the Container:** Run the command below from your project directory.
#
#     *   **For Linux, Windows (WSL), and Intel-based Macs:**
#         ```bash
#         docker run -it --rm -p 8888:8888 -v "$(pwd)":/app ciemcornelissen/puffer-notebook:latest
#
#     *   **For Apple Silicon (M1/M2/M3) Macs:**
#         ```bash
#         docker run -it --rm --platform linux/amd64 -p 8888:8888 -v "$(pwd)":/app ciemcornelissen/puffer-notebook:latest
#
# 3.  **Access Jupyter:** Your terminal will display a URL (e.g., `http://127.0.0.1:8888/lab?token=...`). Copy and paste this full URL into your web browser to start the notebook. Your files will be in the `/app` directory.
#
#
#
# ### **Important Note for Apple Silicon (M1/M2/M3/M4) Users**
#
# The Docker image is built for the `amd64` (Intel/AMD) architecture. If you are using a Mac with Apple Silicon, you must tell Docker to emulate this architecture by adding the `--platform linux/amd64` flag.
#
# ---

# %% [markdown]
# ## 1.1 Setup

# %%
#when using deepnote and you get the error no module pufferlib run this cell

# try:
#     import __editable___pufferlib_3_0_0_finder as _pf
#     _pf.install()          # registers the module loader
#     import pufferlib
#     print("Loaded:", pufferlib.__file__)
# except Exception as e:
#     print("Failed to manually activate editable hook:", e)

# %%
import random, dataclasses
import math
from dataclasses import dataclass
from typing import List, Optional, Dict, Any
from collections import deque

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt

# Import ocean environments, you can import more if you want to experiment with other envs
from pufferlib.ocean.squared import squared
from pufferlib.ocean.pong import pong
from pufferlib.ocean.pacman import pacman
from pufferlib.ocean.enduro import enduro
from pufferlib.ocean.tetris import tetris
from pufferlib.ocean.breakout import breakout
from pufferlib.ocean.cartpole import cartpole

import gymnasium as gym

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', DEVICE)
# Out:
# Using device: cpu

# %% [markdown]
# ## Understanding PufferLib and Ocean Environments
#
# ### What is [PufferLib](https://puffer.ai/ocean.html)?
#
# **PufferLib** is a high-performance reinforcement learning framework designed to bridge the gap between research and production RL. It was created to address common pain points in RL development:
#
# - **Speed:** PufferLib environments are highly optimized, often running 10-100x faster than traditional implementations
# - **Scalability:** Built-in support for massive parallelization across thousands of environments
# - **Simplicity:** Clean, minimal API that follows Gymnasium standards
# - **GPU-Native:** Environments can run directly on GPU, eliminating CPU-GPU transfer bottlenecks
#
#
# ### PufferLib Ocean: Educational RL Environments
#
# **Ocean** is PufferLib's collection of lightweight, educational environments. The name reflects its purpose: a "sea" of diverse environments for learning and experimentation. Ocean environments are specifically designed for:
#
# 1. **Fast Debugging:** Quickly verify your algorithm works before scaling up
# 2. **Rapid Prototyping:** Test new ideas without waiting hours for results
# 3. **Educational Clarity:** Simpler codebases that are easier to understand and modify
# 4. **Vectorization by Default:** Learn modern RL practices from the start
#
# ### Available Ocean Environments
#
# Ocean includes a variety of environments with different characteristics (more can be found in the [docs](https://github.com/PufferAI/PufferLib/tree/3.0/pufferlib/ocean)):
#
# - **Classic Control:** `cartpole`
#   - Simple physics simulations
#   - Low-dimensional observations
#   - Great for debugging and initial testing
#
# - **Grid Worlds:** `squared`, `minigrid_variants`
#   - Discrete state/action spaces
#   - Fast iteration times
#   - Perfect for verifying algorithm correctness
#
# - **Atari-Style:** `breakout`, `pong`, `pacman`, `enduro`
#   - More complex visual observations
#   - Longer training times
#   - Closer to real-world RL challenges
#
# - **Puzzle Games:** `tetris`
#   - Strategic planning required
#   - Sparse rewards
#   - Advanced challenge tasks
#
# ### Why PufferLib for This Assignment?
#
# We chose PufferLib Ocean for several pedagogical reasons:
#
# 1. **Immediate Feedback:** Fast environments mean you can iterate quickly on your code
# 2. **Realistic Scale:** The environment enables easy vectorized environments like in real RL research
# 3. **Low Hardware Requirements:** Efficient implementation means you don't need expensive GPUs because of vectorised observations
# 4. **Clear Progression:** From simple (Squared) to complex (Breakout) in the same framework
# 5. **Industry Relevance:** PufferLib is used in actual RL research and applications

# %% [markdown]
# ## 1.2 Environment Factories

# %%
class TimeLimitVec:
    """
    Generic vector env time-limit wrapper for PufferLib/Gymnasium-like envs.docker run -it --rm -p 8888:8888 -v "$(pwd)":/app ciemcornelissen/puffer-notebook:latest
    - Marks truncations True when per-env step count reaches max_episode_steps.
    - Preserves existing terminals/truncations from the underlying env.
    - Resets per-env counters on reset or when an env ends.
    """
    def __init__(self, env: Any, max_episode_steps: int, info_key: str = "time_limit"):
        assert max_episode_steps and max_episode_steps > 0
        self.env = env
        self.max_episode_steps = int(max_episode_steps)
        self.info_key = info_key

        # Mirror common attributes for compatibility
        self.single_observation_space = getattr(env, "single_observation_space", None)
        self.single_action_space = getattr(env, "single_action_space", None)
        self.observation_space = getattr(env, "observation_space", None)
        self.action_space = getattr(env, "action_space", None)
        self.num_agents = getattr(env, "num_agents", 1)

        self._steps = np.zeros(self.num_agents, dtype=np.int64)

    def reset(self, seed: Optional[int] = 0):
        obs, infos = self.env.reset(seed)
        self._steps[...] = 0
        return obs, infos

    # def reset(self, seed: Optional[int] = None): 
    #     if seed is None:
    #         seed = random.randint(1, 2**32 - 1)
    #     obs, infos = self.env.reset(seed)
    #     self._steps[...] = 0
    #     return obs, infos


    def step(self, actions):
        obs, rewards, terminals, truncations, infos = self.env.step(actions)

        t = np.asarray(terminals, dtype=bool)
        tr = np.asarray(truncations, dtype=bool)
        if t.ndim == 0:
            t = t.reshape(1)
        if tr.ndim == 0:
            tr = tr.reshape(1)

        active = ~(t | tr)
        # Increment only for envs still active before this step's end flags
        self._steps[active] += 1

        # Apply time limit where not already ended this step
        timeouts = (self._steps >= self.max_episode_steps) & active
        if np.any(timeouts):
            tr = np.logical_or(tr, timeouts)
            self._steps[timeouts] = 0
            if infos is None:
                infos = []
            if not isinstance(infos, list):
                infos = [infos]
            infos.append({self.info_key: {"timeouts": timeouts.copy()}})

        # Also reset counters for any envs that ended naturally
        ended = t | tr
        if np.any(ended):
            self._steps[ended] = 0

        return obs, rewards, t, tr, infos

    def render(self, *args, **kwargs):
        return getattr(self.env, "render")(*args, **kwargs)

    def close(self):
        return getattr(self.env, "close")()
def make_env(name: str, seed: int = 0):
    env_map = {
        'squared': squared,
        'pong': pong,
        'pacman': pacman,
        'enduro': enduro,
        'tetris': tetris,
        'breakout': breakout,
        'cartpole': cartpole
    }
    if name not in env_map:
        raise ValueError(f'Unknown environment {name}')

    def thunk():
        # Get the module from the map
        env_module = env_map[name]

        # For example, in the 'squared' module, there is a 'Squared' class.
        env_class_name = name.capitalize()
        env_class = getattr(env_module, env_class_name)

        raw_env = env_class(num_envs=1, render_mode=None, seed=seed)  # Instantiate the class
        env = TimeLimitVec(raw_env, max_episode_steps=200)
        env.reset(seed=seed)
        return env
    return thunk

debug_env_name = 'squared'
intermediate_env_name = 'cartpole'  # Change to 'pacman', 'enduro', or 'tetris' if desired
challenge_env_name = 'breakout'

test_env = make_env(debug_env_name)()
obs, info = test_env.reset()
print('Debug env observation shape:', np.array(obs).shape)
print('Action space:', test_env.action_space)
print('Observation space:', test_env.observation_space)
# Out:
# Debug env observation shape: (1, 121)
# Action space: MultiDiscrete([5])
# Observation space: Box(0, 1, (1, 121), uint8)

# %% [markdown]
# ## 1.3 Configuration
# Adjust hyperparameters and add hyperparameters as needed.

# %%
@dataclass
class Config:
    seed: int = 7
    gamma: float = 0.99  # prioritize short-term rewards
    lr: float = 5e-4  # can reduce to 1e-4 if unstable
    batch_size: int = 64
    buffer_capacity: int = 100_000  # larger buffer for diverse data
    min_buffer_size: int = 20_000  # start training with more data
    max_steps_per_env: int = 2_000_000
    max_episode_len: int = 1000
    epsilon_start: float = 1.0
    epsilon_end: float = 0.01
    epsilon_decay_steps: int = 500_000
    target_update_interval: int = 2000
    train_freq: int = 4
    gradient_clip: float = 10.0
    reward_clip: Optional[float] = 1.0
    use_double_dqn: bool = False
    use_dueling: bool = False  # enabled for better value estimation
    vector_envs: int = 1
    log_interval_episodes: int = 100
    eval_episodes: int = 10
    curriculum: Optional[List[str]] = None
    hidden_size: int = 512

    # these 5 hyperparameters are used for the PER (prioritized experience replay)
    per_alpha: float = 0.6 
    per_eps: float = 0.01
    per_beta_start: float = 0.4
    per_beta_end: float = 1.0
    per_beta_steps: int = 50_000
    use_per: bool = False
    
    n_steps: int = 1
    use_noisy_layer: bool = False

cfg = Config()
cfg.curriculum = [challenge_env_name]

random.seed(cfg.seed)
np.random.seed(cfg.seed)
torch.manual_seed(cfg.seed)
cfg
# Out:
# Config(seed=7, gamma=0.99, lr=0.0005, batch_size=64, buffer_capacity=100000, min_buffer_size=20000, max_steps_per_env=2000000, max_episode_len=1000, epsilon_start=1.0, epsilon_end=0.01, epsilon_decay_steps=500000, target_update_interval=2000, train_freq=4, gradient_clip=10.0, reward_clip=1.0, use_double_dqn=False, use_dueling=False, vector_envs=1, log_interval_episodes=100, eval_episodes=10, curriculum=['breakout'], hidden_size=512, per_alpha=0.6, per_eps=0.01, per_beta_start=0.4, per_beta_end=1.0, per_beta_steps=50000, use_per=False, n_steps=1, use_noisy_layer=False)

# %% [markdown]
# ## 1.4 Replay Buffer

# %%
# SumTree used to store the transitions used for the prioritized replay buffer

# round up capacity to nearest power of 2 so you always have a full and balanced tree, and makes the implementation slightly easier
def next_power_of_two(x):
    return 1 << (x-1).bit_length()

class SumTree:
    def __init__(self, capacity):
        self.real_capacity = capacity
        self.capacity = next_power_of_two(capacity)
        self.tree = np.zeros(2 * self.capacity - 1, dtype=np.float32)
        self.position = 0

    def add(self, priority):
        tree_idx = self.position + self.capacity - 1
        self.update(tree_idx, priority)
        self.position = (self.position + 1) % self.real_capacity

    def update(self, tree_idx, priority):
        change = priority - self.tree[tree_idx]
        self.tree[tree_idx] = priority
        while tree_idx != 0:
            tree_idx = (tree_idx - 1) // 2
            self.tree[tree_idx] += change

    def get_leaf(self, v):
        parent_idx = 0
        while True:
            left_child = 2 * parent_idx + 1
            right_child = left_child + 1
            if left_child >= len(self.tree):
                leaf_idx = parent_idx
                break
            if v <= self.tree[left_child]:
                parent_idx = left_child
            else:
                v -= self.tree[left_child]
                parent_idx = right_child

        data_idx = leaf_idx - self.capacity + 1
        return leaf_idx, self.tree[leaf_idx], data_idx

    def total_priority(self):
        return self.tree[0]

    def leaf_from_data_idx(self, i: int) -> int:
        return i + self.capacity - 1

    def update_leaf(self, leaf_idx: int, priority: float):
        self.update(leaf_idx, priority)


class PrioritizedReplayBuffer:
    def __init__(self, capacity: int, obs_shape: tuple, device, cfg):
        self.cfg = cfg
        self.capacity = capacity
        self.device = device
        self.obs_shape = obs_shape
        self.position = 0
        self.size = 0
        self.frame = 0
        self.max_priority = 1.0

        # PER hyperparameters from cfg
        self.alpha = cfg.per_alpha
        self.eps   = cfg.per_eps
        self.beta_start = cfg.per_beta_start
        self.beta_end   = cfg.per_beta_end
        self.beta_steps = cfg.per_beta_steps

        self.obs = np.zeros((capacity, *obs_shape), dtype=np.float32)
        self.actions = np.zeros((capacity, 1), dtype=np.int64)
        self.rewards = np.zeros((capacity, 1), dtype=np.float32)
        self.next_obs = np.zeros((capacity, *obs_shape), dtype=np.float32)
        self.dones = np.zeros((capacity, 1), dtype=np.float32)

        self.tree = SumTree(capacity)

    def __len__(self): 
        return self.size

    def _beta(self):
        t = min(1.0, self.frame / float(self.beta_steps))
        return self.beta_start + t * (self.beta_end - self.beta_start)

    def _set_priority_by_data_idx(self, data_idx, prio):
        leaf = self.tree.leaf_from_data_idx(data_idx)
        self.tree.update_leaf(leaf, prio)

    def push(self, obs, action, reward, next_obs, done):
        i = self.position
        self.obs[i] = obs
        self.actions[i, 0] = int(action)
        self.rewards[i, 0] = float(reward)
        self.next_obs[i] = next_obs
        self.dones[i, 0] = float(done)

        self._set_priority_by_data_idx(i, self.max_priority)

        self.position = (self.position + 1) % self.capacity
        self.size = min(self.size + 1, self.capacity)

    def sample(self, batch_size):
        assert self.size >= batch_size, "PER buffer not ready"
        self.frame += 1
        beta = self._beta()

        total = self.tree.total_priority()
        if total <= 1e-12 or not np.isfinite(total):
            idxs = np.random.choice(self.size, batch_size, replace=False)
            probs = np.full((batch_size,), 1.0 / self.size, dtype=np.float32)
            leaf_idx = np.array([self.tree.leaf_from_data_idx(i) for i in idxs], dtype=np.int64)
        else:
            segment = total / batch_size
            leaf_idx, idxs, prios = [], [], []
            for k in range(batch_size):
                v = np.random.uniform(k * segment, (k + 1) * segment)
                leaf, p, di = self.tree.get_leaf(v)
                while di >= self.capacity:  # skip ghost leaves
                    v = np.random.uniform(0.0, total)
                    leaf, p, di = self.tree.get_leaf(v)
                leaf_idx.append(leaf); idxs.append(di); prios.append(p)
            leaf_idx = np.asarray(leaf_idx, dtype=np.int64)
            idxs = np.asarray(idxs, dtype=np.int64)
            probs = np.asarray(prios, dtype=np.float32) / (total + 1e-12)

        N = self.size
        
        safe_probs = np.clip(probs, 1e-6, 1.0)
        w = (N * safe_probs) ** (-beta)
        w = w / (np.max(w) + 1e-6)
        w = w.astype(np.float32).reshape(-1, 1)

        obs = torch.as_tensor(self.obs[idxs], dtype=torch.float32, device=self.device)
        actions = torch.as_tensor(self.actions[idxs], dtype=torch.long, device=self.device)
        rewards = torch.as_tensor(self.rewards[idxs], dtype=torch.float32, device=self.device)
        next_obs = torch.as_tensor(self.next_obs[idxs], dtype=torch.float32, device=self.device)
        dones = torch.as_tensor(self.dones[idxs], dtype=torch.float32, device=self.device)
        is_w = torch.as_tensor(w, dtype=torch.float32, device=self.device)

        return obs, actions, rewards, next_obs, dones, is_w, leaf_idx

    def update_priorities(self, leaf_idx: np.ndarray, td_errors: np.ndarray):
        td = np.abs(np.asarray(td_errors).reshape(-1))
        new_p = (td + self.eps) ** self.alpha
        self.max_priority = max(self.max_priority, float(new_p.max()))
        for li, p in zip(leaf_idx.astype(int), new_p.astype(float)):
            self.tree.update_leaf(li, p)


class ReplayBuffer:
    def __init__(self, capacity: int, obs_shape: tuple, device):
        self.capacity = capacity
        self.device = device
        self.obs_shape = obs_shape
        self.position = 0
        self.size = 0
        
        # Pre-allocate numpy arrays for storage
        self.obs = np.zeros((capacity, *obs_shape), dtype=np.float32)
        self.actions = np.zeros((capacity, 1), dtype=np.int64)  # Shape: (capacity, 1)
        self.rewards = np.zeros((capacity, 1), dtype=np.float32)
        self.next_obs = np.zeros((capacity, *obs_shape), dtype=np.float32)
        self.dones = np.zeros((capacity, 1), dtype=np.float32)
    
    def push(self, obs, action, reward, next_obs, done):
        """Store a transition"""
        self.obs[self.position] = obs
        self.actions[self.position, 0] = action  # Store as scalar in (1,) shaped array
        self.rewards[self.position, 0] = reward
        self.next_obs[self.position] = next_obs
        self.dones[self.position, 0] = float(done)
        
        self.position = (self.position + 1) % self.capacity
        self.size = min(self.size + 1, self.capacity)
    
    def sample(self, batch_size: int):
        """Sample a batch of transitions and convert to PyTorch tensors"""
        indices = np.random.choice(self.size, batch_size, replace=False)
        
        # Convert to tensors - actions will have shape (batch_size, 1)
        obs = torch.FloatTensor(self.obs[indices]).to(self.device)
        actions = torch.LongTensor(self.actions[indices]).to(self.device)  # (batch_size, 1)
        rewards = torch.FloatTensor(self.rewards[indices]).to(self.device)
        next_obs = torch.FloatTensor(self.next_obs[indices]).to(self.device)
        dones = torch.FloatTensor(self.dones[indices]).to(self.device)
        
        return obs, actions, rewards, next_obs, dones
    
    def __len__(self):
        return self.size

# Test ReplayBuffer
print("Testing ReplayBuffer...")
test_buffer = ReplayBuffer(100, (4,), DEVICE)
test_buffer.push(np.array([1,2,3,4]), 0, 1.0, np.array([2,3,4,5]), False)
assert len(test_buffer) == 1, "Buffer should have 1 element"
obs, actions, rewards, next_obs, dones = test_buffer.sample(1)
assert obs.shape == (1, 4), f"Expected shape (1, 4), got {obs.shape}"
print("✓ ReplayBuffer tests passed!")

tree = SumTree(6)
for p in [1, 2, 3, 4, 5, 6, 7]:
    tree.add(p)

print(tree.tree)                # should contain cumulative sums
print("Total:", tree.total_priority())  # -> 10.0

# Try sampling
for _ in range(5):
    v = np.random.uniform(0, tree.total_priority())
    leaf, p, idx = tree.get_leaf(v)
    print(f"v={v:.2f} -> leaf={leaf}, data_idx={idx}, priority={p}")
# Out:
# Testing ReplayBuffer...
# ✓ ReplayBuffer tests passed!
# [27. 16. 11.  9.  7. 11.  0.  7.  2.  3.  4.  5.  6.  0.  0.]
# Total: 27.0
# v=2.06 -> leaf=7, data_idx=0, priority=7.0
# v=21.06 -> leaf=12, data_idx=5, priority=6.0
# v=11.84 -> leaf=9, data_idx=2, priority=3.0
# v=19.53 -> leaf=11, data_idx=4, priority=5.0
# v=26.41 -> leaf=12, data_idx=5, priority=6.0

# %% [markdown]
# ## 1.5 Epsilon Schedule
# Linear decay from start to end over `epsilon_decay_steps`.

# %%
def epsilon_by_step(step: int, cfg: Config) -> float:
    per_step = (cfg.epsilon_start-cfg.epsilon_end)/cfg.epsilon_decay_steps
    if step < cfg.epsilon_decay_steps:
        eps = cfg.epsilon_start - (step*per_step)
    else:
        eps = cfg.epsilon_end
    return eps

print('Epsilon(0)=', epsilon_by_step(0, cfg), 'Epsilon(mid)=', epsilon_by_step(cfg.epsilon_decay_steps//2, cfg), 'Epsilon(end)=', epsilon_by_step(cfg.epsilon_decay_steps*2, cfg))
# Out:
# Epsilon(0)= 1.0 Epsilon(mid)= 0.5049999999999999 Epsilon(end)= 0.01

# %% [markdown]
# ## 1.6 Q-Network Architectures

# %%
class NoisyLinear(nn.Module):
    def __init__(self, in_features: int, out_features: int, sigma_init: float = 0.017):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        
        # Standard weight and bias parameters
        self.weight_mu = nn.Parameter(torch.empty(out_features, in_features))
        self.weight_sigma = nn.Parameter(torch.empty(out_features, in_features))
        self.bias_mu = nn.Parameter(torch.empty(out_features))
        self.bias_sigma = nn.Parameter(torch.empty(out_features))
        
        self.reset_parameters(sigma_init)
    
    def reset_parameters(self, sigma_init: float) -> None:
        # Initialize mean parameters with standard uniform
        std = 1.0 / math.sqrt(self.in_features)
        self.weight_mu.data.uniform_(-std, std)
        self.bias_mu.data.uniform_(-std, std)
        
        # Initialize noise parameters to small constant
        self.weight_sigma.data.fill_(sigma_init)
        self.bias_sigma.data.fill_(sigma_init)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        if self.training:
            # Sample noise and add to parameters
            weight_noise = torch.randn_like(self.weight_sigma)
            bias_noise = torch.randn_like(self.bias_sigma)
            
            weight = self.weight_mu + self.weight_sigma * weight_noise
            bias = self.bias_mu + self.bias_sigma * bias_noise
        else:
            # Use mean parameters without noise
            weight = self.weight_mu
            bias = self.bias_mu
        
        return F.linear(x, weight, bias)

# %%
class MLPQ(nn.Module):
    def __init__(self, obs_dim: int, action_dim: int, dueling=False):
        super().__init__()
        self.hidden_size = cfg.hidden_size  # Typically 128, 256, or 512
        self.dueling = dueling
        self.action_dim = action_dim

        final_layer = (
            NoisyLinear(self.hidden_size, action_dim)
            if cfg.use_noisy_layer
            else nn.Linear(self.hidden_size, action_dim)
        )

        # Shared feature extractor
        self.feature = nn.Sequential(
            nn.Linear(obs_dim, self.hidden_size),
            nn.ReLU(),
            nn.Linear(self.hidden_size, self.hidden_size),
            nn.ReLU(),
        )

        # Define output heads
        if not dueling:
            self.q_head = final_layer
        else:
            self.value_stream = nn.Sequential(
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.ReLU(),
                nn.Linear(self.hidden_size, 1),
            )
            self.advantage_stream = nn.Sequential(
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.ReLU(),
                nn.Linear(self.hidden_size, action_dim),
            )

    def forward(self, x):
        features = self.feature(x)
        if not self.dueling:
            return self.q_head(features)
        else:
            value = self.value_stream(features)
            advantages = self.advantage_stream(features)
            q_values = value + (advantages - advantages.mean(dim=1, keepdim=True))
            return q_values


def build_q_network(env, cfg: Config):
    obs_space = env.single_observation_space
    print('Obs space:', obs_space.shape[0])
    act_space = env.single_action_space
    action_dim = act_space.n
    assert isinstance(act_space, gym.spaces.Discrete), 'DQN requires discrete actions'
    if len(obs_space.shape) == 1:
        return MLPQ(obs_space.shape[0], action_dim, dueling=cfg.use_dueling)


# Quick test on debug env
net_test_env = test_env
test_net = build_q_network(net_test_env, cfg).to(DEVICE)
print(test_net)
# Out:
# Obs space: 121
# MLPQ(
#   (feature): Sequential(
#     (0): Linear(in_features=121, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#   )
#   (q_head): Linear(in_features=512, out_features=5, bias=True)
# )

# %% [markdown]
# ## 1.7 Action Selection
# Standard epsilon-greedy policy. (Later you might incorporate noisy networks or exploration bonuses.)

# %%
@torch.no_grad()
def select_action(q_net, obs, epsilon: float, env):
    if random.random() < epsilon:
        return env.action_space.sample()
    if isinstance(obs, torch.Tensor):
        obs_t = obs.to(DEVICE, dtype=torch.float32, non_blocking=True)
    else:
        obs_t = torch.as_tensor(obs, dtype=torch.float32, device=DEVICE)
    q_vals = q_net(obs_t)
    return int(q_vals.argmax(dim=1).item())

# Test call
dummy_action = select_action(test_net, obs, 1.0, test_env)
print('Random/greedy test action:', dummy_action)
# Out:
# Random/greedy test action: [1]

# %% [markdown]
# ## 1.8 Training Step
# Compute standard DQN loss or Double DQN target if `cfg.use_double_dqn=True`.
#
# Target for vanilla DQN:
# $$ y = r + (1-d) \gamma \max_{a'} Q_{target}(s', a') $$
#
# Double DQN variant:
# $$ a^* = \arg\max_{a'} Q_{online}(s', a') \quad; \quad y = r + (1-d) \gamma Q_{target}(s', a^*) $$

# %%
loss_fn = nn.SmoothL1Loss()

def train_step(q_net, target_net, optimizer, replay: ReplayBuffer, cfg: Config):
    """
    Performs one training step of DQN.
    
    Args:
        q_net: Online Q-network (being trained)
        target_net: Target Q-network (frozen, updated periodically)
        optimizer: Optimizer for q_net
        replay: Replay buffer containing transitions
        cfg: Configuration object
    
    Returns:
        Loss value or None if buffer not ready
    """
    # Don't train until we have enough experiences
    if len(replay) < cfg.min_buffer_size:
        return None
    
    sample = replay.sample(cfg.batch_size)
    if len(sample) == 7:
        obs, actions, rewards, next_obs, dones, is_w, handle_idx = sample
    else:
        obs, actions, rewards, next_obs, dones = sample
        is_w, handle_idx = None, None
        
    q_values = q_net(obs)  # Shape: (batch_size, action_dim)

    q_sa = q_values.gather(1, actions)  # Shape: (batch_size, 1)
    
    # ============= Compute Target Q-values =============
    with torch.no_grad():  # Don't compute gradients for target
        if cfg.use_double_dqn:
            
            # Step 1: Use online network to find best action in next state
            next_q_values_online = q_net(next_obs)  # Shape: (batch_size, action_dim)
            best_actions = next_q_values_online.argmax(dim=1, keepdim=True)  # Shape: (batch_size, 1)
            
            # Step 2: Use target network to evaluate that action
            next_q_values_target = target_net(next_obs)  # Shape: (batch_size, action_dim)
            next_q_value = next_q_values_target.gather(1, best_actions)  # Shape: (batch_size, 1)
            
        else:
            # Vanilla DQN: Use target network for both selection and evaluation
            next_q_values = target_net(next_obs)  # Shape: (batch_size, action_dim)
            next_q_value = next_q_values.max(dim=1, keepdim=True)[0]  # Shape: (batch_size, 1)
            # Note: max returns (values, indices), we take [0] for values
        
        # Compute TD target: y = r + γ * max Q(s', a') * (1 - done)
        # The (1 - dones) term zeros out the next_q_value if episode ended
        target = rewards + (cfg.gamma ** cfg.n_steps) * next_q_value * (1 - dones)  # Shape: (batch_size, 1)

    per_sample_loss = loss_fn(q_sa, target)
    if is_w is not None:
        per_sample_loss = per_sample_loss * is_w
    loss = per_sample_loss.mean()

    optimizer.zero_grad()
    loss.backward()
    nn.utils.clip_grad_norm_(q_net.parameters(), cfg.gradient_clip)
    optimizer.step()

    # update priorities with new TD values
    if handle_idx is not None:
        with torch.no_grad():
            td_errors = (q_sa - target).abs().cpu().numpy()
        replay.update_priorities(handle_idx, td_errors)
    
    return float(loss.item())

# %% [markdown]
# ## 1.9 Reward Processing
# Add optional reward clipping to stabilize training on environments with high or varied reward magnitudes.
#
# If `cfg.reward_clip` is set, clip reward to `[-cfg.reward_clip, cfg.reward_clip]`.

# %%
def process_reward(r: float, cfg: Config):
    if cfg.reward_clip is not None:
        return max(-cfg.reward_clip, min(cfg.reward_clip, r))
    return r

# Quick test
cfg.reward_clip = None  # Set to 1.0 to try clipping later
print('Reward test (no clip):', process_reward(5.0, cfg))
cfg.reward_clip = 1.0
print('Reward test (clip=1.0):', process_reward(5.0, cfg))
cfg.reward_clip = None  # Reset for training; modify if desired
# Out:
# Reward test (no clip): 5.0
# Reward test (clip=1.0): 1.0

# %% [markdown]
# ## 1.10 Evaluation Utilities
# Evaluation runs with greedy policy (`epsilon=0`).

# %%
def evaluate(env_fn, q_net, cfg: Config, episodes: int):
    env = env_fn
    returns = []
    for _ in range(episodes):
        obs, _ = env.reset()
        done = False
        ep_ret = 0
        steps = 0
        while not done and steps < cfg.max_episode_len:
            a = select_action(q_net, obs, 0.0, env)
            obs2, r, terminated, truncated, _ = env.step(a)
            done = terminated or truncated
            ep_ret += r
            obs = obs2
            steps += 1
        returns.append(ep_ret)
    return float(np.mean(returns))

def hard_update(target, source):
    target.load_state_dict(source.state_dict())

print('Eval utility ready.')
# Out:
# Eval utility ready.

# %% [markdown]
# ## 1.11 Training Loop
# We iterate over the environments in.
# Logging per stage:
# - `episode_rewards`
# - `losses`
# - `eps_history`
# - `eval` (periodic greedy evaluation)
#
# Increase `max_steps_per_env` for stronger performance. For quick debugging, you may temporarily reduce it.

# %%
import torch
import torch.optim as optim
import numpy as np
import pandas as pd
import os
import dataclasses

def save_checkpoint(path, q_net, optimizer, cfg, stage_name: str):
    torch.save({
        'model': q_net.state_dict(),
        'optimizer': optimizer.state_dict(),
        'config': dataclasses.asdict(cfg),
        'stage': stage_name,
    }, path)
    print('Saved checkpoint:', path)


# === Training ===
all_stage_logs = {}

q_net = None
target_net = None
optimizer = None
stage_index = 0

# Make directories for outputs
os.makedirs("logs", exist_ok=True)
os.makedirs("checkpoints", exist_ok=True)

for stage_env_name in cfg.curriculum:
    print(f"\n=== Stage {stage_index+1}: {stage_env_name} ===")
    env = make_env(stage_env_name, seed=cfg.seed + stage_index)()
    eval_env = make_env(stage_env_name, seed=cfg.seed + 100 + stage_index)()

    q_net = build_q_network(env, cfg).to(DEVICE)
    # if cfg.use_noisy_layer:
    #     q_net.reset_noise()
    #     target_net.reset_noise()
    target_net = build_q_network(env, cfg).to(DEVICE)
    hard_update(target_net, q_net)
    optimizer = optim.Adam(q_net.parameters(), lr=cfg.lr)

    if cfg.use_per:
        replay = PrioritizedReplayBuffer(
            capacity=cfg.buffer_capacity,
            obs_shape=env.single_observation_space.shape,
            device=DEVICE,
            cfg = cfg
        )
        print("[INFO] Using PrioritizedReplayBuffer")
    else:
        replay = ReplayBuffer(cfg.buffer_capacity, env.single_observation_space.shape, DEVICE)
        print("[INFO] Using uniform ReplayBuffer")

    logs = {
        'episode_rewards': [],
        'losses': [],
        'eps_history': [],
        'eval': [],
    }

    obs, _ = env.reset()
    ep_reward = 0
    ep_steps = 0
    episode_counter = 0
    recent_ep_returns = []
    total_steps = 0

    trajectory_buffer = deque(maxlen=cfg.n_steps)

    print('Starting training...')
    while total_steps < cfg.max_steps_per_env:
        if cfg.use_noisy_layer:
            epsilon = 0.0  # No epsilon-greedy when using noisy networks
        else:
            epsilon = epsilon_by_step(total_steps, cfg)
        action = select_action(q_net, obs, epsilon, env)
        next_obs, reward, terminated, truncated, info = env.step(action)
        reward = process_reward(reward, cfg)
        reward = float(np.asarray(reward).reshape(-1)[0])
        done = bool(np.asarray(terminated).reshape(-1)[0] or np.asarray(truncated).reshape(-1)[0])

        trajectory_buffer.append((obs.copy(), int(action), reward, next_obs.copy(), done))

        # Push n-step transitions once we have enough data
        if len(trajectory_buffer) >= cfg.n_steps:
            # Calculate n-step return
            n_step_reward = 0.0
            for i, (_, _, r, _, _) in enumerate(trajectory_buffer):  # Use 'r' to avoid name collision
                n_step_reward += (cfg.gamma ** i) * r
            
            # Extract first obs/action and last next_obs/done
            first_obs, first_action, _, _, _ = trajectory_buffer[0]  # ✅ Define these variables!
            _, _, _, last_next_obs, last_done = trajectory_buffer[-1]
            
            # Push to replay buffer (only once!)
            replay.push(first_obs, first_action, n_step_reward, last_next_obs, last_done)

        # Handle episode end: push remaining incomplete n-step transitions
        if done:
            # Push any remaining partial n-step returns
            for start_idx in range(1, len(trajectory_buffer)):
                steps_available = len(trajectory_buffer) - start_idx
                n_step_reward = 0.0
                
                for i in range(steps_available):
                    _, _, r, _, _ = trajectory_buffer[start_idx + i]
                    n_step_reward += (cfg.gamma ** i) * r
                
                first_obs, first_action, _, _, _ = trajectory_buffer[start_idx]
                _, _, _, last_next_obs, last_done = trajectory_buffer[-1]
                
                replay.push(first_obs, first_action, n_step_reward, last_next_obs, last_done)
            
            trajectory_buffer.clear()

        obs = next_obs.copy()
        ep_reward += reward
        ep_steps += 1
        total_steps += 1

        # Training
        if total_steps % cfg.train_freq == 0:
            loss = train_step(q_net, target_net, optimizer, replay, cfg)
            if loss is not None:
                logs['losses'].append(loss)

        # Target update
        if total_steps % cfg.target_update_interval == 0:
            hard_update(target_net, q_net)

        logs['eps_history'].append(epsilon)

        if done or ep_steps >= cfg.max_episode_len:
            logs['episode_rewards'].append(ep_reward)
            recent_ep_returns.append(ep_reward)
            episode_counter += 1

            # --- DEBUG PRINT ---
            mean_loss = np.mean(logs['losses'][-100:]) if logs['losses'] else 0.0
            mean_reward = np.mean(recent_ep_returns[-cfg.log_interval_episodes:]) if recent_ep_returns else 0.0
            with torch.no_grad():
                q_sample = q_net(torch.FloatTensor(obs).unsqueeze(0).to(DEVICE))
                mean_q = q_sample.mean().item()
            grads = [p.grad.norm().item() for p in q_net.parameters() if p.grad is not None]
            grad_norm = np.mean(grads) if grads else 0.0
            print(f"[DEBUG] Step {total_steps:6d} | Ep {episode_counter:4d} | "
                  f"Eps {epsilon:.3f} | MeanReward(10ep): {mean_reward:7.3f} | "
                  f"MeanLoss(100it): {mean_loss:8.5f} | "
                  f"MeanQ: {mean_q:7.3f} | GradNorm: {grad_norm:7.4f}")

            if episode_counter % cfg.log_interval_episodes == 0:
                mean_recent = np.mean(recent_ep_returns[-cfg.log_interval_episodes:])
                print(f"[{stage_env_name}] Ep {episode_counter} Steps {total_steps} "
                      f"RecentMean {mean_recent:.2f} Eps {epsilon:.3f}")

            obs, _ = env.reset()
            ep_reward = 0
            ep_steps = 0

            # Periodic evaluation (every 2*log_interval episodes if we have progress)
            if episode_counter % (cfg.log_interval_episodes * 2) == 0:
                eval_ret = evaluate(eval_env, q_net, cfg, cfg.eval_episodes)
                logs['eval'].append((total_steps, eval_ret))
                print(f"Eval @ Ep {episode_counter} and {total_steps} steps => mean return {eval_ret:.2f}")

    # --- Save logs and model after each stage ---
    all_stage_logs[stage_env_name] = logs

    # Save training logs
    df = pd.DataFrame({
        'episode_rewards': logs['episode_rewards'],
        'losses': logs['losses'][:len(logs['episode_rewards'])],
        'eps_history': logs['eps_history'][:len(logs['episode_rewards'])],
    })
    train_csv = f"logs/{stage_env_name}_training_log_base.csv"
    df.to_csv(train_csv, index=False)
    print(f"Saved training data → {train_csv}")

    # Save evaluation results
    eval_df = pd.DataFrame(logs['eval'], columns=['total_steps', 'eval_return'])
    eval_csv = f"logs/{stage_env_name}_eval_log_base.csv"
    eval_df.to_csv(eval_csv, index=False)
    print(f"Saved eval data → {eval_csv}")

    # Save model checkpoint
    checkpoint_path = f"checkpoints/{stage_env_name}_final_base.pth"
    save_checkpoint(checkpoint_path, q_net, optimizer, cfg, stage_env_name)

    stage_index += 1
# Out:
# === Stage 1: breakout ===
# Obs space: 118
# Obs space: 118
# [INFO] Using uniform ReplayBuffer
# Starting training...
# [DEBUG] Step    141 | Ep    1 | Eps 1.000 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step    257 | Ep    2 | Eps 0.999 | MeanReward(10ep):   0.500 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step    373 | Ep    3 | Eps 0.999 | MeanReward(10ep):   0.333 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step    515 | Ep    4 | Eps 0.999 | MeanReward(10ep):   0.500 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step    695 | Ep    5 | Eps 0.999 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step    942 | Ep    6 | Eps 0.998 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step   1058 | Ep    7 | Eps 0.998 | MeanReward(10ep):   0.857 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   1238 | Ep    8 | Eps 0.998 | MeanReward(10ep):   0.875 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step   1391 | Ep    9 | Eps 0.997 | MeanReward(10ep):   0.889 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   1507 | Ep   10 | Eps 0.997 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   1659 | Ep   11 | Eps 0.997 | MeanReward(10ep):   0.909 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   1792 | Ep   12 | Eps 0.996 | MeanReward(10ep):   0.917 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   1949 | Ep   13 | Eps 0.996 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   2065 | Ep   14 | Eps 0.996 | MeanReward(10ep):   0.929 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   2219 | Ep   15 | Eps 0.996 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   2335 | Ep   16 | Eps 0.995 | MeanReward(10ep):   0.938 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   2451 | Ep   17 | Eps 0.995 | MeanReward(10ep):   0.882 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   2567 | Ep   18 | Eps 0.995 | MeanReward(10ep):   0.833 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   2683 | Ep   19 | Eps 0.995 | MeanReward(10ep):   0.789 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   2863 | Ep   20 | Eps 0.994 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step   2979 | Ep   21 | Eps 0.994 | MeanReward(10ep):   0.762 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   3171 | Ep   22 | Eps 0.994 | MeanReward(10ep):   0.818 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   3313 | Ep   23 | Eps 0.993 | MeanReward(10ep):   0.826 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   3447 | Ep   24 | Eps 0.993 | MeanReward(10ep):   0.833 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   3673 | Ep   25 | Eps 0.993 | MeanReward(10ep):   0.920 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   3789 | Ep   26 | Eps 0.992 | MeanReward(10ep):   0.885 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   3925 | Ep   27 | Eps 0.992 | MeanReward(10ep):   0.889 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   4041 | Ep   28 | Eps 0.992 | MeanReward(10ep):   0.857 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   4157 | Ep   29 | Eps 0.992 | MeanReward(10ep):   0.828 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   4371 | Ep   30 | Eps 0.991 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step   4487 | Ep   31 | Eps 0.991 | MeanReward(10ep):   0.871 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   4667 | Ep   32 | Eps 0.991 | MeanReward(10ep):   0.906 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   4783 | Ep   33 | Eps 0.991 | MeanReward(10ep):   0.879 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   4899 | Ep   34 | Eps 0.990 | MeanReward(10ep):   0.853 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   5015 | Ep   35 | Eps 0.990 | MeanReward(10ep):   0.829 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   5131 | Ep   36 | Eps 0.990 | MeanReward(10ep):   0.806 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   5247 | Ep   37 | Eps 0.990 | MeanReward(10ep):   0.784 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   5363 | Ep   38 | Eps 0.989 | MeanReward(10ep):   0.763 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   5479 | Ep   39 | Eps 0.989 | MeanReward(10ep):   0.744 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   5595 | Ep   40 | Eps 0.989 | MeanReward(10ep):   0.725 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   5728 | Ep   41 | Eps 0.989 | MeanReward(10ep):   0.732 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   5869 | Ep   42 | Eps 0.988 | MeanReward(10ep):   0.738 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   6002 | Ep   43 | Eps 0.988 | MeanReward(10ep):   0.744 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   6136 | Ep   44 | Eps 0.988 | MeanReward(10ep):   0.750 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   6252 | Ep   45 | Eps 0.988 | MeanReward(10ep):   0.733 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   6368 | Ep   46 | Eps 0.987 | MeanReward(10ep):   0.717 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   6484 | Ep   47 | Eps 0.987 | MeanReward(10ep):   0.702 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   6600 | Ep   48 | Eps 0.987 | MeanReward(10ep):   0.688 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   6716 | Ep   49 | Eps 0.987 | MeanReward(10ep):   0.673 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   6858 | Ep   50 | Eps 0.986 | MeanReward(10ep):   0.680 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   6974 | Ep   51 | Eps 0.986 | MeanReward(10ep):   0.667 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   7230 | Ep   52 | Eps 0.986 | MeanReward(10ep):   0.712 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   7427 | Ep   53 | Eps 0.985 | MeanReward(10ep):   0.755 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step   7587 | Ep   54 | Eps 0.985 | MeanReward(10ep):   0.778 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step   7703 | Ep   55 | Eps 0.985 | MeanReward(10ep):   0.764 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   7844 | Ep   56 | Eps 0.984 | MeanReward(10ep):   0.768 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   7960 | Ep   57 | Eps 0.984 | MeanReward(10ep):   0.754 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   8115 | Ep   58 | Eps 0.984 | MeanReward(10ep):   0.759 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   8316 | Ep   59 | Eps 0.984 | MeanReward(10ep):   0.780 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step   8452 | Ep   60 | Eps 0.983 | MeanReward(10ep):   0.783 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   8568 | Ep   61 | Eps 0.983 | MeanReward(10ep):   0.770 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   8684 | Ep   62 | Eps 0.983 | MeanReward(10ep):   0.758 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   8819 | Ep   63 | Eps 0.983 | MeanReward(10ep):   0.762 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step   8987 | Ep   64 | Eps 0.982 | MeanReward(10ep):   0.781 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   9129 | Ep   65 | Eps 0.982 | MeanReward(10ep):   0.785 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   9263 | Ep   66 | Eps 0.982 | MeanReward(10ep):   0.788 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   9379 | Ep   67 | Eps 0.981 | MeanReward(10ep):   0.776 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   9521 | Ep   68 | Eps 0.981 | MeanReward(10ep):   0.779 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   9637 | Ep   69 | Eps 0.981 | MeanReward(10ep):   0.768 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   9753 | Ep   70 | Eps 0.981 | MeanReward(10ep):   0.757 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step   9976 | Ep   71 | Eps 0.980 | MeanReward(10ep):   0.789 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step  10092 | Ep   72 | Eps 0.980 | MeanReward(10ep):   0.778 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  10208 | Ep   73 | Eps 0.980 | MeanReward(10ep):   0.767 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  10386 | Ep   74 | Eps 0.979 | MeanReward(10ep):   0.797 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  10520 | Ep   75 | Eps 0.979 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  10726 | Ep   76 | Eps 0.979 | MeanReward(10ep):   0.816 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step  10932 | Ep   77 | Eps 0.978 | MeanReward(10ep):   0.831 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step  11048 | Ep   78 | Eps 0.978 | MeanReward(10ep):   0.821 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  11164 | Ep   79 | Eps 0.978 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  11280 | Ep   80 | Eps 0.978 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  11396 | Ep   81 | Eps 0.977 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  11530 | Ep   82 | Eps 0.977 | MeanReward(10ep):   0.793 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  11750 | Ep   83 | Eps 0.977 | MeanReward(10ep):   0.819 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  11892 | Ep   84 | Eps 0.976 | MeanReward(10ep):   0.821 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  12026 | Ep   85 | Eps 0.976 | MeanReward(10ep):   0.824 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  12219 | Ep   86 | Eps 0.976 | MeanReward(10ep):   0.837 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step  12335 | Ep   87 | Eps 0.976 | MeanReward(10ep):   0.828 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  12478 | Ep   88 | Eps 0.975 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  12594 | Ep   89 | Eps 0.975 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  12845 | Ep   90 | Eps 0.975 | MeanReward(10ep):   0.844 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  13038 | Ep   91 | Eps 0.974 | MeanReward(10ep):   0.868 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  13193 | Ep   92 | Eps 0.974 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  13365 | Ep   93 | Eps 0.974 | MeanReward(10ep):   0.892 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step  13535 | Ep   94 | Eps 0.973 | MeanReward(10ep):   0.904 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  13651 | Ep   95 | Eps 0.973 | MeanReward(10ep):   0.895 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  13786 | Ep   96 | Eps 0.973 | MeanReward(10ep):   0.896 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step  13953 | Ep   97 | Eps 0.972 | MeanReward(10ep):   0.907 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  14106 | Ep   98 | Eps 0.972 | MeanReward(10ep):   0.918 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  14222 | Ep   99 | Eps 0.972 | MeanReward(10ep):   0.909 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  14338 | Ep  100 | Eps 0.972 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [breakout] Ep 100 Steps 14338 RecentMean 0.90 Eps 0.972
# [DEBUG] Step  14454 | Ep  101 | Eps 0.971 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  14634 | Ep  102 | Eps 0.971 | MeanReward(10ep):   0.920 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  14767 | Ep  103 | Eps 0.971 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  14931 | Ep  104 | Eps 0.970 | MeanReward(10ep):   0.940 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  15065 | Ep  105 | Eps 0.970 | MeanReward(10ep):   0.940 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  15206 | Ep  106 | Eps 0.970 | MeanReward(10ep):   0.920 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  15340 | Ep  107 | Eps 0.970 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  15476 | Ep  108 | Eps 0.969 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  15652 | Ep  109 | Eps 0.969 | MeanReward(10ep):   0.950 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  15807 | Ep  110 | Eps 0.969 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  15941 | Ep  111 | Eps 0.968 | MeanReward(10ep):   0.950 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  16155 | Ep  112 | Eps 0.968 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step  16343 | Ep  113 | Eps 0.968 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  16479 | Ep  114 | Eps 0.967 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  16664 | Ep  115 | Eps 0.967 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  16780 | Ep  116 | Eps 0.967 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  16896 | Ep  117 | Eps 0.967 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  17029 | Ep  118 | Eps 0.966 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  17209 | Ep  119 | Eps 0.966 | MeanReward(10ep):   1.010 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step  17342 | Ep  120 | Eps 0.966 | MeanReward(10ep):   1.010 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  17458 | Ep  121 | Eps 0.965 | MeanReward(10ep):   1.010 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  17574 | Ep  122 | Eps 0.965 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  17710 | Ep  123 | Eps 0.965 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  17826 | Ep  124 | Eps 0.965 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  17959 | Ep  125 | Eps 0.964 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  18075 | Ep  126 | Eps 0.964 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  18191 | Ep  127 | Eps 0.964 | MeanReward(10ep):   0.950 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  18371 | Ep  128 | Eps 0.964 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00000 | MeanQ:   0.015 | GradNorm:  0.0000
# [DEBUG] Step  18487 | Ep  129 | Eps 0.963 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  18603 | Ep  130 | Eps 0.963 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  18792 | Ep  131 | Eps 0.963 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  19028 | Ep  132 | Eps 0.962 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  19270 | Ep  133 | Eps 0.962 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  19468 | Ep  134 | Eps 0.961 | MeanReward(10ep):   1.040 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  19601 | Ep  135 | Eps 0.961 | MeanReward(10ep):   1.050 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  19786 | Ep  136 | Eps 0.961 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  19902 | Ep  137 | Eps 0.961 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00000 | MeanQ:   0.014 | GradNorm:  0.0000
# [DEBUG] Step  20018 | Ep  138 | Eps 0.960 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00589 | MeanQ:   0.107 | GradNorm:  0.0143
# [DEBUG] Step  20198 | Ep  139 | Eps 0.960 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00322 | MeanQ:   0.077 | GradNorm:  0.0024
# [DEBUG] Step  20376 | Ep  140 | Eps 0.960 | MeanReward(10ep):   1.110 | MeanLoss(100it):  0.00279 | MeanQ:   0.075 | GradNorm:  0.0081
# [DEBUG] Step  20492 | Ep  141 | Eps 0.959 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00270 | MeanQ:   0.083 | GradNorm:  0.0048
# [DEBUG] Step  20608 | Ep  142 | Eps 0.959 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00291 | MeanQ:   0.092 | GradNorm:  0.0057
# [DEBUG] Step  20750 | Ep  143 | Eps 0.959 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00303 | MeanQ:   0.086 | GradNorm:  0.0096
# [DEBUG] Step  20866 | Ep  144 | Eps 0.959 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00369 | MeanQ:   0.070 | GradNorm:  0.0030
# [DEBUG] Step  20982 | Ep  145 | Eps 0.958 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00383 | MeanQ:   0.089 | GradNorm:  0.0029
# [DEBUG] Step  21140 | Ep  146 | Eps 0.958 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00409 | MeanQ:   0.083 | GradNorm:  0.0073
# [DEBUG] Step  21256 | Ep  147 | Eps 0.958 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00339 | MeanQ:   0.097 | GradNorm:  0.0037
# [DEBUG] Step  21372 | Ep  148 | Eps 0.958 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00325 | MeanQ:   0.085 | GradNorm:  0.0032
# [DEBUG] Step  21552 | Ep  149 | Eps 0.957 | MeanReward(10ep):   1.110 | MeanLoss(100it):  0.00317 | MeanQ:   0.085 | GradNorm:  0.0038
# [DEBUG] Step  21668 | Ep  150 | Eps 0.957 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00350 | MeanQ:   0.110 | GradNorm:  0.0094
# [DEBUG] Step  21830 | Ep  151 | Eps 0.957 | MeanReward(10ep):   1.120 | MeanLoss(100it):  0.00363 | MeanQ:   0.110 | GradNorm:  0.0112
# [DEBUG] Step  21946 | Ep  152 | Eps 0.957 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00375 | MeanQ:   0.101 | GradNorm:  0.0054
# [DEBUG] Step  22062 | Ep  153 | Eps 0.956 | MeanReward(10ep):   1.060 | MeanLoss(100it):  0.00432 | MeanQ:   0.114 | GradNorm:  0.0151
# [DEBUG] Step  22242 | Ep  154 | Eps 0.956 | MeanReward(10ep):   1.050 | MeanLoss(100it):  0.00414 | MeanQ:   0.180 | GradNorm:  0.0025
# [DEBUG] Step  22489 | Ep  155 | Eps 0.955 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00281 | MeanQ:   0.187 | GradNorm:  0.0099
# [DEBUG] Step  22625 | Ep  156 | Eps 0.955 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00216 | MeanQ:   0.111 | GradNorm:  0.0014
# [DEBUG] Step  22775 | Ep  157 | Eps 0.955 | MeanReward(10ep):   1.110 | MeanLoss(100it):  0.00215 | MeanQ:   0.174 | GradNorm:  0.0117
# [DEBUG] Step  22891 | Ep  158 | Eps 0.955 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00252 | MeanQ:   0.188 | GradNorm:  0.0083
# [DEBUG] Step  23007 | Ep  159 | Eps 0.954 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00242 | MeanQ:   0.146 | GradNorm:  0.0122
# [DEBUG] Step  23123 | Ep  160 | Eps 0.954 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00247 | MeanQ:   0.117 | GradNorm:  0.0113
# [DEBUG] Step  23239 | Ep  161 | Eps 0.954 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00247 | MeanQ:   0.216 | GradNorm:  0.0062
# [DEBUG] Step  23355 | Ep  162 | Eps 0.954 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00247 | MeanQ:   0.109 | GradNorm:  0.0040
# [DEBUG] Step  23491 | Ep  163 | Eps 0.953 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00228 | MeanQ:   0.125 | GradNorm:  0.0145
# [DEBUG] Step  23607 | Ep  164 | Eps 0.953 | MeanReward(10ep):   1.050 | MeanLoss(100it):  0.00240 | MeanQ:   0.141 | GradNorm:  0.0113
# [DEBUG] Step  23801 | Ep  165 | Eps 0.953 | MeanReward(10ep):   1.060 | MeanLoss(100it):  0.00262 | MeanQ:   0.194 | GradNorm:  0.0136
# [DEBUG] Step  23917 | Ep  166 | Eps 0.953 | MeanReward(10ep):   1.050 | MeanLoss(100it):  0.00254 | MeanQ:   0.143 | GradNorm:  0.0047
# [DEBUG] Step  24103 | Ep  167 | Eps 0.952 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00205 | MeanQ:   0.117 | GradNorm:  0.0143
# [DEBUG] Step  24219 | Ep  168 | Eps 0.952 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00146 | MeanQ:   0.103 | GradNorm:  0.0041
# [DEBUG] Step  24352 | Ep  169 | Eps 0.952 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00150 | MeanQ:   0.149 | GradNorm:  0.0079
# [DEBUG] Step  24468 | Ep  170 | Eps 0.952 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00169 | MeanQ:   0.165 | GradNorm:  0.0043
# [DEBUG] Step  24584 | Ep  171 | Eps 0.951 | MeanReward(10ep):   1.050 | MeanLoss(100it):  0.00169 | MeanQ:   0.163 | GradNorm:  0.0092
# [DEBUG] Step  24764 | Ep  172 | Eps 0.951 | MeanReward(10ep):   1.060 | MeanLoss(100it):  0.00179 | MeanQ:   0.240 | GradNorm:  0.0193
# [DEBUG] Step  24944 | Ep  173 | Eps 0.951 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00166 | MeanQ:   0.118 | GradNorm:  0.0023
# [DEBUG] Step  25060 | Ep  174 | Eps 0.950 | MeanReward(10ep):   1.040 | MeanLoss(100it):  0.00174 | MeanQ:   0.157 | GradNorm:  0.0069
# [DEBUG] Step  25201 | Ep  175 | Eps 0.950 | MeanReward(10ep):   1.040 | MeanLoss(100it):  0.00148 | MeanQ:   0.108 | GradNorm:  0.0073
# [DEBUG] Step  25361 | Ep  176 | Eps 0.950 | MeanReward(10ep):   1.040 | MeanLoss(100it):  0.00155 | MeanQ:   0.104 | GradNorm:  0.0030
# [DEBUG] Step  25477 | Ep  177 | Eps 0.950 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00128 | MeanQ:   0.143 | GradNorm:  0.0016
# [DEBUG] Step  25593 | Ep  178 | Eps 0.949 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00124 | MeanQ:   0.111 | GradNorm:  0.0044
# [DEBUG] Step  25709 | Ep  179 | Eps 0.949 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00110 | MeanQ:   0.125 | GradNorm:  0.0020
# [DEBUG] Step  25954 | Ep  180 | Eps 0.949 | MeanReward(10ep):   1.040 | MeanLoss(100it):  0.00151 | MeanQ:   0.162 | GradNorm:  0.0179
# [DEBUG] Step  26115 | Ep  181 | Eps 0.948 | MeanReward(10ep):   1.060 | MeanLoss(100it):  0.00148 | MeanQ:   0.118 | GradNorm:  0.0026
# [DEBUG] Step  26231 | Ep  182 | Eps 0.948 | MeanReward(10ep):   1.050 | MeanLoss(100it):  0.00146 | MeanQ:   0.137 | GradNorm:  0.0224
# [DEBUG] Step  26347 | Ep  183 | Eps 0.948 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00123 | MeanQ:   0.114 | GradNorm:  0.0047
# [DEBUG] Step  26502 | Ep  184 | Eps 0.948 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00132 | MeanQ:   0.145 | GradNorm:  0.0032
# [DEBUG] Step  26657 | Ep  185 | Eps 0.947 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00120 | MeanQ:   0.105 | GradNorm:  0.0227
# [DEBUG] Step  26790 | Ep  186 | Eps 0.947 | MeanReward(10ep):   1.010 | MeanLoss(100it):  0.00146 | MeanQ:   0.109 | GradNorm:  0.0029
# [DEBUG] Step  26906 | Ep  187 | Eps 0.947 | MeanReward(10ep):   1.010 | MeanLoss(100it):  0.00135 | MeanQ:   0.188 | GradNorm:  0.0165
# [DEBUG] Step  27022 | Ep  188 | Eps 0.946 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00123 | MeanQ:   0.107 | GradNorm:  0.0243
# [DEBUG] Step  27138 | Ep  189 | Eps 0.946 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00114 | MeanQ:   0.124 | GradNorm:  0.0024
# [DEBUG] Step  27273 | Ep  190 | Eps 0.946 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00102 | MeanQ:   0.114 | GradNorm:  0.0119
# [DEBUG] Step  27389 | Ep  191 | Eps 0.946 | MeanReward(10ep):   0.950 | MeanLoss(100it):  0.00100 | MeanQ:   0.172 | GradNorm:  0.0057
# [DEBUG] Step  27587 | Ep  192 | Eps 0.945 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00110 | MeanQ:   0.120 | GradNorm:  0.0126
# [DEBUG] Step  27703 | Ep  193 | Eps 0.945 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00104 | MeanQ:   0.116 | GradNorm:  0.0017
# [DEBUG] Step  27819 | Ep  194 | Eps 0.945 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00108 | MeanQ:   0.115 | GradNorm:  0.0060
# [DEBUG] Step  27972 | Ep  195 | Eps 0.945 | MeanReward(10ep):   0.920 | MeanLoss(100it):  0.00097 | MeanQ:   0.119 | GradNorm:  0.0160
# [DEBUG] Step  28113 | Ep  196 | Eps 0.944 | MeanReward(10ep):   0.920 | MeanLoss(100it):  0.00108 | MeanQ:   0.104 | GradNorm:  0.0128
# [DEBUG] Step  28229 | Ep  197 | Eps 0.944 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00116 | MeanQ:   0.166 | GradNorm:  0.0028
# [DEBUG] Step  28345 | Ep  198 | Eps 0.944 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00121 | MeanQ:   0.145 | GradNorm:  0.0130
# [DEBUG] Step  28461 | Ep  199 | Eps 0.944 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00104 | MeanQ:   0.209 | GradNorm:  0.0208
# [DEBUG] Step  28577 | Ep  200 | Eps 0.943 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00086 | MeanQ:   0.100 | GradNorm:  0.0041
# [breakout] Ep 200 Steps 28577 RecentMean 0.88 Eps 0.943
# Eval @ Ep 200 and 28577 steps => mean return 11.00
# [DEBUG] Step  28734 | Ep  201 | Eps 0.943 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00063 | MeanQ:   0.172 | GradNorm:  0.0246
# [DEBUG] Step  28850 | Ep  202 | Eps 0.943 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00080 | MeanQ:   0.129 | GradNorm:  0.0269
# [DEBUG] Step  28966 | Ep  203 | Eps 0.943 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00073 | MeanQ:   0.121 | GradNorm:  0.0111
# [DEBUG] Step  29120 | Ep  204 | Eps 0.942 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00082 | MeanQ:   0.113 | GradNorm:  0.0018
# [DEBUG] Step  29327 | Ep  205 | Eps 0.942 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00069 | MeanQ:   0.112 | GradNorm:  0.0131
# [DEBUG] Step  29527 | Ep  206 | Eps 0.942 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00085 | MeanQ:   0.116 | GradNorm:  0.0042
# [DEBUG] Step  29660 | Ep  207 | Eps 0.941 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00082 | MeanQ:   0.115 | GradNorm:  0.0021
# [DEBUG] Step  29794 | Ep  208 | Eps 0.941 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00061 | MeanQ:   0.116 | GradNorm:  0.0050
# [DEBUG] Step  29910 | Ep  209 | Eps 0.941 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00071 | MeanQ:   0.130 | GradNorm:  0.0064
# [DEBUG] Step  30043 | Ep  210 | Eps 0.941 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00071 | MeanQ:   0.247 | GradNorm:  0.0437
# [DEBUG] Step  30273 | Ep  211 | Eps 0.940 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00091 | MeanQ:   0.129 | GradNorm:  0.0041
# [DEBUG] Step  30436 | Ep  212 | Eps 0.940 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00115 | MeanQ:   0.106 | GradNorm:  0.0097
# [DEBUG] Step  30633 | Ep  213 | Eps 0.939 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00110 | MeanQ:   0.110 | GradNorm:  0.0385
# [DEBUG] Step  30787 | Ep  214 | Eps 0.939 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00098 | MeanQ:   0.105 | GradNorm:  0.0154
# [DEBUG] Step  30929 | Ep  215 | Eps 0.939 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00114 | MeanQ:   0.117 | GradNorm:  0.0040
# [DEBUG] Step  31082 | Ep  216 | Eps 0.938 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00095 | MeanQ:   0.110 | GradNorm:  0.0061
# [DEBUG] Step  31280 | Ep  217 | Eps 0.938 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00068 | MeanQ:   0.193 | GradNorm:  0.0259
# [DEBUG] Step  31478 | Ep  218 | Eps 0.938 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00064 | MeanQ:   0.125 | GradNorm:  0.0068
# [DEBUG] Step  31594 | Ep  219 | Eps 0.937 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00072 | MeanQ:   0.187 | GradNorm:  0.0147
# [DEBUG] Step  31710 | Ep  220 | Eps 0.937 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00076 | MeanQ:   0.199 | GradNorm:  0.0037
# [DEBUG] Step  31826 | Ep  221 | Eps 0.937 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00081 | MeanQ:   0.109 | GradNorm:  0.0125
# [DEBUG] Step  31960 | Ep  222 | Eps 0.937 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00073 | MeanQ:   0.134 | GradNorm:  0.0066
# [DEBUG] Step  32094 | Ep  223 | Eps 0.936 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00059 | MeanQ:   0.243 | GradNorm:  0.0251
# [DEBUG] Step  32210 | Ep  224 | Eps 0.936 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00071 | MeanQ:   0.219 | GradNorm:  0.0116
# [DEBUG] Step  32326 | Ep  225 | Eps 0.936 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00077 | MeanQ:   0.112 | GradNorm:  0.0042
# [DEBUG] Step  32468 | Ep  226 | Eps 0.936 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00091 | MeanQ:   0.212 | GradNorm:  0.0164
# [DEBUG] Step  32639 | Ep  227 | Eps 0.935 | MeanReward(10ep):   0.920 | MeanLoss(100it):  0.00078 | MeanQ:   0.105 | GradNorm:  0.0090
# [DEBUG] Step  32755 | Ep  228 | Eps 0.935 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00071 | MeanQ:   0.103 | GradNorm:  0.0100
# [DEBUG] Step  33028 | Ep  229 | Eps 0.935 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00102 | MeanQ:   0.299 | GradNorm:  0.0104
# [DEBUG] Step  33227 | Ep  230 | Eps 0.934 | MeanReward(10ep):   1.010 | MeanLoss(100it):  0.00108 | MeanQ:   0.160 | GradNorm:  0.0239
# [DEBUG] Step  33362 | Ep  231 | Eps 0.934 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00083 | MeanQ:   0.110 | GradNorm:  0.0019
# [DEBUG] Step  33478 | Ep  232 | Eps 0.934 | MeanReward(10ep):   0.940 | MeanLoss(100it):  0.00071 | MeanQ:   0.143 | GradNorm:  0.0087
# [DEBUG] Step  33649 | Ep  233 | Eps 0.933 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00081 | MeanQ:   0.135 | GradNorm:  0.0325
# [DEBUG] Step  33765 | Ep  234 | Eps 0.933 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00087 | MeanQ:   0.105 | GradNorm:  0.0163
# [DEBUG] Step  33881 | Ep  235 | Eps 0.933 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00093 | MeanQ:   0.111 | GradNorm:  0.0019
# [DEBUG] Step  34053 | Ep  236 | Eps 0.933 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00074 | MeanQ:   0.110 | GradNorm:  0.0104
# [DEBUG] Step  34169 | Ep  237 | Eps 0.932 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00081 | MeanQ:   0.210 | GradNorm:  0.0209
# [DEBUG] Step  34285 | Ep  238 | Eps 0.932 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00095 | MeanQ:   0.102 | GradNorm:  0.0091
# [DEBUG] Step  34508 | Ep  239 | Eps 0.932 | MeanReward(10ep):   0.940 | MeanLoss(100it):  0.00099 | MeanQ:   0.103 | GradNorm:  0.0122
# [DEBUG] Step  34624 | Ep  240 | Eps 0.931 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00090 | MeanQ:   0.134 | GradNorm:  0.0170
# [DEBUG] Step  34757 | Ep  241 | Eps 0.931 | MeanReward(10ep):   0.920 | MeanLoss(100it):  0.00102 | MeanQ:   0.170 | GradNorm:  0.0296
# [DEBUG] Step  34873 | Ep  242 | Eps 0.931 | MeanReward(10ep):   0.920 | MeanLoss(100it):  0.00125 | MeanQ:   0.264 | GradNorm:  0.0378
# [DEBUG] Step  35064 | Ep  243 | Eps 0.931 | MeanReward(10ep):   0.940 | MeanLoss(100it):  0.00152 | MeanQ:   0.136 | GradNorm:  0.0404
# [DEBUG] Step  35286 | Ep  244 | Eps 0.930 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00140 | MeanQ:   0.206 | GradNorm:  0.0056
# [DEBUG] Step  35466 | Ep  245 | Eps 0.930 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00144 | MeanQ:   0.104 | GradNorm:  0.0073
# [DEBUG] Step  35599 | Ep  246 | Eps 0.930 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00132 | MeanQ:   0.242 | GradNorm:  0.0228
# [DEBUG] Step  35756 | Ep  247 | Eps 0.929 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00118 | MeanQ:   0.112 | GradNorm:  0.0068
# [DEBUG] Step  35872 | Ep  248 | Eps 0.929 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00106 | MeanQ:   0.113 | GradNorm:  0.0081
# [DEBUG] Step  36027 | Ep  249 | Eps 0.929 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00091 | MeanQ:   0.108 | GradNorm:  0.0135
# [DEBUG] Step  36143 | Ep  250 | Eps 0.928 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00098 | MeanQ:   0.111 | GradNorm:  0.0138
# [DEBUG] Step  36323 | Ep  251 | Eps 0.928 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00122 | MeanQ:   0.156 | GradNorm:  0.0179
# [DEBUG] Step  36439 | Ep  252 | Eps 0.928 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00120 | MeanQ:   0.098 | GradNorm:  0.0161
# [DEBUG] Step  36555 | Ep  253 | Eps 0.928 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00126 | MeanQ:   0.122 | GradNorm:  0.0071
# [DEBUG] Step  36772 | Ep  254 | Eps 0.927 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00121 | MeanQ:   0.219 | GradNorm:  0.0228
# [DEBUG] Step  36977 | Ep  255 | Eps 0.927 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00101 | MeanQ:   0.102 | GradNorm:  0.0224
# [DEBUG] Step  37093 | Ep  256 | Eps 0.927 | MeanReward(10ep):   0.950 | MeanLoss(100it):  0.00094 | MeanQ:   0.143 | GradNorm:  0.0013
# [DEBUG] Step  37209 | Ep  257 | Eps 0.926 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00082 | MeanQ:   0.102 | GradNorm:  0.0202
# [DEBUG] Step  37325 | Ep  258 | Eps 0.926 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00082 | MeanQ:   0.230 | GradNorm:  0.0151
# [DEBUG] Step  37441 | Ep  259 | Eps 0.926 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00070 | MeanQ:   0.129 | GradNorm:  0.0164
# [DEBUG] Step  37596 | Ep  260 | Eps 0.926 | MeanReward(10ep):   0.940 | MeanLoss(100it):  0.00076 | MeanQ:   0.103 | GradNorm:  0.0086
# [DEBUG] Step  37712 | Ep  261 | Eps 0.925 | MeanReward(10ep):   0.940 | MeanLoss(100it):  0.00072 | MeanQ:   0.141 | GradNorm:  0.0123
# [DEBUG] Step  37910 | Ep  262 | Eps 0.925 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00114 | MeanQ:   0.102 | GradNorm:  0.0108
# [DEBUG] Step  38043 | Ep  263 | Eps 0.925 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00119 | MeanQ:   0.217 | GradNorm:  0.0129
# [DEBUG] Step  38257 | Ep  264 | Eps 0.924 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00102 | MeanQ:   0.104 | GradNorm:  0.0265
# [DEBUG] Step  38390 | Ep  265 | Eps 0.924 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00091 | MeanQ:   0.244 | GradNorm:  0.0091
# [DEBUG] Step  38506 | Ep  266 | Eps 0.924 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00090 | MeanQ:   0.204 | GradNorm:  0.0032
# [DEBUG] Step  38721 | Ep  267 | Eps 0.923 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00105 | MeanQ:   0.156 | GradNorm:  0.0135
# [DEBUG] Step  38854 | Ep  268 | Eps 0.923 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00092 | MeanQ:   0.207 | GradNorm:  0.0031
# [DEBUG] Step  38970 | Ep  269 | Eps 0.923 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00084 | MeanQ:   0.167 | GradNorm:  0.0053
# [DEBUG] Step  39123 | Ep  270 | Eps 0.923 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00075 | MeanQ:   0.155 | GradNorm:  0.0045
# [DEBUG] Step  39387 | Ep  271 | Eps 0.922 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00070 | MeanQ:   0.157 | GradNorm:  0.0069
# [DEBUG] Step  39522 | Ep  272 | Eps 0.922 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00082 | MeanQ:   0.133 | GradNorm:  0.0103
# [DEBUG] Step  39638 | Ep  273 | Eps 0.922 | MeanReward(10ep):   1.010 | MeanLoss(100it):  0.00087 | MeanQ:   0.106 | GradNorm:  0.0060
# [DEBUG] Step  39836 | Ep  274 | Eps 0.921 | MeanReward(10ep):   1.050 | MeanLoss(100it):  0.00093 | MeanQ:   0.114 | GradNorm:  0.0119
# [DEBUG] Step  40205 | Ep  275 | Eps 0.920 | MeanReward(10ep):   1.110 | MeanLoss(100it):  0.00117 | MeanQ:   0.116 | GradNorm:  0.0174
# [DEBUG] Step  40321 | Ep  276 | Eps 0.920 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00129 | MeanQ:   0.221 | GradNorm:  0.0117
# [DEBUG] Step  40437 | Ep  277 | Eps 0.920 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00121 | MeanQ:   0.199 | GradNorm:  0.0053
# [DEBUG] Step  40578 | Ep  278 | Eps 0.920 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00139 | MeanQ:   0.108 | GradNorm:  0.0201
# [DEBUG] Step  40758 | Ep  279 | Eps 0.919 | MeanReward(10ep):   1.110 | MeanLoss(100it):  0.00155 | MeanQ:   0.115 | GradNorm:  0.0217
# [DEBUG] Step  40900 | Ep  280 | Eps 0.919 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00154 | MeanQ:   0.221 | GradNorm:  0.0053
# [DEBUG] Step  41016 | Ep  281 | Eps 0.919 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00115 | MeanQ:   0.173 | GradNorm:  0.0119
# [DEBUG] Step  41132 | Ep  282 | Eps 0.919 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00087 | MeanQ:   0.234 | GradNorm:  0.0086
# [DEBUG] Step  41248 | Ep  283 | Eps 0.918 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00092 | MeanQ:   0.270 | GradNorm:  0.0334
# [DEBUG] Step  41433 | Ep  284 | Eps 0.918 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00094 | MeanQ:   0.133 | GradNorm:  0.0045
# [DEBUG] Step  41583 | Ep  285 | Eps 0.918 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00106 | MeanQ:   0.146 | GradNorm:  0.0052
# [DEBUG] Step  41741 | Ep  286 | Eps 0.917 | MeanReward(10ep):   1.110 | MeanLoss(100it):  0.00097 | MeanQ:   0.116 | GradNorm:  0.0097
# [DEBUG] Step  41913 | Ep  287 | Eps 0.917 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00086 | MeanQ:   0.195 | GradNorm:  0.0082
# [DEBUG] Step  42029 | Ep  288 | Eps 0.917 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00084 | MeanQ:   0.300 | GradNorm:  0.0237
# [DEBUG] Step  42276 | Ep  289 | Eps 0.916 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00131 | MeanQ:   0.191 | GradNorm:  0.0099
# [DEBUG] Step  42392 | Ep  290 | Eps 0.916 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00155 | MeanQ:   0.164 | GradNorm:  0.0419
# [DEBUG] Step  42508 | Ep  291 | Eps 0.916 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00155 | MeanQ:   0.116 | GradNorm:  0.0303
# [DEBUG] Step  42663 | Ep  292 | Eps 0.916 | MeanReward(10ep):   1.150 | MeanLoss(100it):  0.00148 | MeanQ:   0.106 | GradNorm:  0.0193
# [DEBUG] Step  42779 | Ep  293 | Eps 0.915 | MeanReward(10ep):   1.150 | MeanLoss(100it):  0.00145 | MeanQ:   0.163 | GradNorm:  0.0023
# [DEBUG] Step  42934 | Ep  294 | Eps 0.915 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00134 | MeanQ:   0.141 | GradNorm:  0.0245
# [DEBUG] Step  43050 | Ep  295 | Eps 0.915 | MeanReward(10ep):   1.150 | MeanLoss(100it):  0.00114 | MeanQ:   0.158 | GradNorm:  0.0051
# [DEBUG] Step  43250 | Ep  296 | Eps 0.914 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00119 | MeanQ:   0.158 | GradNorm:  0.0113
# [DEBUG] Step  43467 | Ep  297 | Eps 0.914 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00143 | MeanQ:   0.222 | GradNorm:  0.0221
# [DEBUG] Step  43600 | Ep  298 | Eps 0.914 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00136 | MeanQ:   0.119 | GradNorm:  0.0278
# [DEBUG] Step  43760 | Ep  299 | Eps 0.913 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00121 | MeanQ:   0.236 | GradNorm:  0.0242
# [DEBUG] Step  43876 | Ep  300 | Eps 0.913 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00116 | MeanQ:   0.238 | GradNorm:  0.0049
# [breakout] Ep 300 Steps 43876 RecentMean 1.21 Eps 0.913
# [DEBUG] Step  44076 | Ep  301 | Eps 0.913 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00135 | MeanQ:   0.242 | GradNorm:  0.0222
# [DEBUG] Step  44218 | Ep  302 | Eps 0.912 | MeanReward(10ep):   1.220 | MeanLoss(100it):  0.00125 | MeanQ:   0.114 | GradNorm:  0.0147
# [DEBUG] Step  44464 | Ep  303 | Eps 0.912 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00134 | MeanQ:   0.231 | GradNorm:  0.0378
# [DEBUG] Step  44580 | Ep  304 | Eps 0.912 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00166 | MeanQ:   0.119 | GradNorm:  0.0253
# [DEBUG] Step  44744 | Ep  305 | Eps 0.911 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00167 | MeanQ:   0.145 | GradNorm:  0.0164
# [DEBUG] Step  44924 | Ep  306 | Eps 0.911 | MeanReward(10ep):   1.220 | MeanLoss(100it):  0.00172 | MeanQ:   0.183 | GradNorm:  0.0226
# [DEBUG] Step  45081 | Ep  307 | Eps 0.911 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00170 | MeanQ:   0.175 | GradNorm:  0.0146
# [DEBUG] Step  45279 | Ep  308 | Eps 0.910 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00176 | MeanQ:   0.114 | GradNorm:  0.0205
# [DEBUG] Step  45432 | Ep  309 | Eps 0.910 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00164 | MeanQ:   0.154 | GradNorm:  0.0384
# [DEBUG] Step  45574 | Ep  310 | Eps 0.910 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00162 | MeanQ:   0.182 | GradNorm:  0.0113
# [DEBUG] Step  45819 | Ep  311 | Eps 0.909 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00178 | MeanQ:   0.229 | GradNorm:  0.0254
# [DEBUG] Step  45935 | Ep  312 | Eps 0.909 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00164 | MeanQ:   0.157 | GradNorm:  0.0235
# [DEBUG] Step  46158 | Ep  313 | Eps 0.909 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00195 | MeanQ:   0.124 | GradNorm:  0.0111
# [DEBUG] Step  46274 | Ep  314 | Eps 0.908 | MeanReward(10ep):   1.220 | MeanLoss(100it):  0.00195 | MeanQ:   0.198 | GradNorm:  0.0093
# [DEBUG] Step  46390 | Ep  315 | Eps 0.908 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00218 | MeanQ:   0.125 | GradNorm:  0.0097
# [DEBUG] Step  46506 | Ep  316 | Eps 0.908 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00186 | MeanQ:   0.188 | GradNorm:  0.0175
# [DEBUG] Step  46622 | Ep  317 | Eps 0.908 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00217 | MeanQ:   0.227 | GradNorm:  0.0240
# [DEBUG] Step  46758 | Ep  318 | Eps 0.907 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00215 | MeanQ:   0.215 | GradNorm:  0.0282
# [DEBUG] Step  46874 | Ep  319 | Eps 0.907 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00232 | MeanQ:   0.165 | GradNorm:  0.0351
# [DEBUG] Step  46990 | Ep  320 | Eps 0.907 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00225 | MeanQ:   0.137 | GradNorm:  0.0182
# [DEBUG] Step  47133 | Ep  321 | Eps 0.907 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00250 | MeanQ:   0.170 | GradNorm:  0.0231
# [DEBUG] Step  47283 | Ep  322 | Eps 0.906 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00280 | MeanQ:   0.160 | GradNorm:  0.0359
# [DEBUG] Step  47451 | Ep  323 | Eps 0.906 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00268 | MeanQ:   0.120 | GradNorm:  0.0188
# [DEBUG] Step  47607 | Ep  324 | Eps 0.906 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00215 | MeanQ:   0.188 | GradNorm:  0.0185
# [DEBUG] Step  47723 | Ep  325 | Eps 0.906 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00200 | MeanQ:   0.132 | GradNorm:  0.0055
# [DEBUG] Step  47839 | Ep  326 | Eps 0.905 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00173 | MeanQ:   0.221 | GradNorm:  0.0381
# [DEBUG] Step  47955 | Ep  327 | Eps 0.905 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00195 | MeanQ:   0.139 | GradNorm:  0.0280
# [DEBUG] Step  48195 | Ep  328 | Eps 0.905 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00218 | MeanQ:   0.180 | GradNorm:  0.0393
# [DEBUG] Step  48311 | Ep  329 | Eps 0.904 | MeanReward(10ep):   1.140 | MeanLoss(100it):  0.00254 | MeanQ:   0.248 | GradNorm:  0.0277
# [DEBUG] Step  48472 | Ep  330 | Eps 0.904 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00262 | MeanQ:   0.167 | GradNorm:  0.0057
# [DEBUG] Step  48670 | Ep  331 | Eps 0.904 | MeanReward(10ep):   1.140 | MeanLoss(100it):  0.00216 | MeanQ:   0.205 | GradNorm:  0.0520
# [DEBUG] Step  48875 | Ep  332 | Eps 0.903 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00205 | MeanQ:   0.132 | GradNorm:  0.0255
# [DEBUG] Step  49055 | Ep  333 | Eps 0.903 | MeanReward(10ep):   1.150 | MeanLoss(100it):  0.00217 | MeanQ:   0.156 | GradNorm:  0.0135
# [DEBUG] Step  49207 | Ep  334 | Eps 0.903 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00165 | MeanQ:   0.156 | GradNorm:  0.0097
# [DEBUG] Step  49422 | Ep  335 | Eps 0.902 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00177 | MeanQ:   0.133 | GradNorm:  0.0211
# [DEBUG] Step  49538 | Ep  336 | Eps 0.902 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00168 | MeanQ:   0.167 | GradNorm:  0.0170
# [DEBUG] Step  49679 | Ep  337 | Eps 0.902 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00147 | MeanQ:   0.130 | GradNorm:  0.0213
# [DEBUG] Step  49821 | Ep  338 | Eps 0.901 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00138 | MeanQ:   0.167 | GradNorm:  0.0183
# [DEBUG] Step  49937 | Ep  339 | Eps 0.901 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00174 | MeanQ:   0.215 | GradNorm:  0.0262
# [DEBUG] Step  50094 | Ep  340 | Eps 0.901 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00231 | MeanQ:   0.151 | GradNorm:  0.0350
# [DEBUG] Step  50210 | Ep  341 | Eps 0.901 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00249 | MeanQ:   0.232 | GradNorm:  0.0182
# [DEBUG] Step  50369 | Ep  342 | Eps 0.900 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00269 | MeanQ:   0.225 | GradNorm:  0.0418
# [DEBUG] Step  50539 | Ep  343 | Eps 0.900 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00260 | MeanQ:   0.200 | GradNorm:  0.0226
# [DEBUG] Step  50655 | Ep  344 | Eps 0.900 | MeanReward(10ep):   1.160 | MeanLoss(100it):  0.00259 | MeanQ:   0.209 | GradNorm:  0.0088
# [DEBUG] Step  50771 | Ep  345 | Eps 0.899 | MeanReward(10ep):   1.150 | MeanLoss(100it):  0.00248 | MeanQ:   0.202 | GradNorm:  0.0106
# [DEBUG] Step  50945 | Ep  346 | Eps 0.899 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00218 | MeanQ:   0.142 | GradNorm:  0.0107
# [DEBUG] Step  51122 | Ep  347 | Eps 0.899 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00257 | MeanQ:   0.156 | GradNorm:  0.0232
# [DEBUG] Step  51272 | Ep  348 | Eps 0.898 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00281 | MeanQ:   0.148 | GradNorm:  0.0449
# [DEBUG] Step  51388 | Ep  349 | Eps 0.898 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00268 | MeanQ:   0.219 | GradNorm:  0.0266
# [DEBUG] Step  51504 | Ep  350 | Eps 0.898 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00241 | MeanQ:   0.184 | GradNorm:  0.0128
# [DEBUG] Step  51659 | Ep  351 | Eps 0.898 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00236 | MeanQ:   0.144 | GradNorm:  0.0171
# [DEBUG] Step  51775 | Ep  352 | Eps 0.897 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00259 | MeanQ:   0.169 | GradNorm:  0.0152
# [DEBUG] Step  51891 | Ep  353 | Eps 0.897 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00250 | MeanQ:   0.211 | GradNorm:  0.0215
# ...
# [DEBUG] Step 1924255 | Ep 4242 | Eps 0.010 | MeanReward(10ep):  31.560 | MeanLoss(100it):  0.01437 | MeanQ:   5.432 | GradNorm:  0.1625
# [DEBUG] Step 1924984 | Ep 4243 | Eps 0.010 | MeanReward(10ep):  31.610 | MeanLoss(100it):  0.01733 | MeanQ:   5.479 | GradNorm:  0.1783
# [DEBUG] Step 1925618 | Ep 4244 | Eps 0.010 | MeanReward(10ep):  31.590 | MeanLoss(100it):  0.01770 | MeanQ:   5.449 | GradNorm:  0.1198
# [DEBUG] Step 1926114 | Ep 4245 | Eps 0.010 | MeanReward(10ep):  31.550 | MeanLoss(100it):  0.01936 | MeanQ:   5.465 | GradNorm:  0.1140
# [DEBUG] Step 1926988 | Ep 4246 | Eps 0.010 | MeanReward(10ep):  31.680 | MeanLoss(100it):  0.01875 | MeanQ:   5.619 | GradNorm:  0.1588
# [DEBUG] Step 1927802 | Ep 4247 | Eps 0.010 | MeanReward(10ep):  31.690 | MeanLoss(100it):  0.01804 | MeanQ:   5.601 | GradNorm:  0.1264
# [DEBUG] Step 1928585 | Ep 4248 | Eps 0.010 | MeanReward(10ep):  31.710 | MeanLoss(100it):  0.01740 | MeanQ:   5.584 | GradNorm:  0.1565
# [DEBUG] Step 1929399 | Ep 4249 | Eps 0.010 | MeanReward(10ep):  31.750 | MeanLoss(100it):  0.02053 | MeanQ:   5.485 | GradNorm:  0.1085
# [DEBUG] Step 1930114 | Ep 4250 | Eps 0.010 | MeanReward(10ep):  31.850 | MeanLoss(100it):  0.01730 | MeanQ:   5.584 | GradNorm:  0.2167
# [DEBUG] Step 1930762 | Ep 4251 | Eps 0.010 | MeanReward(10ep):  31.970 | MeanLoss(100it):  0.01978 | MeanQ:   5.633 | GradNorm:  0.1347
# [DEBUG] Step 1931624 | Ep 4252 | Eps 0.010 | MeanReward(10ep):  32.200 | MeanLoss(100it):  0.01643 | MeanQ:   5.507 | GradNorm:  0.1736
# [DEBUG] Step 1932209 | Ep 4253 | Eps 0.010 | MeanReward(10ep):  32.350 | MeanLoss(100it):  0.01544 | MeanQ:   5.476 | GradNorm:  0.1443
# [DEBUG] Step 1932936 | Ep 4254 | Eps 0.010 | MeanReward(10ep):  32.510 | MeanLoss(100it):  0.01832 | MeanQ:   5.505 | GradNorm:  0.0864
# [DEBUG] Step 1933623 | Ep 4255 | Eps 0.010 | MeanReward(10ep):  32.400 | MeanLoss(100it):  0.01607 | MeanQ:   5.499 | GradNorm:  0.1229
# [DEBUG] Step 1934305 | Ep 4256 | Eps 0.010 | MeanReward(10ep):  32.310 | MeanLoss(100it):  0.01889 | MeanQ:   5.471 | GradNorm:  0.1421
# [DEBUG] Step 1934975 | Ep 4257 | Eps 0.010 | MeanReward(10ep):  32.420 | MeanLoss(100it):  0.02146 | MeanQ:   5.473 | GradNorm:  0.1717
# [DEBUG] Step 1935883 | Ep 4258 | Eps 0.010 | MeanReward(10ep):  32.690 | MeanLoss(100it):  0.01873 | MeanQ:   5.441 | GradNorm:  0.1900
# [DEBUG] Step 1936591 | Ep 4259 | Eps 0.010 | MeanReward(10ep):  32.770 | MeanLoss(100it):  0.01662 | MeanQ:   5.445 | GradNorm:  0.0848
# [DEBUG] Step 1937206 | Ep 4260 | Eps 0.010 | MeanReward(10ep):  32.910 | MeanLoss(100it):  0.02020 | MeanQ:   5.606 | GradNorm:  0.1308
# [DEBUG] Step 1937857 | Ep 4261 | Eps 0.010 | MeanReward(10ep):  32.790 | MeanLoss(100it):  0.01991 | MeanQ:   5.447 | GradNorm:  0.2170
# [DEBUG] Step 1938409 | Ep 4262 | Eps 0.010 | MeanReward(10ep):  32.860 | MeanLoss(100it):  0.01754 | MeanQ:   5.474 | GradNorm:  0.1555
# [DEBUG] Step 1938917 | Ep 4263 | Eps 0.010 | MeanReward(10ep):  32.550 | MeanLoss(100it):  0.01890 | MeanQ:   5.424 | GradNorm:  0.1200
# [DEBUG] Step 1939520 | Ep 4264 | Eps 0.010 | MeanReward(10ep):  32.470 | MeanLoss(100it):  0.02142 | MeanQ:   5.458 | GradNorm:  0.1933
# [DEBUG] Step 1940201 | Ep 4265 | Eps 0.010 | MeanReward(10ep):  32.540 | MeanLoss(100it):  0.01686 | MeanQ:   5.605 | GradNorm:  0.1873
# [DEBUG] Step 1940603 | Ep 4266 | Eps 0.010 | MeanReward(10ep):  32.500 | MeanLoss(100it):  0.02011 | MeanQ:   5.441 | GradNorm:  0.1654
# [DEBUG] Step 1941289 | Ep 4267 | Eps 0.010 | MeanReward(10ep):  32.310 | MeanLoss(100it):  0.01613 | MeanQ:   5.595 | GradNorm:  0.1032
# [DEBUG] Step 1942106 | Ep 4268 | Eps 0.010 | MeanReward(10ep):  32.560 | MeanLoss(100it):  0.01690 | MeanQ:   5.474 | GradNorm:  0.1487
# [DEBUG] Step 1942864 | Ep 4269 | Eps 0.010 | MeanReward(10ep):  32.390 | MeanLoss(100it):  0.01958 | MeanQ:   5.487 | GradNorm:  0.1810
# [DEBUG] Step 1943589 | Ep 4270 | Eps 0.010 | MeanReward(10ep):  32.170 | MeanLoss(100it):  0.02002 | MeanQ:   5.492 | GradNorm:  0.0843
# [DEBUG] Step 1944117 | Ep 4271 | Eps 0.010 | MeanReward(10ep):  31.960 | MeanLoss(100it):  0.01856 | MeanQ:   5.443 | GradNorm:  0.1631
# [DEBUG] Step 1944921 | Ep 4272 | Eps 0.010 | MeanReward(10ep):  31.930 | MeanLoss(100it):  0.02137 | MeanQ:   5.415 | GradNorm:  0.0666
# [DEBUG] Step 1945682 | Ep 4273 | Eps 0.010 | MeanReward(10ep):  32.040 | MeanLoss(100it):  0.02041 | MeanQ:   5.433 | GradNorm:  0.0991
# [DEBUG] Step 1946381 | Ep 4274 | Eps 0.010 | MeanReward(10ep):  32.110 | MeanLoss(100it):  0.01906 | MeanQ:   5.538 | GradNorm:  0.1033
# [DEBUG] Step 1947120 | Ep 4275 | Eps 0.010 | MeanReward(10ep):  32.080 | MeanLoss(100it):  0.01923 | MeanQ:   5.425 | GradNorm:  0.1167
# [DEBUG] Step 1947627 | Ep 4276 | Eps 0.010 | MeanReward(10ep):  32.160 | MeanLoss(100it):  0.01895 | MeanQ:   5.395 | GradNorm:  0.1781
# [DEBUG] Step 1948327 | Ep 4277 | Eps 0.010 | MeanReward(10ep):  32.140 | MeanLoss(100it):  0.01878 | MeanQ:   5.356 | GradNorm:  0.1601
# [DEBUG] Step 1948691 | Ep 4278 | Eps 0.010 | MeanReward(10ep):  32.120 | MeanLoss(100it):  0.02008 | MeanQ:   5.348 | GradNorm:  0.1252
# [DEBUG] Step 1949178 | Ep 4279 | Eps 0.010 | MeanReward(10ep):  31.940 | MeanLoss(100it):  0.01932 | MeanQ:   5.533 | GradNorm:  0.1370
# [DEBUG] Step 1949834 | Ep 4280 | Eps 0.010 | MeanReward(10ep):  31.940 | MeanLoss(100it):  0.01887 | MeanQ:   5.411 | GradNorm:  0.1325
# [DEBUG] Step 1950254 | Ep 4281 | Eps 0.010 | MeanReward(10ep):  31.790 | MeanLoss(100it):  0.01779 | MeanQ:   5.386 | GradNorm:  0.1844
# [DEBUG] Step 1951035 | Ep 4282 | Eps 0.010 | MeanReward(10ep):  31.740 | MeanLoss(100it):  0.01795 | MeanQ:   5.324 | GradNorm:  0.1797
# [DEBUG] Step 1951466 | Ep 4283 | Eps 0.010 | MeanReward(10ep):  31.690 | MeanLoss(100it):  0.01851 | MeanQ:   5.304 | GradNorm:  0.0912
# [DEBUG] Step 1952225 | Ep 4284 | Eps 0.010 | MeanReward(10ep):  31.660 | MeanLoss(100it):  0.02106 | MeanQ:   5.309 | GradNorm:  0.1214
# [DEBUG] Step 1953046 | Ep 4285 | Eps 0.010 | MeanReward(10ep):  31.800 | MeanLoss(100it):  0.02037 | MeanQ:   5.340 | GradNorm:  0.1329
# [DEBUG] Step 1953862 | Ep 4286 | Eps 0.010 | MeanReward(10ep):  32.150 | MeanLoss(100it):  0.01975 | MeanQ:   5.333 | GradNorm:  0.1511
# [DEBUG] Step 1954581 | Ep 4287 | Eps 0.010 | MeanReward(10ep):  32.120 | MeanLoss(100it):  0.01868 | MeanQ:   5.309 | GradNorm:  0.2344
# [DEBUG] Step 1955181 | Ep 4288 | Eps 0.010 | MeanReward(10ep):  32.130 | MeanLoss(100it):  0.01820 | MeanQ:   5.450 | GradNorm:  0.1766
# [DEBUG] Step 1955712 | Ep 4289 | Eps 0.010 | MeanReward(10ep):  32.220 | MeanLoss(100it):  0.01734 | MeanQ:   5.315 | GradNorm:  0.0982
# [DEBUG] Step 1956378 | Ep 4290 | Eps 0.010 | MeanReward(10ep):  32.030 | MeanLoss(100it):  0.01936 | MeanQ:   5.373 | GradNorm:  0.0960
# [DEBUG] Step 1957109 | Ep 4291 | Eps 0.010 | MeanReward(10ep):  32.070 | MeanLoss(100it):  0.01663 | MeanQ:   5.358 | GradNorm:  0.1820
# [DEBUG] Step 1957913 | Ep 4292 | Eps 0.010 | MeanReward(10ep):  31.970 | MeanLoss(100it):  0.01815 | MeanQ:   5.340 | GradNorm:  0.1241
# [DEBUG] Step 1958734 | Ep 4293 | Eps 0.010 | MeanReward(10ep):  31.890 | MeanLoss(100it):  0.01858 | MeanQ:   5.383 | GradNorm:  0.1048
# [DEBUG] Step 1959609 | Ep 4294 | Eps 0.010 | MeanReward(10ep):  31.830 | MeanLoss(100it):  0.01899 | MeanQ:   5.458 | GradNorm:  0.1375
# [DEBUG] Step 1960495 | Ep 4295 | Eps 0.010 | MeanReward(10ep):  32.030 | MeanLoss(100it):  0.01660 | MeanQ:   5.337 | GradNorm:  0.1772
# [DEBUG] Step 1961309 | Ep 4296 | Eps 0.010 | MeanReward(10ep):  32.240 | MeanLoss(100it):  0.01968 | MeanQ:   5.318 | GradNorm:  0.1557
# [DEBUG] Step 1961910 | Ep 4297 | Eps 0.010 | MeanReward(10ep):  32.100 | MeanLoss(100it):  0.01841 | MeanQ:   5.374 | GradNorm:  0.1671
# [DEBUG] Step 1962804 | Ep 4298 | Eps 0.010 | MeanReward(10ep):  32.290 | MeanLoss(100it):  0.01756 | MeanQ:   5.409 | GradNorm:  0.1065
# [DEBUG] Step 1963511 | Ep 4299 | Eps 0.010 | MeanReward(10ep):  32.340 | MeanLoss(100it):  0.01974 | MeanQ:   5.377 | GradNorm:  0.1095
# [DEBUG] Step 1964275 | Ep 4300 | Eps 0.010 | MeanReward(10ep):  32.360 | MeanLoss(100it):  0.01682 | MeanQ:   5.359 | GradNorm:  0.0690
# [breakout] Ep 4300 Steps 1964275 RecentMean 32.36 Eps 0.010
# [DEBUG] Step 1964980 | Ep 4301 | Eps 0.010 | MeanReward(10ep):  32.420 | MeanLoss(100it):  0.02057 | MeanQ:   5.321 | GradNorm:  0.1457
# [DEBUG] Step 1965514 | Ep 4302 | Eps 0.010 | MeanReward(10ep):  32.410 | MeanLoss(100it):  0.01999 | MeanQ:   5.392 | GradNorm:  0.1066
# [DEBUG] Step 1966262 | Ep 4303 | Eps 0.010 | MeanReward(10ep):  32.500 | MeanLoss(100it):  0.01942 | MeanQ:   5.512 | GradNorm:  0.1513
# [DEBUG] Step 1966947 | Ep 4304 | Eps 0.010 | MeanReward(10ep):  32.500 | MeanLoss(100it):  0.01701 | MeanQ:   5.500 | GradNorm:  0.1208
# [DEBUG] Step 1967695 | Ep 4305 | Eps 0.010 | MeanReward(10ep):  32.340 | MeanLoss(100it):  0.01928 | MeanQ:   5.383 | GradNorm:  0.1801
# [DEBUG] Step 1968279 | Ep 4306 | Eps 0.010 | MeanReward(10ep):  32.250 | MeanLoss(100it):  0.01906 | MeanQ:   5.506 | GradNorm:  0.1370
# [DEBUG] Step 1969087 | Ep 4307 | Eps 0.010 | MeanReward(10ep):  32.230 | MeanLoss(100it):  0.01984 | MeanQ:   5.400 | GradNorm:  0.1342
# [DEBUG] Step 1969750 | Ep 4308 | Eps 0.010 | MeanReward(10ep):  32.100 | MeanLoss(100it):  0.02094 | MeanQ:   5.427 | GradNorm:  0.1221
# [DEBUG] Step 1970474 | Ep 4309 | Eps 0.010 | MeanReward(10ep):  32.120 | MeanLoss(100it):  0.02075 | MeanQ:   5.341 | GradNorm:  0.2675
# [DEBUG] Step 1971022 | Ep 4310 | Eps 0.010 | MeanReward(10ep):  32.050 | MeanLoss(100it):  0.02184 | MeanQ:   5.351 | GradNorm:  0.0998
# [DEBUG] Step 1971885 | Ep 4311 | Eps 0.010 | MeanReward(10ep):  31.930 | MeanLoss(100it):  0.02156 | MeanQ:   5.487 | GradNorm:  0.2095
# [DEBUG] Step 1972416 | Ep 4312 | Eps 0.010 | MeanReward(10ep):  31.690 | MeanLoss(100it):  0.01734 | MeanQ:   5.289 | GradNorm:  0.1158
# [DEBUG] Step 1973174 | Ep 4313 | Eps 0.010 | MeanReward(10ep):  31.870 | MeanLoss(100it):  0.01867 | MeanQ:   5.264 | GradNorm:  0.1246
# [DEBUG] Step 1973875 | Ep 4314 | Eps 0.010 | MeanReward(10ep):  32.040 | MeanLoss(100it):  0.02111 | MeanQ:   5.505 | GradNorm:  0.2229
# [DEBUG] Step 1974415 | Ep 4315 | Eps 0.010 | MeanReward(10ep):  32.110 | MeanLoss(100it):  0.01793 | MeanQ:   5.507 | GradNorm:  0.1515
# [DEBUG] Step 1975073 | Ep 4316 | Eps 0.010 | MeanReward(10ep):  32.140 | MeanLoss(100it):  0.01894 | MeanQ:   5.287 | GradNorm:  0.1749
# [DEBUG] Step 1975659 | Ep 4317 | Eps 0.010 | MeanReward(10ep):  32.230 | MeanLoss(100it):  0.02299 | MeanQ:   5.306 | GradNorm:  0.1939
# [DEBUG] Step 1976001 | Ep 4318 | Eps 0.010 | MeanReward(10ep):  32.120 | MeanLoss(100it):  0.01881 | MeanQ:   5.291 | GradNorm:  0.1384
# [DEBUG] Step 1976472 | Ep 4319 | Eps 0.010 | MeanReward(10ep):  32.090 | MeanLoss(100it):  0.01833 | MeanQ:   5.278 | GradNorm:  0.1729
# [DEBUG] Step 1977088 | Ep 4320 | Eps 0.010 | MeanReward(10ep):  32.150 | MeanLoss(100it):  0.02554 | MeanQ:   5.342 | GradNorm:  0.1496
# [DEBUG] Step 1977900 | Ep 4321 | Eps 0.010 | MeanReward(10ep):  32.070 | MeanLoss(100it):  0.02291 | MeanQ:   5.317 | GradNorm:  0.3048
# [DEBUG] Step 1978545 | Ep 4322 | Eps 0.010 | MeanReward(10ep):  31.860 | MeanLoss(100it):  0.01898 | MeanQ:   5.319 | GradNorm:  0.1910
# [DEBUG] Step 1979262 | Ep 4323 | Eps 0.010 | MeanReward(10ep):  31.780 | MeanLoss(100it):  0.01846 | MeanQ:   5.289 | GradNorm:  0.1049
# [DEBUG] Step 1979710 | Ep 4324 | Eps 0.010 | MeanReward(10ep):  31.740 | MeanLoss(100it):  0.02094 | MeanQ:   5.543 | GradNorm:  0.1535
# [DEBUG] Step 1980223 | Ep 4325 | Eps 0.010 | MeanReward(10ep):  31.550 | MeanLoss(100it):  0.01857 | MeanQ:   5.308 | GradNorm:  0.2034
# [DEBUG] Step 1980891 | Ep 4326 | Eps 0.010 | MeanReward(10ep):  31.660 | MeanLoss(100it):  0.01802 | MeanQ:   5.551 | GradNorm:  0.1295
# [DEBUG] Step 1981785 | Ep 4327 | Eps 0.010 | MeanReward(10ep):  31.840 | MeanLoss(100it):  0.02035 | MeanQ:   5.558 | GradNorm:  0.1448
# [DEBUG] Step 1982428 | Ep 4328 | Eps 0.010 | MeanReward(10ep):  32.000 | MeanLoss(100it):  0.02189 | MeanQ:   5.388 | GradNorm:  0.1517
# [DEBUG] Step 1983233 | Ep 4329 | Eps 0.010 | MeanReward(10ep):  32.030 | MeanLoss(100it):  0.01977 | MeanQ:   5.238 | GradNorm:  0.1317
# [DEBUG] Step 1983619 | Ep 4330 | Eps 0.010 | MeanReward(10ep):  31.830 | MeanLoss(100it):  0.01950 | MeanQ:   5.293 | GradNorm:  0.1510
# [DEBUG] Step 1984304 | Ep 4331 | Eps 0.010 | MeanReward(10ep):  32.230 | MeanLoss(100it):  0.02057 | MeanQ:   5.297 | GradNorm:  0.1664
# [DEBUG] Step 1984798 | Ep 4332 | Eps 0.010 | MeanReward(10ep):  32.370 | MeanLoss(100it):  0.02250 | MeanQ:   5.333 | GradNorm:  0.1328
# [DEBUG] Step 1985291 | Ep 4333 | Eps 0.010 | MeanReward(10ep):  32.220 | MeanLoss(100it):  0.02068 | MeanQ:   5.589 | GradNorm:  0.1392
# [DEBUG] Step 1985936 | Ep 4334 | Eps 0.010 | MeanReward(10ep):  32.240 | MeanLoss(100it):  0.01985 | MeanQ:   5.337 | GradNorm:  0.1413
# [DEBUG] Step 1986484 | Ep 4335 | Eps 0.010 | MeanReward(10ep):  32.250 | MeanLoss(100it):  0.02051 | MeanQ:   5.379 | GradNorm:  0.3184
# [DEBUG] Step 1987040 | Ep 4336 | Eps 0.010 | MeanReward(10ep):  32.250 | MeanLoss(100it):  0.01847 | MeanQ:   5.657 | GradNorm:  0.0844
# [DEBUG] Step 1987745 | Ep 4337 | Eps 0.010 | MeanReward(10ep):  32.250 | MeanLoss(100it):  0.02069 | MeanQ:   5.380 | GradNorm:  0.0737
# [DEBUG] Step 1988451 | Ep 4338 | Eps 0.010 | MeanReward(10ep):  32.300 | MeanLoss(100it):  0.02054 | MeanQ:   5.369 | GradNorm:  0.2236
# [DEBUG] Step 1989058 | Ep 4339 | Eps 0.010 | MeanReward(10ep):  32.300 | MeanLoss(100it):  0.02083 | MeanQ:   5.396 | GradNorm:  0.0886
# [DEBUG] Step 1989371 | Ep 4340 | Eps 0.010 | MeanReward(10ep):  32.160 | MeanLoss(100it):  0.02113 | MeanQ:   5.397 | GradNorm:  0.0706
# [DEBUG] Step 1989875 | Ep 4341 | Eps 0.010 | MeanReward(10ep):  32.200 | MeanLoss(100it):  0.01469 | MeanQ:   5.441 | GradNorm:  0.0869
# [DEBUG] Step 1990603 | Ep 4342 | Eps 0.010 | MeanReward(10ep):  31.980 | MeanLoss(100it):  0.02031 | MeanQ:   5.525 | GradNorm:  0.1932
# [DEBUG] Step 1991324 | Ep 4343 | Eps 0.010 | MeanReward(10ep):  31.960 | MeanLoss(100it):  0.02084 | MeanQ:   5.564 | GradNorm:  0.1252
# [DEBUG] Step 1991824 | Ep 4344 | Eps 0.010 | MeanReward(10ep):  31.750 | MeanLoss(100it):  0.02010 | MeanQ:   5.456 | GradNorm:  0.1862
# [DEBUG] Step 1992622 | Ep 4345 | Eps 0.010 | MeanReward(10ep):  32.040 | MeanLoss(100it):  0.02119 | MeanQ:   5.439 | GradNorm:  0.1382
# [DEBUG] Step 1993281 | Ep 4346 | Eps 0.010 | MeanReward(10ep):  32.000 | MeanLoss(100it):  0.01905 | MeanQ:   5.449 | GradNorm:  0.1488
# [DEBUG] Step 1993833 | Ep 4347 | Eps 0.010 | MeanReward(10ep):  31.910 | MeanLoss(100it):  0.02059 | MeanQ:   5.466 | GradNorm:  0.1175
# [DEBUG] Step 1994563 | Ep 4348 | Eps 0.010 | MeanReward(10ep):  31.970 | MeanLoss(100it):  0.01773 | MeanQ:   5.499 | GradNorm:  0.2135
# [DEBUG] Step 1995274 | Ep 4349 | Eps 0.010 | MeanReward(10ep):  31.890 | MeanLoss(100it):  0.01951 | MeanQ:   5.643 | GradNorm:  0.2158
# [DEBUG] Step 1995636 | Ep 4350 | Eps 0.010 | MeanReward(10ep):  31.710 | MeanLoss(100it):  0.02241 | MeanQ:   5.485 | GradNorm:  0.1965
# [DEBUG] Step 1996139 | Ep 4351 | Eps 0.010 | MeanReward(10ep):  31.460 | MeanLoss(100it):  0.01962 | MeanQ:   5.471 | GradNorm:  0.1154
# [DEBUG] Step 1996526 | Ep 4352 | Eps 0.010 | MeanReward(10ep):  31.140 | MeanLoss(100it):  0.01855 | MeanQ:   5.432 | GradNorm:  0.1565
# [DEBUG] Step 1997039 | Ep 4353 | Eps 0.010 | MeanReward(10ep):  31.030 | MeanLoss(100it):  0.01780 | MeanQ:   5.394 | GradNorm:  0.1328
# [DEBUG] Step 1997796 | Ep 4354 | Eps 0.010 | MeanReward(10ep):  31.050 | MeanLoss(100it):  0.01934 | MeanQ:   5.427 | GradNorm:  0.1843
# [DEBUG] Step 1998335 | Ep 4355 | Eps 0.010 | MeanReward(10ep):  31.130 | MeanLoss(100it):  0.01687 | MeanQ:   5.387 | GradNorm:  0.2658
# [DEBUG] Step 1999075 | Ep 4356 | Eps 0.010 | MeanReward(10ep):  31.190 | MeanLoss(100it):  0.02307 | MeanQ:   5.333 | GradNorm:  0.1379
# [DEBUG] Step 1999552 | Ep 4357 | Eps 0.010 | MeanReward(10ep):  30.950 | MeanLoss(100it):  0.01958 | MeanQ:   5.426 | GradNorm:  0.1280
# Saved training data → logs/breakout_training_log_base.csv
# Saved eval data → logs/breakout_eval_log_base.csv
# Saved checkpoint: checkpoints/breakout_final_base.pth

# %%
@dataclass
class Config:
    seed: int = 7
    gamma: float = 0.99  # prioritize short-term rewards
    lr: float = 5e-4  # can reduce to 1e-4 if unstable
    batch_size: int = 64
    buffer_capacity: int = 100_000  # larger buffer for diverse data
    min_buffer_size: int = 20_000  # start training with more data
    max_steps_per_env: int = 2_000_000
    max_episode_len: int = 1000
    epsilon_start: float = 1.0
    epsilon_end: float = 0.01
    epsilon_decay_steps: int = 500_000
    target_update_interval: int = 2000
    train_freq: int = 4
    gradient_clip: float = 10.0
    reward_clip: Optional[float] = 1.0
    use_double_dqn: bool = True
    use_dueling: bool = False  # enabled for better value estimation
    vector_envs: int = 1
    log_interval_episodes: int = 100
    eval_episodes: int = 10
    curriculum: Optional[List[str]] = None
    hidden_size: int = 512

    # these 5 hyperparameters are used for the PER (prioritized experience replay)
    per_alpha: float = 0.6 
    per_eps: float = 0.01
    per_beta_start: float = 0.4
    per_beta_end: float = 1.0
    per_beta_steps: int = 50_000
    use_per: bool = False
    
    n_steps: int = 1
    use_noisy_layer: bool = False

cfg = Config()
cfg.curriculum = [challenge_env_name]

random.seed(cfg.seed)
np.random.seed(cfg.seed)
torch.manual_seed(cfg.seed)
cfg
# Out:
# Config(seed=7, gamma=0.99, lr=0.0005, batch_size=64, buffer_capacity=100000, min_buffer_size=20000, max_steps_per_env=2000000, max_episode_len=1000, epsilon_start=1.0, epsilon_end=0.01, epsilon_decay_steps=500000, target_update_interval=2000, train_freq=4, gradient_clip=10.0, reward_clip=1.0, use_double_dqn=True, use_dueling=False, vector_envs=1, log_interval_episodes=100, eval_episodes=10, curriculum=['breakout'], hidden_size=512, per_alpha=0.6, per_eps=0.01, per_beta_start=0.4, per_beta_end=1.0, per_beta_steps=50000, use_per=False, n_steps=1, use_noisy_layer=False)

# %%
import torch
import torch.optim as optim
import numpy as np
import pandas as pd
import os
import dataclasses

def save_checkpoint(path, q_net, optimizer, cfg, stage_name: str):
    torch.save({
        'model': q_net.state_dict(),
        'optimizer': optimizer.state_dict(),
        'config': dataclasses.asdict(cfg),
        'stage': stage_name,
    }, path)
    print('Saved checkpoint:', path)


# === Training ===
all_stage_logs = {}

q_net = None
target_net = None
optimizer = None
stage_index = 0

# Make directories for outputs
os.makedirs("logs", exist_ok=True)
os.makedirs("checkpoints", exist_ok=True)

for stage_env_name in cfg.curriculum:
    print(f"\n=== Stage {stage_index+1}: {stage_env_name} ===")
    env = make_env(stage_env_name, seed=cfg.seed + stage_index)()
    eval_env = make_env(stage_env_name, seed=cfg.seed + 100 + stage_index)()

    q_net = build_q_network(env, cfg).to(DEVICE)
    # if cfg.use_noisy_layer:
    #     q_net.reset_noise()
    #     target_net.reset_noise()
    target_net = build_q_network(env, cfg).to(DEVICE)
    hard_update(target_net, q_net)
    optimizer = optim.Adam(q_net.parameters(), lr=cfg.lr)

    if cfg.use_per:
        replay = PrioritizedReplayBuffer(
            capacity=cfg.buffer_capacity,
            obs_shape=env.single_observation_space.shape,
            device=DEVICE,
            cfg = cfg
        )
        print("[INFO] Using PrioritizedReplayBuffer")
    else:
        replay = ReplayBuffer(cfg.buffer_capacity, env.single_observation_space.shape, DEVICE)
        print("[INFO] Using uniform ReplayBuffer")

    logs = {
        'episode_rewards': [],
        'losses': [],
        'eps_history': [],
        'eval': [],
    }

    obs, _ = env.reset()
    ep_reward = 0
    ep_steps = 0
    episode_counter = 0
    recent_ep_returns = []
    total_steps = 0

    trajectory_buffer = deque(maxlen=cfg.n_steps)

    print('Starting training...')
    while total_steps < cfg.max_steps_per_env:
        if cfg.use_noisy_layer:
            epsilon = 0.0  # No epsilon-greedy when using noisy networks
        else:
            epsilon = epsilon_by_step(total_steps, cfg)
        action = select_action(q_net, obs, epsilon, env)
        next_obs, reward, terminated, truncated, info = env.step(action)
        reward = process_reward(reward, cfg)
        reward = float(np.asarray(reward).reshape(-1)[0])
        done = bool(np.asarray(terminated).reshape(-1)[0] or np.asarray(truncated).reshape(-1)[0])

        trajectory_buffer.append((obs.copy(), int(action), reward, next_obs.copy(), done))

        # Push n-step transitions once we have enough data
        if len(trajectory_buffer) >= cfg.n_steps:
            # Calculate n-step return
            n_step_reward = 0.0
            for i, (_, _, r, _, _) in enumerate(trajectory_buffer):  # Use 'r' to avoid name collision
                n_step_reward += (cfg.gamma ** i) * r
            
            # Extract first obs/action and last next_obs/done
            first_obs, first_action, _, _, _ = trajectory_buffer[0]  # ✅ Define these variables!
            _, _, _, last_next_obs, last_done = trajectory_buffer[-1]
            
            # Push to replay buffer (only once!)
            replay.push(first_obs, first_action, n_step_reward, last_next_obs, last_done)

        # Handle episode end: push remaining incomplete n-step transitions
        if done:
            # Push any remaining partial n-step returns
            for start_idx in range(1, len(trajectory_buffer)):
                steps_available = len(trajectory_buffer) - start_idx
                n_step_reward = 0.0
                
                for i in range(steps_available):
                    _, _, r, _, _ = trajectory_buffer[start_idx + i]
                    n_step_reward += (cfg.gamma ** i) * r
                
                first_obs, first_action, _, _, _ = trajectory_buffer[start_idx]
                _, _, _, last_next_obs, last_done = trajectory_buffer[-1]
                
                replay.push(first_obs, first_action, n_step_reward, last_next_obs, last_done)
            
            trajectory_buffer.clear()

        obs = next_obs.copy()
        ep_reward += reward
        ep_steps += 1
        total_steps += 1

        # Training
        if total_steps % cfg.train_freq == 0:
            loss = train_step(q_net, target_net, optimizer, replay, cfg)
            if loss is not None:
                logs['losses'].append(loss)

        # Target update
        if total_steps % cfg.target_update_interval == 0:
            hard_update(target_net, q_net)

        logs['eps_history'].append(epsilon)

        if done or ep_steps >= cfg.max_episode_len:
            logs['episode_rewards'].append(ep_reward)
            recent_ep_returns.append(ep_reward)
            episode_counter += 1

            # --- DEBUG PRINT ---
            mean_loss = np.mean(logs['losses'][-100:]) if logs['losses'] else 0.0
            mean_reward = np.mean(recent_ep_returns[-cfg.log_interval_episodes:]) if recent_ep_returns else 0.0
            with torch.no_grad():
                q_sample = q_net(torch.FloatTensor(obs).unsqueeze(0).to(DEVICE))
                mean_q = q_sample.mean().item()
            grads = [p.grad.norm().item() for p in q_net.parameters() if p.grad is not None]
            grad_norm = np.mean(grads) if grads else 0.0
            print(f"[DEBUG] Step {total_steps:6d} | Ep {episode_counter:4d} | "
                  f"Eps {epsilon:.3f} | MeanReward(10ep): {mean_reward:7.3f} | "
                  f"MeanLoss(100it): {mean_loss:8.5f} | "
                  f"MeanQ: {mean_q:7.3f} | GradNorm: {grad_norm:7.4f}")

            if episode_counter % cfg.log_interval_episodes == 0:
                mean_recent = np.mean(recent_ep_returns[-cfg.log_interval_episodes:])
                print(f"[{stage_env_name}] Ep {episode_counter} Steps {total_steps} "
                      f"RecentMean {mean_recent:.2f} Eps {epsilon:.3f}")

            obs, _ = env.reset()
            ep_reward = 0
            ep_steps = 0

            # Periodic evaluation (every 2*log_interval episodes if we have progress)
            if episode_counter % (cfg.log_interval_episodes * 2) == 0:
                eval_ret = evaluate(eval_env, q_net, cfg, cfg.eval_episodes)
                logs['eval'].append((total_steps, eval_ret))
                print(f"Eval @ Ep {episode_counter} and {total_steps} steps => mean return {eval_ret:.2f}")

    # --- Save logs and model after each stage ---
    all_stage_logs[stage_env_name] = logs

    # Save training logs
    df = pd.DataFrame({
        'episode_rewards': logs['episode_rewards'],
        'losses': logs['losses'][:len(logs['episode_rewards'])],
        'eps_history': logs['eps_history'][:len(logs['episode_rewards'])],
    })
    train_csv = f"logs/{stage_env_name}_training_log_double.csv"
    df.to_csv(train_csv, index=False)
    print(f"Saved training data → {train_csv}")

    # Save evaluation results
    eval_df = pd.DataFrame(logs['eval'], columns=['total_steps', 'eval_return'])
    eval_csv = f"logs/{stage_env_name}_eval_log_double.csv"
    eval_df.to_csv(eval_csv, index=False)
    print(f"Saved eval data → {eval_csv}")

    # Save model checkpoint
    checkpoint_path = f"checkpoints/{stage_env_name}_final_double.pth"
    save_checkpoint(checkpoint_path, q_net, optimizer, cfg, stage_env_name)

    stage_index += 1
# Out:
# === Stage 1: breakout ===
# Obs space: 118
# Obs space: 118
# [INFO] Using uniform ReplayBuffer
# Starting training...
# [DEBUG] Step    116 | Ep    1 | Eps 1.000 | MeanReward(10ep):   0.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step    334 | Ep    2 | Eps 0.999 | MeanReward(10ep):   2.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step    450 | Ep    3 | Eps 0.999 | MeanReward(10ep):   1.333 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step    605 | Ep    4 | Eps 0.999 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step    840 | Ep    5 | Eps 0.998 | MeanReward(10ep):   1.800 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step    995 | Ep    6 | Eps 0.998 | MeanReward(10ep):   1.667 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   1160 | Ep    7 | Eps 0.998 | MeanReward(10ep):   1.714 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   1276 | Ep    8 | Eps 0.997 | MeanReward(10ep):   1.500 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   1409 | Ep    9 | Eps 0.997 | MeanReward(10ep):   1.444 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   1590 | Ep   10 | Eps 0.997 | MeanReward(10ep):   1.500 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   1706 | Ep   11 | Eps 0.997 | MeanReward(10ep):   1.364 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   1822 | Ep   12 | Eps 0.996 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   1956 | Ep   13 | Eps 0.996 | MeanReward(10ep):   1.231 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   2136 | Ep   14 | Eps 0.996 | MeanReward(10ep):   1.214 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   2252 | Ep   15 | Eps 0.996 | MeanReward(10ep):   1.133 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   2385 | Ep   16 | Eps 0.995 | MeanReward(10ep):   1.125 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   2501 | Ep   17 | Eps 0.995 | MeanReward(10ep):   1.059 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   2617 | Ep   18 | Eps 0.995 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   2733 | Ep   19 | Eps 0.995 | MeanReward(10ep):   0.947 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   2886 | Ep   20 | Eps 0.994 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   3067 | Ep   21 | Eps 0.994 | MeanReward(10ep):   1.048 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   3183 | Ep   22 | Eps 0.994 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   3393 | Ep   23 | Eps 0.993 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   3546 | Ep   24 | Eps 0.993 | MeanReward(10ep):   1.125 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   3736 | Ep   25 | Eps 0.993 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   3852 | Ep   26 | Eps 0.992 | MeanReward(10ep):   1.154 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   3968 | Ep   27 | Eps 0.992 | MeanReward(10ep):   1.111 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   4102 | Ep   28 | Eps 0.992 | MeanReward(10ep):   1.107 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   4268 | Ep   29 | Eps 0.992 | MeanReward(10ep):   1.138 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   4384 | Ep   30 | Eps 0.991 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   4500 | Ep   31 | Eps 0.991 | MeanReward(10ep):   1.065 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   4616 | Ep   32 | Eps 0.991 | MeanReward(10ep):   1.031 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   4732 | Ep   33 | Eps 0.991 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   4848 | Ep   34 | Eps 0.990 | MeanReward(10ep):   0.971 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   4964 | Ep   35 | Eps 0.990 | MeanReward(10ep):   0.943 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   5080 | Ep   36 | Eps 0.990 | MeanReward(10ep):   0.917 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   5196 | Ep   37 | Eps 0.990 | MeanReward(10ep):   0.892 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   5312 | Ep   38 | Eps 0.989 | MeanReward(10ep):   0.868 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   5428 | Ep   39 | Eps 0.989 | MeanReward(10ep):   0.846 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   5591 | Ep   40 | Eps 0.989 | MeanReward(10ep):   0.875 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   5763 | Ep   41 | Eps 0.989 | MeanReward(10ep):   0.902 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   5879 | Ep   42 | Eps 0.988 | MeanReward(10ep):   0.881 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   6020 | Ep   43 | Eps 0.988 | MeanReward(10ep):   0.884 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   6194 | Ep   44 | Eps 0.988 | MeanReward(10ep):   0.909 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   6310 | Ep   45 | Eps 0.988 | MeanReward(10ep):   0.889 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   6426 | Ep   46 | Eps 0.987 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   6542 | Ep   47 | Eps 0.987 | MeanReward(10ep):   0.851 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   6676 | Ep   48 | Eps 0.987 | MeanReward(10ep):   0.854 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   6856 | Ep   49 | Eps 0.986 | MeanReward(10ep):   0.857 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   7032 | Ep   50 | Eps 0.986 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   7148 | Ep   51 | Eps 0.986 | MeanReward(10ep):   0.863 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   7264 | Ep   52 | Eps 0.986 | MeanReward(10ep):   0.846 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   7380 | Ep   53 | Eps 0.985 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   7496 | Ep   54 | Eps 0.985 | MeanReward(10ep):   0.815 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   7612 | Ep   55 | Eps 0.985 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   7728 | Ep   56 | Eps 0.985 | MeanReward(10ep):   0.786 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   7906 | Ep   57 | Eps 0.984 | MeanReward(10ep):   0.807 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   8022 | Ep   58 | Eps 0.984 | MeanReward(10ep):   0.793 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   8138 | Ep   59 | Eps 0.984 | MeanReward(10ep):   0.780 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   8254 | Ep   60 | Eps 0.984 | MeanReward(10ep):   0.767 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   8370 | Ep   61 | Eps 0.983 | MeanReward(10ep):   0.754 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   8486 | Ep   62 | Eps 0.983 | MeanReward(10ep):   0.742 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   8602 | Ep   63 | Eps 0.983 | MeanReward(10ep):   0.730 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   8735 | Ep   64 | Eps 0.983 | MeanReward(10ep):   0.734 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   8890 | Ep   65 | Eps 0.982 | MeanReward(10ep):   0.738 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   9024 | Ep   66 | Eps 0.982 | MeanReward(10ep):   0.742 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   9140 | Ep   67 | Eps 0.982 | MeanReward(10ep):   0.731 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   9337 | Ep   68 | Eps 0.982 | MeanReward(10ep):   0.750 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   9453 | Ep   69 | Eps 0.981 | MeanReward(10ep):   0.739 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   9651 | Ep   70 | Eps 0.981 | MeanReward(10ep):   0.757 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   9767 | Ep   71 | Eps 0.981 | MeanReward(10ep):   0.746 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step   9927 | Ep   72 | Eps 0.980 | MeanReward(10ep):   0.764 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  10043 | Ep   73 | Eps 0.980 | MeanReward(10ep):   0.753 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  10159 | Ep   74 | Eps 0.980 | MeanReward(10ep):   0.743 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  10275 | Ep   75 | Eps 0.980 | MeanReward(10ep):   0.733 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  10391 | Ep   76 | Eps 0.979 | MeanReward(10ep):   0.724 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  10604 | Ep   77 | Eps 0.979 | MeanReward(10ep):   0.753 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  10738 | Ep   78 | Eps 0.979 | MeanReward(10ep):   0.756 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  10880 | Ep   79 | Eps 0.978 | MeanReward(10ep):   0.759 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  10996 | Ep   80 | Eps 0.978 | MeanReward(10ep):   0.750 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  11112 | Ep   81 | Eps 0.978 | MeanReward(10ep):   0.741 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  11228 | Ep   82 | Eps 0.978 | MeanReward(10ep):   0.732 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  11344 | Ep   83 | Eps 0.978 | MeanReward(10ep):   0.723 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  11460 | Ep   84 | Eps 0.977 | MeanReward(10ep):   0.714 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  11576 | Ep   85 | Eps 0.977 | MeanReward(10ep):   0.706 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  11712 | Ep   86 | Eps 0.977 | MeanReward(10ep):   0.709 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  11867 | Ep   87 | Eps 0.977 | MeanReward(10ep):   0.713 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  12020 | Ep   88 | Eps 0.976 | MeanReward(10ep):   0.716 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  12136 | Ep   89 | Eps 0.976 | MeanReward(10ep):   0.708 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  12252 | Ep   90 | Eps 0.976 | MeanReward(10ep):   0.700 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  12368 | Ep   91 | Eps 0.976 | MeanReward(10ep):   0.692 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  12484 | Ep   92 | Eps 0.975 | MeanReward(10ep):   0.685 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  12600 | Ep   93 | Eps 0.975 | MeanReward(10ep):   0.677 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  12716 | Ep   94 | Eps 0.975 | MeanReward(10ep):   0.670 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  12832 | Ep   95 | Eps 0.975 | MeanReward(10ep):   0.663 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  12966 | Ep   96 | Eps 0.974 | MeanReward(10ep):   0.667 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  13082 | Ep   97 | Eps 0.974 | MeanReward(10ep):   0.660 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  13262 | Ep   98 | Eps 0.974 | MeanReward(10ep):   0.663 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  13395 | Ep   99 | Eps 0.973 | MeanReward(10ep):   0.667 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  13585 | Ep  100 | Eps 0.973 | MeanReward(10ep):   0.680 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [breakout] Ep 100 Steps 13585 RecentMean 0.68 Eps 0.973
# [DEBUG] Step  13742 | Ep  101 | Eps 0.973 | MeanReward(10ep):   0.700 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  13858 | Ep  102 | Eps 0.973 | MeanReward(10ep):   0.660 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  14038 | Ep  103 | Eps 0.972 | MeanReward(10ep):   0.670 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  14189 | Ep  104 | Eps 0.972 | MeanReward(10ep):   0.680 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  14331 | Ep  105 | Eps 0.972 | MeanReward(10ep):   0.650 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  14464 | Ep  106 | Eps 0.971 | MeanReward(10ep):   0.650 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  14580 | Ep  107 | Eps 0.971 | MeanReward(10ep):   0.630 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  14720 | Ep  108 | Eps 0.971 | MeanReward(10ep):   0.640 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  14836 | Ep  109 | Eps 0.971 | MeanReward(10ep):   0.630 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  14952 | Ep  110 | Eps 0.970 | MeanReward(10ep):   0.610 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  15068 | Ep  111 | Eps 0.970 | MeanReward(10ep):   0.610 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  15184 | Ep  112 | Eps 0.970 | MeanReward(10ep):   0.610 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  15300 | Ep  113 | Eps 0.970 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  15416 | Ep  114 | Eps 0.969 | MeanReward(10ep):   0.590 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  15549 | Ep  115 | Eps 0.969 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  15793 | Ep  116 | Eps 0.969 | MeanReward(10ep):   0.620 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  15974 | Ep  117 | Eps 0.968 | MeanReward(10ep):   0.640 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  16090 | Ep  118 | Eps 0.968 | MeanReward(10ep):   0.640 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  16206 | Ep  119 | Eps 0.968 | MeanReward(10ep):   0.640 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  16322 | Ep  120 | Eps 0.968 | MeanReward(10ep):   0.620 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  16438 | Ep  121 | Eps 0.967 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  16554 | Ep  122 | Eps 0.967 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  16695 | Ep  123 | Eps 0.967 | MeanReward(10ep):   0.570 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  16837 | Ep  124 | Eps 0.967 | MeanReward(10ep):   0.570 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  16990 | Ep  125 | Eps 0.966 | MeanReward(10ep):   0.560 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  17106 | Ep  126 | Eps 0.966 | MeanReward(10ep):   0.560 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  17222 | Ep  127 | Eps 0.966 | MeanReward(10ep):   0.560 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  17338 | Ep  128 | Eps 0.966 | MeanReward(10ep):   0.550 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  17454 | Ep  129 | Eps 0.965 | MeanReward(10ep):   0.530 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  17570 | Ep  130 | Eps 0.965 | MeanReward(10ep):   0.530 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  17712 | Ep  131 | Eps 0.965 | MeanReward(10ep):   0.540 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  17873 | Ep  132 | Eps 0.965 | MeanReward(10ep):   0.560 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  17989 | Ep  133 | Eps 0.964 | MeanReward(10ep):   0.560 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  18105 | Ep  134 | Eps 0.964 | MeanReward(10ep):   0.560 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  18221 | Ep  135 | Eps 0.964 | MeanReward(10ep):   0.560 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  18356 | Ep  136 | Eps 0.964 | MeanReward(10ep):   0.570 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  18536 | Ep  137 | Eps 0.963 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  18652 | Ep  138 | Eps 0.963 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  18901 | Ep  139 | Eps 0.963 | MeanReward(10ep):   0.620 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  19017 | Ep  140 | Eps 0.962 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  19133 | Ep  141 | Eps 0.962 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  19249 | Ep  142 | Eps 0.962 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  19365 | Ep  143 | Eps 0.962 | MeanReward(10ep):   0.570 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  19548 | Ep  144 | Eps 0.961 | MeanReward(10ep):   0.570 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  19681 | Ep  145 | Eps 0.961 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  19797 | Ep  146 | Eps 0.961 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  19913 | Ep  147 | Eps 0.961 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00000 | MeanQ:   0.019 | GradNorm:  0.0000
# [DEBUG] Step  20100 | Ep  148 | Eps 0.960 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00381 | MeanQ:   0.040 | GradNorm:  0.0058
# [DEBUG] Step  20280 | Ep  149 | Eps 0.960 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00346 | MeanQ:   0.087 | GradNorm:  0.0101
# [DEBUG] Step  20396 | Ep  150 | Eps 0.960 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00326 | MeanQ:   0.093 | GradNorm:  0.0104
# [DEBUG] Step  20512 | Ep  151 | Eps 0.959 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00337 | MeanQ:   0.085 | GradNorm:  0.0033
# [DEBUG] Step  20628 | Ep  152 | Eps 0.959 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00275 | MeanQ:   0.061 | GradNorm:  0.0066
# [DEBUG] Step  20744 | Ep  153 | Eps 0.959 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00256 | MeanQ:   0.045 | GradNorm:  0.0075
# [DEBUG] Step  20878 | Ep  154 | Eps 0.959 | MeanReward(10ep):   0.590 | MeanLoss(100it):  0.00232 | MeanQ:   0.058 | GradNorm:  0.0018
# [DEBUG] Step  20994 | Ep  155 | Eps 0.958 | MeanReward(10ep):   0.590 | MeanLoss(100it):  0.00209 | MeanQ:   0.095 | GradNorm:  0.0066
# [DEBUG] Step  21135 | Ep  156 | Eps 0.958 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00215 | MeanQ:   0.087 | GradNorm:  0.0059
# [DEBUG] Step  21251 | Ep  157 | Eps 0.958 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00219 | MeanQ:   0.087 | GradNorm:  0.0070
# [DEBUG] Step  21480 | Ep  158 | Eps 0.957 | MeanReward(10ep):   0.620 | MeanLoss(100it):  0.00252 | MeanQ:   0.105 | GradNorm:  0.0070
# [DEBUG] Step  21596 | Ep  159 | Eps 0.957 | MeanReward(10ep):   0.620 | MeanLoss(100it):  0.00246 | MeanQ:   0.057 | GradNorm:  0.0068
# [DEBUG] Step  21857 | Ep  160 | Eps 0.957 | MeanReward(10ep):   0.650 | MeanLoss(100it):  0.00201 | MeanQ:   0.093 | GradNorm:  0.0061
# [DEBUG] Step  21973 | Ep  161 | Eps 0.956 | MeanReward(10ep):   0.650 | MeanLoss(100it):  0.00231 | MeanQ:   0.067 | GradNorm:  0.0017
# [DEBUG] Step  22128 | Ep  162 | Eps 0.956 | MeanReward(10ep):   0.660 | MeanLoss(100it):  0.00248 | MeanQ:   0.073 | GradNorm:  0.0021
# [DEBUG] Step  22244 | Ep  163 | Eps 0.956 | MeanReward(10ep):   0.660 | MeanLoss(100it):  0.00277 | MeanQ:   0.086 | GradNorm:  0.0023
# [DEBUG] Step  22491 | Ep  164 | Eps 0.955 | MeanReward(10ep):   0.690 | MeanLoss(100it):  0.00265 | MeanQ:   0.080 | GradNorm:  0.0013
# [DEBUG] Step  22607 | Ep  165 | Eps 0.955 | MeanReward(10ep):   0.680 | MeanLoss(100it):  0.00264 | MeanQ:   0.073 | GradNorm:  0.0019
# [DEBUG] Step  22723 | Ep  166 | Eps 0.955 | MeanReward(10ep):   0.670 | MeanLoss(100it):  0.00240 | MeanQ:   0.053 | GradNorm:  0.0037
# [DEBUG] Step  22839 | Ep  167 | Eps 0.955 | MeanReward(10ep):   0.670 | MeanLoss(100it):  0.00188 | MeanQ:   0.070 | GradNorm:  0.0010
# [DEBUG] Step  22955 | Ep  168 | Eps 0.955 | MeanReward(10ep):   0.650 | MeanLoss(100it):  0.00175 | MeanQ:   0.060 | GradNorm:  0.0022
# [DEBUG] Step  23119 | Ep  169 | Eps 0.954 | MeanReward(10ep):   0.670 | MeanLoss(100it):  0.00184 | MeanQ:   0.094 | GradNorm:  0.0015
# [DEBUG] Step  23235 | Ep  170 | Eps 0.954 | MeanReward(10ep):   0.650 | MeanLoss(100it):  0.00235 | MeanQ:   0.102 | GradNorm:  0.0010
# [DEBUG] Step  23351 | Ep  171 | Eps 0.954 | MeanReward(10ep):   0.650 | MeanLoss(100it):  0.00251 | MeanQ:   0.092 | GradNorm:  0.0020
# [DEBUG] Step  23493 | Ep  172 | Eps 0.953 | MeanReward(10ep):   0.640 | MeanLoss(100it):  0.00324 | MeanQ:   0.110 | GradNorm:  0.0083
# [DEBUG] Step  23609 | Ep  173 | Eps 0.953 | MeanReward(10ep):   0.640 | MeanLoss(100it):  0.00283 | MeanQ:   0.071 | GradNorm:  0.0030
# [DEBUG] Step  23814 | Ep  174 | Eps 0.953 | MeanReward(10ep):   0.680 | MeanLoss(100it):  0.00249 | MeanQ:   0.080 | GradNorm:  0.0008
# [DEBUG] Step  24011 | Ep  175 | Eps 0.952 | MeanReward(10ep):   0.710 | MeanLoss(100it):  0.00207 | MeanQ:   0.073 | GradNorm:  0.0021
# [DEBUG] Step  24153 | Ep  176 | Eps 0.952 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00197 | MeanQ:   0.088 | GradNorm:  0.0040
# [DEBUG] Step  24269 | Ep  177 | Eps 0.952 | MeanReward(10ep):   0.690 | MeanLoss(100it):  0.00207 | MeanQ:   0.076 | GradNorm:  0.0019
# [DEBUG] Step  24424 | Ep  178 | Eps 0.952 | MeanReward(10ep):   0.690 | MeanLoss(100it):  0.00209 | MeanQ:   0.088 | GradNorm:  0.0011
# [DEBUG] Step  24540 | Ep  179 | Eps 0.951 | MeanReward(10ep):   0.680 | MeanLoss(100it):  0.00190 | MeanQ:   0.070 | GradNorm:  0.0022
# [DEBUG] Step  24700 | Ep  180 | Eps 0.951 | MeanReward(10ep):   0.700 | MeanLoss(100it):  0.00169 | MeanQ:   0.083 | GradNorm:  0.0049
# [DEBUG] Step  24816 | Ep  181 | Eps 0.951 | MeanReward(10ep):   0.700 | MeanLoss(100it):  0.00174 | MeanQ:   0.067 | GradNorm:  0.0044
# [DEBUG] Step  24950 | Ep  182 | Eps 0.951 | MeanReward(10ep):   0.710 | MeanLoss(100it):  0.00203 | MeanQ:   0.073 | GradNorm:  0.0179
# [DEBUG] Step  25187 | Ep  183 | Eps 0.950 | MeanReward(10ep):   0.750 | MeanLoss(100it):  0.00199 | MeanQ:   0.133 | GradNorm:  0.0083
# [DEBUG] Step  25303 | Ep  184 | Eps 0.950 | MeanReward(10ep):   0.750 | MeanLoss(100it):  0.00218 | MeanQ:   0.098 | GradNorm:  0.0087
# [DEBUG] Step  25506 | Ep  185 | Eps 0.950 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00228 | MeanQ:   0.069 | GradNorm:  0.0072
# [DEBUG] Step  25639 | Ep  186 | Eps 0.949 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00215 | MeanQ:   0.079 | GradNorm:  0.0031
# [DEBUG] Step  25856 | Ep  187 | Eps 0.949 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00174 | MeanQ:   0.064 | GradNorm:  0.0111
# [DEBUG] Step  26073 | Ep  188 | Eps 0.948 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00196 | MeanQ:   0.382 | GradNorm:  0.0116
# [DEBUG] Step  26232 | Ep  189 | Eps 0.948 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00209 | MeanQ:   0.205 | GradNorm:  0.0197
# [DEBUG] Step  26348 | Ep  190 | Eps 0.948 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00219 | MeanQ:   0.105 | GradNorm:  0.0080
# [DEBUG] Step  26490 | Ep  191 | Eps 0.948 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00191 | MeanQ:   0.235 | GradNorm:  0.0024
# [DEBUG] Step  26653 | Ep  192 | Eps 0.947 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00182 | MeanQ:   0.351 | GradNorm:  0.0136
# [DEBUG] Step  26769 | Ep  193 | Eps 0.947 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00189 | MeanQ:   0.197 | GradNorm:  0.0029
# [DEBUG] Step  26885 | Ep  194 | Eps 0.947 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00193 | MeanQ:   0.194 | GradNorm:  0.0097
# [DEBUG] Step  27001 | Ep  195 | Eps 0.947 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00180 | MeanQ:   0.375 | GradNorm:  0.0196
# [DEBUG] Step  27117 | Ep  196 | Eps 0.946 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00170 | MeanQ:   0.152 | GradNorm:  0.0026
# [DEBUG] Step  27233 | Ep  197 | Eps 0.946 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00145 | MeanQ:   0.235 | GradNorm:  0.0036
# [DEBUG] Step  27374 | Ep  198 | Eps 0.946 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00133 | MeanQ:   0.152 | GradNorm:  0.0180
# [DEBUG] Step  27490 | Ep  199 | Eps 0.946 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00111 | MeanQ:   0.207 | GradNorm:  0.0050
# [DEBUG] Step  27645 | Ep  200 | Eps 0.945 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00116 | MeanQ:   0.221 | GradNorm:  0.0015
# [breakout] Ep 200 Steps 27645 RecentMean 0.85 Eps 0.945
# Eval @ Ep 200 and 27645 steps => mean return 4.00
# [DEBUG] Step  27761 | Ep  201 | Eps 0.945 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00120 | MeanQ:   0.251 | GradNorm:  0.0162
# [DEBUG] Step  27877 | Ep  202 | Eps 0.945 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00125 | MeanQ:   0.212 | GradNorm:  0.0029
# [DEBUG] Step  28084 | Ep  203 | Eps 0.944 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00144 | MeanQ:   0.251 | GradNorm:  0.0036
# [DEBUG] Step  28225 | Ep  204 | Eps 0.944 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00147 | MeanQ:   0.100 | GradNorm:  0.0011
# [DEBUG] Step  28341 | Ep  205 | Eps 0.944 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00130 | MeanQ:   0.221 | GradNorm:  0.0232
# [DEBUG] Step  28457 | Ep  206 | Eps 0.944 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00117 | MeanQ:   0.148 | GradNorm:  0.0035
# [DEBUG] Step  28674 | Ep  207 | Eps 0.943 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00078 | MeanQ:   0.250 | GradNorm:  0.0190
# [DEBUG] Step  28790 | Ep  208 | Eps 0.943 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00106 | MeanQ:   0.147 | GradNorm:  0.0378
# [DEBUG] Step  28970 | Ep  209 | Eps 0.943 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00111 | MeanQ:   0.235 | GradNorm:  0.0033
# [DEBUG] Step  29086 | Ep  210 | Eps 0.942 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00110 | MeanQ:   0.203 | GradNorm:  0.0048
# [DEBUG] Step  29202 | Ep  211 | Eps 0.942 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00094 | MeanQ:   0.273 | GradNorm:  0.0187
# [DEBUG] Step  29318 | Ep  212 | Eps 0.942 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00091 | MeanQ:   0.192 | GradNorm:  0.0086
# [DEBUG] Step  29521 | Ep  213 | Eps 0.942 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00097 | MeanQ:   0.092 | GradNorm:  0.0423
# [DEBUG] Step  29701 | Ep  214 | Eps 0.941 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00090 | MeanQ:   0.117 | GradNorm:  0.0057
# [DEBUG] Step  29817 | Ep  215 | Eps 0.941 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00085 | MeanQ:   0.207 | GradNorm:  0.0024
# [DEBUG] Step  30157 | Ep  216 | Eps 0.940 | MeanReward(10ep):   0.930 | MeanLoss(100it):  0.00089 | MeanQ:   0.077 | GradNorm:  0.0135
# [DEBUG] Step  30307 | Ep  217 | Eps 0.940 | MeanReward(10ep):   0.920 | MeanLoss(100it):  0.00112 | MeanQ:   0.079 | GradNorm:  0.0141
# [DEBUG] Step  30538 | Ep  218 | Eps 0.940 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00133 | MeanQ:   0.127 | GradNorm:  0.0344
# [DEBUG] Step  30654 | Ep  219 | Eps 0.939 | MeanReward(10ep):   0.970 | MeanLoss(100it):  0.00143 | MeanQ:   0.111 | GradNorm:  0.0212
# [DEBUG] Step  30795 | Ep  220 | Eps 0.939 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00132 | MeanQ:   0.090 | GradNorm:  0.0145
# [DEBUG] Step  30935 | Ep  221 | Eps 0.939 | MeanReward(10ep):   0.990 | MeanLoss(100it):  0.00124 | MeanQ:   0.191 | GradNorm:  0.0050
# [DEBUG] Step  31068 | Ep  222 | Eps 0.938 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00103 | MeanQ:   0.072 | GradNorm:  0.0110
# [DEBUG] Step  31205 | Ep  223 | Eps 0.938 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00108 | MeanQ:   0.079 | GradNorm:  0.0263
# [DEBUG] Step  31403 | Ep  224 | Eps 0.938 | MeanReward(10ep):   1.010 | MeanLoss(100it):  0.00105 | MeanQ:   0.073 | GradNorm:  0.0065
# [DEBUG] Step  31583 | Ep  225 | Eps 0.937 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00096 | MeanQ:   0.077 | GradNorm:  0.0011
# [DEBUG] Step  31725 | Ep  226 | Eps 0.937 | MeanReward(10ep):   1.010 | MeanLoss(100it):  0.00097 | MeanQ:   0.075 | GradNorm:  0.0055
# [DEBUG] Step  31858 | Ep  227 | Eps 0.937 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00098 | MeanQ:   0.146 | GradNorm:  0.0093
# [DEBUG] Step  31994 | Ep  228 | Eps 0.937 | MeanReward(10ep):   1.030 | MeanLoss(100it):  0.00095 | MeanQ:   0.080 | GradNorm:  0.0110
# [DEBUG] Step  32174 | Ep  229 | Eps 0.936 | MeanReward(10ep):   1.040 | MeanLoss(100it):  0.00086 | MeanQ:   0.113 | GradNorm:  0.0013
# [DEBUG] Step  32290 | Ep  230 | Eps 0.936 | MeanReward(10ep):   1.040 | MeanLoss(100it):  0.00085 | MeanQ:   0.239 | GradNorm:  0.0193
# [DEBUG] Step  32406 | Ep  231 | Eps 0.936 | MeanReward(10ep):   1.030 | MeanLoss(100it):  0.00087 | MeanQ:   0.072 | GradNorm:  0.0171
# [DEBUG] Step  32548 | Ep  232 | Eps 0.936 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00088 | MeanQ:   0.089 | GradNorm:  0.0197
# [DEBUG] Step  32682 | Ep  233 | Eps 0.935 | MeanReward(10ep):   1.030 | MeanLoss(100it):  0.00091 | MeanQ:   0.090 | GradNorm:  0.0244
# [DEBUG] Step  32918 | Ep  234 | Eps 0.935 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00076 | MeanQ:   0.136 | GradNorm:  0.0146
# [DEBUG] Step  33034 | Ep  235 | Eps 0.935 | MeanReward(10ep):   1.070 | MeanLoss(100it):  0.00072 | MeanQ:   0.116 | GradNorm:  0.0221
# [DEBUG] Step  33283 | Ep  236 | Eps 0.934 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00090 | MeanQ:   0.274 | GradNorm:  0.0319
# [DEBUG] Step  33433 | Ep  237 | Eps 0.934 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00088 | MeanQ:   0.089 | GradNorm:  0.0070
# [DEBUG] Step  33613 | Ep  238 | Eps 0.933 | MeanReward(10ep):   1.110 | MeanLoss(100it):  0.00078 | MeanQ:   0.066 | GradNorm:  0.0054
# [DEBUG] Step  33793 | Ep  239 | Eps 0.933 | MeanReward(10ep):   1.080 | MeanLoss(100it):  0.00078 | MeanQ:   0.095 | GradNorm:  0.0045
# [DEBUG] Step  33936 | Ep  240 | Eps 0.933 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00078 | MeanQ:   0.154 | GradNorm:  0.0140
# [DEBUG] Step  34122 | Ep  241 | Eps 0.932 | MeanReward(10ep):   1.120 | MeanLoss(100it):  0.00087 | MeanQ:   0.160 | GradNorm:  0.0129
# [DEBUG] Step  34238 | Ep  242 | Eps 0.932 | MeanReward(10ep):   1.120 | MeanLoss(100it):  0.00088 | MeanQ:   0.172 | GradNorm:  0.0039
# [DEBUG] Step  34354 | Ep  243 | Eps 0.932 | MeanReward(10ep):   1.120 | MeanLoss(100it):  0.00092 | MeanQ:   0.058 | GradNorm:  0.0239
# [DEBUG] Step  34488 | Ep  244 | Eps 0.932 | MeanReward(10ep):   1.110 | MeanLoss(100it):  0.00092 | MeanQ:   0.070 | GradNorm:  0.0081
# [DEBUG] Step  34604 | Ep  245 | Eps 0.931 | MeanReward(10ep):   1.100 | MeanLoss(100it):  0.00083 | MeanQ:   0.145 | GradNorm:  0.0160
# [DEBUG] Step  34786 | Ep  246 | Eps 0.931 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00093 | MeanQ:   0.163 | GradNorm:  0.0158
# [DEBUG] Step  34975 | Ep  247 | Eps 0.931 | MeanReward(10ep):   1.150 | MeanLoss(100it):  0.00107 | MeanQ:   0.062 | GradNorm:  0.0183
# [DEBUG] Step  35116 | Ep  248 | Eps 0.930 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00116 | MeanQ:   0.119 | GradNorm:  0.0142
# [DEBUG] Step  35266 | Ep  249 | Eps 0.930 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00111 | MeanQ:   0.083 | GradNorm:  0.0047
# [DEBUG] Step  35382 | Ep  250 | Eps 0.930 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00107 | MeanQ:   0.141 | GradNorm:  0.0044
# [DEBUG] Step  35516 | Ep  251 | Eps 0.930 | MeanReward(10ep):   1.140 | MeanLoss(100it):  0.00099 | MeanQ:   0.062 | GradNorm:  0.0124
# [DEBUG] Step  35650 | Ep  252 | Eps 0.929 | MeanReward(10ep):   1.150 | MeanLoss(100it):  0.00082 | MeanQ:   0.117 | GradNorm:  0.0064
# [DEBUG] Step  35766 | Ep  253 | Eps 0.929 | MeanReward(10ep):   1.150 | MeanLoss(100it):  0.00084 | MeanQ:   0.063 | GradNorm:  0.0062
# [DEBUG] Step  35908 | Ep  254 | Eps 0.929 | MeanReward(10ep):   1.150 | MeanLoss(100it):  0.00097 | MeanQ:   0.237 | GradNorm:  0.0234
# [DEBUG] Step  36169 | Ep  255 | Eps 0.928 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00125 | MeanQ:   0.229 | GradNorm:  0.0114
# [DEBUG] Step  36285 | Ep  256 | Eps 0.928 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00124 | MeanQ:   0.144 | GradNorm:  0.0184
# [DEBUG] Step  36564 | Ep  257 | Eps 0.928 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00113 | MeanQ:   0.059 | GradNorm:  0.0033
# [DEBUG] Step  36723 | Ep  258 | Eps 0.927 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00115 | MeanQ:   0.211 | GradNorm:  0.0135
# [DEBUG] Step  36877 | Ep  259 | Eps 0.927 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00118 | MeanQ:   0.074 | GradNorm:  0.0155
# [DEBUG] Step  36993 | Ep  260 | Eps 0.927 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00109 | MeanQ:   0.195 | GradNorm:  0.0090
# [DEBUG] Step  37127 | Ep  261 | Eps 0.926 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00097 | MeanQ:   0.109 | GradNorm:  0.0200
# [DEBUG] Step  37243 | Ep  262 | Eps 0.926 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00098 | MeanQ:   0.077 | GradNorm:  0.0101
# [DEBUG] Step  37377 | Ep  263 | Eps 0.926 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00087 | MeanQ:   0.164 | GradNorm:  0.0109
# [DEBUG] Step  37551 | Ep  264 | Eps 0.926 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00094 | MeanQ:   0.093 | GradNorm:  0.0249
# [DEBUG] Step  37704 | Ep  265 | Eps 0.925 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00096 | MeanQ:   0.129 | GradNorm:  0.0182
# [DEBUG] Step  37845 | Ep  266 | Eps 0.925 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00100 | MeanQ:   0.125 | GradNorm:  0.0135
# [DEBUG] Step  37979 | Ep  267 | Eps 0.925 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00088 | MeanQ:   0.138 | GradNorm:  0.0060
# [DEBUG] Step  38113 | Ep  268 | Eps 0.925 | MeanReward(10ep):   1.220 | MeanLoss(100it):  0.00097 | MeanQ:   0.180 | GradNorm:  0.0185
# [DEBUG] Step  38229 | Ep  269 | Eps 0.924 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00110 | MeanQ:   0.129 | GradNorm:  0.0081
# [DEBUG] Step  38365 | Ep  270 | Eps 0.924 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00141 | MeanQ:   0.251 | GradNorm:  0.0051
# [DEBUG] Step  38544 | Ep  271 | Eps 0.924 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00158 | MeanQ:   0.142 | GradNorm:  0.0174
# [DEBUG] Step  38744 | Ep  272 | Eps 0.923 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00126 | MeanQ:   0.070 | GradNorm:  0.0094
# [DEBUG] Step  38860 | Ep  273 | Eps 0.923 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00112 | MeanQ:   0.203 | GradNorm:  0.0082
# [DEBUG] Step  39012 | Ep  274 | Eps 0.923 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00110 | MeanQ:   0.083 | GradNorm:  0.0082
# [DEBUG] Step  39128 | Ep  275 | Eps 0.923 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00113 | MeanQ:   0.119 | GradNorm:  0.0144
# [DEBUG] Step  39244 | Ep  276 | Eps 0.922 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00131 | MeanQ:   0.210 | GradNorm:  0.1025
# [DEBUG] Step  39360 | Ep  277 | Eps 0.922 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00150 | MeanQ:   0.206 | GradNorm:  0.0236
# [DEBUG] Step  39476 | Ep  278 | Eps 0.922 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00154 | MeanQ:   0.069 | GradNorm:  0.0101
# [DEBUG] Step  39781 | Ep  279 | Eps 0.921 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00127 | MeanQ:   0.153 | GradNorm:  0.0277
# [DEBUG] Step  39933 | Ep  280 | Eps 0.921 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00128 | MeanQ:   0.088 | GradNorm:  0.0163
# [DEBUG] Step  40149 | Ep  281 | Eps 0.921 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00146 | MeanQ:   0.092 | GradNorm:  0.0255
# [DEBUG] Step  40282 | Ep  282 | Eps 0.920 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00135 | MeanQ:   0.126 | GradNorm:  0.0216
# [DEBUG] Step  40418 | Ep  283 | Eps 0.920 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00143 | MeanQ:   0.071 | GradNorm:  0.0094
# [DEBUG] Step  40551 | Ep  284 | Eps 0.920 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00136 | MeanQ:   0.070 | GradNorm:  0.0061
# [DEBUG] Step  40667 | Ep  285 | Eps 0.919 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00132 | MeanQ:   0.127 | GradNorm:  0.0356
# [DEBUG] Step  40891 | Ep  286 | Eps 0.919 | MeanReward(10ep):   1.220 | MeanLoss(100it):  0.00156 | MeanQ:   0.193 | GradNorm:  0.0070
# [DEBUG] Step  41072 | Ep  287 | Eps 0.919 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00179 | MeanQ:   0.065 | GradNorm:  0.0314
# [DEBUG] Step  41265 | Ep  288 | Eps 0.918 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00145 | MeanQ:   0.089 | GradNorm:  0.0155
# [DEBUG] Step  41399 | Ep  289 | Eps 0.918 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00144 | MeanQ:   0.121 | GradNorm:  0.0073
# [DEBUG] Step  41515 | Ep  290 | Eps 0.918 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00116 | MeanQ:   0.123 | GradNorm:  0.0068
# [DEBUG] Step  41760 | Ep  291 | Eps 0.917 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00143 | MeanQ:   0.080 | GradNorm:  0.0113
# [DEBUG] Step  41876 | Ep  292 | Eps 0.917 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00166 | MeanQ:   0.076 | GradNorm:  0.0063
# [DEBUG] Step  42055 | Ep  293 | Eps 0.917 | MeanReward(10ep):   1.220 | MeanLoss(100it):  0.00169 | MeanQ:   0.075 | GradNorm:  0.0569
# [DEBUG] Step  42171 | Ep  294 | Eps 0.917 | MeanReward(10ep):   1.220 | MeanLoss(100it):  0.00166 | MeanQ:   0.090 | GradNorm:  0.0078
# [DEBUG] Step  42327 | Ep  295 | Eps 0.916 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00149 | MeanQ:   0.127 | GradNorm:  0.0111
# [DEBUG] Step  42443 | Ep  296 | Eps 0.916 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00149 | MeanQ:   0.095 | GradNorm:  0.0068
# [DEBUG] Step  42643 | Ep  297 | Eps 0.916 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00165 | MeanQ:   0.096 | GradNorm:  0.0296
# [DEBUG] Step  42822 | Ep  298 | Eps 0.915 | MeanReward(10ep):   1.270 | MeanLoss(100it):  0.00200 | MeanQ:   0.149 | GradNorm:  0.0163
# [DEBUG] Step  42974 | Ep  299 | Eps 0.915 | MeanReward(10ep):   1.290 | MeanLoss(100it):  0.00197 | MeanQ:   0.117 | GradNorm:  0.0094
# [DEBUG] Step  43090 | Ep  300 | Eps 0.915 | MeanReward(10ep):   1.280 | MeanLoss(100it):  0.00193 | MeanQ:   0.082 | GradNorm:  0.0434
# [breakout] Ep 300 Steps 43090 RecentMean 1.28 Eps 0.915
# [DEBUG] Step  43232 | Ep  301 | Eps 0.914 | MeanReward(10ep):   1.290 | MeanLoss(100it):  0.00173 | MeanQ:   0.102 | GradNorm:  0.0151
# [DEBUG] Step  43385 | Ep  302 | Eps 0.914 | MeanReward(10ep):   1.310 | MeanLoss(100it):  0.00166 | MeanQ:   0.076 | GradNorm:  0.0065
# [DEBUG] Step  43538 | Ep  303 | Eps 0.914 | MeanReward(10ep):   1.290 | MeanLoss(100it):  0.00165 | MeanQ:   0.093 | GradNorm:  0.0162
# [DEBUG] Step  43654 | Ep  304 | Eps 0.914 | MeanReward(10ep):   1.280 | MeanLoss(100it):  0.00151 | MeanQ:   0.163 | GradNorm:  0.0054
# [DEBUG] Step  43791 | Ep  305 | Eps 0.913 | MeanReward(10ep):   1.290 | MeanLoss(100it):  0.00137 | MeanQ:   0.094 | GradNorm:  0.0049
# [DEBUG] Step  43944 | Ep  306 | Eps 0.913 | MeanReward(10ep):   1.300 | MeanLoss(100it):  0.00106 | MeanQ:   0.115 | GradNorm:  0.0252
# [DEBUG] Step  44157 | Ep  307 | Eps 0.913 | MeanReward(10ep):   1.310 | MeanLoss(100it):  0.00133 | MeanQ:   0.141 | GradNorm:  0.0267
# [DEBUG] Step  44363 | Ep  308 | Eps 0.912 | MeanReward(10ep):   1.330 | MeanLoss(100it):  0.00210 | MeanQ:   0.082 | GradNorm:  0.0347
# [DEBUG] Step  44543 | Ep  309 | Eps 0.912 | MeanReward(10ep):   1.330 | MeanLoss(100it):  0.00250 | MeanQ:   0.094 | GradNorm:  0.0180
# [DEBUG] Step  44659 | Ep  310 | Eps 0.912 | MeanReward(10ep):   1.330 | MeanLoss(100it):  0.00265 | MeanQ:   0.111 | GradNorm:  0.0467
# [DEBUG] Step  44775 | Ep  311 | Eps 0.911 | MeanReward(10ep):   1.330 | MeanLoss(100it):  0.00269 | MeanQ:   0.081 | GradNorm:  0.0250
# [DEBUG] Step  44955 | Ep  312 | Eps 0.911 | MeanReward(10ep):   1.340 | MeanLoss(100it):  0.00259 | MeanQ:   0.096 | GradNorm:  0.0270
# [DEBUG] Step  45071 | Ep  313 | Eps 0.911 | MeanReward(10ep):   1.300 | MeanLoss(100it):  0.00264 | MeanQ:   0.101 | GradNorm:  0.0223
# [DEBUG] Step  45286 | Ep  314 | Eps 0.910 | MeanReward(10ep):   1.320 | MeanLoss(100it):  0.00220 | MeanQ:   0.094 | GradNorm:  0.0319
# [DEBUG] Step  45402 | Ep  315 | Eps 0.910 | MeanReward(10ep):   1.320 | MeanLoss(100it):  0.00194 | MeanQ:   0.089 | GradNorm:  0.0137
# [DEBUG] Step  45518 | Ep  316 | Eps 0.910 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00221 | MeanQ:   0.084 | GradNorm:  0.0276
# [DEBUG] Step  45753 | Ep  317 | Eps 0.909 | MeanReward(10ep):   1.280 | MeanLoss(100it):  0.00223 | MeanQ:   0.083 | GradNorm:  0.0181
# [DEBUG] Step  45894 | Ep  318 | Eps 0.909 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00224 | MeanQ:   0.090 | GradNorm:  0.0144
# [DEBUG] Step  46010 | Ep  319 | Eps 0.909 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00214 | MeanQ:   0.129 | GradNorm:  0.0146
# [DEBUG] Step  46186 | Ep  320 | Eps 0.909 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00199 | MeanQ:   0.185 | GradNorm:  0.0161
# [DEBUG] Step  46322 | Ep  321 | Eps 0.908 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00198 | MeanQ:   0.176 | GradNorm:  0.0276
# [DEBUG] Step  46525 | Ep  322 | Eps 0.908 | MeanReward(10ep):   1.280 | MeanLoss(100it):  0.00282 | MeanQ:   0.099 | GradNorm:  0.0187
# [DEBUG] Step  46682 | Ep  323 | Eps 0.908 | MeanReward(10ep):   1.280 | MeanLoss(100it):  0.00311 | MeanQ:   0.138 | GradNorm:  0.0287
# [DEBUG] Step  46815 | Ep  324 | Eps 0.907 | MeanReward(10ep):   1.270 | MeanLoss(100it):  0.00292 | MeanQ:   0.096 | GradNorm:  0.0141
# [DEBUG] Step  46965 | Ep  325 | Eps 0.907 | MeanReward(10ep):   1.270 | MeanLoss(100it):  0.00277 | MeanQ:   0.104 | GradNorm:  0.0074
# [DEBUG] Step  47177 | Ep  326 | Eps 0.907 | MeanReward(10ep):   1.310 | MeanLoss(100it):  0.00264 | MeanQ:   0.095 | GradNorm:  0.0342
# [DEBUG] Step  47375 | Ep  327 | Eps 0.906 | MeanReward(10ep):   1.320 | MeanLoss(100it):  0.00238 | MeanQ:   0.117 | GradNorm:  0.0060
# [DEBUG] Step  47510 | Ep  328 | Eps 0.906 | MeanReward(10ep):   1.320 | MeanLoss(100it):  0.00250 | MeanQ:   0.096 | GradNorm:  0.0177
# [DEBUG] Step  47663 | Ep  329 | Eps 0.906 | MeanReward(10ep):   1.330 | MeanLoss(100it):  0.00262 | MeanQ:   0.104 | GradNorm:  0.0172
# [DEBUG] Step  47841 | Ep  330 | Eps 0.905 | MeanReward(10ep):   1.360 | MeanLoss(100it):  0.00226 | MeanQ:   0.100 | GradNorm:  0.0414
# [DEBUG] Step  48024 | Ep  331 | Eps 0.905 | MeanReward(10ep):   1.380 | MeanLoss(100it):  0.00181 | MeanQ:   0.194 | GradNorm:  0.0131
# [DEBUG] Step  48189 | Ep  332 | Eps 0.905 | MeanReward(10ep):   1.390 | MeanLoss(100it):  0.00223 | MeanQ:   0.153 | GradNorm:  0.0202
# [DEBUG] Step  48305 | Ep  333 | Eps 0.904 | MeanReward(10ep):   1.380 | MeanLoss(100it):  0.00252 | MeanQ:   0.137 | GradNorm:  0.0181
# [DEBUG] Step  48439 | Ep  334 | Eps 0.904 | MeanReward(10ep):   1.350 | MeanLoss(100it):  0.00270 | MeanQ:   0.126 | GradNorm:  0.0266
# [DEBUG] Step  48555 | Ep  335 | Eps 0.904 | MeanReward(10ep):   1.350 | MeanLoss(100it):  0.00266 | MeanQ:   0.171 | GradNorm:  0.0209
# [DEBUG] Step  48835 | Ep  336 | Eps 0.903 | MeanReward(10ep):   1.360 | MeanLoss(100it):  0.00219 | MeanQ:   0.106 | GradNorm:  0.0038
# [DEBUG] Step  48951 | Ep  337 | Eps 0.903 | MeanReward(10ep):   1.340 | MeanLoss(100it):  0.00237 | MeanQ:   0.110 | GradNorm:  0.0175
# [DEBUG] Step  49126 | Ep  338 | Eps 0.903 | MeanReward(10ep):   1.350 | MeanLoss(100it):  0.00280 | MeanQ:   0.126 | GradNorm:  0.0235
# [DEBUG] Step  49330 | Ep  339 | Eps 0.902 | MeanReward(10ep):   1.380 | MeanLoss(100it):  0.00281 | MeanQ:   0.120 | GradNorm:  0.0175
# [DEBUG] Step  49485 | Ep  340 | Eps 0.902 | MeanReward(10ep):   1.390 | MeanLoss(100it):  0.00257 | MeanQ:   0.136 | GradNorm:  0.0184
# [DEBUG] Step  49619 | Ep  341 | Eps 0.902 | MeanReward(10ep):   1.370 | MeanLoss(100it):  0.00203 | MeanQ:   0.125 | GradNorm:  0.0096
# [DEBUG] Step  49793 | Ep  342 | Eps 0.901 | MeanReward(10ep):   1.390 | MeanLoss(100it):  0.00238 | MeanQ:   0.112 | GradNorm:  0.0571
# [DEBUG] Step  49927 | Ep  343 | Eps 0.901 | MeanReward(10ep):   1.400 | MeanLoss(100it):  0.00269 | MeanQ:   0.125 | GradNorm:  0.0223
# [DEBUG] Step  50043 | Ep  344 | Eps 0.901 | MeanReward(10ep):   1.390 | MeanLoss(100it):  0.00280 | MeanQ:   0.134 | GradNorm:  0.0184
# [DEBUG] Step  50159 | Ep  345 | Eps 0.901 | MeanReward(10ep):   1.390 | MeanLoss(100it):  0.00220 | MeanQ:   0.148 | GradNorm:  0.0136
# [DEBUG] Step  50275 | Ep  346 | Eps 0.900 | MeanReward(10ep):   1.360 | MeanLoss(100it):  0.00246 | MeanQ:   0.148 | GradNorm:  0.0477
# [DEBUG] Step  50473 | Ep  347 | Eps 0.900 | MeanReward(10ep):   1.360 | MeanLoss(100it):  0.00272 | MeanQ:   0.141 | GradNorm:  0.0165
# [DEBUG] Step  50683 | Ep  348 | Eps 0.900 | MeanReward(10ep):   1.390 | MeanLoss(100it):  0.00256 | MeanQ:   0.137 | GradNorm:  0.0287
# [DEBUG] Step  50799 | Ep  349 | Eps 0.899 | MeanReward(10ep):   1.380 | MeanLoss(100it):  0.00249 | MeanQ:   0.130 | GradNorm:  0.0137
# [DEBUG] Step  50940 | Ep  350 | Eps 0.899 | MeanReward(10ep):   1.390 | MeanLoss(100it):  0.00242 | MeanQ:   0.141 | GradNorm:  0.0220
# [DEBUG] Step  51056 | Ep  351 | Eps 0.899 | MeanReward(10ep):   1.380 | MeanLoss(100it):  0.00272 | MeanQ:   0.127 | GradNorm:  0.0331
# [DEBUG] Step  51197 | Ep  352 | Eps 0.899 | MeanReward(10ep):   1.380 | MeanLoss(100it):  0.00253 | MeanQ:   0.123 | GradNorm:  0.0456
# [DEBUG] Step  51350 | Ep  353 | Eps 0.898 | MeanReward(10ep):   1.400 | MeanLoss(100it):  0.00242 | MeanQ:   0.174 | GradNorm:  0.0166
# ...
# [DEBUG] Step 1908135 | Ep 3860 | Eps 0.010 | MeanReward(10ep):  36.460 | MeanLoss(100it):  0.00592 | MeanQ:   4.578 | GradNorm:  0.0537
# [DEBUG] Step 1909135 | Ep 3861 | Eps 0.010 | MeanReward(10ep):  36.360 | MeanLoss(100it):  0.00689 | MeanQ:   3.137 | GradNorm:  0.0475
# [DEBUG] Step 1910135 | Ep 3862 | Eps 0.010 | MeanReward(10ep):  36.610 | MeanLoss(100it):  0.00634 | MeanQ:  -0.841 | GradNorm:  0.0448
# [DEBUG] Step 1910906 | Ep 3863 | Eps 0.010 | MeanReward(10ep):  36.490 | MeanLoss(100it):  0.00530 | MeanQ:   4.551 | GradNorm:  0.0337
# [DEBUG] Step 1911820 | Ep 3864 | Eps 0.010 | MeanReward(10ep):  36.590 | MeanLoss(100it):  0.00614 | MeanQ:   4.593 | GradNorm:  0.0859
# [DEBUG] Step 1912755 | Ep 3865 | Eps 0.010 | MeanReward(10ep):  36.740 | MeanLoss(100it):  0.00619 | MeanQ:   4.539 | GradNorm:  0.0823
# [DEBUG] Step 1913755 | Ep 3866 | Eps 0.010 | MeanReward(10ep):  36.770 | MeanLoss(100it):  0.00603 | MeanQ:   0.768 | GradNorm:  0.0717
# [DEBUG] Step 1914267 | Ep 3867 | Eps 0.010 | MeanReward(10ep):  36.650 | MeanLoss(100it):  0.00561 | MeanQ:   4.592 | GradNorm:  0.0852
# [DEBUG] Step 1914953 | Ep 3868 | Eps 0.010 | MeanReward(10ep):  36.670 | MeanLoss(100it):  0.00597 | MeanQ:   4.571 | GradNorm:  0.0408
# [DEBUG] Step 1915718 | Ep 3869 | Eps 0.010 | MeanReward(10ep):  36.610 | MeanLoss(100it):  0.00613 | MeanQ:   4.607 | GradNorm:  0.0960
# [DEBUG] Step 1916523 | Ep 3870 | Eps 0.010 | MeanReward(10ep):  36.700 | MeanLoss(100it):  0.00568 | MeanQ:   4.547 | GradNorm:  0.0427
# [DEBUG] Step 1917285 | Ep 3871 | Eps 0.010 | MeanReward(10ep):  36.790 | MeanLoss(100it):  0.00578 | MeanQ:   4.445 | GradNorm:  0.0803
# [DEBUG] Step 1918182 | Ep 3872 | Eps 0.010 | MeanReward(10ep):  36.860 | MeanLoss(100it):  0.00674 | MeanQ:   4.559 | GradNorm:  0.0580
# [DEBUG] Step 1918759 | Ep 3873 | Eps 0.010 | MeanReward(10ep):  36.750 | MeanLoss(100it):  0.00623 | MeanQ:   4.526 | GradNorm:  0.0754
# [DEBUG] Step 1919727 | Ep 3874 | Eps 0.010 | MeanReward(10ep):  36.880 | MeanLoss(100it):  0.00650 | MeanQ:   4.587 | GradNorm:  0.0350
# [DEBUG] Step 1920538 | Ep 3875 | Eps 0.010 | MeanReward(10ep):  36.800 | MeanLoss(100it):  0.00594 | MeanQ:   4.531 | GradNorm:  0.0396
# [DEBUG] Step 1921495 | Ep 3876 | Eps 0.010 | MeanReward(10ep):  36.880 | MeanLoss(100it):  0.00566 | MeanQ:   4.619 | GradNorm:  0.0758
# [DEBUG] Step 1922278 | Ep 3877 | Eps 0.010 | MeanReward(10ep):  36.790 | MeanLoss(100it):  0.00603 | MeanQ:   4.630 | GradNorm:  0.0802
# [DEBUG] Step 1923164 | Ep 3878 | Eps 0.010 | MeanReward(10ep):  36.890 | MeanLoss(100it):  0.00537 | MeanQ:   4.682 | GradNorm:  0.0693
# [DEBUG] Step 1924164 | Ep 3879 | Eps 0.010 | MeanReward(10ep):  36.830 | MeanLoss(100it):  0.00527 | MeanQ:   2.756 | GradNorm:  0.0868
# [DEBUG] Step 1924961 | Ep 3880 | Eps 0.010 | MeanReward(10ep):  36.780 | MeanLoss(100it):  0.00529 | MeanQ:   4.656 | GradNorm:  0.0856
# [DEBUG] Step 1925745 | Ep 3881 | Eps 0.010 | MeanReward(10ep):  36.680 | MeanLoss(100it):  0.00468 | MeanQ:   4.671 | GradNorm:  0.0731
# [DEBUG] Step 1926723 | Ep 3882 | Eps 0.010 | MeanReward(10ep):  36.700 | MeanLoss(100it):  0.00709 | MeanQ:   4.577 | GradNorm:  0.1101
# [DEBUG] Step 1927438 | Ep 3883 | Eps 0.010 | MeanReward(10ep):  36.560 | MeanLoss(100it):  0.00608 | MeanQ:   4.654 | GradNorm:  0.0657
# [DEBUG] Step 1928225 | Ep 3884 | Eps 0.010 | MeanReward(10ep):  36.620 | MeanLoss(100it):  0.00567 | MeanQ:   4.663 | GradNorm:  0.0842
# [DEBUG] Step 1929015 | Ep 3885 | Eps 0.010 | MeanReward(10ep):  36.560 | MeanLoss(100it):  0.00535 | MeanQ:   4.660 | GradNorm:  0.0478
# [DEBUG] Step 1929606 | Ep 3886 | Eps 0.010 | MeanReward(10ep):  36.410 | MeanLoss(100it):  0.00507 | MeanQ:   4.650 | GradNorm:  0.0597
# [DEBUG] Step 1930149 | Ep 3887 | Eps 0.010 | MeanReward(10ep):  36.250 | MeanLoss(100it):  0.00575 | MeanQ:   4.675 | GradNorm:  0.0638
# [DEBUG] Step 1930784 | Ep 3888 | Eps 0.010 | MeanReward(10ep):  36.190 | MeanLoss(100it):  0.00570 | MeanQ:   4.597 | GradNorm:  0.0577
# [DEBUG] Step 1931511 | Ep 3889 | Eps 0.010 | MeanReward(10ep):  36.130 | MeanLoss(100it):  0.00583 | MeanQ:   4.599 | GradNorm:  0.0628
# [DEBUG] Step 1932334 | Ep 3890 | Eps 0.010 | MeanReward(10ep):  36.090 | MeanLoss(100it):  0.00505 | MeanQ:   4.619 | GradNorm:  0.0600
# [DEBUG] Step 1933193 | Ep 3891 | Eps 0.010 | MeanReward(10ep):  36.100 | MeanLoss(100it):  0.00560 | MeanQ:   4.548 | GradNorm:  0.0383
# [DEBUG] Step 1934088 | Ep 3892 | Eps 0.010 | MeanReward(10ep):  36.200 | MeanLoss(100it):  0.00622 | MeanQ:   4.586 | GradNorm:  0.0724
# [DEBUG] Step 1934681 | Ep 3893 | Eps 0.010 | MeanReward(10ep):  36.020 | MeanLoss(100it):  0.00639 | MeanQ:   4.514 | GradNorm:  0.0383
# [DEBUG] Step 1935502 | Ep 3894 | Eps 0.010 | MeanReward(10ep):  35.910 | MeanLoss(100it):  0.00673 | MeanQ:   4.596 | GradNorm:  0.0608
# [DEBUG] Step 1936350 | Ep 3895 | Eps 0.010 | MeanReward(10ep):  35.900 | MeanLoss(100it):  0.00697 | MeanQ:   4.488 | GradNorm:  0.0543
# [DEBUG] Step 1937025 | Ep 3896 | Eps 0.010 | MeanReward(10ep):  35.900 | MeanLoss(100it):  0.00630 | MeanQ:   4.521 | GradNorm:  0.0504
# [DEBUG] Step 1937875 | Ep 3897 | Eps 0.010 | MeanReward(10ep):  35.910 | MeanLoss(100it):  0.00595 | MeanQ:   4.627 | GradNorm:  0.0852
# [DEBUG] Step 1938845 | Ep 3898 | Eps 0.010 | MeanReward(10ep):  35.950 | MeanLoss(100it):  0.00476 | MeanQ:   4.557 | GradNorm:  0.0700
# [DEBUG] Step 1939763 | Ep 3899 | Eps 0.010 | MeanReward(10ep):  36.040 | MeanLoss(100it):  0.00573 | MeanQ:   4.691 | GradNorm:  0.0573
# [DEBUG] Step 1940710 | Ep 3900 | Eps 0.010 | MeanReward(10ep):  36.020 | MeanLoss(100it):  0.00531 | MeanQ:   4.655 | GradNorm:  0.0511
# [breakout] Ep 3900 Steps 1940710 RecentMean 36.02 Eps 0.010
# [DEBUG] Step 1941567 | Ep 3901 | Eps 0.010 | MeanReward(10ep):  36.020 | MeanLoss(100it):  0.00572 | MeanQ:   4.638 | GradNorm:  0.0551
# [DEBUG] Step 1942567 | Ep 3902 | Eps 0.010 | MeanReward(10ep):  36.110 | MeanLoss(100it):  0.00619 | MeanQ:   1.372 | GradNorm:  0.0729
# [DEBUG] Step 1943242 | Ep 3903 | Eps 0.010 | MeanReward(10ep):  35.960 | MeanLoss(100it):  0.00575 | MeanQ:   4.567 | GradNorm:  0.0498
# [DEBUG] Step 1944242 | Ep 3904 | Eps 0.010 | MeanReward(10ep):  36.070 | MeanLoss(100it):  0.00529 | MeanQ:   0.485 | GradNorm:  0.0362
# [DEBUG] Step 1945156 | Ep 3905 | Eps 0.010 | MeanReward(10ep):  36.000 | MeanLoss(100it):  0.00565 | MeanQ:   4.630 | GradNorm:  0.0470
# [DEBUG] Step 1945851 | Ep 3906 | Eps 0.010 | MeanReward(10ep):  35.800 | MeanLoss(100it):  0.00627 | MeanQ:   4.668 | GradNorm:  0.0670
# [DEBUG] Step 1946702 | Ep 3907 | Eps 0.010 | MeanReward(10ep):  35.730 | MeanLoss(100it):  0.00565 | MeanQ:   4.616 | GradNorm:  0.0498
# [DEBUG] Step 1947356 | Ep 3908 | Eps 0.010 | MeanReward(10ep):  35.580 | MeanLoss(100it):  0.00628 | MeanQ:   4.678 | GradNorm:  0.0624
# [DEBUG] Step 1948337 | Ep 3909 | Eps 0.010 | MeanReward(10ep):  35.620 | MeanLoss(100it):  0.00497 | MeanQ:   4.592 | GradNorm:  0.0448
# [DEBUG] Step 1949252 | Ep 3910 | Eps 0.010 | MeanReward(10ep):  35.710 | MeanLoss(100it):  0.00471 | MeanQ:   4.651 | GradNorm:  0.0526
# [DEBUG] Step 1950201 | Ep 3911 | Eps 0.010 | MeanReward(10ep):  35.920 | MeanLoss(100it):  0.00544 | MeanQ:   4.613 | GradNorm:  0.0631
# [DEBUG] Step 1951016 | Ep 3912 | Eps 0.010 | MeanReward(10ep):  35.840 | MeanLoss(100it):  0.00509 | MeanQ:   4.511 | GradNorm:  0.0379
# [DEBUG] Step 1951744 | Ep 3913 | Eps 0.010 | MeanReward(10ep):  35.730 | MeanLoss(100it):  0.00562 | MeanQ:   4.614 | GradNorm:  0.0531
# [DEBUG] Step 1952744 | Ep 3914 | Eps 0.010 | MeanReward(10ep):  35.830 | MeanLoss(100it):  0.00517 | MeanQ:   2.241 | GradNorm:  0.0474
# [DEBUG] Step 1953427 | Ep 3915 | Eps 0.010 | MeanReward(10ep):  35.790 | MeanLoss(100it):  0.00566 | MeanQ:   4.545 | GradNorm:  0.0431
# [DEBUG] Step 1953868 | Ep 3916 | Eps 0.010 | MeanReward(10ep):  35.470 | MeanLoss(100it):  0.00522 | MeanQ:   4.588 | GradNorm:  0.0540
# [DEBUG] Step 1954577 | Ep 3917 | Eps 0.010 | MeanReward(10ep):  35.430 | MeanLoss(100it):  0.00663 | MeanQ:   4.537 | GradNorm:  0.0852
# [DEBUG] Step 1955577 | Ep 3918 | Eps 0.010 | MeanReward(10ep):  35.570 | MeanLoss(100it):  0.00470 | MeanQ:   1.013 | GradNorm:  0.0500
# [DEBUG] Step 1956230 | Ep 3919 | Eps 0.010 | MeanReward(10ep):  35.570 | MeanLoss(100it):  0.00544 | MeanQ:   4.561 | GradNorm:  0.0389
# [DEBUG] Step 1957229 | Ep 3920 | Eps 0.010 | MeanReward(10ep):  35.620 | MeanLoss(100it):  0.00608 | MeanQ:   4.543 | GradNorm:  0.0509
# [DEBUG] Step 1958152 | Ep 3921 | Eps 0.010 | MeanReward(10ep):  35.810 | MeanLoss(100it):  0.00616 | MeanQ:   4.627 | GradNorm:  0.0673
# [DEBUG] Step 1958550 | Ep 3922 | Eps 0.010 | MeanReward(10ep):  35.530 | MeanLoss(100it):  0.00515 | MeanQ:   4.554 | GradNorm:  0.0420
# [DEBUG] Step 1959239 | Ep 3923 | Eps 0.010 | MeanReward(10ep):  35.380 | MeanLoss(100it):  0.00490 | MeanQ:   4.548 | GradNorm:  0.0465
# [DEBUG] Step 1959675 | Ep 3924 | Eps 0.010 | MeanReward(10ep):  35.090 | MeanLoss(100it):  0.00552 | MeanQ:   4.619 | GradNorm:  0.0495
# [DEBUG] Step 1960475 | Ep 3925 | Eps 0.010 | MeanReward(10ep):  34.930 | MeanLoss(100it):  0.00524 | MeanQ:   4.645 | GradNorm:  0.0506
# [DEBUG] Step 1961264 | Ep 3926 | Eps 0.010 | MeanReward(10ep):  34.860 | MeanLoss(100it):  0.00592 | MeanQ:   4.622 | GradNorm:  0.1117
# [DEBUG] Step 1962015 | Ep 3927 | Eps 0.010 | MeanReward(10ep):  34.750 | MeanLoss(100it):  0.00668 | MeanQ:   4.608 | GradNorm:  0.0596
# [DEBUG] Step 1962792 | Ep 3928 | Eps 0.010 | MeanReward(10ep):  34.790 | MeanLoss(100it):  0.00629 | MeanQ:   4.582 | GradNorm:  0.0462
# [DEBUG] Step 1963514 | Ep 3929 | Eps 0.010 | MeanReward(10ep):  34.680 | MeanLoss(100it):  0.00598 | MeanQ:   4.599 | GradNorm:  0.0485
# [DEBUG] Step 1964266 | Ep 3930 | Eps 0.010 | MeanReward(10ep):  34.600 | MeanLoss(100it):  0.00604 | MeanQ:   4.609 | GradNorm:  0.0431
# [DEBUG] Step 1964941 | Ep 3931 | Eps 0.010 | MeanReward(10ep):  34.510 | MeanLoss(100it):  0.00651 | MeanQ:   4.584 | GradNorm:  0.0546
# [DEBUG] Step 1965837 | Ep 3932 | Eps 0.010 | MeanReward(10ep):  34.610 | MeanLoss(100it):  0.00566 | MeanQ:   4.607 | GradNorm:  0.0545
# [DEBUG] Step 1966566 | Ep 3933 | Eps 0.010 | MeanReward(10ep):  34.620 | MeanLoss(100it):  0.00616 | MeanQ:   4.677 | GradNorm:  0.0998
# [DEBUG] Step 1967334 | Ep 3934 | Eps 0.010 | MeanReward(10ep):  34.710 | MeanLoss(100it):  0.00657 | MeanQ:   4.627 | GradNorm:  0.0758
# [DEBUG] Step 1968191 | Ep 3935 | Eps 0.010 | MeanReward(10ep):  34.730 | MeanLoss(100it):  0.00594 | MeanQ:   4.592 | GradNorm:  0.0312
# [DEBUG] Step 1969086 | Ep 3936 | Eps 0.010 | MeanReward(10ep):  34.790 | MeanLoss(100it):  0.00534 | MeanQ:   4.609 | GradNorm:  0.0716
# [DEBUG] Step 1969770 | Ep 3937 | Eps 0.010 | MeanReward(10ep):  34.730 | MeanLoss(100it):  0.00474 | MeanQ:   4.590 | GradNorm:  0.0772
# [DEBUG] Step 1970649 | Ep 3938 | Eps 0.010 | MeanReward(10ep):  34.680 | MeanLoss(100it):  0.00600 | MeanQ:   4.591 | GradNorm:  0.0654
# [DEBUG] Step 1971624 | Ep 3939 | Eps 0.010 | MeanReward(10ep):  34.700 | MeanLoss(100it):  0.00555 | MeanQ:   4.583 | GradNorm:  0.0603
# [DEBUG] Step 1972328 | Ep 3940 | Eps 0.010 | MeanReward(10ep):  34.590 | MeanLoss(100it):  0.00498 | MeanQ:   4.534 | GradNorm:  0.0397
# [DEBUG] Step 1972981 | Ep 3941 | Eps 0.010 | MeanReward(10ep):  34.410 | MeanLoss(100it):  0.00445 | MeanQ:   4.565 | GradNorm:  0.0542
# [DEBUG] Step 1973981 | Ep 3942 | Eps 0.010 | MeanReward(10ep):  34.560 | MeanLoss(100it):  0.00614 | MeanQ:   2.190 | GradNorm:  0.0644
# [DEBUG] Step 1974755 | Ep 3943 | Eps 0.010 | MeanReward(10ep):  34.420 | MeanLoss(100it):  0.00479 | MeanQ:   4.567 | GradNorm:  0.0736
# [DEBUG] Step 1975398 | Ep 3944 | Eps 0.010 | MeanReward(10ep):  34.280 | MeanLoss(100it):  0.00560 | MeanQ:   4.517 | GradNorm:  0.0383
# [DEBUG] Step 1976155 | Ep 3945 | Eps 0.010 | MeanReward(10ep):  34.210 | MeanLoss(100it):  0.00492 | MeanQ:   4.544 | GradNorm:  0.0702
# [DEBUG] Step 1976841 | Ep 3946 | Eps 0.010 | MeanReward(10ep):  34.070 | MeanLoss(100it):  0.00579 | MeanQ:   4.570 | GradNorm:  0.0914
# [DEBUG] Step 1977765 | Ep 3947 | Eps 0.010 | MeanReward(10ep):  34.060 | MeanLoss(100it):  0.00592 | MeanQ:   4.569 | GradNorm:  0.0327
# [DEBUG] Step 1978691 | Ep 3948 | Eps 0.010 | MeanReward(10ep):  34.210 | MeanLoss(100it):  0.00584 | MeanQ:   4.591 | GradNorm:  0.0547
# [DEBUG] Step 1979505 | Ep 3949 | Eps 0.010 | MeanReward(10ep):  34.200 | MeanLoss(100it):  0.00737 | MeanQ:   4.522 | GradNorm:  0.0717
# [DEBUG] Step 1980447 | Ep 3950 | Eps 0.010 | MeanReward(10ep):  34.400 | MeanLoss(100it):  0.00572 | MeanQ:   4.512 | GradNorm:  0.0612
# [DEBUG] Step 1981197 | Ep 3951 | Eps 0.010 | MeanReward(10ep):  34.400 | MeanLoss(100it):  0.00657 | MeanQ:   4.523 | GradNorm:  0.1041
# [DEBUG] Step 1982054 | Ep 3952 | Eps 0.010 | MeanReward(10ep):  34.360 | MeanLoss(100it):  0.00590 | MeanQ:   4.564 | GradNorm:  0.0334
# [DEBUG] Step 1982885 | Ep 3953 | Eps 0.010 | MeanReward(10ep):  34.370 | MeanLoss(100it):  0.00646 | MeanQ:   4.544 | GradNorm:  0.0691
# [DEBUG] Step 1983557 | Ep 3954 | Eps 0.010 | MeanReward(10ep):  34.300 | MeanLoss(100it):  0.00714 | MeanQ:   4.561 | GradNorm:  0.0492
# [DEBUG] Step 1984322 | Ep 3955 | Eps 0.010 | MeanReward(10ep):  34.160 | MeanLoss(100it):  0.00836 | MeanQ:   4.527 | GradNorm:  0.0960
# [DEBUG] Step 1985096 | Ep 3956 | Eps 0.010 | MeanReward(10ep):  34.150 | MeanLoss(100it):  0.00571 | MeanQ:   4.509 | GradNorm:  0.0658
# [DEBUG] Step 1985967 | Ep 3957 | Eps 0.010 | MeanReward(10ep):  34.220 | MeanLoss(100it):  0.00586 | MeanQ:   4.518 | GradNorm:  0.0508
# [DEBUG] Step 1986443 | Ep 3958 | Eps 0.010 | MeanReward(10ep):  33.940 | MeanLoss(100it):  0.00490 | MeanQ:   4.490 | GradNorm:  0.0556
# [DEBUG] Step 1987411 | Ep 3959 | Eps 0.010 | MeanReward(10ep):  34.160 | MeanLoss(100it):  0.00510 | MeanQ:   4.547 | GradNorm:  0.0339
# [DEBUG] Step 1987977 | Ep 3960 | Eps 0.010 | MeanReward(10ep):  34.100 | MeanLoss(100it):  0.00590 | MeanQ:   4.501 | GradNorm:  0.0756
# [DEBUG] Step 1988939 | Ep 3961 | Eps 0.010 | MeanReward(10ep):  34.080 | MeanLoss(100it):  0.00647 | MeanQ:   4.551 | GradNorm:  0.0447
# [DEBUG] Step 1989688 | Ep 3962 | Eps 0.010 | MeanReward(10ep):  33.890 | MeanLoss(100it):  0.00636 | MeanQ:   4.498 | GradNorm:  0.0703
# [DEBUG] Step 1990546 | Ep 3963 | Eps 0.010 | MeanReward(10ep):  33.990 | MeanLoss(100it):  0.00656 | MeanQ:   4.480 | GradNorm:  0.0543
# [DEBUG] Step 1991470 | Ep 3964 | Eps 0.010 | MeanReward(10ep):  33.950 | MeanLoss(100it):  0.00653 | MeanQ:   4.505 | GradNorm:  0.0846
# [DEBUG] Step 1992190 | Ep 3965 | Eps 0.010 | MeanReward(10ep):  33.770 | MeanLoss(100it):  0.00648 | MeanQ:   4.465 | GradNorm:  0.0886
# [DEBUG] Step 1992868 | Ep 3966 | Eps 0.010 | MeanReward(10ep):  33.550 | MeanLoss(100it):  0.00739 | MeanQ:   4.475 | GradNorm:  0.0363
# [DEBUG] Step 1993555 | Ep 3967 | Eps 0.010 | MeanReward(10ep):  33.630 | MeanLoss(100it):  0.00590 | MeanQ:   4.496 | GradNorm:  0.1056
# [DEBUG] Step 1994450 | Ep 3968 | Eps 0.010 | MeanReward(10ep):  33.700 | MeanLoss(100it):  0.00648 | MeanQ:   4.459 | GradNorm:  0.0451
# [DEBUG] Step 1995270 | Ep 3969 | Eps 0.010 | MeanReward(10ep):  33.690 | MeanLoss(100it):  0.00614 | MeanQ:   4.455 | GradNorm:  0.0402
# [DEBUG] Step 1995938 | Ep 3970 | Eps 0.010 | MeanReward(10ep):  33.590 | MeanLoss(100it):  0.00601 | MeanQ:   4.415 | GradNorm:  0.0512
# [DEBUG] Step 1996760 | Ep 3971 | Eps 0.010 | MeanReward(10ep):  33.610 | MeanLoss(100it):  0.00921 | MeanQ:   4.467 | GradNorm:  0.0480
# [DEBUG] Step 1997570 | Ep 3972 | Eps 0.010 | MeanReward(10ep):  33.500 | MeanLoss(100it):  0.00856 | MeanQ:   4.395 | GradNorm:  0.0776
# [DEBUG] Step 1998570 | Ep 3973 | Eps 0.010 | MeanReward(10ep):  33.700 | MeanLoss(100it):  0.00808 | MeanQ:   0.653 | GradNorm:  0.0731
# [DEBUG] Step 1999570 | Ep 3974 | Eps 0.010 | MeanReward(10ep):  33.730 | MeanLoss(100it):  0.00708 | MeanQ:   0.638 | GradNorm:  0.1143
# Saved training data → logs/breakout_training_log_double.csv
# Saved eval data → logs/breakout_eval_log_double.csv
# Saved checkpoint: checkpoints/breakout_final_double.pth

# %%
@dataclass
class Config:
    seed: int = 7
    gamma: float = 0.99  # prioritize short-term rewards
    lr: float = 5e-4  # can reduce to 1e-4 if unstable
    batch_size: int = 64
    buffer_capacity: int = 100_000  # larger buffer for diverse data
    min_buffer_size: int = 20_000  # start training with more data
    max_steps_per_env: int = 2_000_000
    max_episode_len: int = 1000
    epsilon_start: float = 1.0
    epsilon_end: float = 0.01
    epsilon_decay_steps: int = 500_000
    target_update_interval: int = 2000
    train_freq: int = 4
    gradient_clip: float = 10.0
    reward_clip: Optional[float] = 1.0
    use_double_dqn: bool = False
    use_dueling: bool = True   # enabled for better value estimation
    vector_envs: int = 1
    log_interval_episodes: int = 100
    eval_episodes: int = 10
    curriculum: Optional[List[str]] = None
    hidden_size: int = 512

    # these 5 hyperparameters are used for the PER (prioritized experience replay)
    per_alpha: float = 0.6 
    per_eps: float = 0.01
    per_beta_start: float = 0.4
    per_beta_end: float = 1.0
    per_beta_steps: int = 50_000
    use_per: bool = False
    
    n_steps: int = 1
    use_noisy_layer: bool = False

cfg = Config()
cfg.curriculum = [challenge_env_name]

random.seed(cfg.seed)
np.random.seed(cfg.seed)
torch.manual_seed(cfg.seed)
cfg
# Out:
# Config(seed=7, gamma=0.99, lr=0.0005, batch_size=64, buffer_capacity=100000, min_buffer_size=20000, max_steps_per_env=2000000, max_episode_len=1000, epsilon_start=1.0, epsilon_end=0.01, epsilon_decay_steps=500000, target_update_interval=2000, train_freq=4, gradient_clip=10.0, reward_clip=1.0, use_double_dqn=False, use_dueling=True, vector_envs=1, log_interval_episodes=100, eval_episodes=10, curriculum=['breakout'], hidden_size=512, per_alpha=0.6, per_eps=0.01, per_beta_start=0.4, per_beta_end=1.0, per_beta_steps=50000, use_per=False, n_steps=1, use_noisy_layer=False)

# %%
import torch
import torch.optim as optim
import numpy as np
import pandas as pd
import os
import dataclasses

def save_checkpoint(path, q_net, optimizer, cfg, stage_name: str):
    torch.save({
        'model': q_net.state_dict(),
        'optimizer': optimizer.state_dict(),
        'config': dataclasses.asdict(cfg),
        'stage': stage_name,
    }, path)
    print('Saved checkpoint:', path)


# === Training ===
all_stage_logs = {}

q_net = None
target_net = None
optimizer = None
stage_index = 0

# Make directories for outputs
os.makedirs("logs", exist_ok=True)
os.makedirs("checkpoints", exist_ok=True)

for stage_env_name in cfg.curriculum:
    print(f"\n=== Stage {stage_index+1}: {stage_env_name} ===")
    env = make_env(stage_env_name, seed=cfg.seed + stage_index)()
    eval_env = make_env(stage_env_name, seed=cfg.seed + 100 + stage_index)()

    q_net = build_q_network(env, cfg).to(DEVICE)
    # if cfg.use_noisy_layer:
    #     q_net.reset_noise()
    #     target_net.reset_noise()
    target_net = build_q_network(env, cfg).to(DEVICE)
    hard_update(target_net, q_net)
    optimizer = optim.Adam(q_net.parameters(), lr=cfg.lr)

    if cfg.use_per:
        replay = PrioritizedReplayBuffer(
            capacity=cfg.buffer_capacity,
            obs_shape=env.single_observation_space.shape,
            device=DEVICE,
            cfg = cfg
        )
        print("[INFO] Using PrioritizedReplayBuffer")
    else:
        replay = ReplayBuffer(cfg.buffer_capacity, env.single_observation_space.shape, DEVICE)
        print("[INFO] Using uniform ReplayBuffer")

    logs = {
        'episode_rewards': [],
        'losses': [],
        'eps_history': [],
        'eval': [],
    }

    obs, _ = env.reset()
    ep_reward = 0
    ep_steps = 0
    episode_counter = 0
    recent_ep_returns = []
    total_steps = 0

    trajectory_buffer = deque(maxlen=cfg.n_steps)

    print('Starting training...')
    while total_steps < cfg.max_steps_per_env:
        if cfg.use_noisy_layer:
            epsilon = 0.0  # No epsilon-greedy when using noisy networks
        else:
            epsilon = epsilon_by_step(total_steps, cfg)
        action = select_action(q_net, obs, epsilon, env)
        next_obs, reward, terminated, truncated, info = env.step(action)
        reward = process_reward(reward, cfg)
        reward = float(np.asarray(reward).reshape(-1)[0])
        done = bool(np.asarray(terminated).reshape(-1)[0] or np.asarray(truncated).reshape(-1)[0])

        trajectory_buffer.append((obs.copy(), int(action), reward, next_obs.copy(), done))

        # Push n-step transitions once we have enough data
        if len(trajectory_buffer) >= cfg.n_steps:
            # Calculate n-step return
            n_step_reward = 0.0
            for i, (_, _, r, _, _) in enumerate(trajectory_buffer):  # Use 'r' to avoid name collision
                n_step_reward += (cfg.gamma ** i) * r
            
            # Extract first obs/action and last next_obs/done
            first_obs, first_action, _, _, _ = trajectory_buffer[0]  # ✅ Define these variables!
            _, _, _, last_next_obs, last_done = trajectory_buffer[-1]
            
            # Push to replay buffer (only once!)
            replay.push(first_obs, first_action, n_step_reward, last_next_obs, last_done)

        # Handle episode end: push remaining incomplete n-step transitions
        if done:
            # Push any remaining partial n-step returns
            for start_idx in range(1, len(trajectory_buffer)):
                steps_available = len(trajectory_buffer) - start_idx
                n_step_reward = 0.0
                
                for i in range(steps_available):
                    _, _, r, _, _ = trajectory_buffer[start_idx + i]
                    n_step_reward += (cfg.gamma ** i) * r
                
                first_obs, first_action, _, _, _ = trajectory_buffer[start_idx]
                _, _, _, last_next_obs, last_done = trajectory_buffer[-1]
                
                replay.push(first_obs, first_action, n_step_reward, last_next_obs, last_done)
            
            trajectory_buffer.clear()

        obs = next_obs.copy()
        ep_reward += reward
        ep_steps += 1
        total_steps += 1

        # Training
        if total_steps % cfg.train_freq == 0:
            loss = train_step(q_net, target_net, optimizer, replay, cfg)
            if loss is not None:
                logs['losses'].append(loss)

        # Target update
        if total_steps % cfg.target_update_interval == 0:
            hard_update(target_net, q_net)

        logs['eps_history'].append(epsilon)

        if done or ep_steps >= cfg.max_episode_len:
            logs['episode_rewards'].append(ep_reward)
            recent_ep_returns.append(ep_reward)
            episode_counter += 1

            # --- DEBUG PRINT ---
            mean_loss = np.mean(logs['losses'][-100:]) if logs['losses'] else 0.0
            mean_reward = np.mean(recent_ep_returns[-cfg.log_interval_episodes:]) if recent_ep_returns else 0.0
            with torch.no_grad():
                q_sample = q_net(torch.FloatTensor(obs).unsqueeze(0).to(DEVICE))
                mean_q = q_sample.mean().item()
            grads = [p.grad.norm().item() for p in q_net.parameters() if p.grad is not None]
            grad_norm = np.mean(grads) if grads else 0.0


            if episode_counter % cfg.log_interval_episodes == 0:
                mean_recent = np.mean(recent_ep_returns[-cfg.log_interval_episodes:])
                print(f"[{stage_env_name}] Ep {episode_counter} Steps {total_steps} "
                      f"RecentMean {mean_recent:.2f} Eps {epsilon:.3f}")

            obs, _ = env.reset()
            ep_reward = 0
            ep_steps = 0

            # Periodic evaluation (every 2*log_interval episodes if we have progress)
            if episode_counter % (cfg.log_interval_episodes * 2) == 0:
                eval_ret = evaluate(eval_env, q_net, cfg, cfg.eval_episodes)
                logs['eval'].append((total_steps, eval_ret))
                print(f"Eval @ Ep {episode_counter} and {total_steps} steps => mean return {eval_ret:.2f}")

    # --- Save logs and model after each stage ---
    all_stage_logs[stage_env_name] = logs

    # Save training logs
    df = pd.DataFrame({
        'episode_rewards': logs['episode_rewards'],
        'losses': logs['losses'][:len(logs['episode_rewards'])],
        'eps_history': logs['eps_history'][:len(logs['episode_rewards'])],
    })
    train_csv = f"logs/{stage_env_name}_training_log_dueling.csv"
    df.to_csv(train_csv, index=False)
    print(f"Saved training data → {train_csv}")

    # Save evaluation results
    eval_df = pd.DataFrame(logs['eval'], columns=['total_steps', 'eval_return'])
    eval_csv = f"logs/{stage_env_name}_eval_log_dueling.csv"
    eval_df.to_csv(eval_csv, index=False)
    print(f"Saved eval data → {eval_csv}")

    # Save model checkpoint
    checkpoint_path = f"checkpoints/{stage_env_name}_final_dueling.pth"
    save_checkpoint(checkpoint_path, q_net, optimizer, cfg, stage_env_name)

    stage_index += 1
# Out:
# === Stage 1: breakout ===
# Obs space: 118
# Obs space: 118
# [INFO] Using uniform ReplayBuffer
# Starting training...
# [DEBUG] Step    116 | Ep    1 | Eps 1.000 | MeanReward(10ep):   0.000 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step    257 | Ep    2 | Eps 0.999 | MeanReward(10ep):   0.500 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step    373 | Ep    3 | Eps 0.999 | MeanReward(10ep):   0.333 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step    553 | Ep    4 | Eps 0.999 | MeanReward(10ep):   0.500 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step    669 | Ep    5 | Eps 0.999 | MeanReward(10ep):   0.400 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step    824 | Ep    6 | Eps 0.998 | MeanReward(10ep):   0.500 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step    940 | Ep    7 | Eps 0.998 | MeanReward(10ep):   0.429 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   1056 | Ep    8 | Eps 0.998 | MeanReward(10ep):   0.375 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   1236 | Ep    9 | Eps 0.998 | MeanReward(10ep):   0.444 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   1391 | Ep   10 | Eps 0.997 | MeanReward(10ep):   0.500 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   1525 | Ep   11 | Eps 0.997 | MeanReward(10ep):   0.545 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   1678 | Ep   12 | Eps 0.997 | MeanReward(10ep):   0.583 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   1882 | Ep   13 | Eps 0.996 | MeanReward(10ep):   0.769 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   1998 | Ep   14 | Eps 0.996 | MeanReward(10ep):   0.714 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   2162 | Ep   15 | Eps 0.996 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   2340 | Ep   16 | Eps 0.995 | MeanReward(10ep):   0.938 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   2456 | Ep   17 | Eps 0.995 | MeanReward(10ep):   0.882 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   2572 | Ep   18 | Eps 0.995 | MeanReward(10ep):   0.833 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   2688 | Ep   19 | Eps 0.995 | MeanReward(10ep):   0.789 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   2838 | Ep   20 | Eps 0.994 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   2954 | Ep   21 | Eps 0.994 | MeanReward(10ep):   0.762 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   3070 | Ep   22 | Eps 0.994 | MeanReward(10ep):   0.727 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   3186 | Ep   23 | Eps 0.994 | MeanReward(10ep):   0.696 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   3302 | Ep   24 | Eps 0.993 | MeanReward(10ep):   0.667 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   3418 | Ep   25 | Eps 0.993 | MeanReward(10ep):   0.640 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   3534 | Ep   26 | Eps 0.993 | MeanReward(10ep):   0.615 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   3650 | Ep   27 | Eps 0.993 | MeanReward(10ep):   0.593 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   3825 | Ep   28 | Eps 0.992 | MeanReward(10ep):   0.679 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   3941 | Ep   29 | Eps 0.992 | MeanReward(10ep):   0.655 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   4122 | Ep   30 | Eps 0.992 | MeanReward(10ep):   0.733 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   4238 | Ep   31 | Eps 0.992 | MeanReward(10ep):   0.710 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   4354 | Ep   32 | Eps 0.991 | MeanReward(10ep):   0.688 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   4470 | Ep   33 | Eps 0.991 | MeanReward(10ep):   0.667 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   4586 | Ep   34 | Eps 0.991 | MeanReward(10ep):   0.647 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   4702 | Ep   35 | Eps 0.991 | MeanReward(10ep):   0.629 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   4836 | Ep   36 | Eps 0.990 | MeanReward(10ep):   0.639 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   4952 | Ep   37 | Eps 0.990 | MeanReward(10ep):   0.622 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   5068 | Ep   38 | Eps 0.990 | MeanReward(10ep):   0.605 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   5210 | Ep   39 | Eps 0.990 | MeanReward(10ep):   0.615 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   5326 | Ep   40 | Eps 0.989 | MeanReward(10ep):   0.600 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   5498 | Ep   41 | Eps 0.989 | MeanReward(10ep):   0.634 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   5614 | Ep   42 | Eps 0.989 | MeanReward(10ep):   0.619 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   5730 | Ep   43 | Eps 0.989 | MeanReward(10ep):   0.605 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   5846 | Ep   44 | Eps 0.988 | MeanReward(10ep):   0.591 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   6013 | Ep   45 | Eps 0.988 | MeanReward(10ep):   0.622 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   6146 | Ep   46 | Eps 0.988 | MeanReward(10ep):   0.630 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   6262 | Ep   47 | Eps 0.988 | MeanReward(10ep):   0.617 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   6378 | Ep   48 | Eps 0.987 | MeanReward(10ep):   0.604 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   6494 | Ep   49 | Eps 0.987 | MeanReward(10ep):   0.592 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   6610 | Ep   50 | Eps 0.987 | MeanReward(10ep):   0.580 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   6726 | Ep   51 | Eps 0.987 | MeanReward(10ep):   0.569 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   6859 | Ep   52 | Eps 0.986 | MeanReward(10ep):   0.577 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   6992 | Ep   53 | Eps 0.986 | MeanReward(10ep):   0.585 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   7126 | Ep   54 | Eps 0.986 | MeanReward(10ep):   0.593 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   7341 | Ep   55 | Eps 0.985 | MeanReward(10ep):   0.655 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   7515 | Ep   56 | Eps 0.985 | MeanReward(10ep):   0.696 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   7649 | Ep   57 | Eps 0.985 | MeanReward(10ep):   0.702 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   7765 | Ep   58 | Eps 0.985 | MeanReward(10ep):   0.690 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   7881 | Ep   59 | Eps 0.984 | MeanReward(10ep):   0.678 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   7997 | Ep   60 | Eps 0.984 | MeanReward(10ep):   0.667 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   8152 | Ep   61 | Eps 0.984 | MeanReward(10ep):   0.672 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   8343 | Ep   62 | Eps 0.983 | MeanReward(10ep):   0.694 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   8520 | Ep   63 | Eps 0.983 | MeanReward(10ep):   0.714 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   8718 | Ep   64 | Eps 0.983 | MeanReward(10ep):   0.734 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   8949 | Ep   65 | Eps 0.982 | MeanReward(10ep):   0.769 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   9082 | Ep   66 | Eps 0.982 | MeanReward(10ep):   0.773 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   9198 | Ep   67 | Eps 0.982 | MeanReward(10ep):   0.761 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   9353 | Ep   68 | Eps 0.981 | MeanReward(10ep):   0.765 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   9489 | Ep   69 | Eps 0.981 | MeanReward(10ep):   0.768 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   9605 | Ep   70 | Eps 0.981 | MeanReward(10ep):   0.757 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   9787 | Ep   71 | Eps 0.981 | MeanReward(10ep):   0.789 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step   9903 | Ep   72 | Eps 0.980 | MeanReward(10ep):   0.778 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  10019 | Ep   73 | Eps 0.980 | MeanReward(10ep):   0.767 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  10135 | Ep   74 | Eps 0.980 | MeanReward(10ep):   0.757 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  10305 | Ep   75 | Eps 0.980 | MeanReward(10ep):   0.773 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  10421 | Ep   76 | Eps 0.979 | MeanReward(10ep):   0.763 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  10537 | Ep   77 | Eps 0.979 | MeanReward(10ep):   0.753 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  10680 | Ep   78 | Eps 0.979 | MeanReward(10ep):   0.756 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  10796 | Ep   79 | Eps 0.979 | MeanReward(10ep):   0.747 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  10912 | Ep   80 | Eps 0.978 | MeanReward(10ep):   0.738 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  11028 | Ep   81 | Eps 0.978 | MeanReward(10ep):   0.728 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  11144 | Ep   82 | Eps 0.978 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  11260 | Ep   83 | Eps 0.978 | MeanReward(10ep):   0.711 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  11376 | Ep   84 | Eps 0.977 | MeanReward(10ep):   0.702 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  11531 | Ep   85 | Eps 0.977 | MeanReward(10ep):   0.706 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  11647 | Ep   86 | Eps 0.977 | MeanReward(10ep):   0.698 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  11763 | Ep   87 | Eps 0.977 | MeanReward(10ep):   0.690 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  11974 | Ep   88 | Eps 0.976 | MeanReward(10ep):   0.716 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  12116 | Ep   89 | Eps 0.976 | MeanReward(10ep):   0.719 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  12232 | Ep   90 | Eps 0.976 | MeanReward(10ep):   0.711 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  12348 | Ep   91 | Eps 0.976 | MeanReward(10ep):   0.703 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  12464 | Ep   92 | Eps 0.975 | MeanReward(10ep):   0.696 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  12619 | Ep   93 | Eps 0.975 | MeanReward(10ep):   0.699 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  12735 | Ep   94 | Eps 0.975 | MeanReward(10ep):   0.691 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  12904 | Ep   95 | Eps 0.974 | MeanReward(10ep):   0.705 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  13037 | Ep   96 | Eps 0.974 | MeanReward(10ep):   0.708 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  13180 | Ep   97 | Eps 0.974 | MeanReward(10ep):   0.711 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  13296 | Ep   98 | Eps 0.974 | MeanReward(10ep):   0.704 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  13432 | Ep   99 | Eps 0.973 | MeanReward(10ep):   0.707 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  13548 | Ep  100 | Eps 0.973 | MeanReward(10ep):   0.700 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [breakout] Ep 100 Steps 13548 RecentMean 0.70 Eps 0.973
# [DEBUG] Step  13664 | Ep  101 | Eps 0.973 | MeanReward(10ep):   0.700 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  13834 | Ep  102 | Eps 0.973 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  13950 | Ep  103 | Eps 0.972 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  14066 | Ep  104 | Eps 0.972 | MeanReward(10ep):   0.710 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  14182 | Ep  105 | Eps 0.972 | MeanReward(10ep):   0.710 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  14362 | Ep  106 | Eps 0.972 | MeanReward(10ep):   0.710 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  14478 | Ep  107 | Eps 0.971 | MeanReward(10ep):   0.710 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  14634 | Ep  108 | Eps 0.971 | MeanReward(10ep):   0.730 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  14750 | Ep  109 | Eps 0.971 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  14866 | Ep  110 | Eps 0.971 | MeanReward(10ep):   0.710 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  15008 | Ep  111 | Eps 0.970 | MeanReward(10ep):   0.710 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  15124 | Ep  112 | Eps 0.970 | MeanReward(10ep):   0.700 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  15240 | Ep  113 | Eps 0.970 | MeanReward(10ep):   0.670 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  15356 | Ep  114 | Eps 0.970 | MeanReward(10ep):   0.670 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  15518 | Ep  115 | Eps 0.969 | MeanReward(10ep):   0.670 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  15710 | Ep  116 | Eps 0.969 | MeanReward(10ep):   0.670 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  15907 | Ep  117 | Eps 0.969 | MeanReward(10ep):   0.700 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  16113 | Ep  118 | Eps 0.968 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  16229 | Ep  119 | Eps 0.968 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  16445 | Ep  120 | Eps 0.967 | MeanReward(10ep):   0.740 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  16561 | Ep  121 | Eps 0.967 | MeanReward(10ep):   0.740 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  16677 | Ep  122 | Eps 0.967 | MeanReward(10ep):   0.740 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  16793 | Ep  123 | Eps 0.967 | MeanReward(10ep):   0.740 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  16909 | Ep  124 | Eps 0.967 | MeanReward(10ep):   0.740 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  17025 | Ep  125 | Eps 0.966 | MeanReward(10ep):   0.740 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  17208 | Ep  126 | Eps 0.966 | MeanReward(10ep):   0.760 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  17324 | Ep  127 | Eps 0.966 | MeanReward(10ep):   0.760 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  17440 | Ep  128 | Eps 0.965 | MeanReward(10ep):   0.730 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  17582 | Ep  129 | Eps 0.965 | MeanReward(10ep):   0.740 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  17716 | Ep  130 | Eps 0.965 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  17832 | Ep  131 | Eps 0.965 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  17948 | Ep  132 | Eps 0.964 | MeanReward(10ep):   0.720 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  18121 | Ep  133 | Eps 0.964 | MeanReward(10ep):   0.740 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  18391 | Ep  134 | Eps 0.964 | MeanReward(10ep):   0.780 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  18531 | Ep  135 | Eps 0.963 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  18647 | Ep  136 | Eps 0.963 | MeanReward(10ep):   0.780 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  18835 | Ep  137 | Eps 0.963 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  19002 | Ep  138 | Eps 0.962 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  19157 | Ep  139 | Eps 0.962 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  19273 | Ep  140 | Eps 0.962 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  19425 | Ep  141 | Eps 0.962 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  19541 | Ep  142 | Eps 0.961 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  19682 | Ep  143 | Eps 0.961 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  19823 | Ep  144 | Eps 0.961 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  19957 | Ep  145 | Eps 0.960 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00000 | MeanQ:   0.036 | GradNorm:  0.0000
# [DEBUG] Step  20073 | Ep  146 | Eps 0.960 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00441 | MeanQ:   0.099 | GradNorm:  0.0016
# [DEBUG] Step  20189 | Ep  147 | Eps 0.960 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00437 | MeanQ:   0.135 | GradNorm:  0.0032
# [DEBUG] Step  20352 | Ep  148 | Eps 0.960 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00420 | MeanQ:   0.137 | GradNorm:  0.0047
# [DEBUG] Step  20524 | Ep  149 | Eps 0.959 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00405 | MeanQ:   0.133 | GradNorm:  0.0043
# [DEBUG] Step  20682 | Ep  150 | Eps 0.959 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00373 | MeanQ:   0.107 | GradNorm:  0.0015
# [DEBUG] Step  20862 | Ep  151 | Eps 0.959 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00302 | MeanQ:   0.149 | GradNorm:  0.0035
# [DEBUG] Step  20978 | Ep  152 | Eps 0.958 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00252 | MeanQ:   0.102 | GradNorm:  0.0071
# [DEBUG] Step  21094 | Ep  153 | Eps 0.958 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00272 | MeanQ:   0.116 | GradNorm:  0.0017
# [DEBUG] Step  21263 | Ep  154 | Eps 0.958 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00285 | MeanQ:   0.107 | GradNorm:  0.0009
# [DEBUG] Step  21414 | Ep  155 | Eps 0.958 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00317 | MeanQ:   0.116 | GradNorm:  0.0027
# [DEBUG] Step  21530 | Ep  156 | Eps 0.957 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00310 | MeanQ:   0.117 | GradNorm:  0.0031
# [DEBUG] Step  21663 | Ep  157 | Eps 0.957 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00314 | MeanQ:   0.136 | GradNorm:  0.0024
# [DEBUG] Step  21779 | Ep  158 | Eps 0.957 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00280 | MeanQ:   0.124 | GradNorm:  0.0043
# [DEBUG] Step  21921 | Ep  159 | Eps 0.957 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00227 | MeanQ:   0.120 | GradNorm:  0.0009
# [DEBUG] Step  22037 | Ep  160 | Eps 0.956 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00196 | MeanQ:   0.147 | GradNorm:  0.0022
# [DEBUG] Step  22153 | Ep  161 | Eps 0.956 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00161 | MeanQ:   0.132 | GradNorm:  0.0098
# [DEBUG] Step  22286 | Ep  162 | Eps 0.956 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00172 | MeanQ:   0.118 | GradNorm:  0.0122
# [DEBUG] Step  22420 | Ep  163 | Eps 0.956 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00281 | MeanQ:   0.137 | GradNorm:  0.0090
# [DEBUG] Step  22536 | Ep  164 | Eps 0.955 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00318 | MeanQ:   0.123 | GradNorm:  0.0017
# [DEBUG] Step  22652 | Ep  165 | Eps 0.955 | MeanReward(10ep):   0.770 | MeanLoss(100it):  0.00352 | MeanQ:   0.138 | GradNorm:  0.0030
# [DEBUG] Step  22768 | Ep  166 | Eps 0.955 | MeanReward(10ep):   0.760 | MeanLoss(100it):  0.00312 | MeanQ:   0.142 | GradNorm:  0.0015
# [DEBUG] Step  23003 | Ep  167 | Eps 0.954 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00306 | MeanQ:   0.150 | GradNorm:  0.0025
# [DEBUG] Step  23145 | Ep  168 | Eps 0.954 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00333 | MeanQ:   0.134 | GradNorm:  0.0054
# [DEBUG] Step  23261 | Ep  169 | Eps 0.954 | MeanReward(10ep):   0.780 | MeanLoss(100it):  0.00302 | MeanQ:   0.151 | GradNorm:  0.0064
# [DEBUG] Step  23441 | Ep  170 | Eps 0.954 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00267 | MeanQ:   0.171 | GradNorm:  0.0056
# [DEBUG] Step  23557 | Ep  171 | Eps 0.953 | MeanReward(10ep):   0.760 | MeanLoss(100it):  0.00269 | MeanQ:   0.127 | GradNorm:  0.0090
# [DEBUG] Step  23673 | Ep  172 | Eps 0.953 | MeanReward(10ep):   0.760 | MeanLoss(100it):  0.00286 | MeanQ:   0.172 | GradNorm:  0.0007
# [DEBUG] Step  23814 | Ep  173 | Eps 0.953 | MeanReward(10ep):   0.770 | MeanLoss(100it):  0.00245 | MeanQ:   0.129 | GradNorm:  0.0115
# [DEBUG] Step  23994 | Ep  174 | Eps 0.952 | MeanReward(10ep):   0.780 | MeanLoss(100it):  0.00184 | MeanQ:   0.181 | GradNorm:  0.0033
# [DEBUG] Step  24192 | Ep  175 | Eps 0.952 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00145 | MeanQ:   0.239 | GradNorm:  0.0032
# [DEBUG] Step  24342 | Ep  176 | Eps 0.952 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00130 | MeanQ:   0.201 | GradNorm:  0.0145
# [DEBUG] Step  24497 | Ep  177 | Eps 0.951 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00111 | MeanQ:   0.145 | GradNorm:  0.0049
# [DEBUG] Step  24613 | Ep  178 | Eps 0.951 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00119 | MeanQ:   0.168 | GradNorm:  0.0200
# [DEBUG] Step  24729 | Ep  179 | Eps 0.951 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00128 | MeanQ:   0.139 | GradNorm:  0.0034
# [DEBUG] Step  24879 | Ep  180 | Eps 0.951 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00145 | MeanQ:   0.148 | GradNorm:  0.0201
# [DEBUG] Step  25053 | Ep  181 | Eps 0.950 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00128 | MeanQ:   0.125 | GradNorm:  0.0025
# [DEBUG] Step  25233 | Ep  182 | Eps 0.950 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00134 | MeanQ:   0.194 | GradNorm:  0.0014
# [DEBUG] Step  25349 | Ep  183 | Eps 0.950 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00130 | MeanQ:   0.211 | GradNorm:  0.0132
# [DEBUG] Step  25517 | Ep  184 | Eps 0.949 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00137 | MeanQ:   0.124 | GradNorm:  0.0205
# [DEBUG] Step  25633 | Ep  185 | Eps 0.949 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00133 | MeanQ:   0.126 | GradNorm:  0.0020
# [DEBUG] Step  25749 | Ep  186 | Eps 0.949 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00128 | MeanQ:   0.150 | GradNorm:  0.0024
# [DEBUG] Step  25904 | Ep  187 | Eps 0.949 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00135 | MeanQ:   0.172 | GradNorm:  0.0033
# [DEBUG] Step  26020 | Ep  188 | Eps 0.948 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00146 | MeanQ:   0.119 | GradNorm:  0.0014
# [DEBUG] Step  26136 | Ep  189 | Eps 0.948 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00144 | MeanQ:   0.159 | GradNorm:  0.0072
# [DEBUG] Step  26252 | Ep  190 | Eps 0.948 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00126 | MeanQ:   0.153 | GradNorm:  0.0042
# [DEBUG] Step  26368 | Ep  191 | Eps 0.948 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00109 | MeanQ:   0.142 | GradNorm:  0.0120
# [DEBUG] Step  26484 | Ep  192 | Eps 0.948 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00118 | MeanQ:   0.124 | GradNorm:  0.0071
# [DEBUG] Step  26618 | Ep  193 | Eps 0.947 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00139 | MeanQ:   0.121 | GradNorm:  0.0023
# [DEBUG] Step  26798 | Ep  194 | Eps 0.947 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00142 | MeanQ:   0.217 | GradNorm:  0.0066
# [DEBUG] Step  26940 | Ep  195 | Eps 0.947 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00120 | MeanQ:   0.145 | GradNorm:  0.0124
# [DEBUG] Step  27056 | Ep  196 | Eps 0.946 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00109 | MeanQ:   0.119 | GradNorm:  0.0083
# [DEBUG] Step  27172 | Ep  197 | Eps 0.946 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00100 | MeanQ:   0.217 | GradNorm:  0.0154
# [DEBUG] Step  27288 | Ep  198 | Eps 0.946 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00093 | MeanQ:   0.120 | GradNorm:  0.0038
# [DEBUG] Step  27404 | Ep  199 | Eps 0.946 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00083 | MeanQ:   0.161 | GradNorm:  0.0048
# [DEBUG] Step  27520 | Ep  200 | Eps 0.946 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00081 | MeanQ:   0.128 | GradNorm:  0.0106
# [breakout] Ep 200 Steps 27520 RecentMean 0.79 Eps 0.946
# Eval @ Ep 200 and 27520 steps => mean return 9.00
# [DEBUG] Step  27662 | Ep  201 | Eps 0.945 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00079 | MeanQ:   0.164 | GradNorm:  0.0033
# [DEBUG] Step  27822 | Ep  202 | Eps 0.945 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00086 | MeanQ:   0.170 | GradNorm:  0.0054
# [DEBUG] Step  27964 | Ep  203 | Eps 0.945 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00080 | MeanQ:   0.117 | GradNorm:  0.0052
# [DEBUG] Step  28080 | Ep  204 | Eps 0.944 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00100 | MeanQ:   0.144 | GradNorm:  0.0100
# [DEBUG] Step  28213 | Ep  205 | Eps 0.944 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00108 | MeanQ:   0.120 | GradNorm:  0.0077
# [DEBUG] Step  28425 | Ep  206 | Eps 0.944 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00104 | MeanQ:   0.150 | GradNorm:  0.0097
# [DEBUG] Step  28605 | Ep  207 | Eps 0.943 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00123 | MeanQ:   0.140 | GradNorm:  0.0128
# [DEBUG] Step  28738 | Ep  208 | Eps 0.943 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00123 | MeanQ:   0.242 | GradNorm:  0.0045
# [DEBUG] Step  28880 | Ep  209 | Eps 0.943 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00115 | MeanQ:   0.175 | GradNorm:  0.0017
# [DEBUG] Step  28996 | Ep  210 | Eps 0.943 | MeanReward(10ep):   0.830 | MeanLoss(100it):  0.00099 | MeanQ:   0.182 | GradNorm:  0.0029
# [DEBUG] Step  29184 | Ep  211 | Eps 0.942 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00094 | MeanQ:   0.225 | GradNorm:  0.0062
# [DEBUG] Step  29300 | Ep  212 | Eps 0.942 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00083 | MeanQ:   0.126 | GradNorm:  0.0032
# [DEBUG] Step  29416 | Ep  213 | Eps 0.942 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00086 | MeanQ:   0.149 | GradNorm:  0.0099
# [DEBUG] Step  29549 | Ep  214 | Eps 0.941 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00078 | MeanQ:   0.192 | GradNorm:  0.0168
# [DEBUG] Step  29665 | Ep  215 | Eps 0.941 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00078 | MeanQ:   0.174 | GradNorm:  0.0030
# [DEBUG] Step  29781 | Ep  216 | Eps 0.941 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00067 | MeanQ:   0.129 | GradNorm:  0.0019
# [DEBUG] Step  29936 | Ep  217 | Eps 0.941 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00081 | MeanQ:   0.117 | GradNorm:  0.0043
# [DEBUG] Step  30119 | Ep  218 | Eps 0.940 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00078 | MeanQ:   0.111 | GradNorm:  0.0093
# [DEBUG] Step  30317 | Ep  219 | Eps 0.940 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00138 | MeanQ:   0.203 | GradNorm:  0.0066
# [DEBUG] Step  30433 | Ep  220 | Eps 0.940 | MeanReward(10ep):   0.780 | MeanLoss(100it):  0.00158 | MeanQ:   0.137 | GradNorm:  0.0063
# [DEBUG] Step  30589 | Ep  221 | Eps 0.939 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00162 | MeanQ:   0.204 | GradNorm:  0.0143
# [DEBUG] Step  30705 | Ep  222 | Eps 0.939 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00120 | MeanQ:   0.141 | GradNorm:  0.0070
# [DEBUG] Step  30871 | Ep  223 | Eps 0.939 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00092 | MeanQ:   0.107 | GradNorm:  0.0037
# [DEBUG] Step  31023 | Ep  224 | Eps 0.939 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00098 | MeanQ:   0.124 | GradNorm:  0.0132
# [DEBUG] Step  31203 | Ep  225 | Eps 0.938 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00118 | MeanQ:   0.232 | GradNorm:  0.0129
# [DEBUG] Step  31336 | Ep  226 | Eps 0.938 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00105 | MeanQ:   0.183 | GradNorm:  0.0010
# [DEBUG] Step  31452 | Ep  227 | Eps 0.938 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00087 | MeanQ:   0.132 | GradNorm:  0.0053
# [DEBUG] Step  31632 | Ep  228 | Eps 0.937 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00073 | MeanQ:   0.119 | GradNorm:  0.0009
# [DEBUG] Step  31766 | Ep  229 | Eps 0.937 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00077 | MeanQ:   0.255 | GradNorm:  0.0034
# [DEBUG] Step  31946 | Ep  230 | Eps 0.937 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00086 | MeanQ:   0.156 | GradNorm:  0.0035
# [DEBUG] Step  32101 | Ep  231 | Eps 0.936 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00085 | MeanQ:   0.148 | GradNorm:  0.0126
# [DEBUG] Step  32217 | Ep  232 | Eps 0.936 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00089 | MeanQ:   0.145 | GradNorm:  0.0067
# [DEBUG] Step  32333 | Ep  233 | Eps 0.936 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00090 | MeanQ:   0.119 | GradNorm:  0.0065
# [DEBUG] Step  32469 | Ep  234 | Eps 0.936 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00083 | MeanQ:   0.207 | GradNorm:  0.0091
# [DEBUG] Step  32585 | Ep  235 | Eps 0.935 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00081 | MeanQ:   0.297 | GradNorm:  0.0023
# [DEBUG] Step  32701 | Ep  236 | Eps 0.935 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00075 | MeanQ:   0.115 | GradNorm:  0.0063
# [DEBUG] Step  32817 | Ep  237 | Eps 0.935 | MeanReward(10ep):   0.770 | MeanLoss(100it):  0.00088 | MeanQ:   0.186 | GradNorm:  0.0031
# [DEBUG] Step  32998 | Ep  238 | Eps 0.935 | MeanReward(10ep):   0.770 | MeanLoss(100it):  0.00073 | MeanQ:   0.167 | GradNorm:  0.0115
# [DEBUG] Step  33132 | Ep  239 | Eps 0.934 | MeanReward(10ep):   0.770 | MeanLoss(100it):  0.00089 | MeanQ:   0.137 | GradNorm:  0.0027
# [DEBUG] Step  33287 | Ep  240 | Eps 0.934 | MeanReward(10ep):   0.780 | MeanLoss(100it):  0.00087 | MeanQ:   0.163 | GradNorm:  0.0021
# [DEBUG] Step  33504 | Ep  241 | Eps 0.934 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00084 | MeanQ:   0.118 | GradNorm:  0.0095
# [DEBUG] Step  33620 | Ep  242 | Eps 0.933 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00082 | MeanQ:   0.147 | GradNorm:  0.0031
# [DEBUG] Step  33818 | Ep  243 | Eps 0.933 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00079 | MeanQ:   0.227 | GradNorm:  0.0060
# [DEBUG] Step  33934 | Ep  244 | Eps 0.933 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00079 | MeanQ:   0.189 | GradNorm:  0.0021
# [DEBUG] Step  34050 | Ep  245 | Eps 0.933 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00090 | MeanQ:   0.225 | GradNorm:  0.0184
# [DEBUG] Step  34166 | Ep  246 | Eps 0.932 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00091 | MeanQ:   0.286 | GradNorm:  0.0035
# [DEBUG] Step  34282 | Ep  247 | Eps 0.932 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00105 | MeanQ:   0.138 | GradNorm:  0.0052
# [DEBUG] Step  34423 | Ep  248 | Eps 0.932 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00089 | MeanQ:   0.232 | GradNorm:  0.0064
# [DEBUG] Step  34556 | Ep  249 | Eps 0.932 | MeanReward(10ep):   0.780 | MeanLoss(100it):  0.00073 | MeanQ:   0.169 | GradNorm:  0.0041
# [DEBUG] Step  34689 | Ep  250 | Eps 0.931 | MeanReward(10ep):   0.770 | MeanLoss(100it):  0.00056 | MeanQ:   0.207 | GradNorm:  0.0115
# [DEBUG] Step  34911 | Ep  251 | Eps 0.931 | MeanReward(10ep):   0.790 | MeanLoss(100it):  0.00057 | MeanQ:   0.200 | GradNorm:  0.0070
# [DEBUG] Step  35077 | Ep  252 | Eps 0.931 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00061 | MeanQ:   0.179 | GradNorm:  0.0112
# [DEBUG] Step  35193 | Ep  253 | Eps 0.930 | MeanReward(10ep):   0.810 | MeanLoss(100it):  0.00061 | MeanQ:   0.230 | GradNorm:  0.0085
# [DEBUG] Step  35422 | Ep  254 | Eps 0.930 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00055 | MeanQ:   0.130 | GradNorm:  0.0141
# [DEBUG] Step  35538 | Ep  255 | Eps 0.930 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00059 | MeanQ:   0.134 | GradNorm:  0.0077
# [DEBUG] Step  35654 | Ep  256 | Eps 0.929 | MeanReward(10ep):   0.800 | MeanLoss(100it):  0.00071 | MeanQ:   0.204 | GradNorm:  0.0019
# [DEBUG] Step  35830 | Ep  257 | Eps 0.929 | MeanReward(10ep):   0.820 | MeanLoss(100it):  0.00069 | MeanQ:   0.274 | GradNorm:  0.0047
# [DEBUG] Step  36013 | Ep  258 | Eps 0.929 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00069 | MeanQ:   0.178 | GradNorm:  0.0083
# [DEBUG] Step  36154 | Ep  259 | Eps 0.928 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00079 | MeanQ:   0.281 | GradNorm:  0.0052
# [DEBUG] Step  36288 | Ep  260 | Eps 0.928 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00089 | MeanQ:   0.106 | GradNorm:  0.0101
# [DEBUG] Step  36404 | Ep  261 | Eps 0.928 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00092 | MeanQ:   0.120 | GradNorm:  0.0074
# [DEBUG] Step  36545 | Ep  262 | Eps 0.928 | MeanReward(10ep):   0.850 | MeanLoss(100it):  0.00081 | MeanQ:   0.117 | GradNorm:  0.0073
# [DEBUG] Step  36661 | Ep  263 | Eps 0.927 | MeanReward(10ep):   0.840 | MeanLoss(100it):  0.00069 | MeanQ:   0.164 | GradNorm:  0.0138
# [DEBUG] Step  36844 | Ep  264 | Eps 0.927 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00076 | MeanQ:   0.141 | GradNorm:  0.0027
# [DEBUG] Step  37082 | Ep  265 | Eps 0.927 | MeanReward(10ep):   0.900 | MeanLoss(100it):  0.00073 | MeanQ:   0.236 | GradNorm:  0.0086
# [DEBUG] Step  37237 | Ep  266 | Eps 0.926 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00065 | MeanQ:   0.126 | GradNorm:  0.0113
# [DEBUG] Step  37378 | Ep  267 | Eps 0.926 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00072 | MeanQ:   0.110 | GradNorm:  0.0095
# [DEBUG] Step  37520 | Ep  268 | Eps 0.926 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00073 | MeanQ:   0.137 | GradNorm:  0.0082
# [DEBUG] Step  37636 | Ep  269 | Eps 0.925 | MeanReward(10ep):   0.890 | MeanLoss(100it):  0.00075 | MeanQ:   0.112 | GradNorm:  0.0102
# [DEBUG] Step  37752 | Ep  270 | Eps 0.925 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00066 | MeanQ:   0.116 | GradNorm:  0.0054
# [DEBUG] Step  37868 | Ep  271 | Eps 0.925 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00072 | MeanQ:   0.214 | GradNorm:  0.0242
# [DEBUG] Step  37984 | Ep  272 | Eps 0.925 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00073 | MeanQ:   0.115 | GradNorm:  0.0038
# [DEBUG] Step  38100 | Ep  273 | Eps 0.925 | MeanReward(10ep):   0.870 | MeanLoss(100it):  0.00085 | MeanQ:   0.135 | GradNorm:  0.0134
# [DEBUG] Step  38270 | Ep  274 | Eps 0.924 | MeanReward(10ep):   0.880 | MeanLoss(100it):  0.00103 | MeanQ:   0.120 | GradNorm:  0.0265
# [DEBUG] Step  38425 | Ep  275 | Eps 0.924 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00101 | MeanQ:   0.236 | GradNorm:  0.0113
# [DEBUG] Step  38558 | Ep  276 | Eps 0.924 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00098 | MeanQ:   0.110 | GradNorm:  0.0041
# [DEBUG] Step  38711 | Ep  277 | Eps 0.923 | MeanReward(10ep):   0.860 | MeanLoss(100it):  0.00097 | MeanQ:   0.127 | GradNorm:  0.0076
# [DEBUG] Step  38930 | Ep  278 | Eps 0.923 | MeanReward(10ep):   0.910 | MeanLoss(100it):  0.00105 | MeanQ:   0.177 | GradNorm:  0.0156
# [DEBUG] Step  39194 | Ep  279 | Eps 0.922 | MeanReward(10ep):   0.950 | MeanLoss(100it):  0.00074 | MeanQ:   0.133 | GradNorm:  0.0039
# [DEBUG] Step  39310 | Ep  280 | Eps 0.922 | MeanReward(10ep):   0.940 | MeanLoss(100it):  0.00068 | MeanQ:   0.202 | GradNorm:  0.0025
# [DEBUG] Step  39462 | Ep  281 | Eps 0.922 | MeanReward(10ep):   0.940 | MeanLoss(100it):  0.00061 | MeanQ:   0.154 | GradNorm:  0.0081
# [DEBUG] Step  39620 | Ep  282 | Eps 0.922 | MeanReward(10ep):   0.950 | MeanLoss(100it):  0.00063 | MeanQ:   0.118 | GradNorm:  0.0071
# [DEBUG] Step  39841 | Ep  283 | Eps 0.921 | MeanReward(10ep):   0.980 | MeanLoss(100it):  0.00080 | MeanQ:   0.122 | GradNorm:  0.0030
# [DEBUG] Step  39957 | Ep  284 | Eps 0.921 | MeanReward(10ep):   0.960 | MeanLoss(100it):  0.00084 | MeanQ:   0.140 | GradNorm:  0.0096
# [DEBUG] Step  40157 | Ep  285 | Eps 0.920 | MeanReward(10ep):   1.000 | MeanLoss(100it):  0.00089 | MeanQ:   0.376 | GradNorm:  0.0054
# [DEBUG] Step  40338 | Ep  286 | Eps 0.920 | MeanReward(10ep):   1.020 | MeanLoss(100it):  0.00099 | MeanQ:   0.134 | GradNorm:  0.0108
# [DEBUG] Step  40613 | Ep  287 | Eps 0.920 | MeanReward(10ep):   1.060 | MeanLoss(100it):  0.00111 | MeanQ:   0.190 | GradNorm:  0.0135
# [DEBUG] Step  40729 | Ep  288 | Eps 0.919 | MeanReward(10ep):   1.060 | MeanLoss(100it):  0.00099 | MeanQ:   0.224 | GradNorm:  0.0042
# [DEBUG] Step  40956 | Ep  289 | Eps 0.919 | MeanReward(10ep):   1.090 | MeanLoss(100it):  0.00084 | MeanQ:   0.200 | GradNorm:  0.0108
# [DEBUG] Step  41219 | Ep  290 | Eps 0.918 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00141 | MeanQ:   0.120 | GradNorm:  0.0340
# [DEBUG] Step  41335 | Ep  291 | Eps 0.918 | MeanReward(10ep):   1.130 | MeanLoss(100it):  0.00156 | MeanQ:   0.188 | GradNorm:  0.0107
# [DEBUG] Step  41586 | Ep  292 | Eps 0.918 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00112 | MeanQ:   0.170 | GradNorm:  0.0044
# [DEBUG] Step  41739 | Ep  293 | Eps 0.917 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00091 | MeanQ:   0.177 | GradNorm:  0.0111
# [DEBUG] Step  41880 | Ep  294 | Eps 0.917 | MeanReward(10ep):   1.180 | MeanLoss(100it):  0.00083 | MeanQ:   0.150 | GradNorm:  0.0078
# [DEBUG] Step  41996 | Ep  295 | Eps 0.917 | MeanReward(10ep):   1.170 | MeanLoss(100it):  0.00079 | MeanQ:   0.143 | GradNorm:  0.0037
# [DEBUG] Step  42177 | Ep  296 | Eps 0.916 | MeanReward(10ep):   1.190 | MeanLoss(100it):  0.00105 | MeanQ:   0.165 | GradNorm:  0.0072
# [DEBUG] Step  42357 | Ep  297 | Eps 0.916 | MeanReward(10ep):   1.200 | MeanLoss(100it):  0.00147 | MeanQ:   0.138 | GradNorm:  0.0151
# [DEBUG] Step  42512 | Ep  298 | Eps 0.916 | MeanReward(10ep):   1.210 | MeanLoss(100it):  0.00151 | MeanQ:   0.148 | GradNorm:  0.0081
# [DEBUG] Step  42770 | Ep  299 | Eps 0.915 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00139 | MeanQ:   0.131 | GradNorm:  0.0255
# [DEBUG] Step  42924 | Ep  300 | Eps 0.915 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00121 | MeanQ:   0.127 | GradNorm:  0.0095
# [breakout] Ep 300 Steps 42924 RecentMean 1.26 Eps 0.915
# [DEBUG] Step  43040 | Ep  301 | Eps 0.915 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00127 | MeanQ:   0.175 | GradNorm:  0.0139
# [DEBUG] Step  43173 | Ep  302 | Eps 0.915 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00132 | MeanQ:   0.124 | GradNorm:  0.0066
# [DEBUG] Step  43289 | Ep  303 | Eps 0.914 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00138 | MeanQ:   0.123 | GradNorm:  0.0068
# [DEBUG] Step  43405 | Ep  304 | Eps 0.914 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00134 | MeanQ:   0.125 | GradNorm:  0.0050
# [DEBUG] Step  43548 | Ep  305 | Eps 0.914 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00119 | MeanQ:   0.328 | GradNorm:  0.0152
# [DEBUG] Step  43729 | Ep  306 | Eps 0.913 | MeanReward(10ep):   1.230 | MeanLoss(100it):  0.00121 | MeanQ:   0.137 | GradNorm:  0.0073
# [DEBUG] Step  43845 | Ep  307 | Eps 0.913 | MeanReward(10ep):   1.220 | MeanLoss(100it):  0.00155 | MeanQ:   0.119 | GradNorm:  0.0189
# [DEBUG] Step  44103 | Ep  308 | Eps 0.913 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00177 | MeanQ:   0.134 | GradNorm:  0.0188
# [DEBUG] Step  44219 | Ep  309 | Eps 0.912 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00160 | MeanQ:   0.142 | GradNorm:  0.0038
# [DEBUG] Step  44353 | Ep  310 | Eps 0.912 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00144 | MeanQ:   0.169 | GradNorm:  0.0069
# [DEBUG] Step  44469 | Ep  311 | Eps 0.912 | MeanReward(10ep):   1.220 | MeanLoss(100it):  0.00155 | MeanQ:   0.177 | GradNorm:  0.0064
# [DEBUG] Step  44652 | Ep  312 | Eps 0.912 | MeanReward(10ep):   1.240 | MeanLoss(100it):  0.00175 | MeanQ:   0.131 | GradNorm:  0.0170
# [DEBUG] Step  44807 | Ep  313 | Eps 0.911 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00164 | MeanQ:   0.193 | GradNorm:  0.0083
# [DEBUG] Step  44987 | Ep  314 | Eps 0.911 | MeanReward(10ep):   1.250 | MeanLoss(100it):  0.00181 | MeanQ:   0.108 | GradNorm:  0.0072
# [DEBUG] Step  45142 | Ep  315 | Eps 0.911 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00165 | MeanQ:   0.150 | GradNorm:  0.0107
# [DEBUG] Step  45258 | Ep  316 | Eps 0.910 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00168 | MeanQ:   0.135 | GradNorm:  0.0096
# [DEBUG] Step  45411 | Ep  317 | Eps 0.910 | MeanReward(10ep):   1.270 | MeanLoss(100it):  0.00159 | MeanQ:   0.250 | GradNorm:  0.0049
# [DEBUG] Step  45656 | Ep  318 | Eps 0.910 | MeanReward(10ep):   1.270 | MeanLoss(100it):  0.00167 | MeanQ:   0.127 | GradNorm:  0.0032
# [DEBUG] Step  45798 | Ep  319 | Eps 0.909 | MeanReward(10ep):   1.260 | MeanLoss(100it):  0.00182 | MeanQ:   0.213 | GradNorm:  0.0107
# [DEBUG] Step  46004 | Ep  320 | Eps 0.909 | MeanReward(10ep):   1.280 | MeanLoss(100it):  0.00214 | MeanQ:   0.152 | GradNorm:  0.0382
# [DEBUG] Step  46219 | Ep  321 | Eps 0.908 | MeanReward(10ep):   1.290 | MeanLoss(100it):  0.00255 | MeanQ:   0.134 | GradNorm:  0.0137
# [DEBUG] Step  46352 | Ep  322 | Eps 0.908 | MeanReward(10ep):   1.300 | MeanLoss(100it):  0.00305 | MeanQ:   0.110 | GradNorm:  0.0180
# [DEBUG] Step  46468 | Ep  323 | Eps 0.908 | MeanReward(10ep):   1.280 | MeanLoss(100it):  0.00299 | MeanQ:   0.114 | GradNorm:  0.0118
# [DEBUG] Step  46646 | Ep  324 | Eps 0.908 | MeanReward(10ep):   1.290 | MeanLoss(100it):  0.00291 | MeanQ:   0.138 | GradNorm:  0.0050
# [DEBUG] Step  46801 | Ep  325 | Eps 0.907 | MeanReward(10ep):   1.290 | MeanLoss(100it):  0.00297 | MeanQ:   0.131 | GradNorm:  0.0426
# [DEBUG] Step  47001 | Ep  326 | Eps 0.907 | MeanReward(10ep):   1.300 | MeanLoss(100it):  0.00256 | MeanQ:   0.142 | GradNorm:  0.0068
# [DEBUG] Step  47117 | Ep  327 | Eps 0.907 | MeanReward(10ep):   1.300 | MeanLoss(100it):  0.00256 | MeanQ:   0.259 | GradNorm:  0.0061
# [DEBUG] Step  47233 | Ep  328 | Eps 0.906 | MeanReward(10ep):   1.290 | MeanLoss(100it):  0.00236 | MeanQ:   0.153 | GradNorm:  0.0093
# [DEBUG] Step  47433 | Ep  329 | Eps 0.906 | MeanReward(10ep):   1.300 | MeanLoss(100it):  0.00225 | MeanQ:   0.205 | GradNorm:  0.0098
# [DEBUG] Step  47626 | Ep  330 | Eps 0.906 | MeanReward(10ep):   1.310 | MeanLoss(100it):  0.00246 | MeanQ:   0.107 | GradNorm:  0.0149
# [DEBUG] Step  47742 | Ep  331 | Eps 0.905 | MeanReward(10ep):   1.300 | MeanLoss(100it):  0.00220 | MeanQ:   0.267 | GradNorm:  0.0097
# [DEBUG] Step  47858 | Ep  332 | Eps 0.905 | MeanReward(10ep):   1.300 | MeanLoss(100it):  0.00236 | MeanQ:   0.137 | GradNorm:  0.0070
# [DEBUG] Step  48019 | Ep  333 | Eps 0.905 | MeanReward(10ep):   1.320 | MeanLoss(100it):  0.00204 | MeanQ:   0.164 | GradNorm:  0.0031
# [DEBUG] Step  48155 | Ep  334 | Eps 0.905 | MeanReward(10ep):   1.320 | MeanLoss(100it):  0.00229 | MeanQ:   0.147 | GradNorm:  0.0165
# [DEBUG] Step  48387 | Ep  335 | Eps 0.904 | MeanReward(10ep):   1.370 | MeanLoss(100it):  0.00331 | MeanQ:   0.135 | GradNorm:  0.0347
# [DEBUG] Step  48503 | Ep  336 | Eps 0.904 | MeanReward(10ep):   1.370 | MeanLoss(100it):  0.00329 | MeanQ:   0.132 | GradNorm:  0.0085
# [DEBUG] Step  48658 | Ep  337 | Eps 0.904 | MeanReward(10ep):   1.380 | MeanLoss(100it):  0.00323 | MeanQ:   0.114 | GradNorm:  0.0240
# [DEBUG] Step  48799 | Ep  338 | Eps 0.903 | MeanReward(10ep):   1.370 | MeanLoss(100it):  0.00341 | MeanQ:   0.138 | GradNorm:  0.0392
# [DEBUG] Step  48915 | Ep  339 | Eps 0.903 | MeanReward(10ep):   1.360 | MeanLoss(100it):  0.00346 | MeanQ:   0.157 | GradNorm:  0.0256
# [DEBUG] Step  49031 | Ep  340 | Eps 0.903 | MeanReward(10ep):   1.350 | MeanLoss(100it):  0.00384 | MeanQ:   0.230 | GradNorm:  0.0259
# [DEBUG] Step  49184 | Ep  341 | Eps 0.903 | MeanReward(10ep):   1.330 | MeanLoss(100it):  0.00347 | MeanQ:   0.168 | GradNorm:  0.0175
# [DEBUG] Step  49300 | Ep  342 | Eps 0.902 | MeanReward(10ep):   1.330 | MeanLoss(100it):  0.00344 | MeanQ:   0.134 | GradNorm:  0.0067
# [DEBUG] Step  49416 | Ep  343 | Eps 0.902 | MeanReward(10ep):   1.290 | MeanLoss(100it):  0.00289 | MeanQ:   0.127 | GradNorm:  0.0066
# [DEBUG] Step  49580 | Ep  344 | Eps 0.902 | MeanReward(10ep):   1.310 | MeanLoss(100it):  0.00299 | MeanQ:   0.149 | GradNorm:  0.0258
# [DEBUG] Step  49716 | Ep  345 | Eps 0.902 | MeanReward(10ep):   1.320 | MeanLoss(100it):  0.00310 | MeanQ:   0.165 | GradNorm:  0.0094
# [DEBUG] Step  49832 | Ep  346 | Eps 0.901 | MeanReward(10ep):   1.320 | MeanLoss(100it):  0.00271 | MeanQ:   0.122 | GradNorm:  0.0112
# [DEBUG] Step  49996 | Ep  347 | Eps 0.901 | MeanReward(10ep):   1.340 | MeanLoss(100it):  0.00281 | MeanQ:   0.142 | GradNorm:  0.0135
# [DEBUG] Step  50112 | Ep  348 | Eps 0.901 | MeanReward(10ep):   1.330 | MeanLoss(100it):  0.00301 | MeanQ:   0.173 | GradNorm:  0.0307
# [DEBUG] Step  50228 | Ep  349 | Eps 0.901 | MeanReward(10ep):   1.320 | MeanLoss(100it):  0.00327 | MeanQ:   0.167 | GradNorm:  0.0423
# [DEBUG] Step  50387 | Ep  350 | Eps 0.900 | MeanReward(10ep):   1.330 | MeanLoss(100it):  0.00403 | MeanQ:   0.169 | GradNorm:  0.0231
# [DEBUG] Step  50701 | Ep  351 | Eps 0.900 | MeanReward(10ep):   1.340 | MeanLoss(100it):  0.00405 | MeanQ:   0.239 | GradNorm:  0.0097
# [DEBUG] Step  50861 | Ep  352 | Eps 0.899 | MeanReward(10ep):   1.340 | MeanLoss(100it):  0.00357 | MeanQ:   0.357 | GradNorm:  0.0225
# [DEBUG] Step  51016 | Ep  353 | Eps 0.899 | MeanReward(10ep):   1.350 | MeanLoss(100it):  0.00386 | MeanQ:   0.146 | GradNorm:  0.0141
# ...
# [DEBUG] Step 1907731 | Ep 3927 | Eps 0.010 | MeanReward(10ep):  28.940 | MeanLoss(100it):  0.00563 | MeanQ:   4.221 | GradNorm:  0.0353
# [DEBUG] Step 1908629 | Ep 3928 | Eps 0.010 | MeanReward(10ep):  28.960 | MeanLoss(100it):  0.00613 | MeanQ:   3.990 | GradNorm:  0.0296
# [DEBUG] Step 1909399 | Ep 3929 | Eps 0.010 | MeanReward(10ep):  28.960 | MeanLoss(100it):  0.00590 | MeanQ:   4.066 | GradNorm:  0.0630
# [DEBUG] Step 1909803 | Ep 3930 | Eps 0.010 | MeanReward(10ep):  28.850 | MeanLoss(100it):  0.00561 | MeanQ:   4.012 | GradNorm:  0.0211
# [DEBUG] Step 1910579 | Ep 3931 | Eps 0.010 | MeanReward(10ep):  28.860 | MeanLoss(100it):  0.00475 | MeanQ:   4.301 | GradNorm:  0.0541
# [DEBUG] Step 1911502 | Ep 3932 | Eps 0.010 | MeanReward(10ep):  28.880 | MeanLoss(100it):  0.00603 | MeanQ:   4.049 | GradNorm:  0.0319
# [DEBUG] Step 1912050 | Ep 3933 | Eps 0.010 | MeanReward(10ep):  29.000 | MeanLoss(100it):  0.00554 | MeanQ:   4.064 | GradNorm:  0.0308
# [DEBUG] Step 1912781 | Ep 3934 | Eps 0.010 | MeanReward(10ep):  29.010 | MeanLoss(100it):  0.00546 | MeanQ:   4.221 | GradNorm:  0.0240
# [DEBUG] Step 1913622 | Ep 3935 | Eps 0.010 | MeanReward(10ep):  29.100 | MeanLoss(100it):  0.00581 | MeanQ:   4.092 | GradNorm:  0.0367
# [DEBUG] Step 1914324 | Ep 3936 | Eps 0.010 | MeanReward(10ep):  29.300 | MeanLoss(100it):  0.00679 | MeanQ:   4.257 | GradNorm:  0.1025
# [DEBUG] Step 1914939 | Ep 3937 | Eps 0.010 | MeanReward(10ep):  29.280 | MeanLoss(100it):  0.00819 | MeanQ:   4.023 | GradNorm:  0.0508
# [DEBUG] Step 1915654 | Ep 3938 | Eps 0.010 | MeanReward(10ep):  29.380 | MeanLoss(100it):  0.00735 | MeanQ:   4.018 | GradNorm:  0.0710
# [DEBUG] Step 1916442 | Ep 3939 | Eps 0.010 | MeanReward(10ep):  29.280 | MeanLoss(100it):  0.00657 | MeanQ:   4.078 | GradNorm:  0.0427
# [DEBUG] Step 1917344 | Ep 3940 | Eps 0.010 | MeanReward(10ep):  29.590 | MeanLoss(100it):  0.00698 | MeanQ:   4.074 | GradNorm:  0.0562
# [DEBUG] Step 1917990 | Ep 3941 | Eps 0.010 | MeanReward(10ep):  29.830 | MeanLoss(100it):  0.00618 | MeanQ:   4.038 | GradNorm:  0.0483
# [DEBUG] Step 1918990 | Ep 3942 | Eps 0.010 | MeanReward(10ep):  29.950 | MeanLoss(100it):  0.00704 | MeanQ:   0.249 | GradNorm:  0.0254
# [DEBUG] Step 1919866 | Ep 3943 | Eps 0.010 | MeanReward(10ep):  29.960 | MeanLoss(100it):  0.00658 | MeanQ:   4.047 | GradNorm:  0.0369
# [DEBUG] Step 1920442 | Ep 3944 | Eps 0.010 | MeanReward(10ep):  29.840 | MeanLoss(100it):  0.00698 | MeanQ:   4.048 | GradNorm:  0.0513
# [DEBUG] Step 1921162 | Ep 3945 | Eps 0.010 | MeanReward(10ep):  29.740 | MeanLoss(100it):  0.00578 | MeanQ:   4.096 | GradNorm:  0.0381
# [DEBUG] Step 1921828 | Ep 3946 | Eps 0.010 | MeanReward(10ep):  29.670 | MeanLoss(100it):  0.00510 | MeanQ:   4.370 | GradNorm:  0.0250
# [DEBUG] Step 1922682 | Ep 3947 | Eps 0.010 | MeanReward(10ep):  29.780 | MeanLoss(100it):  0.00544 | MeanQ:   4.134 | GradNorm:  0.0419
# [DEBUG] Step 1923268 | Ep 3948 | Eps 0.010 | MeanReward(10ep):  29.620 | MeanLoss(100it):  0.00714 | MeanQ:   4.378 | GradNorm:  0.0514
# [DEBUG] Step 1924101 | Ep 3949 | Eps 0.010 | MeanReward(10ep):  29.620 | MeanLoss(100it):  0.00587 | MeanQ:   4.121 | GradNorm:  0.0353
# [DEBUG] Step 1924997 | Ep 3950 | Eps 0.010 | MeanReward(10ep):  29.630 | MeanLoss(100it):  0.00599 | MeanQ:   4.278 | GradNorm:  0.0275
# [DEBUG] Step 1925620 | Ep 3951 | Eps 0.010 | MeanReward(10ep):  29.590 | MeanLoss(100it):  0.00614 | MeanQ:   4.125 | GradNorm:  0.0612
# [DEBUG] Step 1926402 | Ep 3952 | Eps 0.010 | MeanReward(10ep):  29.480 | MeanLoss(100it):  0.00585 | MeanQ:   4.083 | GradNorm:  0.0471
# [DEBUG] Step 1927402 | Ep 3953 | Eps 0.010 | MeanReward(10ep):  29.490 | MeanLoss(100it):  0.00575 | MeanQ:   0.318 | GradNorm:  0.0405
# [DEBUG] Step 1928361 | Ep 3954 | Eps 0.010 | MeanReward(10ep):  29.620 | MeanLoss(100it):  0.00519 | MeanQ:   4.261 | GradNorm:  0.0571
# [DEBUG] Step 1929179 | Ep 3955 | Eps 0.010 | MeanReward(10ep):  29.670 | MeanLoss(100it):  0.00621 | MeanQ:   4.245 | GradNorm:  0.0332
# [DEBUG] Step 1929968 | Ep 3956 | Eps 0.010 | MeanReward(10ep):  29.520 | MeanLoss(100it):  0.00718 | MeanQ:   4.263 | GradNorm:  0.0371
# [DEBUG] Step 1930857 | Ep 3957 | Eps 0.010 | MeanReward(10ep):  29.590 | MeanLoss(100it):  0.00648 | MeanQ:   4.070 | GradNorm:  0.0271
# [DEBUG] Step 1931743 | Ep 3958 | Eps 0.010 | MeanReward(10ep):  29.640 | MeanLoss(100it):  0.00690 | MeanQ:   4.033 | GradNorm:  0.0365
# [DEBUG] Step 1932477 | Ep 3959 | Eps 0.010 | MeanReward(10ep):  29.600 | MeanLoss(100it):  0.00626 | MeanQ:   4.098 | GradNorm:  0.0460
# [DEBUG] Step 1933187 | Ep 3960 | Eps 0.010 | MeanReward(10ep):  29.500 | MeanLoss(100it):  0.00463 | MeanQ:   4.071 | GradNorm:  0.0313
# [DEBUG] Step 1934085 | Ep 3961 | Eps 0.010 | MeanReward(10ep):  29.510 | MeanLoss(100it):  0.00619 | MeanQ:   4.099 | GradNorm:  0.0441
# [DEBUG] Step 1935004 | Ep 3962 | Eps 0.010 | MeanReward(10ep):  29.620 | MeanLoss(100it):  0.00586 | MeanQ:   4.084 | GradNorm:  0.0342
# [DEBUG] Step 1935636 | Ep 3963 | Eps 0.010 | MeanReward(10ep):  29.570 | MeanLoss(100it):  0.00516 | MeanQ:   4.277 | GradNorm:  0.0342
# [DEBUG] Step 1936432 | Ep 3964 | Eps 0.010 | MeanReward(10ep):  29.530 | MeanLoss(100it):  0.00575 | MeanQ:   4.129 | GradNorm:  0.0635
# [DEBUG] Step 1937363 | Ep 3965 | Eps 0.010 | MeanReward(10ep):  29.590 | MeanLoss(100it):  0.00520 | MeanQ:   4.129 | GradNorm:  0.0377
# [DEBUG] Step 1938239 | Ep 3966 | Eps 0.010 | MeanReward(10ep):  29.630 | MeanLoss(100it):  0.00513 | MeanQ:   4.349 | GradNorm:  0.0474
# [DEBUG] Step 1939052 | Ep 3967 | Eps 0.010 | MeanReward(10ep):  29.640 | MeanLoss(100it):  0.00603 | MeanQ:   4.248 | GradNorm:  0.0412
# [DEBUG] Step 1940014 | Ep 3968 | Eps 0.010 | MeanReward(10ep):  29.710 | MeanLoss(100it):  0.00614 | MeanQ:   4.260 | GradNorm:  0.0452
# [DEBUG] Step 1941014 | Ep 3969 | Eps 0.010 | MeanReward(10ep):  29.980 | MeanLoss(100it):  0.00679 | MeanQ:   1.410 | GradNorm:  0.0561
# [DEBUG] Step 1941703 | Ep 3970 | Eps 0.010 | MeanReward(10ep):  30.130 | MeanLoss(100it):  0.00555 | MeanQ:   4.286 | GradNorm:  0.0309
# [DEBUG] Step 1942382 | Ep 3971 | Eps 0.010 | MeanReward(10ep):  30.250 | MeanLoss(100it):  0.00465 | MeanQ:   4.181 | GradNorm:  0.0289
# [DEBUG] Step 1943184 | Ep 3972 | Eps 0.010 | MeanReward(10ep):  30.230 | MeanLoss(100it):  0.00472 | MeanQ:   4.254 | GradNorm:  0.0302
# [DEBUG] Step 1944036 | Ep 3973 | Eps 0.010 | MeanReward(10ep):  30.250 | MeanLoss(100it):  0.00522 | MeanQ:   4.092 | GradNorm:  0.0293
# [DEBUG] Step 1944991 | Ep 3974 | Eps 0.010 | MeanReward(10ep):  30.280 | MeanLoss(100it):  0.00671 | MeanQ:   4.062 | GradNorm:  0.0594
# [DEBUG] Step 1945810 | Ep 3975 | Eps 0.010 | MeanReward(10ep):  30.190 | MeanLoss(100it):  0.00659 | MeanQ:   4.144 | GradNorm:  0.0538
# [DEBUG] Step 1946674 | Ep 3976 | Eps 0.010 | MeanReward(10ep):  30.230 | MeanLoss(100it):  0.00625 | MeanQ:   4.154 | GradNorm:  0.0453
# [DEBUG] Step 1947580 | Ep 3977 | Eps 0.010 | MeanReward(10ep):  30.290 | MeanLoss(100it):  0.00731 | MeanQ:   4.114 | GradNorm:  0.0384
# [DEBUG] Step 1948360 | Ep 3978 | Eps 0.010 | MeanReward(10ep):  30.330 | MeanLoss(100it):  0.00615 | MeanQ:   4.102 | GradNorm:  0.0481
# [DEBUG] Step 1949174 | Ep 3979 | Eps 0.010 | MeanReward(10ep):  30.430 | MeanLoss(100it):  0.00669 | MeanQ:   4.098 | GradNorm:  0.0406
# [DEBUG] Step 1950173 | Ep 3980 | Eps 0.010 | MeanReward(10ep):  30.500 | MeanLoss(100it):  0.00581 | MeanQ:   4.128 | GradNorm:  0.0243
# [DEBUG] Step 1951123 | Ep 3981 | Eps 0.010 | MeanReward(10ep):  30.570 | MeanLoss(100it):  0.00613 | MeanQ:   4.433 | GradNorm:  0.0270
# [DEBUG] Step 1952007 | Ep 3982 | Eps 0.010 | MeanReward(10ep):  30.600 | MeanLoss(100it):  0.00636 | MeanQ:   4.195 | GradNorm:  0.0430
# [DEBUG] Step 1952940 | Ep 3983 | Eps 0.010 | MeanReward(10ep):  30.730 | MeanLoss(100it):  0.00615 | MeanQ:   4.226 | GradNorm:  0.0565
# [DEBUG] Step 1953617 | Ep 3984 | Eps 0.010 | MeanReward(10ep):  30.700 | MeanLoss(100it):  0.00688 | MeanQ:   4.455 | GradNorm:  0.0494
# [DEBUG] Step 1954254 | Ep 3985 | Eps 0.010 | MeanReward(10ep):  30.560 | MeanLoss(100it):  0.00664 | MeanQ:   4.142 | GradNorm:  0.0348
# [DEBUG] Step 1955115 | Ep 3986 | Eps 0.010 | MeanReward(10ep):  30.620 | MeanLoss(100it):  0.00639 | MeanQ:   4.143 | GradNorm:  0.0414
# [DEBUG] Step 1955806 | Ep 3987 | Eps 0.010 | MeanReward(10ep):  30.540 | MeanLoss(100it):  0.00647 | MeanQ:   4.452 | GradNorm:  0.0315
# [DEBUG] Step 1956497 | Ep 3988 | Eps 0.010 | MeanReward(10ep):  30.650 | MeanLoss(100it):  0.00594 | MeanQ:   4.155 | GradNorm:  0.0344
# [DEBUG] Step 1957335 | Ep 3989 | Eps 0.010 | MeanReward(10ep):  30.630 | MeanLoss(100it):  0.00494 | MeanQ:   4.129 | GradNorm:  0.0399
# [DEBUG] Step 1958221 | Ep 3990 | Eps 0.010 | MeanReward(10ep):  30.660 | MeanLoss(100it):  0.00505 | MeanQ:   4.239 | GradNorm:  0.0234
# [DEBUG] Step 1959041 | Ep 3991 | Eps 0.010 | MeanReward(10ep):  30.770 | MeanLoss(100it):  0.00636 | MeanQ:   4.237 | GradNorm:  0.0279
# [DEBUG] Step 1959668 | Ep 3992 | Eps 0.010 | MeanReward(10ep):  30.770 | MeanLoss(100it):  0.00531 | MeanQ:   4.245 | GradNorm:  0.0330
# [DEBUG] Step 1960511 | Ep 3993 | Eps 0.010 | MeanReward(10ep):  30.790 | MeanLoss(100it):  0.00539 | MeanQ:   4.426 | GradNorm:  0.0278
# [DEBUG] Step 1961511 | Ep 3994 | Eps 0.010 | MeanReward(10ep):  31.060 | MeanLoss(100it):  0.00580 | MeanQ:   0.135 | GradNorm:  0.0278
# [DEBUG] Step 1962273 | Ep 3995 | Eps 0.010 | MeanReward(10ep):  31.120 | MeanLoss(100it):  0.00513 | MeanQ:   4.221 | GradNorm:  0.0690
# [DEBUG] Step 1963036 | Ep 3996 | Eps 0.010 | MeanReward(10ep):  31.220 | MeanLoss(100it):  0.00660 | MeanQ:   4.211 | GradNorm:  0.1061
# [DEBUG] Step 1963717 | Ep 3997 | Eps 0.010 | MeanReward(10ep):  31.110 | MeanLoss(100it):  0.00599 | MeanQ:   4.186 | GradNorm:  0.0538
# [DEBUG] Step 1964550 | Ep 3998 | Eps 0.010 | MeanReward(10ep):  31.070 | MeanLoss(100it):  0.00621 | MeanQ:   4.433 | GradNorm:  0.0385
# [DEBUG] Step 1965550 | Ep 3999 | Eps 0.010 | MeanReward(10ep):  31.170 | MeanLoss(100it):  0.00644 | MeanQ:   1.246 | GradNorm:  0.0524
# [DEBUG] Step 1966415 | Ep 4000 | Eps 0.010 | MeanReward(10ep):  31.220 | MeanLoss(100it):  0.00608 | MeanQ:   4.214 | GradNorm:  0.0736
# [breakout] Ep 4000 Steps 1966415 RecentMean 31.22 Eps 0.010
# Eval @ Ep 4000 and 1966415 steps => mean return 31.00
# [DEBUG] Step 1967099 | Ep 4001 | Eps 0.010 | MeanReward(10ep):  31.120 | MeanLoss(100it):  0.00564 | MeanQ:   4.874 | GradNorm:  0.0392
# [DEBUG] Step 1967851 | Ep 4002 | Eps 0.010 | MeanReward(10ep):  31.050 | MeanLoss(100it):  0.00771 | MeanQ:   4.252 | GradNorm:  0.0380
# [DEBUG] Step 1968605 | Ep 4003 | Eps 0.010 | MeanReward(10ep):  30.960 | MeanLoss(100it):  0.00556 | MeanQ:   4.228 | GradNorm:  0.0253
# [DEBUG] Step 1969388 | Ep 4004 | Eps 0.010 | MeanReward(10ep):  31.010 | MeanLoss(100it):  0.00641 | MeanQ:   4.232 | GradNorm:  0.0650
# [DEBUG] Step 1970384 | Ep 4005 | Eps 0.010 | MeanReward(10ep):  31.040 | MeanLoss(100it):  0.00604 | MeanQ:   4.306 | GradNorm:  0.0662
# [DEBUG] Step 1971136 | Ep 4006 | Eps 0.010 | MeanReward(10ep):  31.100 | MeanLoss(100it):  0.00730 | MeanQ:   4.242 | GradNorm:  0.0484
# [DEBUG] Step 1971839 | Ep 4007 | Eps 0.010 | MeanReward(10ep):  31.060 | MeanLoss(100it):  0.00602 | MeanQ:   4.525 | GradNorm:  0.0509
# [DEBUG] Step 1972823 | Ep 4008 | Eps 0.010 | MeanReward(10ep):  31.030 | MeanLoss(100it):  0.00612 | MeanQ:   4.275 | GradNorm:  0.0612
# [DEBUG] Step 1973664 | Ep 4009 | Eps 0.010 | MeanReward(10ep):  31.070 | MeanLoss(100it):  0.00473 | MeanQ:   4.235 | GradNorm:  0.0305
# [DEBUG] Step 1974521 | Ep 4010 | Eps 0.010 | MeanReward(10ep):  31.150 | MeanLoss(100it):  0.00608 | MeanQ:   4.225 | GradNorm:  0.0828
# [DEBUG] Step 1975194 | Ep 4011 | Eps 0.010 | MeanReward(10ep):  31.070 | MeanLoss(100it):  0.00576 | MeanQ:   4.186 | GradNorm:  0.0303
# [DEBUG] Step 1975830 | Ep 4012 | Eps 0.010 | MeanReward(10ep):  30.940 | MeanLoss(100it):  0.00712 | MeanQ:   4.194 | GradNorm:  0.0371
# [DEBUG] Step 1976620 | Ep 4013 | Eps 0.010 | MeanReward(10ep):  30.980 | MeanLoss(100it):  0.00540 | MeanQ:   4.183 | GradNorm:  0.0270
# [DEBUG] Step 1977185 | Ep 4014 | Eps 0.010 | MeanReward(10ep):  30.910 | MeanLoss(100it):  0.00581 | MeanQ:   4.165 | GradNorm:  0.0278
# [DEBUG] Step 1978067 | Ep 4015 | Eps 0.010 | MeanReward(10ep):  30.940 | MeanLoss(100it):  0.00568 | MeanQ:   4.203 | GradNorm:  0.0270
# [DEBUG] Step 1978917 | Ep 4016 | Eps 0.010 | MeanReward(10ep):  31.110 | MeanLoss(100it):  0.00457 | MeanQ:   4.234 | GradNorm:  0.0338
# [DEBUG] Step 1979905 | Ep 4017 | Eps 0.010 | MeanReward(10ep):  31.210 | MeanLoss(100it):  0.00686 | MeanQ:   4.162 | GradNorm:  0.0673
# [DEBUG] Step 1980680 | Ep 4018 | Eps 0.010 | MeanReward(10ep):  31.160 | MeanLoss(100it):  0.00697 | MeanQ:   4.180 | GradNorm:  0.0387
# [DEBUG] Step 1981427 | Ep 4019 | Eps 0.010 | MeanReward(10ep):  31.110 | MeanLoss(100it):  0.00646 | MeanQ:   4.228 | GradNorm:  0.0323
# [DEBUG] Step 1982100 | Ep 4020 | Eps 0.010 | MeanReward(10ep):  31.060 | MeanLoss(100it):  0.00586 | MeanQ:   4.227 | GradNorm:  0.0476
# [DEBUG] Step 1982856 | Ep 4021 | Eps 0.010 | MeanReward(10ep):  31.060 | MeanLoss(100it):  0.00590 | MeanQ:   4.278 | GradNorm:  0.0413
# [DEBUG] Step 1983741 | Ep 4022 | Eps 0.010 | MeanReward(10ep):  30.980 | MeanLoss(100it):  0.00663 | MeanQ:   4.203 | GradNorm:  0.0339
# [DEBUG] Step 1984690 | Ep 4023 | Eps 0.010 | MeanReward(10ep):  31.090 | MeanLoss(100it):  0.00627 | MeanQ:   4.322 | GradNorm:  0.0485
# [DEBUG] Step 1985465 | Ep 4024 | Eps 0.010 | MeanReward(10ep):  31.130 | MeanLoss(100it):  0.00613 | MeanQ:   4.365 | GradNorm:  0.0441
# [DEBUG] Step 1986465 | Ep 4025 | Eps 0.010 | MeanReward(10ep):  31.220 | MeanLoss(100it):  0.00568 | MeanQ:   0.566 | GradNorm:  0.0599
# [DEBUG] Step 1987455 | Ep 4026 | Eps 0.010 | MeanReward(10ep):  31.340 | MeanLoss(100it):  0.00566 | MeanQ:   4.657 | GradNorm:  0.0479
# [DEBUG] Step 1988109 | Ep 4027 | Eps 0.010 | MeanReward(10ep):  31.210 | MeanLoss(100it):  0.00553 | MeanQ:   4.314 | GradNorm:  0.0291
# [DEBUG] Step 1989016 | Ep 4028 | Eps 0.010 | MeanReward(10ep):  31.220 | MeanLoss(100it):  0.00682 | MeanQ:   4.730 | GradNorm:  0.0253
# [DEBUG] Step 1989914 | Ep 4029 | Eps 0.010 | MeanReward(10ep):  31.280 | MeanLoss(100it):  0.00553 | MeanQ:   4.658 | GradNorm:  0.0293
# [DEBUG] Step 1990516 | Ep 4030 | Eps 0.010 | MeanReward(10ep):  31.320 | MeanLoss(100it):  0.00574 | MeanQ:   4.389 | GradNorm:  0.0370
# [DEBUG] Step 1991322 | Ep 4031 | Eps 0.010 | MeanReward(10ep):  31.310 | MeanLoss(100it):  0.00615 | MeanQ:   4.393 | GradNorm:  0.0623
# [DEBUG] Step 1992096 | Ep 4032 | Eps 0.010 | MeanReward(10ep):  31.250 | MeanLoss(100it):  0.00630 | MeanQ:   4.743 | GradNorm:  0.0406
# [DEBUG] Step 1992981 | Ep 4033 | Eps 0.010 | MeanReward(10ep):  31.390 | MeanLoss(100it):  0.00611 | MeanQ:   4.363 | GradNorm:  0.0614
# [DEBUG] Step 1993856 | Ep 4034 | Eps 0.010 | MeanReward(10ep):  31.400 | MeanLoss(100it):  0.00499 | MeanQ:   4.714 | GradNorm:  0.0283
# [DEBUG] Step 1994742 | Ep 4035 | Eps 0.010 | MeanReward(10ep):  31.410 | MeanLoss(100it):  0.00585 | MeanQ:   4.334 | GradNorm:  0.0280
# [DEBUG] Step 1995473 | Ep 4036 | Eps 0.010 | MeanReward(10ep):  31.350 | MeanLoss(100it):  0.00689 | MeanQ:   4.317 | GradNorm:  0.0383
# [DEBUG] Step 1996323 | Ep 4037 | Eps 0.010 | MeanReward(10ep):  31.400 | MeanLoss(100it):  0.00587 | MeanQ:   4.299 | GradNorm:  0.0336
# [DEBUG] Step 1997203 | Ep 4038 | Eps 0.010 | MeanReward(10ep):  31.460 | MeanLoss(100it):  0.00632 | MeanQ:   4.267 | GradNorm:  0.0245
# [DEBUG] Step 1998107 | Ep 4039 | Eps 0.010 | MeanReward(10ep):  31.560 | MeanLoss(100it):  0.00627 | MeanQ:   4.257 | GradNorm:  0.0385
# [DEBUG] Step 1998906 | Ep 4040 | Eps 0.010 | MeanReward(10ep):  31.500 | MeanLoss(100it):  0.00614 | MeanQ:   4.324 | GradNorm:  0.0391
# [DEBUG] Step 1999601 | Ep 4041 | Eps 0.010 | MeanReward(10ep):  31.500 | MeanLoss(100it):  0.00623 | MeanQ:   4.262 | GradNorm:  0.0621
# Saved training data → logs/breakout_training_log_dueling.csv
# Saved eval data → logs/breakout_eval_log_dueling.csv
# Saved checkpoint: checkpoints/breakout_final_dueling.pth

# %%
"""
@dataclass
class Config:
    seed: int = 7
    gamma: float = 0.99  # prioritize short-term rewards
    lr: float = 5e-4  # can reduce to 1e-4 if unstable
    batch_size: int = 64
    buffer_capacity: int = 100_000  # larger buffer for diverse data
    min_buffer_size: int = 20_000  # start training with more data
    max_steps_per_env: int = 2_000_000
    max_episode_len: int = 1000
    epsilon_start: float = 1.0
    epsilon_end: float = 0.01
    epsilon_decay_steps: int = 500_000
    target_update_interval: int = 2000
    train_freq: int = 4
    gradient_clip: float = 10.0
    reward_clip: Optional[float] = 1.0
    use_double_dqn: bool = False
    use_dueling: bool = True   # enabled for better value estimation
    vector_envs: int = 1
    log_interval_episodes: int = 100
    eval_episodes: int = 10
    curriculum: Optional[List[str]] = None
    hidden_size: int = 512

    # these 5 hyperparameters are used for the PER (prioritized experience replay)
    per_alpha: float = 0.6 
    per_eps: float = 0.01
    per_beta_start: float = 0.4
    per_beta_end: float = 1.0
    per_beta_steps: int = 50_000
    use_per: bool = False
    
    n_steps: int = 1
    use_noisy_layer: bool = False

cfg = Config()
cfg.curriculum = [challenge_env_name]

random.seed(cfg.seed)
np.random.seed(cfg.seed)
torch.manual_seed(cfg.seed)
cfg"""


@dataclass
class Config:
    seed: int = 7
    gamma: float = 0.95                # prioritize short-term rewards
    lr: float = 1e-3                   # can reduce to 1e-4 if unstable
    batch_size: int = 128
    buffer_capacity: int = 1000      # larger buffer for diverse data
    min_buffer_size: int = 200       # start training with more data
    max_steps_per_env: int = 100_000
    max_episode_len: int = 500
    epsilon_start: float = 1.0
    epsilon_end: float = 0.01
    epsilon_decay_steps: int = 20000
    target_update_interval: int = 100
    train_freq: int = 4
    gradient_clip: float = 10.0
    reward_clip: Optional[float] = None
    use_double_dqn: bool = False
    use_dueling: bool = True         # enabled for better value estimation
    vector_envs: int = 1
    log_interval_episodes: int = 10
    eval_episodes: int = 3
    curriculum: List[str] = None
    hidden_size: int = 256

    per_alpha: float = 0.6 
    per_eps: float = 0.01
    per_beta_start: float = 0.4
    per_beta_end: float = 1.0
    per_beta_steps: int = 50_000
    use_per: bool = False
    
    n_steps: int = 1
    use_noisy_layer: bool = False

cfg = Config()
cfg.curriculum = [intermediate_env_name]

random.seed(cfg.seed)
np.random.seed(cfg.seed)
torch.manual_seed(cfg.seed)
cfg
# Out:
# Config(seed=7, gamma=0.95, lr=0.001, batch_size=128, buffer_capacity=1000, min_buffer_size=200, max_steps_per_env=100000, max_episode_len=500, epsilon_start=1.0, epsilon_end=0.01, epsilon_decay_steps=20000, target_update_interval=100, train_freq=4, gradient_clip=10.0, reward_clip=None, use_double_dqn=False, use_dueling=True, vector_envs=1, log_interval_episodes=10, eval_episodes=3, curriculum=['cartpole'], hidden_size=256, per_alpha=0.6, per_eps=0.01, per_beta_start=0.4, per_beta_end=1.0, per_beta_steps=50000, use_per=False, n_steps=1, use_noisy_layer=False)

# %%
import torch
import torch.optim as optim
import numpy as np
import pandas as pd
import os
import dataclasses

def save_checkpoint(path, q_net, optimizer, cfg, stage_name: str):
    torch.save({
        'model': q_net.state_dict(),
        'optimizer': optimizer.state_dict(),
        'config': dataclasses.asdict(cfg),
        'stage': stage_name,
    }, path)
    print('Saved checkpoint:', path)


# === Training ===
all_stage_logs = {}

q_net = None
target_net = None
optimizer = None
stage_index = 0

# Make directories for outputs
os.makedirs("logs", exist_ok=True)
os.makedirs("checkpoints", exist_ok=True)

for stage_env_name in cfg.curriculum:
    print(f"\n=== Stage {stage_index+1}: {stage_env_name} ===")
    env = make_env(stage_env_name, seed=cfg.seed + stage_index)()
    eval_env = make_env(stage_env_name, seed=cfg.seed + 100 + stage_index)()

    q_net = build_q_network(env, cfg).to(DEVICE)
    # if cfg.use_noisy_layer:
    #     q_net.reset_noise()
    #     target_net.reset_noise()
    target_net = build_q_network(env, cfg).to(DEVICE)
    hard_update(target_net, q_net)
    optimizer = optim.Adam(q_net.parameters(), lr=cfg.lr)

    if cfg.use_per:
        replay = PrioritizedReplayBuffer(
            capacity=cfg.buffer_capacity,
            obs_shape=env.single_observation_space.shape,
            device=DEVICE,
            cfg = cfg
        )
        print("[INFO] Using PrioritizedReplayBuffer")
    else:
        replay = ReplayBuffer(cfg.buffer_capacity, env.single_observation_space.shape, DEVICE)
        print("[INFO] Using uniform ReplayBuffer")

    logs = {
        'episode_rewards': [],
        'losses': [],
        'eps_history': [],
        'eval': [],
    }

    obs, _ = env.reset()
    ep_reward = 0
    ep_steps = 0
    episode_counter = 0
    recent_ep_returns = []
    total_steps = 0

    trajectory_buffer = deque(maxlen=cfg.n_steps)

    print('Starting training...')
    while total_steps < cfg.max_steps_per_env:
        if cfg.use_noisy_layer:
            epsilon = 0.0  # No epsilon-greedy when using noisy networks
        else:
            epsilon = epsilon_by_step(total_steps, cfg)
        action = select_action(q_net, obs, epsilon, env)
        next_obs, reward, terminated, truncated, info = env.step(action)
        reward = process_reward(reward, cfg)
        reward = float(np.asarray(reward).reshape(-1)[0])
        done = bool(np.asarray(terminated).reshape(-1)[0] or np.asarray(truncated).reshape(-1)[0])

        trajectory_buffer.append((obs.copy(), int(action), reward, next_obs.copy(), done))

        # Push n-step transitions once we have enough data
        if len(trajectory_buffer) >= cfg.n_steps:
            # Calculate n-step return
            n_step_reward = 0.0
            for i, (_, _, r, _, _) in enumerate(trajectory_buffer):  # Use 'r' to avoid name collision
                n_step_reward += (cfg.gamma ** i) * r
            
            # Extract first obs/action and last next_obs/done
            first_obs, first_action, _, _, _ = trajectory_buffer[0]  # ✅ Define these variables!
            _, _, _, last_next_obs, last_done = trajectory_buffer[-1]
            
            # Push to replay buffer (only once!)
            replay.push(first_obs, first_action, n_step_reward, last_next_obs, last_done)

        # Handle episode end: push remaining incomplete n-step transitions
        if done:
            # Push any remaining partial n-step returns
            for start_idx in range(1, len(trajectory_buffer)):
                steps_available = len(trajectory_buffer) - start_idx
                n_step_reward = 0.0
                
                for i in range(steps_available):
                    _, _, r, _, _ = trajectory_buffer[start_idx + i]
                    n_step_reward += (cfg.gamma ** i) * r
                
                first_obs, first_action, _, _, _ = trajectory_buffer[start_idx]
                _, _, _, last_next_obs, last_done = trajectory_buffer[-1]
                
                replay.push(first_obs, first_action, n_step_reward, last_next_obs, last_done)
            
            trajectory_buffer.clear()

        obs = next_obs.copy()
        ep_reward += reward
        ep_steps += 1
        total_steps += 1

        # Training
        if total_steps % cfg.train_freq == 0:
            loss = train_step(q_net, target_net, optimizer, replay, cfg)
            if loss is not None:
                logs['losses'].append(loss)

        # Target update
        if total_steps % cfg.target_update_interval == 0:
            hard_update(target_net, q_net)

        logs['eps_history'].append(epsilon)

        if done or ep_steps >= cfg.max_episode_len:
            logs['episode_rewards'].append(ep_reward)
            recent_ep_returns.append(ep_reward)
            episode_counter += 1

            # --- DEBUG PRINT ---
            mean_loss = np.mean(logs['losses'][-100:]) if logs['losses'] else 0.0
            mean_reward = np.mean(recent_ep_returns[-cfg.log_interval_episodes:]) if recent_ep_returns else 0.0
            with torch.no_grad():
                q_sample = q_net(torch.FloatTensor(obs).unsqueeze(0).to(DEVICE))
                mean_q = q_sample.mean().item()
            grads = [p.grad.norm().item() for p in q_net.parameters() if p.grad is not None]
            grad_norm = np.mean(grads) if grads else 0.0

            if episode_counter % cfg.log_interval_episodes == 0:
                mean_recent = np.mean(recent_ep_returns[-cfg.log_interval_episodes:])
                print(f"[{stage_env_name}] Ep {episode_counter} Steps {total_steps} "
                      f"RecentMean {mean_recent:.2f} Eps {epsilon:.3f}")

            obs, _ = env.reset()
            ep_reward = 0
            ep_steps = 0

            # Periodic evaluation (every 2*log_interval episodes if we have progress)
            if episode_counter % (cfg.log_interval_episodes * 2) == 0:
                eval_ret = evaluate(eval_env, q_net, cfg, cfg.eval_episodes)
                logs['eval'].append((total_steps, eval_ret))
                print(f"Eval @ Ep {episode_counter} and {total_steps} steps => mean return {eval_ret:.2f}")

    # --- Save logs and model after each stage ---
    all_stage_logs[stage_env_name] = logs

    # Save training logs
    df = pd.DataFrame({
        'episode_rewards': logs['episode_rewards'],
        'losses': logs['losses'][:len(logs['episode_rewards'])],
        'eps_history': logs['eps_history'][:len(logs['episode_rewards'])],
    })
    train_csv = f"logs/{stage_env_name}_training_log_duel.csv"
    df.to_csv(train_csv, index=False)
    print(f"Saved training data → {train_csv}")

    # Save evaluation results
    eval_df = pd.DataFrame(logs['eval'], columns=['total_steps', 'eval_return'])
    eval_csv = f"logs/{stage_env_name}_eval_log_duel.csv"
    eval_df.to_csv(eval_csv, index=False)
    print(f"Saved eval data → {eval_csv}")

    # Save model checkpoint
    checkpoint_path = f"checkpoints/{stage_env_name}_final_duel.pth"
    save_checkpoint(checkpoint_path, q_net, optimizer, cfg, stage_env_name)

    stage_index += 1
# Out:
# === Stage 1: cartpole ===
# Obs space: 4
# Obs space: 4
# [INFO] Using uniform ReplayBuffer
# Starting training...
# [cartpole] Ep 10 Steps 83 RecentMean 7.30 Eps 0.996
# [cartpole] Ep 20 Steps 211 RecentMean 11.80 Eps 0.990
# Eval @ Ep 20 and 211 steps => mean return 5.00
# [cartpole] Ep 30 Steps 305 RecentMean 8.40 Eps 0.985
# [cartpole] Ep 40 Steps 404 RecentMean 8.90 Eps 0.980
# Eval @ Ep 40 and 404 steps => mean return 5.00
# [cartpole] Ep 50 Steps 516 RecentMean 10.20 Eps 0.975
# [cartpole] Ep 60 Steps 710 RecentMean 18.40 Eps 0.965
# Eval @ Ep 60 and 710 steps => mean return 34.00
# [cartpole] Ep 70 Steps 817 RecentMean 9.70 Eps 0.960
# [cartpole] Ep 80 Steps 934 RecentMean 10.70 Eps 0.954
# Eval @ Ep 80 and 934 steps => mean return 47.00
# [cartpole] Ep 90 Steps 1026 RecentMean 8.20 Eps 0.949
# [cartpole] Ep 100 Steps 1185 RecentMean 14.90 Eps 0.941
# Eval @ Ep 100 and 1185 steps => mean return 88.00
# [cartpole] Ep 110 Steps 1327 RecentMean 13.20 Eps 0.934
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 124
#     122 # Training
#     123 if total_steps % cfg.train_freq == 0:
# --> 124     loss = train_step(q_net, target_net, optimizer, replay, cfg)
#     125     if loss is not None:
#     126         logs['losses'].append(loss)
#
# Cell In[33], line 60, in train_step(q_net, target_net, optimizer, replay, cfg)
#      57 loss = per_sample_loss.mean()
#      59 optimizer.zero_grad()
# ---> 60 loss.backward()
#      61 nn.utils.clip_grad_norm_(q_net.parameters(), cfg.gradient_clip)
#      62 optimizer.step()
#
# File /opt/conda/lib/python3.11/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ##  Visualization Per Stage
# helper code for plots, feel free to modify or use different tools, e.g. WandB.
# Plots: Episode rewards, Epsilon schedule, Loss curve, and Evaluation returns.

# %%
def moving_average(x, w):
    # Ensure x is a flattened 1D numpy array to handle lists like [[1],[2],[3]]
    x = np.array(x).flatten()
    if len(x) < w:
        return x
    return np.convolve(x, np.ones(w)/w, mode='valid')

for stage, logs in all_stage_logs.items():
    rewards = logs['episode_rewards']
    losses = logs['losses']
    eps_hist = logs['eps_history']
    evals = logs['eval']
    print(f"\n=== {stage} ===")
    plt.figure(figsize=(14,4))
    # Rewards
    plt.subplot(1,3,1)
    plt.title(f'{stage} Rewards')
    plt.plot(rewards, alpha=0.5, label='Return')
    ma = moving_average(rewards, 100)
    if len(ma) != len(rewards):
        plt.plot(range(len(rewards)-len(ma), len(rewards)), ma, label='MA(20)')
    plt.legend()
    plt.xlabel('Episode')

    # Epsilon
    plt.subplot(1,3,2)
    plt.title('Epsilon')
    plt.plot(eps_hist)
    plt.xlabel('Step')

    # Losses
    plt.subplot(1,3,3)
    plt.title('Loss (smoothed)')
    if len(losses) > 0:
        lma = moving_average(losses, 200)
        plt.plot(losses, alpha=0.3)
        plt.plot(range(len(losses)-len(lma), len(losses)), lma, label='MA(200)')
        plt.legend()
    plt.tight_layout()
    plt.show()

    if len(evals) > 0:
        xs = [x for x,_ in evals]
        ys = [y for _,y in evals]
        plt.figure()
        plt.title(f'{stage} Evaluation Returns')
        plt.plot(xs, ys, marker='o')
        plt.xlabel('Env Steps')
        plt.ylabel('Mean Return (greedy)')
        plt.show()
# Out:
# === cartpole ===

# %% [markdown]
# ## 2.1 Group Project: Extensions and Analysis
#
# This assignment is a group project. After familiarizing yourselves with the baseline DQN code, your group will divide the following implementation tasks. Once each part is complete, you will merge your code and collaborate on a final report that analyzes and compares the performance of each extension.
#
# ---
# ### **Part 1: Individual Implementation Tasks**
#
# Each group member must implement one of the following sets of extensions. You will need to modify the core components (`MLPQ`, `ReplayBuffer`, `train_step`) to support these new algorithms, using the `cfg` object to toggle them on and off.
#
# ---
# #### **Extension A: Double DQN & Dueling DQN**
#
# **Assigned to:** *Gerwoud Van den Eynden*
#
# This set of tasks focuses on improving the Q-value estimation and network architecture.
#
# **TODO (A1): Implement Double DQN**
# In the `train_step` function, implement the logic inside the `if cfg.use_double_dqn:` block. This involves decoupling action selection from evaluation to mitigate overestimation bias by using the **online network** to select the best next action and the **target network** to evaluate its value.
#
# **TODO (A2): Implement Dueling DQN**
# In the `MLPQ` class, modify the `__init__` and `forward` methods to support a dueling architecture. You will need to create separate `value_head` and `advantage_head` layers and combine their outputs using the formula: `Q(s,a) = V(s) + (A(s,a) - mean(A(s,:)))`.
#
# ---
# #### **Extension B: Prioritized Experience Replay (PER)**
#
# **Assigned to:** *Alexander Van Oyen*
#
# This task replaces the uniform `ReplayBuffer` with a more intelligent sampling strategy that prioritizes "surprising" transitions.
#
# **TODO (B1): Implement `PrioritizedReplayBuffer`**
# Create a new `PrioritizedReplayBuffer` class. This class must manage transition priorities (based on TD-error), sample transitions according to these priorities, and compute importance sampling (IS) weights to correct for the biased sampling. Implementing a **SumTree** is the standard approach for this.
#
# **TODO (B2): Integrate PER into `train_step`**
# Modify the training loop to use your new buffer. In `train_step`, you must use the IS weights to scale the loss for each transition and then call a method on your buffer to update the priorities of the sampled transitions with their new TD-errors.
#
# ---
# #### **Extension C: N-Step Returns & Noisy Networks**
#
# **Assigned to:** *Tristan Verbeken*
#
# This set of tasks focuses on improving the TD target and the agent's exploration strategy.
#
# **TODO (C1): Implement N-Step Returns**
# Modify the training loop and `train_step` to use N-step returns. This involves temporarily storing the last `N` transitions to calculate the discounted N-step reward (`R_n`) and updating the target formula in `train_step` to use `γ^N` for bootstrapping.
#
# **TODO (C2): Implement Noisy Networks**
# Replace epsilon-greedy exploration with learned exploration. Create a custom `NoisyLinear` PyTorch layer that adds parametric noise to its weights. Replace the final linear layers of your `MLPQ` with this new layer and disable epsilon-greedy exploration in the main loop when this feature is active.
#
# ---
# ### **Optional Extension**
#
# #### **Vectorized Environments**
# For a deeper challenge, modify the entire pipeline to support vectorized environments. This involves changing `cfg.vector_envs` to > 1 and refactoring the training loop to handle batched operations for action selection, environment stepping, and episode tracking. This is a highly effective method for speeding up training but requires careful management of parallel data streams.
#
# ---
# ### **Part 2: Final Report (Group Task)**
#
# Your group's final submission should be a report that includes the following:
#
# **1. Experimental Analysis:**
# *   Run experiments on the Comparing environment comparing your baseline DQN against each of the implemented extensions (A, B, and C) and all extension combined on the challenge environment.
# *   Generate and include plots for each experiment (Episode Rewards, Loss, etc.).
# *  For the replay buffer size and N-Step Returns, test out 2-4 different values and reflect on the difference in performance. You may change other hyperparameters as needed to get good performance, also put the highlights in the report.
# *   Analyze the plots: Reflect how you can see the improvements for each extension. Which extension provided the biggest performance boost or the most stable training? Justify your claims with evidence.
#
# **2. Conceptual Questions:**
#
# *   **Q1:** Explain "maximization bias" in Q-learning. How does your **Double DQN** implementation address it?
# *   **Q2:** What is the theoretical motivation for the **Dueling DQN** architecture? Why is the special averaging mechanism important?
# *   **Q3:** Why is uniform sampling from the replay buffer inefficient? How do the **importance sampling weights** in **PER** correct for the biased sampling you introduced?
# *   **Q4:** Explain the difference between epsilon-greedy exploration and the exploration provided by **Noisy Networks**. What is an advantage of the latter?
# *   **Q5:** How does changing 'N' in **N-Step Returns** affect the bias-variance trade-off in your Q-learning updates?
#
# **3. Reflection:**
# *   Briefly discuss the biggest challenge your group faced during implementation and how you solved it.
# *   Were some of the results unexpected, if so in what way?
# *   If you implemented the vectorized environments, describe the performance improvement you observed in terms of wall-clock time.
#
# **4. Code Submission:**
# *   Submit your complete code with all extensions implemented. Ensure it is well-commented and organized.
# ---

# %% [markdown]
# # Visualize agent
# helper code to visualize your trained agent in the notebook. You may modify this code as needed or visualize it in a different way.

# %%
from pyvirtualdisplay import Display
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time
import os
import pyscreenshot as ImageGrab
import torch
import numpy as np

# --- Visualization Setup (from our debugging) ---
seed = 0
steps_to_show = 1000 # Your original value
game_width = 576
game_height = 330
bbox = (0, 0, game_width, game_height)

# Initialize variables to None before the try block for safe cleanup
vdisplay = None
env = None

original_dir = os.getcwd()
pufferlib_dir = '/opt/pufferlib'
# -------------------------------------------------
def first_obs(x):
    x = np.asarray(x)
    return x[0] if x.ndim > 1 else x

# This is your agent's decision-making function, it's perfect as is.
def policy_net(st):
    return q_net(st)


@torch.no_grad()
def greedy_action(state_np):
    st = torch.as_tensor(state_np, dtype=torch.float32, device=DEVICE).unsqueeze(0)
    q = policy_net(st)
    print(q)
    return int(q.argmax(dim=1).item())

# The robust 'try...finally' block for safe execution and cleanup
try:
    vdisplay = Display(visible=False, size=(game_width, game_height))
    vdisplay.start()

    # os.chdir(pufferlib_dir)
    # env = breakout.Breakout(num_envs=1, render_mode='human', seed=seed)
    env = cartpole.Cartpole(num_envs=1, render_mode='human', seed=seed)
    # env = cartpole.Cartpole(num_envs=1, render_mode='human', seed=seed)
    
    fig, ax = plt.subplots(1)

    current_directory = os.getcwd()
    print(f"Current directory: {current_directory}")
    
    # List all files and directories in the current directory
    contents = os.listdir(current_directory)
    print("Contents of the directory:")
    for item in contents:
        print(item)

    q_net = build_q_network(env, cfg).to(DEVICE)
    optimizer = torch.optim.Adam(q_net.parameters(), lr=cfg.lr)  # Placeholder optimizer for load_checkpoint
    checkpoint_path = 'checkpoint_cartpole_stage0.pth'  # Adjust path to your saved checkpoint
    if os.path.exists(checkpoint_path):
        print(f"File found at: {checkpoint_path}")
    
    load_checkpoint(checkpoint_path, q_net, optimizer)  # Load the trained model

    raise Error
    
    q_net.eval()  # Set to evaluation mode

    # --- Your Agent's Logic Starts Here ---
    obs, _ = env.reset(seed)
    state = first_obs(obs).astype(np.float32)
    episode_return = 0.0

    print("Starting agent visualization... Press 'Stop' to interrupt cleanly.")
    print("IMPORTANT: After interrupting, you MUST restart the kernel before running this cell again.")

    for t in range(steps_to_show):
        # The inner 'try...except' for clean interruption
        try:
            # Get action from your policy instead of random
            # q_net = build_q_network(env, cfg).to(DEVICE)
            a = greedy_action(state)

            # Step the environment
            obs, reward, term, trunc, _info = env.step(a)

            # --- Apply the Visualization Pipeline ---
            # 1. Render the game to the invisible virtual display
            env.render()

            # 2. Grab a cropped screenshot of the virtual display
            frame = ImageGrab.grab(bbox=bbox)

            # 3. Display the screenshot in the notebook
            clear_output(wait=True)
            ax.imshow(frame)
            ax.axis('off')
            display(fig)

            time.sleep(0.01)
            # --- End of Visualization Pipeline ---

            # Continue with your agent's logic
            state = first_obs(obs).astype(np.float32)
            episode_return += float(first_obs(reward))
            done = bool(first_obs(term)) or bool(first_obs(trunc))
            if done:
                print("Episode finished.")
                break

        except KeyboardInterrupt:
            print("\n\nInterrupted by user. The kernel is now in an unstable state and must be restarted.")
            break

    print(f'Greedy policy return: {episode_return:.2f}')

finally:
    # This block is ALWAYS executed, ensuring a safe shutdown.
    print("Cleaning up resources...")
    os.chdir(original_dir)

    if env is not None:
        env.close()

    time.sleep(0.5)

    if vdisplay is not None:
        vdisplay.stop()
    print("Cleanup complete. If you interrupted the cell, please restart the kernel now.")
# Out:
# Current directory: /home/jovyan
# Contents of the directory:
# .bash_logout
# .bashrc
# .profile
# .local
# .ipython
# resources
# checkpoint_cartpole_stage0.pth
# .cache
# .npm
# .config
# .conda
# .jupyter
# work
# Obs space: 4
# File found at: checkpoint_cartpole_stage0.pth
# Loaded checkpoint from checkpoint_cartpole_stage0.pth
# {'seed': 7, 'gamma': 0.95, 'lr': 0.001, 'batch_size': 128, 'buffer_capacity': 1000, 'min_buffer_size': 200, 'max_steps_per_env': 60000, 'max_episode_len': 500, 'epsilon_start': 1.0, 'epsilon_end': 0.01, 'epsilon_decay_steps': 5000, 'target_update_interval': 100, 'train_freq': 4, 'gradient_clip': 10.0, 'reward_clip': None, 'use_double_dqn': False, 'use_dueling': False, 'vector_envs': 1, 'log_interval_episodes': 10, 'eval_episodes': 3, 'curriculum': ['squared', 'cartpole'], 'hidden_size': 256, 'n_steps': 3, 'use_noisy_layer': True}
# Cleaning up resources...
# /tmp/ipykernel_339/314024412.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=DEVICE)
# Cleanup complete. If you interrupted the cell, please restart the kernel now.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 69
#      65     print(f"File found at: {checkpoint_path}")
#      67 load_checkpoint(checkpoint_path, q_net, optimizer)  # Load the trained model
# ---> 69 raise Error
#      71 q_net.eval()  # Set to evaluation mode
#      73 # --- Your Agent's Logic Starts Here ---
#
# NameError: name 'Error' is not defined

# %%
def save_checkpoint(path, q_net, optimizer, cfg: Config, stage_name: str):
    torch.save({
        'model': q_net.state_dict(),
        'optimizer': optimizer.state_dict(),
        'config': dataclasses.asdict(cfg),
        'stage': stage_name,
    }, path)
    print('Saved checkpoint:', path)

def load_checkpoint(path, q_net, optimizer):
    data = torch.load(path, map_location=DEVICE)
    q_net.load_state_dict(data['model'])
    optimizer.load_state_dict(data['optimizer'])
    print('Loaded checkpoint from', path)
    print(data['config'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

def moving_average(x, w):
    x = np.array(x).flatten()
    if len(x) < w:
        return x
    return np.convolve(x, np.ones(w) / w, mode='valid')

def plot_combined_training_logs(
    csv_files,
    eval_csvs=None,
    ma_rewards=100,
    ma_loss=200,
    labels=None,
    save_dir="plots",
    show_plots=True
):
    """
    Plot combined comparison for multiple training logs and save the figures.

    Args:
        csv_files (list[str]): List of training CSV file paths.
        eval_csvs (list[str] or None): Optional list of eval CSV paths (each with 'total_steps', 'eval_return').
        ma_rewards (int): Window size for reward moving average.
        ma_loss (int): Window size for loss moving average.
        labels (list[str] or None): Optional list of legend names for the plots.
        save_dir (str): Directory to save plots in.
        show_plots (bool): Whether to display the plots after saving.
    """
    if eval_csvs is None:
        eval_csvs = [None] * len(csv_files)
    if labels is None:
        labels = [os.path.basename(f).replace(".csv", "") for f in csv_files]

    os.makedirs(save_dir, exist_ok=True)

    all_data = []
    for train_path, eval_path, label in zip(csv_files, eval_csvs, labels):
        train_df = pd.read_csv(train_path)
        eval_df = pd.read_csv(eval_path) if eval_path and eval_path.endswith(".csv") else pd.DataFrame()

        data = {
            "name": label,
            "rewards": train_df["episode_rewards"].dropna().values,
            "losses": train_df["losses"].dropna().values,
            "eps": train_df["eps_history"].dropna().values,
            "eval": eval_df
        }
        all_data.append(data)

    # === Plot Combined Rewards ===
    plt.figure(figsize=(12, 4))
    plt.title("Reward Comparison")
    for d in all_data:
        rewards = d["rewards"]
        ma = moving_average(rewards, ma_rewards)
        plt.plot(range(len(rewards)-len(ma), len(rewards)), ma, label=d["name"])
    plt.xlabel("Episode")
    plt.ylabel("Smoothed Return")
    plt.legend()
    plt.tight_layout()
    reward_path = os.path.join(save_dir, "reward_comparison.png")
    plt.savefig(reward_path, dpi=300)
    if show_plots:
        plt.show()
    plt.close()

    # === Plot Combined Loss ===
    plt.figure(figsize=(12, 4))
    plt.title("Loss Comparison (smoothed)")
    for d in all_data:
        losses = d["losses"]
        if len(losses) > 0:
            lma = moving_average(losses, ma_loss)
            plt.plot(range(len(losses)-len(lma), len(losses)), lma, label=d["name"])
    plt.xlabel("Training Step")
    plt.ylabel("Loss (MA)")
    plt.legend()
    plt.tight_layout()
    loss_path = os.path.join(save_dir, "loss_comparison.png")
    plt.savefig(loss_path, dpi=300)
    if show_plots:
        plt.show()
    plt.close()

    # === Plot Combined Evaluation ===
    plt.figure(figsize=(8, 4))
    plt.title("Evaluation Comparison")
    for d in all_data:
        if not d["eval"].empty:
            xs = d["eval"]["total_steps"].values
            ys = d["eval"]["eval_return"].values
            plt.plot(xs, ys, marker='o', label=d["name"])
    plt.xlabel("Env Steps")
    plt.ylabel("Mean Return (greedy)")
    plt.legend()
    plt.tight_layout()
    eval_path = os.path.join(save_dir, "evaluation_comparison.png")
    plt.savefig(eval_path, dpi=300)
    if show_plots:
        plt.show()
    plt.close()

    print(f"✅ Saved plots to: {save_dir}")

# %%
training_csvs = [
    "logs/breakout_training_log_base.csv",
    "logs/breakout_training_log_double.csv",
    "logs/breakout_training_log_dueling.csv",
    "logs/breakout_training_log_per.csv",
    "logs/breakout_training_10nstep.csv",
    "logs/breakout_training_log_full.csv"
]

eval_csvs = [
    "logs/breakout_eval_log_base.csv",
    "logs/breakout_eval_log_double.csv",
    "logs/breakout_eval_log_dueling.csv",
    "logs/breakout_eval_log_per.csv",
    "logs/breakout_eval_10nstep.csv",
    "logs/breakout_eval_log_full.csv"
]

labels = [
    "Base DQN",
    "Double DQN",
    "Dueling DQN",
    "PER DQN",
    "10 n-steps",
    "Full DQN"
]
'''

training_csvs = [
    "logs/breakout_training_log_50k_n1.csv",
    "logs/breakout_training_log_50k_n3.csv",
    "logs/breakout_training_log_nstep1_200k.csv",
    "logs/breakout_training_log_nstep3_200k.csv"
]

eval_csvs = [
    "logs/breakout_eval_log_50k_n1.csv",
    "logs/breakout_eval_log_50k_n3.csv",
    "logs/breakout_eval_log_nstep1_200k.csv",
    "logs/breakout_eval_log_nstep3_200k.csv"
]

labels = [
    "50k buffer n-step 1",
    "50k buffer n-step 3",
    "100k buffer n-step 1",
    "100k buffer n-step 3"
]'''

plot_combined_training_logs(training_csvs, eval_csvs, labels=labels)
# Out:
# ✅ Saved plots to: plots
